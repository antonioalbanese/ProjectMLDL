# %% [markdown]
# <a href="https://colab.research.google.com/github/cosminnedescu/ProjectMLDL/blob/main/baselines/iCaRL-v1_3_0-ablation-CE_L2_seed42.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Avoid K80
# !nvidia-smi
# Out:
# Thu Jul  1 12:06:49 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import random

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
from torch.autograd import Variable

import torchvision
from torchvision import transforms, datasets, models
from torch.utils.data import Subset, DataLoader

from PIL import Image

import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
from copy import copy
from copy import deepcopy

# %% [markdown]
# #### Cloning the Git repository

# %%
# !rm -rf ProjectMLDL
if not os.path.isdir('/content/ProjectMLDL'):
  # !git clone https://github.com/cosminnedescu/ProjectMLDL.git
  # %cd /content/ProjectMLDL
  # !rm -rf LICENSE README.md
# Out:
# Cloning into 'ProjectMLDL'...
# remote: Enumerating objects: 1503, done.
# remote: Counting objects: 100% (418/418), done.
# remote: Compressing objects: 100% (340/340), done.
# remote: Total 1503 (delta 260), reused 74 (delta 74), pack-reused 1085
# Receiving objects: 100% (1503/1503), 61.28 MiB | 26.36 MiB/s, done.
# Resolving deltas: 100% (778/778), done.
# /content/ProjectMLDL

# %%
from data.cifar100 import CIFAR100
from model.resnet32 import resnet32
import data.utils
from model.icarl_ablation import iCaRL

# %%
# True mean and std of Cifar100 dataset (src="https://gist.github.com/weiaicunzai/e623931921efefd4c331622c344d8151")
mean = [0.5071, 0.4867, 0.4408]
std = [0.2675, 0.2565, 0.2761]

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])
test_transform = transforms.Compose(
    [transforms.ToTensor(), 
     transforms.Normalize(mean, std),
     ])

# %% [markdown]
# ## Incremental Classifier and Representation Learning

# %% [markdown]
# ### Defining hyperparameters according to iCarl paper

# %%
# Settings
DEVICE = 'cuda'
NUM_CLASSES = 100         # Total number of classes
VAL_SIZE = 0.2            # Proportion of validation set with respect to training set (between 0 and 1)

# Training
BATCH_SIZE = 128          # Batch size
LR = 0.1                    # Initial learning rate
                       
MOMENTUM = 0.9            # Momentum for stochastic gradient descent (SGD)
WEIGHT_DECAY = 1e-5       # Weight decay from iCaRL

RANDOM_SEED = [42]  # Random seeds defining the runs of every method
                          # Note: this should be at least 3 to have a fair benchmark

NUM_EPOCHS = 70          # Total number of training epochs
MILESTONES = [49, 63]     # Step down policy from iCaRL (MultiStepLR)
                          # Decrease the learning rate by gamma at each milestone
GAMMA = 1 #0.2               # Gamma factor from iCaRL (1/5)

HERDING = False           # True to perform prioritized selection, False to perform random selection
CLASSIFY = True           # True to use mean-of-exemplar classifier, False to use network's output directly for classification

# %%
def do_group_classes(run):

  train_subset = [[] for i in range(10)]
  train_dataloader = [[] for i in range(10)]
  val_dataloader = [[] for i in range(10)]
  test_dataloader = [[] for i in range(10)]

  for i in range(10):
    train_data = CIFAR100("dataset", 
                          train=True, 
                          transform=train_transform, 
                          download=(run+i==0),
                          random_state=RANDOM_SEED[run])
    test_data = CIFAR100("dataset", 
                         train=False, 
                         transform=test_transform, 
                         download=False,
                         random_state=RANDOM_SEED[run])
    
    train_data.set_index_map(train_data.splits[i])
    test_data.set_index_map([test_data.splits[j] for j in range(0, i+1)])
    
    train_indices, val_indices = train_data.train_val_split(VAL_SIZE, RANDOM_SEED[run])
    
    train_subset[i] = copy(Subset(train_data, train_indices))
    val_subset = Subset(train_data, val_indices)

    tmp_dl = DataLoader(val_subset,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    val_dataloader[i] = copy(tmp_dl)

    tmp_dl = DataLoader(test_data,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    test_dataloader[i] = copy(tmp_dl)

  return train_dataloader, val_dataloader, test_dataloader, train_subset

# %% [markdown]
# ### Going on with the model
# This is the main iCaRL step.
#
# This step is run 3 times with different `RANDOM_SEED`.
# Here the model is instantiated, trained and tested.
#
# Results and some statistics are then stored in the variable `logs`.

# %%
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
logs = [[] for i in range(len(RANDOM_SEED))]
best_net_tot_classes = [None for i in range(len(RANDOM_SEED))]

for run in range(len(RANDOM_SEED)):
  print("#################################")
  print(f"Radom seed: {RANDOM_SEED[run]}")
  print("")

  # get data_subsets separated in incremental groups of 10 classes
  train_dl, val_dl, test_dl, train_set = do_group_classes(run)

  #create the resnet
  net = resnet32()
  
  trainer = iCaRL(DEVICE,
                  net,
                  LR,
                  MOMENTUM,
                  WEIGHT_DECAY,
                  MILESTONES,
                  GAMMA,
                  train_dl,
                  val_dl,
                  test_dl,
                  BATCH_SIZE,
                  train_set,
                  train_transform,
                  test_transform, 2)

  #train and evaluate the model
  logs[run] = trainer.train_model(NUM_EPOCHS, HERDING, CLASSIFY)

  best_net_tot_classes[run] = deepcopy(trainer.best_net)

  print("#################################")
  print("")
  print("")
# Out:
# #################################
# Radom seed: 42
#
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to dataset/cifar-100-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=169001437.0), HTML(value='')))
# Extracting dataset/cifar-100-python.tar.gz to dataset
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Length of exemplars set: 0
# traing_loss = 2.107822614331399
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.19
# Best model updated
#
# traing_loss = 1.818179311290864
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.31
# Best model updated
#
# traing_loss = 1.7309093513796407
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.28
#
# traing_loss = 1.6746827710059382
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.37
# Best model updated
#
# traing_loss = 1.62437452039411
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.35
#
# traing_loss = 1.5964948323465162
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.33
#
# traing_loss = 1.5724038770121913
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.38
# Best model updated
#
# traing_loss = 1.5158847301237044
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.40
# Best model updated
#
# traing_loss = 1.5014591024767967
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.42
# Best model updated
#
# traing_loss = 1.47913626317055
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.42
#
# traing_loss = 1.5013060377490135
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.38
#
# traing_loss = 1.416019662734001
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.46
# Best model updated
#
# traing_loss = 1.369393652485263
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.43
#
# traing_loss = 1.3745387638768842
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.43
#
# traing_loss = 1.3600524702379782
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.46
# Best model updated
#
# traing_loss = 1.2942155330411849
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.49
# Best model updated
#
# traing_loss = 1.2962418948450396
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.49
#
# traing_loss = 1.2556159419398154
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.50
# Best model updated
#
# traing_loss = 1.2025373212752803
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.49
#
# traing_loss = 1.1688481800017818
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.48
#
# traing_loss = 1.1522606995797926
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.52
# Best model updated
#
# traing_loss = 1.1286167444721344
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.52
# Best model updated
#
# traing_loss = 1.1037541800929653
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.50
#
# traing_loss = 1.0656892484234226
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.55
# Best model updated
#
# traing_loss = 1.033383757837357
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.51
#
# traing_loss = 0.9952519728291419
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.45
#
# traing_loss = 0.9701285189197909
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.56
# Best model updated
#
# traing_loss = 0.9363125158894446
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.56
#
# traing_loss = 0.8748421092187205
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.57
# Best model updated
#
# traing_loss = 0.8979751852250868
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.57
# Best model updated
#
# traing_loss = 0.8315236952997023
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.57
#
# traing_loss = 0.8119923549313699
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.60
# Best model updated
#
# traing_loss = 0.7732602703955865
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.62
# Best model updated
#
# traing_loss = 0.7445772309457103
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.62
#
# traing_loss = 0.7101384632049068
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.57
#
# traing_loss = 0.6809445907992702
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.60
#
# traing_loss = 0.6729377181299271
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.61
#
# traing_loss = 0.7019216668221259
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.63
# Best model updated
#
# traing_loss = 0.618148261500943
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.66
# Best model updated
#
# traing_loss = 0.6014951304081948
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.64
#
# traing_loss = 0.5441723802397328
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.64
#
# traing_loss = 0.5723096113051137
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.60
#
# traing_loss = 0.5410169612976813
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.65
#
# traing_loss = 0.5131180738249133
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.62
#
# traing_loss = 0.4763174768417112
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.65
#
# traing_loss = 0.5052940172533835
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.60
#
# traing_loss = 0.48580479045068065
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.64
#
# traing_loss = 0.46464042605892303
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.65
#
# traing_loss = 0.463310839668397
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.68
# Best model updated
#
# traing_loss = 0.40939507849754825
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.70
# Best model updated
#
# traing_loss = 0.40458845948019334
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.62
#
# traing_loss = 0.3928431185983842
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.69
#
# traing_loss = 0.37581291217957774
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.65
#
# traing_loss = 0.36973036489179056
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.67
#
# traing_loss = 0.3683718688065006
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.68
#
# traing_loss = 0.3461157295011705
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.65
#
# traing_loss = 0.3209719172408504
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.64
#
# traing_loss = 0.3618688016168533
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.67
#
# traing_loss = 0.35045606474722585
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.65
#
# traing_loss = 0.31440064022617953
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.67
#
# traing_loss = 0.30519156494448263
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.67
#
# traing_loss = 0.2762991468752584
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.68
#
# traing_loss = 0.2934227556951584
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.68
#
# traing_loss = 0.2742010816451042
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.69
#
# traing_loss = 0.24956595080514107
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.66
#
# traing_loss = 0.2383769986129576
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.70
#
# traing_loss = 0.22523197844143836
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.69
#
# traing_loss = 0.21592017984197986
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.70
#
# traing_loss = 0.21623619741970493
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.67
#
# traing_loss = 0.24013200786805922
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.68
#
# Group 1 Finished!
# Best accuracy found at epoch 50: 0.70
# Target number of exemplars: 200
# Randomly extracting exemplars from class 0 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 200 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.68
#
# =============================================
#
# Length of exemplars set: 2000
# traing_loss = 2.374085115349811
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.47
# Best model updated
#
# traing_loss = 1.7815070618753848
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.52
# Best model updated
#
# traing_loss = 1.6086502956307454
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.61
# Best model updated
#
# traing_loss = 1.4843723955361738
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.64
# Best model updated
#
# traing_loss = 1.3930033030717268
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.65
# Best model updated
#
# traing_loss = 1.3320451430652454
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.62
#
# traing_loss = 1.2667917790620222
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.64
#
# traing_loss = 1.216943639775981
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.61
#
# traing_loss = 1.1683797978836556
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.63
#
# traing_loss = 1.138474157323008
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.66
# Best model updated
#
# traing_loss = 1.103083865798038
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.65
#
# traing_loss = 1.069250244161357
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.65
#
# traing_loss = 1.0373303216436636
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.69
# Best model updated
#
# traing_loss = 1.005737762088361
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.63
#
# traing_loss = 0.9945569738097813
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.67
#
# traing_loss = 0.9799574108227439
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.69
#
# traing_loss = 0.9304778653642406
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.62
#
# traing_loss = 0.9177868897500245
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.67
#
# traing_loss = 0.8999791806158812
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.67
#
# traing_loss = 0.897791035797285
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.66
#
# traing_loss = 0.8805061280727386
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.70
# Best model updated
#
# traing_loss = 0.8702129877131918
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.70
#
# traing_loss = 0.8345563333967457
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.69
#
# traing_loss = 0.8114017235196155
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.71
# Best model updated
#
# traing_loss = 0.7899375298748845
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.68
#
# traing_loss = 0.7840571895889614
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.68
#
# traing_loss = 0.7690108962680983
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.69
#
# traing_loss = 0.7530397850534191
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.72
# Best model updated
#
# traing_loss = 0.7415352956108425
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.71
#
# traing_loss = 0.7397061340186907
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.73
# Best model updated
#
# traing_loss = 0.7291189587634542
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.65
#
# traing_loss = 0.7092661481836567
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.67
#
# traing_loss = 0.6965915405231974
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.72
#
# traing_loss = 0.6851947605609894
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.72
#
# traing_loss = 0.6706660843413809
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.69
#
# traing_loss = 0.6734383158061815
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.69
#
# traing_loss = 0.6460291561873063
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.72
#
# traing_loss = 0.6543797772863637
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.69
#
# traing_loss = 0.6761173022829968
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.70
#
# traing_loss = 0.6313444686972577
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.73
# Best model updated
#
# traing_loss = 0.5877578232599341
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.69
#
# traing_loss = 0.5849562047616296
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.70
#
# traing_loss = 0.5989233067502147
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.69
#
# traing_loss = 0.6227583496466927
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.70
#
# traing_loss = 0.5924289984547574
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.73
# Best model updated
#
# traing_loss = 0.5637082457542419
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.71
#
# traing_loss = 0.5746161885883497
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.70
#
# traing_loss = 0.5596469115951787
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.73
#
# traing_loss = 0.5598759294851966
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.72
#
# traing_loss = 0.5598155175862105
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.73
# Best model updated
#
# traing_loss = 0.569416123887767
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.70
#
# traing_loss = 0.5596959636263226
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.71
#
# traing_loss = 0.5498110308595325
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.72
#
# traing_loss = 0.5424181281224542
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.69
#
# traing_loss = 0.5271012666432754
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.70
#
# traing_loss = 0.5418601606203162
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.72
#
# traing_loss = 0.5348804858715638
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.71
#
# traing_loss = 0.5386207706254461
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.71
#
# traing_loss = 0.5381487329369006
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.71
#
# traing_loss = 0.5066387446030326
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.72
#
# traing_loss = 0.496773568832356
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.75
# Best model updated
#
# traing_loss = 0.4890961757172709
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.73
#
# traing_loss = 0.5161058287257734
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.71
#
# traing_loss = 0.49938010651132336
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.73
#
# traing_loss = 0.49092098487460095
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.70
#
# traing_loss = 0.5057564798904501
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.71
#
# traing_loss = 0.4881727248430252
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.72
#
# traing_loss = 0.4832743464604668
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.74
#
# traing_loss = 0.49134498834609985
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.74
#
# traing_loss = 0.4988290557394857
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.72
#
# Group 2 Finished!
# Best accuracy found at epoch 61: 0.75
# Target number of exemplars: 100
# Randomly extracting exemplars from class 0 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 100 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.68
#
# =============================================
#
# Length of exemplars set: 2000
# traing_loss = 2.447686060615208
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.54
# Best model updated
#
# traing_loss = 1.8022702958272852
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.60
# Best model updated
#
# traing_loss = 1.6478452371514363
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.59
#
# traing_loss = 1.5155484598615896
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.62
# Best model updated
#
# traing_loss = 1.4191647431124812
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
# Best model updated
#
# traing_loss = 1.375784264958423
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 1.3170760325763538
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.63
#
# traing_loss = 1.2380167401355247
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.61
#
# traing_loss = 1.1993874130041704
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 1.1634416735690574
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.64
#
# traing_loss = 1.1177034948183142
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.64
#
# traing_loss = 1.0975541524265124
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.67
# Best model updated
#
# traing_loss = 1.0590755356394725
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
# Best model updated
#
# traing_loss = 1.0655672744564388
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 1.006882501685101
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.9557334871395774
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 0.9481920599937439
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.62
#
# traing_loss = 0.9412764945755834
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.64
#
# traing_loss = 0.9362624248732692
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.62
#
# traing_loss = 0.8976365496282992
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.70
# Best model updated
#
# traing_loss = 0.8797392028829326
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.8617776308370673
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.846726884012637
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.8618523789488751
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.64
#
# traing_loss = 0.833495213933613
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.7811430226201597
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.7570548666560132
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.7657829769279646
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 0.7483405691126118
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.7201832254295764
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 0.7176174301168193
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.64
#
# traing_loss = 0.716565454783647
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.67
#
# traing_loss = 0.7057130284931349
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 0.6720263336015784
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.67
#
# traing_loss = 0.6734419335489688
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.64
#
# traing_loss = 0.6670762028383173
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.6517474819784579
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.6907799179139344
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.61
#
# traing_loss = 0.6888656512550686
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.67
#
# traing_loss = 0.6667822560538417
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.640753387109093
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.63
#
# traing_loss = 0.6333654276702715
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.67
#
# traing_loss = 0.6269561428090801
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.5913448528103207
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.605822350019994
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.70
#
# traing_loss = 0.605733736053757
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.71
# Best model updated
#
# traing_loss = 0.6036868756232054
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.5687007463496664
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.5566784914420999
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 0.5456452907427497
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.5622748097647792
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.5602427941301594
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.70
#
# traing_loss = 0.5597691665525022
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.5561744434678036
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 0.5583887333455293
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.70
#
# traing_loss = 0.5528816328100536
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.5193918826787368
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.5207207500934601
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.5134197259726732
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.5243811672148497
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 0.5529504042604695
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.514710268896559
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.532816430148871
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.5372980068559232
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.5276286070761473
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.71
# Best model updated
#
# traing_loss = 0.508528986054918
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.4894868498263152
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.4832106971222421
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.4869145673254262
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.49206193828064465
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# Group 3 Finished!
# Best accuracy found at epoch 65: 0.71
# Target number of exemplars: 66
# Randomly extracting exemplars from class 0 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 66 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.57
#
# =============================================
#
# Length of exemplars set: 1980
# traing_loss = 2.54327464622
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.57
# Best model updated
#
# traing_loss = 1.683387525703596
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.63
# Best model updated
#
# traing_loss = 1.4806795819945957
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.61
#
# traing_loss = 1.3792684622432874
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.65
# Best model updated
#
# traing_loss = 1.2909805023151895
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.66
# Best model updated
#
# traing_loss = 1.1931395919426628
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.68
# Best model updated
#
# traing_loss = 1.1334985300250675
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.68
#
# traing_loss = 1.0831302650596784
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.69
# Best model updated
#
# traing_loss = 1.0443811870139579
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.65
#
# traing_loss = 1.0275528793749602
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.67
#
# traing_loss = 0.9725918847581615
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.71
# Best model updated
#
# traing_loss = 0.918421710314958
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.68
#
# traing_loss = 0.8923264599364736
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.69
#
# traing_loss = 0.9012828741384589
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.68
#
# traing_loss = 0.872419139613276
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.71
#
# traing_loss = 0.8389424072659534
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.70
#
# traing_loss = 0.8359099937521893
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.62
#
# traing_loss = 0.8142581906007684
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.64
#
# traing_loss = 0.7519567051659459
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.68
#
# traing_loss = 0.7200275206047556
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.70
#
# traing_loss = 0.7294067520162334
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.72
# Best model updated
#
# traing_loss = 0.6946429817572884
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.69
#
# traing_loss = 0.7237741072540698
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.69
#
# traing_loss = 0.6887370335019153
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.68
#
# traing_loss = 0.6659237139898798
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.70
#
# traing_loss = 0.669204724871594
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.70
#
# traing_loss = 0.6417514383792877
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.72
#
# traing_loss = 0.656468774313512
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.72
#
# traing_loss = 0.6126205985960753
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.68
#
# traing_loss = 0.6238481810559398
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.67
#
# traing_loss = 0.6014513425205065
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.73
# Best model updated
#
# traing_loss = 0.5990244253821995
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.68
#
# traing_loss = 0.6085787558037302
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.68
#
# traing_loss = 0.6065923603980438
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.68
#
# traing_loss = 0.5981248111828513
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.72
#
# traing_loss = 0.5964214950799942
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.72
#
# traing_loss = 0.5627508467954138
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.65
#
# traing_loss = 0.5579703793577526
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.73
# Best model updated
#
# traing_loss = 0.5520481771748998
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.70
#
# traing_loss = 0.5582804945500001
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.71
#
# traing_loss = 0.5347499646570372
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.68
#
# traing_loss = 0.5552867320568665
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.69
#
# traing_loss = 0.5349076999270398
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.71
#
# traing_loss = 0.5089274891044783
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.70
#
# traing_loss = 0.5027474015951157
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.72
#
# traing_loss = 0.5033950552992199
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.72
#
# traing_loss = 0.4963277273851892
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.71
#
# traing_loss = 0.4844347854023394
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.70
#
# traing_loss = 0.49714345841304114
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.71
#
# traing_loss = 0.48960888191409735
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.73
#
# traing_loss = 0.49806487625059875
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.69
#
# traing_loss = 0.4838118300489757
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.71
#
# traing_loss = 0.476913381529891
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.70
#
# traing_loss = 0.46685778900333075
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.70
#
# traing_loss = 0.5058325943739518
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.69
#
# traing_loss = 0.495191488576972
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.69
#
# traing_loss = 0.4938928640407065
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.70
#
# traing_loss = 0.47295365320599597
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.72
#
# traing_loss = 0.469190899444663
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.72
#
# traing_loss = 0.4424979803354844
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
# Best model updated
#
# traing_loss = 0.4512234064547912
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.70
#
# traing_loss = 0.43429814732593036
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
# Best model updated
#
# traing_loss = 0.4303511517203372
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.66
#
# traing_loss = 0.4249952493802361
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.73
#
# traing_loss = 0.4302781146505605
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.71
#
# traing_loss = 0.41710090118905774
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
# Best model updated
#
# traing_loss = 0.42236619539882825
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.71
#
# traing_loss = 0.4270974805821543
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.73
#
# traing_loss = 0.42067426183949347
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.72
#
# traing_loss = 0.4192435313826022
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.69
#
# Group 4 Finished!
# Best accuracy found at epoch 66: 0.74
# Target number of exemplars: 50
# Randomly extracting exemplars from class 0 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 50 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.50
#
# =============================================
#
# Length of exemplars set: 2000
# traing_loss = 2.5412960000660108
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.63
# Best model updated
#
# traing_loss = 1.5388712597929912
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.69
# Best model updated
#
# traing_loss = 1.3509686641071155
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
# Best model updated
#
# traing_loss = 1.2441837100879005
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 1.1734156064365222
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
# Best model updated
#
# traing_loss = 1.0789384595725848
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.75
# Best model updated
#
# traing_loss = 1.0515909959440646
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.9805579237315966
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
# Best model updated
#
# traing_loss = 0.9675967861776766
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.9204381522925004
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.8513162161992944
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.8382278343905574
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.75
#
# traing_loss = 0.8267600160578022
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.77
#
# traing_loss = 0.8080631675927535
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.7892428208952365
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.77
#
# traing_loss = 0.7426735693993776
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.77
#
# traing_loss = 0.7377679555312447
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.75
#
# traing_loss = 0.7196784032427747
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.709526301726051
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.66914559835973
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.81
# Best model updated
#
# traing_loss = 0.6669893303643102
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.6437337048675703
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.638695935840192
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.6446785538092904
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.6131047995194144
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.5878918954859609
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.5799525937308436
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.77
#
# traing_loss = 0.5699350652487382
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.75
#
# traing_loss = 0.5445892078721005
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.77
#
# traing_loss = 0.5669553033683611
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.5654984680206879
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.77
#
# traing_loss = 0.5636749377717143
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.560165009420851
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.5489746073017949
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.5600742794897245
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.5386891624201899
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.75
#
# traing_loss = 0.5145582653906035
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.5059336365565009
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.5160050612428914
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.5081123677284821
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.5066234806309575
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.77
#
# traing_loss = 0.49101852917152905
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.5072113210740297
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.77
#
# traing_loss = 0.4796196662861368
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.4712957940671755
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.77
#
# traing_loss = 0.4552296115004498
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.4336084010808364
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.4492706170548563
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.81
#
# traing_loss = 0.45393975662148517
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.44271838405857916
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.42527336789214093
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.412711431150851
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.42043611212917
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.4450942822124647
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.4372365474700928
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.432131752371788
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.4290246497029844
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.41184106598729675
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.43142308942649676
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.4436338537413141
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.4378400425548139
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.43296218371909595
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.4274062747540681
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.77
#
# traing_loss = 0.4367273572994315
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.4188914370277654
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.4248888401881508
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.39663035778895667
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.38382843331150385
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.38558615290600323
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.37481024343034497
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.82
# Best model updated
#
# Group 5 Finished!
# Best accuracy found at epoch 70: 0.82
# Target number of exemplars: 40
# Randomly extracting exemplars from class 0 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 40 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.45
#
# =============================================
#
# Length of exemplars set: 2000
# traing_loss = 2.626470843087072
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.59
# Best model updated
#
# traing_loss = 1.5530099272727966
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.66
# Best model updated
#
# traing_loss = 1.3364766758421194
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.68
# Best model updated
#
# traing_loss = 1.230234822501307
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.67
#
# traing_loss = 1.1322404042534207
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.72
# Best model updated
#
# traing_loss = 1.0662566410458607
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.71
#
# traing_loss = 1.0488806172557499
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.71
#
# traing_loss = 0.983525759500006
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.73
# Best model updated
#
# traing_loss = 0.9122782505076864
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.73
# Best model updated
#
# traing_loss = 0.8749466059000596
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.69
#
# traing_loss = 0.8691111336583677
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
# Best model updated
#
# traing_loss = 0.8186834882134977
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.8039144160954849
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.7602772764537645
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.67
#
# traing_loss = 0.7664018934187682
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.72
#
# traing_loss = 0.7290570010309634
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
# Best model updated
#
# traing_loss = 0.7231158134729966
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.6976958124533944
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.6928104071513467
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.6602096181848774
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.6334306442219279
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.70
#
# traing_loss = 0.6553071024625198
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.6254050783489061
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.612379640340805
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.6093623547450356
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.71
#
# traing_loss = 0.5883175380851912
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.5805754985498346
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.5573604605768038
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.5329716173203095
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.551140730795653
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.5533457819534384
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.5427767673264379
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.72
#
# traing_loss = 0.565870357596356
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
# Best model updated
#
# traing_loss = 0.526906853136809
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.5265680292378301
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.73
#
# traing_loss = 0.5218816626331081
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
# Best model updated
#
# traing_loss = 0.5014304635317429
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.500734058411225
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.498167810232743
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
# Best model updated
#
# traing_loss = 0.4646285117968269
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.4565607821163924
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.80
# Best model updated
#
# traing_loss = 0.46802090043606964
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.45956633596316626
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.4680811574925547
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.44675387053386023
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.4310560686432797
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.43185477736203565
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.41946089202943054
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.80
#
# traing_loss = 0.4245095855515936
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.43920327658238617
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.43213219940662384
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.43045055412727856
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.43974990235722583
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.451858045614284
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.4639491387035536
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.46367273058580316
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.43679011710312055
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.79
#
# traing_loss = 0.4271604230870371
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.4346538769162219
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.4447794005922649
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.4244126515543979
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.42805589670720307
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.41770688800708106
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.421900384452032
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.42115977276926453
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.40707792924798053
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.40514163089835126
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.4036935516025709
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.3800328710804815
# Epoch 69/70 LR: [0.1]
# ...
# Validation accuracy on group 9/10: 0.74
# Best model updated
#
# traing_loss = 1.2100175800530806
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
# Best model updated
#
# traing_loss = 1.097440709238467
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.80
# Best model updated
#
# traing_loss = 1.0007407652295155
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.80
#
# traing_loss = 0.9647777236026266
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.936720582454101
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.8694555616897085
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.80
#
# traing_loss = 0.813864819381548
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.81
# Best model updated
#
# traing_loss = 0.8058452126772507
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.81
# Best model updated
#
# traing_loss = 0.7933528604714767
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.83
# Best model updated
#
# traing_loss = 0.7737192641133848
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.7319087023320405
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.81
#
# traing_loss = 0.7118472936360732
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.7260172256956929
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.6958029995793882
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.83
# Best model updated
#
# traing_loss = 0.657890687170236
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.660764138335767
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.641208634428356
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.81
#
# traing_loss = 0.6294165143500203
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.6263713765403499
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.81
#
# traing_loss = 0.6013076674679051
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.83
# Best model updated
#
# traing_loss = 0.5986878288828809
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.5979436111191044
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.618182201748309
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.5709053446417269
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.83
#
# traing_loss = 0.5593867697145628
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.83
#
# traing_loss = 0.5521755348081174
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.5527466587398363
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.80
#
# traing_loss = 0.5556989772164304
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.80
#
# traing_loss = 0.5622311389964559
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.80
#
# traing_loss = 0.5513033653083055
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.81
#
# traing_loss = 0.5422435376955115
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.83
#
# traing_loss = 0.5340041790319525
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.83
#
# traing_loss = 0.5088853661132895
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.5080303335967271
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.83
#
# traing_loss = 0.4892265388499136
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.83
# Best model updated
#
# traing_loss = 0.48950110116730566
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.5031637277292169
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.80
#
# traing_loss = 0.48876289569813275
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.85
# Best model updated
#
# traing_loss = 0.4904332011938095
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.83
#
# traing_loss = 0.494806913577992
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.83
#
# traing_loss = 0.4927687353414038
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.80
#
# traing_loss = 0.4753341616495796
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.84
#
# traing_loss = 0.4706670395706011
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.81
#
# traing_loss = 0.4532362747451533
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.43942189864490344
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.4274772885053054
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.83
#
# traing_loss = 0.44515828982643457
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.79
#
# traing_loss = 0.45008606690427533
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.4428977836733279
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.4510542685570924
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.4282628427381101
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.81
#
# traing_loss = 0.4321406665055648
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.84
#
# traing_loss = 0.4376140133194301
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.83
#
# traing_loss = 0.4503675407689551
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.46590095369712164
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.80
#
# traing_loss = 0.4683755830578182
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.79
#
# traing_loss = 0.4911211418068927
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.4573933773714563
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.47255766262178833
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.81
#
# traing_loss = 0.4568936157485713
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.80
#
# traing_loss = 0.4433820623418559
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.83
#
# traing_loss = 0.4511908273334089
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.83
#
# traing_loss = 0.44256109517553577
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.81
#
# traing_loss = 0.4330264880605366
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.42415291977965314
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.84
#
# traing_loss = 0.4070848207110944
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.84
#
# traing_loss = 0.40712088281693665
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.83
#
# traing_loss = 0.4006392813247183
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.85
#
# Group 9 Finished!
# Best accuracy found at epoch 40: 0.85
# Target number of exemplars: 22
# Randomly extracting exemplars from class 0 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 22 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.33
#
# =============================================
#
# Length of exemplars set: 1980
# traing_loss = 2.6838712070299233
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.65
# Best model updated
#
# traing_loss = 1.4281357863674993
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
# Best model updated
#
# traing_loss = 1.154554008141808
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
# Best model updated
#
# traing_loss = 1.0618352332840795
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.9910410551921182
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.9365947363169297
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
# Best model updated
#
# traing_loss = 0.8831074108248171
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
# Best model updated
#
# traing_loss = 0.857610373393349
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.8230375958525616
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
# Best model updated
#
# traing_loss = 0.7825339643851571
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.7611001522644706
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.735683016155077
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.6971744830193727
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.7018534910419713
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
# Best model updated
#
# traing_loss = 0.6821681274020154
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.6587781847819038
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.6584830148064572
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.6688996203567671
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.6616999636525693
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.6501176182342612
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.6458892627902653
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.6207027202067168
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.6173874677523322
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.82
# Best model updated
#
# traing_loss = 0.5931947833817938
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.5749452781418095
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.5790553326192109
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.5562072733174199
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.5482717234155406
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.5491984680942867
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.5386866337579229
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.5469779015883155
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.5505788591892823
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.5231796457715656
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.5184960825287778
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.5436096606047257
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.5153809772885364
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.5270295492980791
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.5159116089344025
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.49382612173971924
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.4957950458578441
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.4928801487321439
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.4957362581854281
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.4864388062902119
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.4780124374057936
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.47201793349307514
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.4731799014236616
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.4633240894131038
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.82
# Best model updated
#
# traing_loss = 0.48334647520728735
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.47161967080572376
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.47013187602810236
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.4709079608969066
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.47274807484253595
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.4842728881732277
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.48458997451740765
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.48858035258624866
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.47643247570680536
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.46663998326529627
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.83
# Best model updated
#
# traing_loss = 0.4416817316542501
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.43533831446067145
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.42788953820000525
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.4397328223871148
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.4421564580305763
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.4219700642254042
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.40915407564329065
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.4164376297722692
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.41472347858159436
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.40559217009855353
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.3876420356657194
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.83
# Best model updated
#
# traing_loss = 0.3912398335726365
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.40383347804131714
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# Group 10 Finished!
# Best accuracy found at epoch 68: 0.83
# Target number of exemplars: 20
# Randomly extracting exemplars from class 0 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 20 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.32
#
# =============================================
#
# #################################

# %% [markdown]
# ### Store logs in more usable dtype

# %%
train_loss = [[logs[run_i]['group_train_loss'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
train_accuracy = [[logs[run_i]['group_train_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
val_loss = [[logs[run_i]['val_losses'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
val_accuracy = [[logs[run_i]['val_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
test_accuracy = [[logs[run_i]['test_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
predictions = [logs[run_i]['predictions'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]
true_labels = [logs[run_i]['true_labels'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]

# %% [markdown]
# ### Save the model

# %% [markdown]
# #### Saving logs in JSON files

# %%
import json

with open('states/iCaRL_ablationCE+L2_train_loss_seed42.json', 'w') as f:
  json.dump(train_loss, f)
f.close
with open('states/iCaRL_ablationCE+L2_train_accuracy_seed42.json', 'w') as f:
  json.dump(train_accuracy, f)
f.close
with open('states/iCaRL_ablationCE+L2_val_loss_seed42.json', 'w') as f:
  json.dump(val_loss, f)
f.close  
with open('states/iCaRL_ablationCE+L2_val_accuracy_seed42.json', 'w') as f:
  json.dump(val_accuracy, f)
f.close
with open('states/iCaRL_ablationCE+L2_test_accuracy_seed42.json', 'w') as f:
  json.dump(test_accuracy, f)
f.close
with open('states/iCaRL_ablationCE+L2_predictions_seed42.json', 'w') as f:
  json.dump(predictions, f)
f.close
with open('states/iCaRL_ablationCE+L2_true_labels_seed42.json', 'w') as f:
  json.dump(true_labels, f)
f.close
# Out:
# <function TextIOWrapper.close>

# %% [markdown]
# #### Saving best resnet on 100 classes for each seed

# %%
for i in range(len(RANDOM_SEED)):
  torch.save(best_net_tot_classes[i].state_dict(), "states/iCaRL_ablationCE+L2_bestnet_seed[{}]".format(RANDOM_SEED[i]))

# %%
from google.colab import files
files.download('states/iCaRL_ablationCE+L2_train_loss_seed42.json')
files.download('states/iCaRL_ablationCE+L2_train_accuracy_seed42.json')
files.download('states/iCaRL_ablationCE+L2_val_loss_seed42.json')
files.download('states/iCaRL_ablationCE+L2_val_accuracy_seed42.json')
files.download('states/iCaRL_ablationCE+L2_test_accuracy_seed42.json')
files.download('states/iCaRL_ablationCE+L2_predictions_seed42.json')
files.download('states/iCaRL_ablationCE+L2_true_labels_seed42.json')
for i in range(len(RANDOM_SEED)):
  files.download('states/iCaRL_ablationCE+L2_bestnet_seed[{}]'.format(RANDOM_SEED[i]))

# %% [markdown]
# ### Print some graphs

# %%
from data.utils_plot import plot_train_val, plot_test_accuracies, plot_confusion_matrix

# %%
train_loss = np.array(train_loss)
train_accuracy = np.array(train_accuracy)
val_loss = np.array(val_loss)
val_accuracy = np.array(val_accuracy)
test_accuracy = np.array(test_accuracy)

train_loss_stats = np.array([train_loss.mean(0), train_loss.std(0)]).transpose()
train_accuracy_stats = np.array([train_accuracy.mean(0), train_accuracy.std(0)]).transpose()
val_loss_stats = np.array([val_loss.mean(0), val_loss.std(0)]).transpose()
val_accuracy_stats = np.array([val_accuracy.mean(0), val_accuracy.std(0)]).transpose()
test_accuracy_stats = np.array([test_accuracy.mean(0), test_accuracy.std(0)]).transpose()

# %% [markdown]
# #### Train validation loss

# %%
plot_train_val(train_loss_stats, val_loss_stats, loss = True)

# %% [markdown]
# #### Train validation accuracy

# %%
plot_train_val(train_accuracy_stats, val_accuracy_stats, loss = False)

# %% [markdown]
# #### Test accuracy

# %%
plot_test_accuracies(test_accuracy_stats)

# %% [markdown]
# #### Confusion Matrix

# %%
for run in range(len(RANDOM_SEED)):
  targets = np.array(true_labels[run])
  preds = np.array(predictions[run])

  plot_confusion_matrix(targets, preds, RANDOM_SEED[run], 'iCaRL')
