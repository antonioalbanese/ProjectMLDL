# %% [markdown]
# <a href="https://colab.research.google.com/github/cosminnedescu/ProjectMLDL/blob/main/baselines/iCaRL-v1_3_0-ablation-cosine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Avoid K80
# !nvidia-smi
# Out:
# Wed Jun 30 13:20:16 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import random

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
from torch.autograd import Variable

import torchvision
from torchvision import transforms, datasets, models
from torch.utils.data import Subset, DataLoader

from PIL import Image

import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
from copy import copy
from copy import deepcopy

# %% [markdown]
# #### Cloning the Git repository

# %%
# !rm -rf ProjectMLDL
if not os.path.isdir('/content/ProjectMLDL'):
  # !git clone https://github.com/cosminnedescu/ProjectMLDL.git
  # %cd /content/ProjectMLDL
  # !rm -rf LICENSE README.md
# Out:
# Cloning into 'ProjectMLDL'...
# remote: Enumerating objects: 1491, done.
# remote: Counting objects: 100% (406/406), done.
# remote: Compressing objects: 100% (328/328), done.
# remote: Total 1491 (delta 252), reused 74 (delta 74), pack-reused 1085
# Receiving objects: 100% (1491/1491), 61.09 MiB | 26.25 MiB/s, done.
# Resolving deltas: 100% (770/770), done.
# /content/ProjectMLDL

# %%
from data.cifar100 import CIFAR100
from model.resnet32 import resnet32
import data.utils
from model.icarl_ablation import iCaRL

# %%
# True mean and std of Cifar100 dataset (src="https://gist.github.com/weiaicunzai/e623931921efefd4c331622c344d8151")
mean = [0.5071, 0.4867, 0.4408]
std = [0.2675, 0.2565, 0.2761]

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])
test_transform = transforms.Compose(
    [transforms.ToTensor(), 
     transforms.Normalize(mean, std),
     ])

# %% [markdown]
# ## Incremental Classifier and Representation Learning

# %% [markdown]
# ### Defining hyperparameters according to iCarl paper

# %%
# Settings
DEVICE = 'cuda'
NUM_CLASSES = 100         # Total number of classes
VAL_SIZE = 0.2            # Proportion of validation set with respect to training set (between 0 and 1)

# Training
BATCH_SIZE = 128          # Batch size
LR = 0.1                    # Initial learning rate
                       
MOMENTUM = 0.9            # Momentum for stochastic gradient descent (SGD)
WEIGHT_DECAY = 1e-5       # Weight decay from iCaRL

RANDOM_SEED = [42,13,10]  # Random seeds defining the runs of every method
                          # Note: this should be at least 3 to have a fair benchmark

NUM_EPOCHS = 70          # Total number of training epochs
MILESTONES = [49, 63]     # Step down policy from iCaRL (MultiStepLR)
                          # Decrease the learning rate by gamma at each milestone
GAMMA = 1 #0.2               # Gamma factor from iCaRL (1/5)

HERDING = False           # True to perform prioritized selection, False to perform random selection
CLASSIFY = True           # True to use mean-of-exemplar classifier, False to use network's output directly for classification

# %%
def do_group_classes(run):

  train_subset = [[] for i in range(10)]
  train_dataloader = [[] for i in range(10)]
  val_dataloader = [[] for i in range(10)]
  test_dataloader = [[] for i in range(10)]

  for i in range(10):
    train_data = CIFAR100("dataset", 
                          train=True, 
                          transform=train_transform, 
                          download=(run+i==0),
                          random_state=RANDOM_SEED[run])
    test_data = CIFAR100("dataset", 
                         train=False, 
                         transform=test_transform, 
                         download=False,
                         random_state=RANDOM_SEED[run])
    
    train_data.set_index_map(train_data.splits[i])
    test_data.set_index_map([test_data.splits[j] for j in range(0, i+1)])
    
    train_indices, val_indices = train_data.train_val_split(VAL_SIZE, RANDOM_SEED[run])
    
    train_subset[i] = copy(Subset(train_data, train_indices))
    val_subset = Subset(train_data, val_indices)

    tmp_dl = DataLoader(val_subset,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    val_dataloader[i] = copy(tmp_dl)

    tmp_dl = DataLoader(test_data,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    test_dataloader[i] = copy(tmp_dl)

  return train_dataloader, val_dataloader, test_dataloader, train_subset

# %% [markdown]
# ### Going on with the model
# This is the main iCaRL step.
#
# This step is run 3 times with different `RANDOM_SEED`.
# Here the model is instantiated, trained and tested.
#
# Results and some statistics are then stored in the variable `logs`.

# %%
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
logs = [[] for i in range(len(RANDOM_SEED))]
best_net_tot_classes = [None for i in range(len(RANDOM_SEED))]

for run in range(len(RANDOM_SEED)):
  print("#################################")
  print(f"Radom seed: {RANDOM_SEED[run]}")
  print("")

  # get data_subsets separated in incremental groups of 10 classes
  train_dl, val_dl, test_dl, train_set = do_group_classes(run)

  #create the resnet
  net = resnet32()
  
  trainer = iCaRL(DEVICE,
                  net,
                  LR,
                  MOMENTUM,
                  WEIGHT_DECAY,
                  MILESTONES,
                  GAMMA,
                  train_dl,
                  val_dl,
                  test_dl,
                  BATCH_SIZE,
                  train_set,
                  train_transform,
                  test_transform, 1)

  #train and evaluate the model
  logs[run] = trainer.train_model(NUM_EPOCHS, HERDING, CLASSIFY)

  best_net_tot_classes[run] = deepcopy(trainer.best_net)

  print("#################################")
  print("")
  print("")
# Out:
# #################################
# Radom seed: 42
#
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to dataset/cifar-100-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=169001437.0), HTML(value='')))
# Extracting dataset/cifar-100-python.tar.gz to dataset
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Output streaming troncato alle ultime 5000 righe.
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.79
#
# traing_loss = 0.049910874996820224
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.79
#
# traing_loss = 0.04593839447783387
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.79
#
# traing_loss = 0.05344409451050603
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.79
#
# traing_loss = 0.08088338565405297
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
#
# traing_loss = 0.07506008745859498
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
#
# Group 4 Finished!
# Best accuracy found at epoch 42: 0.80
# Target number of exemplars: 50
# Randomly extracting exemplars from class 0 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 50 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.59
#
# =============================================
#
# Length of exemplars set: 2000
# traing_loss = 1.8608004023199496
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.64
# Best model updated
#
# traing_loss = 0.9752241748830547
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.62
#
# traing_loss = 0.88516547628071
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.61
#
# traing_loss = 0.7271250732567
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.69
# Best model updated
#
# traing_loss = 0.616413890019707
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.69
#
# traing_loss = 0.5577803085679593
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
# Best model updated
#
# traing_loss = 0.5303855654986008
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.65
#
# traing_loss = 0.4675815844017526
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.44708499765914417
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.75
# Best model updated
#
# traing_loss = 0.4384942650794983
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.70
#
# traing_loss = 0.3867363417926042
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.70
#
# traing_loss = 0.3864205874826597
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.71
#
# traing_loss = 0.32431219388609345
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.34141716069501377
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.70
#
# traing_loss = 0.2988214956029602
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.2671300597164942
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.70
#
# traing_loss = 0.26727344063313113
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.2532692794566569
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.24742405748237734
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.69
#
# traing_loss = 0.22640165038730786
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.69
#
# traing_loss = 0.2540395327884218
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.71
#
# traing_loss = 0.22501113087586735
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.66
#
# traing_loss = 0.21047067593621172
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.71
#
# traing_loss = 0.22296788543462753
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.71
#
# traing_loss = 0.20890711345102475
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.68
#
# traing_loss = 0.19376029074192047
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.18023347725038943
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.18750024943248086
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.15329380252439043
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
# Best model updated
#
# traing_loss = 0.1435154840026213
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.14776419686234515
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.1653483961911305
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.75
#
# traing_loss = 0.17056995970399483
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.14001260762629303
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.12760056595763433
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.1406106654068698
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.11190733750877173
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.11202201749319615
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.1130248811095953
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.13395555519863314
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.71
#
# traing_loss = 0.11730754108208677
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.12038063201243462
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.12294215984318567
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.10644835144605326
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.75
#
# traing_loss = 0.09073795272928217
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.08571864389207053
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.09148648640383845
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.71
#
# traing_loss = 0.10322842090998006
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.11337166465818882
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.09563288481339165
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.10861434755117996
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.10767347398011581
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.10645968167354232
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.13782731192591396
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.14404820845178937
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.10777412921838138
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.08929691666170307
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.07890852087217828
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.07402144712598427
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.07713157084325085
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.07551250266640083
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.07678725979412379
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.0793417816090843
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.75
#
# traing_loss = 0.07903717790284882
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.08283851344300353
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.08351891038372465
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.07920479158992352
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.77
# Best model updated
#
# traing_loss = 0.08283265352087177
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.07808110134109207
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.06543151924953512
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# Group 5 Finished!
# Best accuracy found at epoch 67: 0.77
# Target number of exemplars: 40
# Randomly extracting exemplars from class 0 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 40 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.55
#
# =============================================
#
# Length of exemplars set: 2000
# traing_loss = 2.0080579830252607
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.66
# Best model updated
#
# traing_loss = 0.9569456292235333
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.72
# Best model updated
#
# traing_loss = 0.814156297756278
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.68
#
# traing_loss = 0.7190203018810438
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.69
#
# traing_loss = 0.6503943120655806
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.72
#
# traing_loss = 0.5766631734112034
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.72
#
# traing_loss = 0.502149198366248
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
# Best model updated
#
# traing_loss = 0.4711617445168288
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.70
#
# traing_loss = 0.4544772991667623
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.4163122669510219
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.70
#
# traing_loss = 0.41669768872468366
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.73
#
# traing_loss = 0.3353520414751509
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
# Best model updated
#
# traing_loss = 0.32634221535661945
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.72
#
# traing_loss = 0.32106238700773404
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.73
#
# traing_loss = 0.3401146181251692
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.2859210919426835
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.27275413469127985
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.71
#
# traing_loss = 0.259113233698451
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
# Best model updated
#
# traing_loss = 0.25200469063028047
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.2668573137210763
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.72
#
# traing_loss = 0.2442436423962531
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.207615633211706
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.20039879482077516
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.18904065437938855
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.73
#
# traing_loss = 0.21100293164667877
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.20818362530806792
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.71
#
# traing_loss = 0.1607664280935474
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.13012027416540228
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.12941524013876915
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.13313489731239236
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.1411689396785653
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.72
#
# traing_loss = 0.15603355609852335
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.15267686319092047
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.14326251662619735
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.73
#
# traing_loss = 0.15002343560690465
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.73
#
# traing_loss = 0.15739133905457414
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.72
#
# traing_loss = 0.12462046693848527
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.11399327024169591
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.1128124670813913
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.10799244831761588
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.08956880130521629
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.09653425111394862
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.08649740279044794
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.09815465926152209
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.10789179826236289
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.08416711717196133
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.07936950108927229
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.0795637686210482
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
# Best model updated
#
# traing_loss = 0.06669379070239223
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.07805599863438503
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.0971673141517069
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
# Best model updated
#
# traing_loss = 0.08473185806170754
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.08109145226847866
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.09207589406034221
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.07524457509103029
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.07016341663573099
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.0798609307764665
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.07734708694498175
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.07101953879970571
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.09006980243746353
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.0851351348683238
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.06880855997619421
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.07184416768343552
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.07452752890632204
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.07953473917492059
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.08273377569149369
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.0788797185877743
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.061416400191576584
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.07214454800376426
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.07832157166431779
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.73
#
# Group 6 Finished!
# Best accuracy found at epoch 51: 0.78
# Target number of exemplars: 33
# Randomly extracting exemplars from class 0 of current split... Extracted 33 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 33 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 33 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 33 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 33 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 33 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 33 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 33 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 33 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 33 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.49
#
# =============================================
#
# Length of exemplars set: 1980
# traing_loss = 2.38741744082907
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.61
# Best model updated
#
# traing_loss = 1.1288531824298527
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.65
# Best model updated
#
# traing_loss = 0.8976943570634593
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.66
# Best model updated
#
# traing_loss = 0.801693979812705
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.63
#
# traing_loss = 0.6815984871076501
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.67
# Best model updated
#
# traing_loss = 0.6611244095408398
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.68
# Best model updated
#
# traing_loss = 0.6055093686217847
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.67
#
# traing_loss = 0.5190353412990985
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.69
# Best model updated
#
# traing_loss = 0.4801456228546474
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.69
# Best model updated
#
# traing_loss = 0.4417795312145482
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.71
# Best model updated
#
# traing_loss = 0.3989749042236287
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.69
#
# traing_loss = 0.36859484502802725
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.73
# Best model updated
#
# traing_loss = 0.34028457882611646
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.71
#
# traing_loss = 0.3219969133320062
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.73
#
# traing_loss = 0.2954712892356126
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.72
#
# traing_loss = 0.30202821706948074
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.71
#
# traing_loss = 0.27682713062866876
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.73
#
# traing_loss = 0.272295151391755
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.73
#
# traing_loss = 0.22991414530121762
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.73
#
# traing_loss = 0.24057938012739885
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.75
# Best model updated
#
# traing_loss = 0.21442262682577837
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.72
#
# traing_loss = 0.2187366929391156
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.73
#
# traing_loss = 0.23277823173481485
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.69
#
# traing_loss = 0.19012454427454784
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.72
#
# traing_loss = 0.17948950746137163
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.74
#
# traing_loss = 0.18626359655805255
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.73
#
# traing_loss = 0.1615729895622834
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.74
#
# traing_loss = 0.1456304469510265
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.73
#
# traing_loss = 0.14237074092354463
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.73
#
# traing_loss = 0.13564240948661513
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.74
#
# traing_loss = 0.13025352180651997
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.76
# Best model updated
#
# traing_loss = 0.11647095466437547
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.75
#
# traing_loss = 0.12288579668687738
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.76
# Best model updated
#
# traing_loss = 0.10349385075919006
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.72
#
# traing_loss = 0.11949271927385227
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.74
#
# traing_loss = 0.1313098935491365
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.72
#
# traing_loss = 0.11726598141957885
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.73
#
# traing_loss = 0.11584324575960636
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.75
#
# traing_loss = 0.1239278931170702
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.75
#
# traing_loss = 0.11754242557546367
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.75
#
# traing_loss = 0.12044376029592493
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.75
#
# traing_loss = 0.09316448875419471
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.74
#
# traing_loss = 0.11430156166138856
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.76
#
# traing_loss = 0.08955013096008611
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.76
# Best model updated
#
# traing_loss = 0.08023919889946347
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.75
#
# traing_loss = 0.09794856883261514
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.70
#
# traing_loss = 0.10969114311687324
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.75
#
# traing_loss = 0.1228679357825414
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.71
#
# traing_loss = 0.12777989163346912
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.74
#
# traing_loss = 0.11197135799928852
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.72
#
# traing_loss = 0.09523978877974593
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.75
#
# traing_loss = 0.08977336128768713
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.76
#
# traing_loss = 0.0905238865348308
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.74
#
# traing_loss = 0.08806983478691267
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.78
# Best model updated
#
# traing_loss = 0.08303847139620263
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.77
#
# traing_loss = 0.07679446292636187
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.75
#
# traing_loss = 0.0662218133068603
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.75
#
# traing_loss = 0.05755148649863575
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.74
#
# traing_loss = 0.059705970282463924
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.75
#
# traing_loss = 0.06089495211515738
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.75
#
# traing_loss = 0.06415482756236325
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.75
#
# traing_loss = 0.05666273168247679
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.77
#
# traing_loss = 0.053843165221421616
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.76
#
# traing_loss = 0.054366595071295036
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.76
#
# traing_loss = 0.060728372398601925
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.75
#
# traing_loss = 0.06148056208115557
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.75
#
# traing_loss = 0.055439636192244034
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.73
#
# traing_loss = 0.05251604666852433
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.75
#
# traing_loss = 0.05362107179573049
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.77
#
# traing_loss = 0.05377715635720803
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 7/10: 0.76
#
# Group 7 Finished!
# Best accuracy found at epoch 54: 0.78
# Target number of exemplars: 28
# Randomly extracting exemplars from class 0 of current split... Extracted 28 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 28 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 28 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 28 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 28 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 28 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 28 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 28 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 28 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 28 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.47
#
# =============================================
#
# Length of exemplars set: 1960
# traing_loss = 2.3683978811554285
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.60
# Best model updated
#
# traing_loss = 1.1315351089705592
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.62
# Best model updated
#
# traing_loss = 0.8288837800855222
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.71
# Best model updated
#
# traing_loss = 0.7018537443617116
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.69
#
# traing_loss = 0.6378558109635892
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.65
#
# traing_loss = 0.580308546838553
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.69
#
# traing_loss = 0.5115912679744803
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.73
# Best model updated
#
# traing_loss = 0.4706075654729553
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.70
#
# traing_loss = 0.4072742364976717
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.71
#
# traing_loss = 0.35406746456156607
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.71
#
# traing_loss = 0.3190732248451399
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.72
#
# traing_loss = 0.28864692734635394
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.72
#
# Validation accuracy on group 8/10: 0.70
#
# traing_loss = 0.2532697809131249
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.74
# Best model updated
#
# traing_loss = 0.23275592437256937
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.73
#
# traing_loss = 0.23955606701581375
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.75
# Best model updated
#
# traing_loss = 0.23775585740804672
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.74
#
# traing_loss = 0.20726531792594038
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.72
#
# traing_loss = 0.17873855874590253
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.71
#
# traing_loss = 0.16725860746658366
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.72
#
# traing_loss = 0.17951515948642854
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.74
#
# traing_loss = 0.16782579781568568
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.70
#
# traing_loss = 0.1598858187056106
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.72
#
# traing_loss = 0.15892699441832045
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.75
# Best model updated
#
# traing_loss = 0.138289133572708
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.76
# Best model updated
#
# traing_loss = 0.1358143034512582
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.73
#
# traing_loss = 0.11748272399215595
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.73
#
# traing_loss = 0.12090382773591124
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.74
#
# traing_loss = 0.13064515023775722
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.74
#
# traing_loss = 0.12596789504522862
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.74
#
# traing_loss = 0.11333604448515436
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.73
#
# traing_loss = 0.12081935078553531
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.70
#
# traing_loss = 0.10741169313373773
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.74
#
# traing_loss = 0.09752653280030125
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.74
#
# traing_loss = 0.09334431693929693
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.74
#
# traing_loss = 0.08980694826206435
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.74
#
# traing_loss = 0.10684741669051025
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.71
#
# traing_loss = 0.08559659180109916
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.75
#
# traing_loss = 0.0947967502086059
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.74
#
# traing_loss = 0.09358803304317205
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.75
#
# traing_loss = 0.0973907611940218
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.73
#
# traing_loss = 0.08834404441649499
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.74
#
# traing_loss = 0.09742715242116348
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.74
#
# traing_loss = 0.08315017876093803
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.73
#
# traing_loss = 0.07944873898573544
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.71
#
# traing_loss = 0.07951148275447928
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.74
#
# traing_loss = 0.09799458669579547
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.72
#
# traing_loss = 0.08093992009273042
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.72
#
# traing_loss = 0.07848493216316337
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.75
#
# traing_loss = 0.0763379494133203
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.76
#
# traing_loss = 0.06074605793084787
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.73
#
# traing_loss = 0.06589689611902703
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.75
#
# traing_loss = 0.06725887452130733
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.71
#
# traing_loss = 0.06184984743595123
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.74
#
# traing_loss = 0.06286136360596055
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.76
#
# traing_loss = 0.05638169063984052
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.75
#
# traing_loss = 0.06495268205585687
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.72
#
# traing_loss = 0.06158952674140101
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.75
#
# traing_loss = 0.04885433452284854
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.77
# Best model updated
#
# traing_loss = 0.050552337349432964
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.76
#
# traing_loss = 0.04131326954001966
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.75
#
# traing_loss = 0.045570080735437245
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.75
#
# traing_loss = 0.04575281582124855
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.74
#
# traing_loss = 0.047207394493338856
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.75
#
# traing_loss = 0.05262334997077351
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.74
#
# traing_loss = 0.05779423455343298
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.72
#
# traing_loss = 0.05839827964487283
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.73
#
# traing_loss = 0.04600790118717629
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.73
#
# traing_loss = 0.03888560965171327
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.77
#
# traing_loss = 0.03159074793043344
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 8/10: 0.75
#
# Group 8 Finished!
# Best accuracy found at epoch 59: 0.77
# Target number of exemplars: 25
# Randomly extracting exemplars from class 0 of current split... Extracted 25 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 25 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 25 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 25 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 25 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 25 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 25 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 25 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 25 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 25 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.44
#
# =============================================
#
# Length of exemplars set: 2000
# traing_loss = 2.4443835253300876
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.67
# Best model updated
#
# traing_loss = 1.086901298035746
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.70
# Best model updated
#
# traing_loss = 0.9065429866313934
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
# Best model updated
#
# traing_loss = 0.676784234850303
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.70
#
# traing_loss = 0.6257766705492268
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.5654090733631797
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.72
#
# traing_loss = 0.5127321235511614
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.72
#
# traing_loss = 0.4261131234790968
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.41265954627938894
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.3140258471602979
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.30924176878255344
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.27276039382685785
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.268208732423575
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.72
#
# traing_loss = 0.288256172252738
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.2327828938546388
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
# Best model updated
#
# traing_loss = 0.21223795656924663
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.19285670441129935
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.19237127009293306
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.71
#
# traing_loss = 0.1932951166577961
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.19380081768917
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.71
#
# traing_loss = 0.19222073078803395
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.1662629705084407
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
# Best model updated
#
# traing_loss = 0.13043519611591878
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
# Best model updated
#
# traing_loss = 0.13153851825905882
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.14016595191281775
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.14434469134911246
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.13591349740391193
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.12257993925848733
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
# Best model updated
#
# traing_loss = 0.12467551701094794
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.11610957461854686
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.11478553744761841
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.10351520995407001
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.10078046333206736
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.10386969003340472
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
# Best model updated
#
# traing_loss = 0.09283551282208899
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.07206290782145831
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.07089852233943732
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.0848280832009471
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.08144095969264922
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.09104385793856952
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.0852242587539165
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.08671413272943186
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.072830555960536
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.0696698714695547
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.05960298200016436
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.07575276097201783
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.0653876723802608
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.79
# Best model updated
#
# traing_loss = 0.07553360931089391
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.07583356033200803
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.07363206917501014
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.07269139413762352
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.07198192470747491
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.06290513329693805
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.06487680186072121
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.79
# Best model updated
#
# traing_loss = 0.05758945324012767
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.0501501250040272
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.046488268341383206
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.79
#
# traing_loss = 0.0548022344465489
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.79
# Best model updated
#
# traing_loss = 0.051088350703534874
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.044832816671418106
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.0397289405050485
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.043902802847973675
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.79
# Best model updated
#
# traing_loss = 0.04138469764881808
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.79
#
# traing_loss = 0.03626467492026479
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.038363392140878284
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.041706413557024105
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.039789755342771176
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.80
# Best model updated
#
# traing_loss = 0.038851621236814106
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.04705733980011681
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
#
# Group 9 Finished!
# Best accuracy found at epoch 68: 0.80
# Target number of exemplars: 22
# Randomly extracting exemplars from class 0 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 22 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.41
#
# =============================================
#
# Length of exemplars set: 1980
# traing_loss = 2.44568918062293
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.69
# Best model updated
#
# traing_loss = 1.037302667679994
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.72
# Best model updated
#
# traing_loss = 0.8187350345694501
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.70
#
# traing_loss = 0.6789422054653582
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.72
# Best model updated
#
# traing_loss = 0.5896009336347166
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
# Best model updated
#
# traing_loss = 0.5204358062018519
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.4364690288253453
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.74
#
# traing_loss = 0.40519460517427197
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.72
#
# traing_loss = 0.40110611526862433
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.74
#
# traing_loss = 0.3728217242852501
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
# Best model updated
#
# traing_loss = 0.35084380889716354
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.73
#
# traing_loss = 0.31536417260118155
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
# Best model updated
#
# traing_loss = 0.2890656784824703
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.2570354727947194
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.74
#
# traing_loss = 0.25934007796256436
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.20473650292209958
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.16476219260822172
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.1889359155750793
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.19889807506747867
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.17239728505196777
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.18129908795589986
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.14818985015153885
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.14257812435212341
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.1556915545269199
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.15542009667209958
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.13294288742801416
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.12942679234496926
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.11180586618897707
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.10033908850796845
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
# Best model updated
#
# traing_loss = 0.11980882529979167
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.10747478594598563
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.11707923496546953
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.09907468950942806
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.10355031611802785
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.08569226162913053
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.08851085425071094
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.09948274865746498
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.10673576617694419
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.09817495261845381
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.08731182778011197
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.08236901316305865
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.06766319420674573
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.060225737483605095
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.063509834120455
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.06907236729951008
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
# Best model updated
#
# traing_loss = 0.06275300017517546
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.82
# Best model updated
#
# traing_loss = 0.05648777593413125
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.82
# Best model updated
#
# traing_loss = 0.06953187942828822
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.06474059556975313
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.07149974815547466
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.05714529955192753
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.05637100253902052
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.05340721166652182
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# ...
# Best model updated
#
# traing_loss = 1.0742556660071663
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.64
#
# traing_loss = 0.8987507833086926
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.70
#
# traing_loss = 0.7057206721409507
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.69
#
# traing_loss = 0.6102700537961462
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.67
#
# traing_loss = 0.5593824503214463
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.72
# Best model updated
#
# traing_loss = 0.5106088668107986
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.69
#
# traing_loss = 0.4762785791055016
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.68
#
# traing_loss = 0.450503945350647
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.69
#
# traing_loss = 0.39926358798275824
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
# Best model updated
#
# traing_loss = 0.36298297540001245
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.71
#
# traing_loss = 0.3519704384000405
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.3431254207440045
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.3290084338058596
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.27887247178865515
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.2654871419072151
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.24803275614976883
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.72
#
# traing_loss = 0.27616148733574414
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.72
#
# traing_loss = 0.22909333913222604
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.20947923770417337
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
# Best model updated
#
# traing_loss = 0.21454010855244554
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.70
#
# traing_loss = 0.22308507529289825
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.19086748053846153
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.16687122052130493
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.72
#
# traing_loss = 0.18551727513904157
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.72
#
# traing_loss = 0.17705440148711205
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.16536618250867594
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.1476929983852998
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.13412400497042615
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.16421467195386472
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.14152456949586453
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.14426423528272173
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.72
#
# traing_loss = 0.12951418125759
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.12004296287246373
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.1365043054456296
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.12854019455287768
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.11759145881818689
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.10466255765894185
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.10865060037568859
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.09885278522320416
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.10067903679674087
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.093107877218205
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.09302270242377468
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.09799839378051135
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.11022743793285411
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.10461823739435362
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.09231469585843709
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.0923156835462736
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.09412285053859586
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.0848527984774631
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.10324030312830987
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.11012026983434739
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.10357586116246555
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.72
#
# traing_loss = 0.0911693487154401
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.08499457274118195
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.1035182430692341
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.08439787461057953
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.72
#
# traing_loss = 0.07637169406465862
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.07255526899319628
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.07074321154505014
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.09603436400546976
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.08086833544075489
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.0763871186291394
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.0798762908772282
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.0721869322511813
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.07265336293241252
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.06536553634087676
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.05654950942034307
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.06757554901844781
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.06394002554209335
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# Group 9 Finished!
# Best accuracy found at epoch 20: 0.77
# Target number of exemplars: 22
# Randomly extracting exemplars from class 0 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 22 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.40
#
# =============================================
#
# Length of exemplars set: 1980
# traing_loss = 2.316041671711466
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.63
# Best model updated
#
# traing_loss = 1.0057614756667095
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.72
# Best model updated
#
# traing_loss = 0.8060190612855165
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.69
#
# traing_loss = 0.7008122762908107
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.67
#
# traing_loss = 0.59324045220147
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.73
# Best model updated
#
# traing_loss = 0.543207190606905
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.71
#
# traing_loss = 0.46506243555442145
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.71
#
# traing_loss = 0.40982714554537897
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.72
#
# traing_loss = 0.33971153588398645
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.72
#
# traing_loss = 0.3270938869403756
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.73
# Best model updated
#
# traing_loss = 0.31735759876344516
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.72
#
# traing_loss = 0.3014595252664193
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.70
#
# traing_loss = 0.28372189273004944
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.73
#
# traing_loss = 0.27083650620087335
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.73
#
# traing_loss = 0.232719238685525
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.73
# Best model updated
#
# traing_loss = 0.21255499416071436
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.72
#
# traing_loss = 0.20319498897246693
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.73
# Best model updated
#
# traing_loss = 0.20955132142357205
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.73
# Best model updated
#
# traing_loss = 0.20255798214803572
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
# Best model updated
#
# traing_loss = 0.24234494242979132
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.73
#
# traing_loss = 0.20892810918714688
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.71
#
# traing_loss = 0.19374774283041124
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.74
#
# traing_loss = 0.16735878975495047
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.73
#
# traing_loss = 0.16038140201050302
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.74
#
# traing_loss = 0.14719870783712552
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.74
#
# traing_loss = 0.15259664343750995
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.12126563246483388
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.11609707311119723
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
# Best model updated
#
# traing_loss = 0.11956461826744287
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.13468429721567943
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.73
#
# traing_loss = 0.1353081224243278
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.1284300893869089
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.11740256400535935
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.11292375178764695
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.73
#
# traing_loss = 0.11290738099943036
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.10449021512075611
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.11485281125034975
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.11092235123657662
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.09379710362333318
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.10847795730375726
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.09619127473105556
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.08403633502514465
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.085020298867122
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.07240563096559566
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
# Best model updated
#
# traing_loss = 0.06463388329290826
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.07793774561065694
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.08177200640025346
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.74
#
# traing_loss = 0.07513337420380634
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.07794550458050292
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.08219184997774985
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.07801642058336217
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.07707738248712342
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.07618329933156139
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.056789121023662716
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.06550489888405023
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.73
#
# traing_loss = 0.06320485330956138
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.06705910562659087
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.05932000874663177
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.0579787570497264
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.74
#
# traing_loss = 0.048382626643971256
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.05377487356410078
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.0647872867791549
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.06520092633107434
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.0647477443208513
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.06933133449891339
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.05323562702245038
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.04818032791271158
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.05169654066633919
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.044982258594878345
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.05233337252360323
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
#
# Group 10 Finished!
# Best accuracy found at epoch 44: 0.79
# Target number of exemplars: 20
# Randomly extracting exemplars from class 0 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 20 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.40
#
# =============================================
#
# #################################

# %% [markdown]
# ### Store logs in more usable dtype

# %%
train_loss = [[logs[run_i]['group_train_loss'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
train_accuracy = [[logs[run_i]['group_train_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
val_loss = [[logs[run_i]['val_losses'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
val_accuracy = [[logs[run_i]['val_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
test_accuracy = [[logs[run_i]['test_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
predictions = [logs[run_i]['predictions'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]
true_labels = [logs[run_i]['true_labels'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]

# %% [markdown]
# ### Save the model

# %% [markdown]
# #### Saving logs in JSON files

# %%
import json

with open('states/iCaRL_train_loss.json', 'w') as f:
  json.dump(train_loss, f)
f.close
with open('states/iCaRL_train_accuracy.json', 'w') as f:
  json.dump(train_accuracy, f)
f.close
with open('states/iCaRL_val_loss.json', 'w') as f:
  json.dump(val_loss, f)
f.close  
with open('states/iCaRL_val_accuracy.json', 'w') as f:
  json.dump(val_accuracy, f)
f.close
with open('states/iCaRL_test_accuracy.json', 'w') as f:
  json.dump(test_accuracy, f)
f.close
with open('states/iCaRL_predictions.json', 'w') as f:
  json.dump(predictions, f)
f.close
with open('states/iCaRL_true_labels.json', 'w') as f:
  json.dump(true_labels, f)
f.close
# Out:
# <function TextIOWrapper.close>

# %% [markdown]
# #### Saving best resnet on 100 classes for each seed

# %%
for i in range(len(RANDOM_SEED)):
  torch.save(best_net_tot_classes[i].state_dict(), "states/iCaRL_bestnet_seed[{}]".format(RANDOM_SEED[i]))

# %%
from google.colab import files
files.download('states/iCaRL_train_loss.json')
files.download('states/iCaRL_train_accuracy.json')
files.download('states/iCaRL_val_loss.json')
files.download('states/iCaRL_val_accuracy.json')
files.download('states/iCaRL_test_accuracy.json')
files.download('states/iCaRL_predictions.json')
files.download('states/iCaRL_true_labels.json')
files.download('states/iCaRL_bestnet_seed[13]')

# %% [markdown]
# ### Print some graphs

# %%
from data.utils_plot import plot_train_val, plot_test_accuracies, plot_confusion_matrix

# %%
train_loss = np.array(train_loss)
train_accuracy = np.array(train_accuracy)
val_loss = np.array(val_loss)
val_accuracy = np.array(val_accuracy)
test_accuracy = np.array(test_accuracy)

train_loss_stats = np.array([train_loss.mean(0), train_loss.std(0)]).transpose()
train_accuracy_stats = np.array([train_accuracy.mean(0), train_accuracy.std(0)]).transpose()
val_loss_stats = np.array([val_loss.mean(0), val_loss.std(0)]).transpose()
val_accuracy_stats = np.array([val_accuracy.mean(0), val_accuracy.std(0)]).transpose()
test_accuracy_stats = np.array([test_accuracy.mean(0), test_accuracy.std(0)]).transpose()

# %% [markdown]
# #### Train validation loss

# %%
plot_train_val(train_loss_stats, val_loss_stats, loss = True)

# %% [markdown]
# #### Train validation accuracy

# %%
plot_train_val(train_accuracy_stats, val_accuracy_stats, loss = False)

# %% [markdown]
# #### Test accuracy

# %%
plot_test_accuracies(test_accuracy_stats)

# %% [markdown]
# #### Confusion Matrix

# %%
for run in range(len(RANDOM_SEED)):
  targets = np.array(true_labels[run])
  preds = np.array(predictions[run])

  plot_confusion_matrix(targets, preds, RANDOM_SEED[run], 'iCaRL')
