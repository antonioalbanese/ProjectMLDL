# %% [markdown]
# <a href="https://colab.research.google.com/github/cosminnedescu/ProjectMLDL/blob/main/baselines/owr-v1.0.0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Avoid K80
# !nvidia-smi
# Out:
# Mon Jul  5 18:35:03 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import random

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
from torch.autograd import Variable

import torchvision
from torchvision import transforms, datasets, models
from torch.utils.data import Subset, DataLoader

from PIL import Image

import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
from copy import copy
from copy import deepcopy

# %% [markdown]
# #### Cloning the Git repository

# %%
# !rm -rf ProjectMLDL
if not os.path.isdir('/content/ProjectMLDL'):
  # !git clone https://github.com/antonioalbanese/ProjectMLDL.git
  # %cd /content/ProjectMLDL
  # !rm -rf LICENSE README.md
# Out:
# Cloning into 'ProjectMLDL'...
# remote: Enumerating objects: 1938, done.
# remote: Counting objects: 100% (151/151), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 1938 (delta 127), reused 80 (delta 80), pack-reused 1787
# Receiving objects: 100% (1938/1938), 75.26 MiB | 32.06 MiB/s, done.
# Resolving deltas: 100% (1043/1043), done.
# /content/ProjectMLDL

# %%
from data.cifar100 import CIFAR100
from model.resnet32 import resnet32
import data.utils
from model.OWR import owrIncremental

# %%
# True mean and std of Cifar100 dataset (src="https://gist.github.com/weiaicunzai/e623931921efefd4c331622c344d8151")
mean = [0.5071, 0.4867, 0.4408]
std = [0.2675, 0.2565, 0.2761]

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])
test_transform = transforms.Compose(
    [transforms.ToTensor(), 
     transforms.Normalize(mean, std),
     ])

# %% [markdown]
# ## Incremental Classifier and Representation Learning

# %% [markdown]
# ### Defining hyperparameters according to iCarl paper

# %%
# Settings
DEVICE = 'cuda'
NUM_CLASSES = 100         # Total number of classes
VAL_SIZE = 0.2            # Proportion of validation set with respect to training set (between 0 and 1)

# Training
BATCH_SIZE = 128          # Batch size
LR = 1                    # Initial learning rate
                       
MOMENTUM = 0.9            # Momentum for stochastic gradient descent (SGD)
WEIGHT_DECAY = 1e-5       # Weight decay from iCaRL

RANDOM_SEED = [20,24,66]  # Random seeds defining the runs of every method
                          # Note: this should be at least 3 to have a fair benchmark

NUM_EPOCHS = 70           # Total number of training epochs
MILESTONES = [43, 63]     # Step down policy from iCaRL (MultiStepLR)
                          # Decrease the learning rate by gamma at each milestone
GAMMA = 0.2               # Gamma factor from iCaRL (1/5)

HERDING = False           # True to perform prioritized selection, False to perform random selection
CLASSIFY = True           # True to use mean-of-exemplar classifier, False to use network's output directly for classification

# %%
def do_group_classes(run):

  train_subset = [[] for i in range(10)]
  train_dataloader = [[] for i in range(10)]
  val_dataloader = [[] for i in range(10)]
  test_dataloader = [[] for i in range(10)]

  for i in range(10):
    train_data = CIFAR100("dataset", 
                          train=True, 
                          transform=train_transform, 
                          download=(run+i==0),
                          random_state=RANDOM_SEED[run])
    test_data = CIFAR100("dataset", 
                         train=False, 
                         transform=test_transform, 
                         download=False,
                         random_state=RANDOM_SEED[run])
    
    train_data.set_index_map(train_data.splits[i])
    test_data.set_index_map([test_data.splits[j] for j in range(0, i+1)])
    
    train_indices, val_indices = train_data.train_val_split(VAL_SIZE, RANDOM_SEED[run])
    
    train_subset[i] = copy(Subset(train_data, train_indices))
    val_subset = Subset(train_data, val_indices)

    tmp_dl = DataLoader(val_subset,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    val_dataloader[i] = copy(tmp_dl)

    tmp_dl = DataLoader(test_data,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    test_dataloader[i] = copy(tmp_dl)

  return train_dataloader, val_dataloader, test_dataloader, train_subset

# %% [markdown]
# ### Going on with the model
# This is the main iCaRL step.
#
# This step is run 3 times with different `RANDOM_SEED`.
# Here the model is instantiated, trained and tested.
#
# Results and some statistics are then stored in the variable `logs`.

# %%
logs = [[] for i in range(len(RANDOM_SEED))]
best_net_tot_classes = [None for i in range(len(RANDOM_SEED))]

for run in range(len(RANDOM_SEED)):
  print("#################################")
  print(f"Radom seed: {RANDOM_SEED[run]}")
  print("")

  # get data_subsets separated in incremental groups of 10 classes
  train_dl, val_dl, test_dl, train_set = do_group_classes(run)

  #create the resnet
  net = resnet32()
  
  trainer = owrIncremental(DEVICE,
                  net,
                  LR,
                  MOMENTUM,
                  WEIGHT_DECAY,
                  MILESTONES,
                  GAMMA,
                  train_dl,
                  val_dl,
                  test_dl,
                  BATCH_SIZE,
                  train_set,
                  train_transform,
                  test_transform,
                  True) #test_on_open

  #train and evaluate the model
  logs[run] = trainer.train_model(NUM_EPOCHS)

  best_net_tot_classes[run] = deepcopy(trainer.best_net)

  print("#################################")
  print("")
  print("")
# Out:
# #################################
# Radom seed: 20
#
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to dataset/cifar-100-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=169001437.0), HTML(value='')))
# Extracting dataset/cifar-100-python.tar.gz to dataset
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Length of exemplars set: 0
# Epoch 1/70 LR: [1]
# Validation accuracy on group 1/10: 0.09
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 1/10: 0.11
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 1/10: 0.12
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 1/10: 0.11
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 1/10: 0.12
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 1/10: 0.14
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 1/10: 0.20
# Best model updated
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 1/10: 0.28
# Best model updated
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 1/10: 0.28
# Best model updated
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 1/10: 0.31
# Best model updated
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 1/10: 0.32
# Best model updated
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 1/10: 0.35
# Best model updated
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 1/10: 0.38
# Best model updated
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 1/10: 0.42
# Best model updated
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 1/10: 0.36
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 1/10: 0.40
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 1/10: 0.48
# Best model updated
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 1/10: 0.52
# Best model updated
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 1/10: 0.49
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 1/10: 0.50
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 1/10: 0.54
# Best model updated
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 1/10: 0.50
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 1/10: 0.52
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 1/10: 0.44
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 1/10: 0.59
# Best model updated
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 1/10: 0.61
# Best model updated
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 1/10: 0.55
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 1/10: 0.49
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 1/10: 0.65
# Best model updated
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 1/10: 0.63
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 1/10: 0.61
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 1/10: 0.64
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 1/10: 0.64
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 1/10: 0.63
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 1/10: 0.67
# Best model updated
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 1/10: 0.69
# Best model updated
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 1/10: 0.66
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 1/10: 0.65
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 1/10: 0.69
# Best model updated
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 1/10: 0.68
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 1/10: 0.75
# Best model updated
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 1/10: 0.66
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 1/10: 0.69
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.79
# Best model updated
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.79
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.82
# Best model updated
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.79
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.80
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.80
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.79
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.81
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.81
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.80
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.82
# Best model updated
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.80
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.80
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.79
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.79
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.81
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.82
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.80
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.78
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.80
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/10: 0.82
# Best model updated
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/10: 0.82
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/10: 0.82
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/10: 0.83
# Best model updated
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/10: 0.84
# Best model updated
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/10: 0.83
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/10: 0.82
#
# Group 1 Finished!
# Best accuracy found at epoch 68: 0.84
# Target number of exemplars: 200
# Randomly extracting exemplars from class 0 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 200 exemplars.
# Testing openset: 50 clasess never seen, rejection accuracy: 0.3123991935483871
# 12396 unkown found over 39680 images unkown
#
# =============================================
#
# Length of exemplars set: 2000
# Epoch 1/70 LR: [1]
# Validation accuracy on group 2/10: 0.04
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 2/10: 0.09
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 2/10: 0.17
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 2/10: 0.24
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 2/10: 0.24
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 2/10: 0.25
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 2/10: 0.31
# Best model updated
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 2/10: 0.31
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 2/10: 0.31
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 2/10: 0.36
# Best model updated
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 2/10: 0.31
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 2/10: 0.36
# Best model updated
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 2/10: 0.42
# Best model updated
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 2/10: 0.37
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 2/10: 0.37
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 2/10: 0.41
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 2/10: 0.44
# Best model updated
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 2/10: 0.36
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 2/10: 0.44
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 2/10: 0.45
# Best model updated
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 2/10: 0.45
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 2/10: 0.53
# Best model updated
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 2/10: 0.46
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 2/10: 0.44
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 2/10: 0.47
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 2/10: 0.48
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 2/10: 0.49
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 2/10: 0.46
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 2/10: 0.51
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 2/10: 0.46
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 2/10: 0.51
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 2/10: 0.49
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 2/10: 0.47
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 2/10: 0.55
# Best model updated
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 2/10: 0.46
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 2/10: 0.48
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 2/10: 0.51
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 2/10: 0.52
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 2/10: 0.46
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 2/10: 0.54
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 2/10: 0.51
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 2/10: 0.49
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 2/10: 0.58
# Best model updated
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.58
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.60
# Best model updated
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.60
# Best model updated
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.58
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.58
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.58
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.60
# Best model updated
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.56
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.60
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.60
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.59
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.58
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.59
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.60
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.60
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.60
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.61
# Best model updated
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.61
# Best model updated
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.58
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.59
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/10: 0.60
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/10: 0.57
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/10: 0.59
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/10: 0.59
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/10: 0.60
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/10: 0.60
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/10: 0.60
#
# Group 2 Finished!
# Best accuracy found at epoch 61: 0.61
# Target number of exemplars: 100
# Randomly extracting exemplars from class 0 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 100 exemplars.
# Testing openset: 50 clasess never seen, rejection accuracy: 0.2278477822580645
# 9041 unkown found over 39680 images unkown
#
# =============================================
#
# Length of exemplars set: 2000
# Epoch 1/70 LR: [1]
# Validation accuracy on group 3/10: 0.06
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 3/10: 0.13
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 3/10: 0.14
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 3/10: 0.19
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 3/10: 0.24
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 3/10: 0.26
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 3/10: 0.29
# Best model updated
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 3/10: 0.30
# Best model updated
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 3/10: 0.31
# Best model updated
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 3/10: 0.32
# Best model updated
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 3/10: 0.33
# Best model updated
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 3/10: 0.36
# Best model updated
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 3/10: 0.38
# Best model updated
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 3/10: 0.40
# Best model updated
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 3/10: 0.45
# Best model updated
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 3/10: 0.40
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 3/10: 0.45
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 3/10: 0.45
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 3/10: 0.38
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 3/10: 0.47
# Best model updated
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 3/10: 0.53
# Best model updated
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 3/10: 0.48
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 3/10: 0.49
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 3/10: 0.51
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 3/10: 0.46
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 3/10: 0.47
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 3/10: 0.51
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 3/10: 0.46
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 3/10: 0.52
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 3/10: 0.53
# Best model updated
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 3/10: 0.51
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 3/10: 0.53
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 3/10: 0.52
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 3/10: 0.49
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 3/10: 0.51
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 3/10: 0.54
# Best model updated
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 3/10: 0.48
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 3/10: 0.51
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 3/10: 0.51
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 3/10: 0.52
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 3/10: 0.53
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 3/10: 0.51
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 3/10: 0.54
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.58
# Best model updated
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.56
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.58
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.58
# Best model updated
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.56
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.59
# Best model updated
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.56
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.54
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.58
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.54
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.57
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.61
# Best model updated
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.57
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.56
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.58
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.57
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.58
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.55
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.57
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.57
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.56
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.58
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.58
#
# Group 3 Finished!
# Best accuracy found at epoch 55: 0.61
# Target number of exemplars: 66
# Randomly extracting exemplars from class 0 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 66 exemplars.
# Testing openset: 50 clasess never seen, rejection accuracy: 0.19475806451612904
# 7728 unkown found over 39680 images unkown
#
# =============================================
#
# Length of exemplars set: 1980
# Epoch 1/70 LR: [1]
# Validation accuracy on group 4/10: 0.09
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 4/10: 0.18
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 4/10: 0.19
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 4/10: 0.22
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 4/10: 0.27
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 4/10: 0.28
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 4/10: 0.30
# Best model updated
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 4/10: 0.29
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 4/10: 0.31
# Best model updated
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 4/10: 0.34
# Best model updated
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 4/10: 0.33
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 4/10: 0.36
# Best model updated
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 4/10: 0.34
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 4/10: 0.38
# Best model updated
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 4/10: 0.39
# Best model updated
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 4/10: 0.40
# Best model updated
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 4/10: 0.39
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 4/10: 0.41
# Best model updated
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 4/10: 0.36
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 4/10: 0.43
# Best model updated
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 4/10: 0.45
# Best model updated
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 4/10: 0.42
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 4/10: 0.44
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 4/10: 0.41
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 4/10: 0.43
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 4/10: 0.48
# Best model updated
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 4/10: 0.44
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 4/10: 0.47
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 4/10: 0.45
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 4/10: 0.49
# Best model updated
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 4/10: 0.46
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 4/10: 0.48
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 4/10: 0.50
# Best model updated
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 4/10: 0.46
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 4/10: 0.45
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 4/10: 0.48
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 4/10: 0.49
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 4/10: 0.49
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 4/10: 0.50
# Best model updated
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 4/10: 0.51
# Best model updated
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 4/10: 0.49
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 4/10: 0.53
# Best model updated
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 4/10: 0.51
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.53
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.52
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.50
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.52
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.51
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.52
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.51
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.51
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.52
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.50
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.50
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.51
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.52
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.52
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.49
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.51
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.54
# Best model updated
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.51
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.54
# Best model updated
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.52
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/10: 0.53
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/10: 0.51
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/10: 0.52
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/10: 0.54
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/10: 0.53
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/10: 0.52
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/10: 0.52
#
# Group 4 Finished!
# Best accuracy found at epoch 62: 0.54
# Target number of exemplars: 50
# Randomly extracting exemplars from class 0 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 50 exemplars.
# Testing openset: 50 clasess never seen, rejection accuracy: 0.17983870967741936
# 7136 unkown found over 39680 images unkown
#
# =============================================
#
# Length of exemplars set: 2000
# Epoch 1/70 LR: [1]
# Validation accuracy on group 5/10: 0.23
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 5/10: 0.32
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 5/10: 0.32
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 5/10: 0.31
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 5/10: 0.36
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 5/10: 0.41
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 5/10: 0.37
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 5/10: 0.38
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 5/10: 0.38
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 5/10: 0.40
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 5/10: 0.43
# Best model updated
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 5/10: 0.41
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 5/10: 0.43
# Best model updated
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 5/10: 0.44
# Best model updated
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 5/10: 0.46
# Best model updated
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 5/10: 0.43
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 5/10: 0.49
# Best model updated
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 5/10: 0.48
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 5/10: 0.52
# Best model updated
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 5/10: 0.51
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 5/10: 0.50
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 5/10: 0.50
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 5/10: 0.47
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 5/10: 0.52
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 5/10: 0.52
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 5/10: 0.50
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 5/10: 0.53
# Best model updated
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 5/10: 0.50
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 5/10: 0.52
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 5/10: 0.55
# Best model updated
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 5/10: 0.55
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 5/10: 0.56
# Best model updated
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 5/10: 0.55
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 5/10: 0.56
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 5/10: 0.51
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 5/10: 0.54
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 5/10: 0.53
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 5/10: 0.50
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 5/10: 0.56
# Best model updated
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 5/10: 0.54
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 5/10: 0.55
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 5/10: 0.55
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 5/10: 0.55
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.56
# Best model updated
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.58
# Best model updated
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.59
# Best model updated
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.58
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.60
# Best model updated
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.56
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.58
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.58
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.56
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.57
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.57
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.58
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.59
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.58
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.57
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.58
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.56
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.57
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.58
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.58
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/10: 0.58
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/10: 0.56
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/10: 0.56
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/10: 0.59
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/10: 0.59
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/10: 0.58
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/10: 0.57
#
# Group 5 Finished!
# Best accuracy found at epoch 48: 0.60
# Target number of exemplars: 40
# Randomly extracting exemplars from class 0 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 40 exemplars.
# Testing openset: 50 clasess never seen, rejection accuracy: 0.18190524193548388
# 7218 unkown found over 39680 images unkown
#
# =============================================
#
# #################################
#
#
# #################################
# Radom seed: 24
#
# Length of exemplars set: 0
# Epoch 1/70 LR: [1]
# Validation accuracy on group 1/10: 0.13
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 1/10: 0.13
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 1/10: 0.15
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 1/10: 0.17
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 1/10: 0.17
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 1/10: 0.19
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 1/10: 0.24
# Best model updated
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 1/10: 0.28
# Best model updated
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 1/10: 0.30
# Best model updated
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 1/10: 0.29
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 1/10: 0.40
# Best model updated
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 1/10: 0.44
# Best model updated
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 1/10: 0.43
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 1/10: 0.40
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 1/10: 0.49
# Best model updated
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 1/10: 0.57
# Best model updated
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 1/10: 0.55
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 1/10: 0.59
# Best model updated
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 1/10: 0.55
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 1/10: 0.58
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 1/10: 0.61
# Best model updated
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 1/10: 0.57
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 1/10: 0.62
# Best model updated
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 1/10: 0.59
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 1/10: 0.64
# Best model updated
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 1/10: 0.64
# Best model updated
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 1/10: 0.64
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 1/10: 0.64
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 1/10: 0.68
# Best model updated
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 1/10: 0.70
# Best model updated
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 1/10: 0.72
# Best model updated
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 1/10: 0.69
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 1/10: 0.74
# Best model updated
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 1/10: 0.71
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 1/10: 0.67
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 1/10: 0.74
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 1/10: 0.75
# Best model updated
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 1/10: 0.64
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 1/10: 0.77
# Best model updated
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 1/10: 0.71
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 1/10: 0.67
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 1/10: 0.74
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 1/10: 0.72
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.82
# Best model updated
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.84
# Best model updated
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.84
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.85
# Best model updated
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.84
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.83
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.84
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.85
# Best model updated
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.84
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.82
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.84
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.84
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.83
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.84
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.83
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.82
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.84
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.83
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.83
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 1/10: 0.84
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/10: 0.85
# Best model updated
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/10: 0.84
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/10: 0.85
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/10: 0.85
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/10: 0.86
# Best model updated
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/10: 0.85
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/10: 0.86
#
# Group 1 Finished!
# Best accuracy found at epoch 68: 0.86
# Target number of exemplars: 200
# Randomly extracting exemplars from class 0 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 200 exemplars.
# Testing openset: 50 clasess never seen, rejection accuracy: 0.3121471774193548
# 12386 unkown found over 39680 images unkown
#
# =============================================
#
# Length of exemplars set: 2000
# Epoch 1/70 LR: [1]
# Validation accuracy on group 2/10: 0.08
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 2/10: 0.11
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 2/10: 0.21
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 2/10: 0.29
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 2/10: 0.31
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 2/10: 0.33
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 2/10: 0.36
# Best model updated
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 2/10: 0.39
# Best model updated
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 2/10: 0.43
# Best model updated
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 2/10: 0.38
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 2/10: 0.46
# Best model updated
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 2/10: 0.44
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 2/10: 0.48
# Best model updated
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 2/10: 0.47
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 2/10: 0.46
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 2/10: 0.52
# Best model updated
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 2/10: 0.45
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 2/10: 0.52
# Best model updated
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 2/10: 0.56
# Best model updated
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 2/10: 0.51
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 2/10: 0.45
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 2/10: 0.55
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 2/10: 0.60
# Best model updated
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 2/10: 0.55
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 2/10: 0.55
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 2/10: 0.54
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 2/10: 0.57
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 2/10: 0.56
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 2/10: 0.51
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 2/10: 0.63
# Best model updated
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 2/10: 0.61
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 2/10: 0.61
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 2/10: 0.56
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 2/10: 0.56
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 2/10: 0.59
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 2/10: 0.59
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 2/10: 0.64
# Best model updated
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 2/10: 0.61
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 2/10: 0.62
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 2/10: 0.57
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 2/10: 0.52
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 2/10: 0.59
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 2/10: 0.59
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.65
# Best model updated
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.66
# Best model updated
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.65
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.67
# Best model updated
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.64
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.67
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.66
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.64
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.65
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.64
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.65
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.66
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.66
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.66
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.65
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.65
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.64
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.67
# Best model updated
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.64
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 2/10: 0.64
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/10: 0.66
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/10: 0.65
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/10: 0.65
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/10: 0.65
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/10: 0.64
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/10: 0.66
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/10: 0.65
#
# Group 2 Finished!
# Best accuracy found at epoch 61: 0.67
# Target number of exemplars: 100
# Randomly extracting exemplars from class 0 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 100 exemplars.
# Testing openset: 50 clasess never seen, rejection accuracy: 0.21315524193548388
# 8458 unkown found over 39680 images unkown
#
# =============================================
#
# Length of exemplars set: 2000
# Epoch 1/70 LR: [1]
# Validation accuracy on group 3/10: 0.03
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 3/10: 0.15
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 3/10: 0.20
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 3/10: 0.21
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 3/10: 0.30
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 3/10: 0.31
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 3/10: 0.34
# Best model updated
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 3/10: 0.35
# Best model updated
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 3/10: 0.32
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 3/10: 0.39
# Best model updated
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 3/10: 0.44
# Best model updated
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 3/10: 0.43
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 3/10: 0.43
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 3/10: 0.44
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 3/10: 0.46
# Best model updated
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 3/10: 0.42
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 3/10: 0.48
# Best model updated
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 3/10: 0.44
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 3/10: 0.49
# Best model updated
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 3/10: 0.52
# Best model updated
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 3/10: 0.46
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 3/10: 0.46
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 3/10: 0.51
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 3/10: 0.55
# Best model updated
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 3/10: 0.53
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 3/10: 0.49
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 3/10: 0.54
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 3/10: 0.50
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 3/10: 0.55
# Best model updated
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 3/10: 0.55
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 3/10: 0.54
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 3/10: 0.50
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 3/10: 0.47
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 3/10: 0.48
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 3/10: 0.55
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 3/10: 0.52
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 3/10: 0.57
# Best model updated
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 3/10: 0.55
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 3/10: 0.55
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 3/10: 0.55
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 3/10: 0.50
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 3/10: 0.54
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 3/10: 0.57
# Best model updated
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.59
# Best model updated
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.57
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.57
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.58
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.61
# Best model updated
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.57
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.57
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.58
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.57
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.57
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.58
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.58
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.57
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.58
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.57
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.61
# Best model updated
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.57
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.59
#
# Group 3 Finished!
# Best accuracy found at epoch 65: 0.61
# ...
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 3/10: 0.55
# Best model updated
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 3/10: 0.57
# Best model updated
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 3/10: 0.53
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 3/10: 0.54
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 3/10: 0.54
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 3/10: 0.53
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 3/10: 0.55
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 3/10: 0.55
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 3/10: 0.53
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 3/10: 0.55
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 3/10: 0.56
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 3/10: 0.55
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 3/10: 0.57
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 3/10: 0.58
# Best model updated
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 3/10: 0.60
# Best model updated
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.58
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.61
# Best model updated
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.58
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.57
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.62
# Best model updated
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.58
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.58
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.61
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.57
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.58
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.62
# Best model updated
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/10: 0.59
#
# Group 3 Finished!
# Best accuracy found at epoch 68: 0.62
# Target number of exemplars: 66
# Randomly extracting exemplars from class 0 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 66 exemplars.
# Testing openset: 50 clasess never seen, rejection accuracy: 0.1892641129032258
# 7510 unkown found over 39680 images unkown
#
# =============================================
#
# Length of exemplars set: 1980
# Epoch 1/70 LR: [1]
# Validation accuracy on group 4/10: 0.05
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 4/10: 0.11
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 4/10: 0.13
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 4/10: 0.17
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 4/10: 0.21
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 4/10: 0.20
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 4/10: 0.22
# Best model updated
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 4/10: 0.22
# Best model updated
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 4/10: 0.27
# Best model updated
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 4/10: 0.29
# Best model updated
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 4/10: 0.27
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 4/10: 0.29
# Best model updated
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 4/10: 0.32
# Best model updated
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 4/10: 0.27
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 4/10: 0.31
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 4/10: 0.37
# Best model updated
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 4/10: 0.35
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 4/10: 0.34
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 4/10: 0.35
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 4/10: 0.37
# Best model updated
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 4/10: 0.34
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 4/10: 0.38
# Best model updated
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 4/10: 0.36
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 4/10: 0.39
# Best model updated
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 4/10: 0.39
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 4/10: 0.36
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 4/10: 0.39
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 4/10: 0.41
# Best model updated
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 4/10: 0.37
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 4/10: 0.41
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 4/10: 0.45
# Best model updated
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 4/10: 0.41
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 4/10: 0.39
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 4/10: 0.45
# Best model updated
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 4/10: 0.36
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 4/10: 0.46
# Best model updated
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 4/10: 0.45
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 4/10: 0.44
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 4/10: 0.43
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 4/10: 0.42
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 4/10: 0.44
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 4/10: 0.41
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 4/10: 0.48
# Best model updated
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.47
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.47
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.48
# Best model updated
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.45
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.48
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.47
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.48
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.48
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.46
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.47
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.50
# Best model updated
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.47
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.48
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.48
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.45
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.49
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.50
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.50
# Best model updated
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.48
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 4/10: 0.50
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/10: 0.48
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/10: 0.47
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/10: 0.49
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/10: 0.46
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/10: 0.46
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/10: 0.49
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/10: 0.47
#
# Group 4 Finished!
# Best accuracy found at epoch 61: 0.50
# Target number of exemplars: 50
# Randomly extracting exemplars from class 0 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 50 exemplars.
# Testing openset: 50 clasess never seen, rejection accuracy: 0.20070564516129033
# 7964 unkown found over 39680 images unkown
#
# =============================================
#
# Length of exemplars set: 2000
# Epoch 1/70 LR: [1]
# Validation accuracy on group 5/10: 0.09
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 5/10: 0.18
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 5/10: 0.20
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 5/10: 0.22
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 5/10: 0.25
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 5/10: 0.25
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 5/10: 0.30
# Best model updated
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 5/10: 0.34
# Best model updated
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 5/10: 0.31
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 5/10: 0.33
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 5/10: 0.34
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 5/10: 0.34
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 5/10: 0.36
# Best model updated
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 5/10: 0.37
# Best model updated
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 5/10: 0.43
# Best model updated
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 5/10: 0.38
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 5/10: 0.40
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 5/10: 0.42
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 5/10: 0.41
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 5/10: 0.42
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 5/10: 0.41
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 5/10: 0.43
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 5/10: 0.41
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 5/10: 0.43
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 5/10: 0.46
# Best model updated
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 5/10: 0.44
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 5/10: 0.45
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 5/10: 0.45
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 5/10: 0.46
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 5/10: 0.46
# Best model updated
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 5/10: 0.47
# Best model updated
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 5/10: 0.46
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 5/10: 0.48
# Best model updated
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 5/10: 0.48
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 5/10: 0.51
# Best model updated
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 5/10: 0.46
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 5/10: 0.47
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 5/10: 0.49
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 5/10: 0.48
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 5/10: 0.49
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 5/10: 0.48
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 5/10: 0.51
# Best model updated
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 5/10: 0.49
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.52
# Best model updated
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.52
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.50
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.52
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.51
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.51
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.52
# Best model updated
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.50
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.53
# Best model updated
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.51
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.52
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.51
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.52
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.52
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.51
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.51
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.52
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.52
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.51
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 5/10: 0.51
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/10: 0.53
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/10: 0.52
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/10: 0.52
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/10: 0.51
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/10: 0.51
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/10: 0.50
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/10: 0.52
#
# Group 5 Finished!
# Best accuracy found at epoch 52: 0.53
# Target number of exemplars: 40
# Randomly extracting exemplars from class 0 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 40 exemplars.
# Testing openset: 50 clasess never seen, rejection accuracy: 0.1891381048387097
# 7505 unkown found over 39680 images unkown
#
# =============================================
#
# #################################

# %% [markdown]
# ### Store logs in more usable dtype

# %%
train_loss = [[logs[run_i]['group_train_loss'][i] for i in range(5)] for run_i in range(len(RANDOM_SEED))]
train_accuracy = [[logs[run_i]['group_train_accuracies'][i] for i in range(5)] for run_i in range(len(RANDOM_SEED))]
val_loss = [[logs[run_i]['val_losses'][i] for i in range(5)] for run_i in range(len(RANDOM_SEED))]
val_accuracy = [[logs[run_i]['val_accuracies'][i] for i in range(5)] for run_i in range(len(RANDOM_SEED))]
test_accuracy = [[logs[run_i]['test_accuracies'][i] for i in range(5)] for run_i in range(len(RANDOM_SEED))]
predictions = [logs[run_i]['predictions'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]
true_labels = [logs[run_i]['true_labels'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]

# %% [markdown]
# ### Save the model

# %% [markdown]
# #### Saving logs in JSON files

# %%
import json

with open('states/reject_train_loss.json', 'w') as f:
  json.dump(train_loss, f)
f.close
with open('states/reject_train_accuracy.json', 'w') as f:
  json.dump(train_accuracy, f)
f.close
with open('states/reject_val_loss.json', 'w') as f:
  json.dump(val_loss, f)
f.close  
with open('states/reject_val_accuracy.json', 'w') as f:
  json.dump(val_accuracy, f)
f.close
with open('states/reject_test_accuracy.json', 'w') as f:
  json.dump(test_accuracy, f)
f.close
with open('states/reject_predictions.json', 'w') as f:
  json.dump(predictions, f)
f.close
with open('states/reject_true_labels.json', 'w') as f:
  json.dump(true_labels, f)
f.close
# Out:
# <function TextIOWrapper.close>

# %% [markdown]
# #### Saving best resnet on 100 classes for each seed

# %%
for i in range(len(RANDOM_SEED)):
  torch.save(best_net_tot_classes[i].state_dict(), "states/reject_bestnet_seed[{}]".format(RANDOM_SEED[i]))

# %%
from google.colab import files
files.download('states/reject_train_loss.json')
files.download('states/reject_train_accuracy.json')
files.download('states/reject_val_loss.json')
files.download('states/reject_val_accuracy.json')
files.download('states/reject_test_accuracy.json')
files.download('states/reject_predictions.json')
files.download('states/reject_true_labels.json')
files.download('states/reject_bestnet_seed[24]')
files.download('states/reject_bestnet_seed[20]')
files.download('states/reject_bestnet_seed[66]')

# %% [markdown]
# ### Print some graphs

# %%
from data.utils_plot import plot_train_val, plot_test_accuracies, plot_confusion_matrix

# %%
train_loss = np.array(train_loss)
train_accuracy = np.array(train_accuracy)
val_loss = np.array(val_loss)
val_accuracy = np.array(val_accuracy)
test_accuracy = np.array(test_accuracy)



train_loss_stats = np.array([train_loss.mean(0), train_loss.std(0)]).transpose()
train_accuracy_stats = np.array([train_accuracy.mean(0), train_accuracy.std(0)]).transpose()
val_loss_stats = np.array([val_loss.mean(0), val_loss.std(0)]).transpose()
val_accuracy_stats = np.array([val_accuracy.mean(0), val_accuracy.std(0)]).transpose()
test_accuracy_stats = np.array([test_accuracy.mean(0), test_accuracy.std(0)]).transpose()

# %% [markdown]
# #### Train validation loss

# %%
def plot_losses(train_stats, val_stats, loss = bool, save_directory = None):
  train_mean = np.array(train_stats)[:, 0]
  train_std = np.array(train_stats)[:, 1]
  val_mean = np.array(val_stats)[:, 0]
  val_std = np.array(val_stats)[:, 1]
  fig, ax = plt.subplots(figsize = (10, 5), dpi = 100)
  x = np.arange(10,51,10)
  ax.errorbar(x, train_mean, train_std, label = 'Training')
  ax.errorbar(x, val_mean, val_std, label = 'Validation')
  if loss:
    ax.set_title("Training and validation loss")
    ax.set_ylabel("Loss")
  else:
    ax.set_title("Training and validation accuracy")
    ax.set_ylabel("Accuracy")
  ax.set_xlabel("Number of classes")
  plt.tight_layout()
  ax.legend()
  if save_directory != None:
    fig.savefig(save_directory)
  plt.show()

plot_losses(train_loss_stats, val_loss_stats, loss = True)

# %% [markdown]
# #### Train validation accuracy

# %%
def plot_acc(train_stats, val_stats, loss = bool, save_directory = None):
  train_mean = np.array(train_stats)[:, 0]
  train_std = np.array(train_stats)[:, 1]
  val_mean = np.array(val_stats)[:, 0]
  val_std = np.array(val_stats)[:, 1]
  fig, ax = plt.subplots(figsize = (10, 5), dpi = 100)
  x = np.arange(10, 51, 10)
  ax.errorbar(x, train_mean, train_std, label = 'Training')
  ax.errorbar(x, val_mean, val_std, label = 'Validation')
  if loss:
    ax.set_title("Training and validation loss")
    ax.set_ylabel("Loss")
  else:
    ax.set_title("Training and validation accuracy")
    ax.set_ylabel("Accuracy")
  ax.set_xlabel("Number of classes")
  plt.tight_layout()
  ax.legend()
  if save_directory != None:
    fig.savefig(save_directory)
  plt.show()

plot_acc(train_accuracy_stats, val_accuracy_stats, loss = False)

# %% [markdown]
# #### Test accuracy

# %%
def plot_test(stats, save_directory = None):
  mean = np.array(stats)[:, 0]
  std = np.array(stats)[:, 1]
  fig, ax = plt.subplots(figsize = (10, 5), dpi = 100)
  x = np.arange(10, 51, 10)
  ax.errorbar(x, mean, std)
  ax.set_title("Test accuracy")
  ax.set_xlabel("Number of classes")
  ax.set_ylabel("Accuracy")
  plt.tight_layout()
  if save_directory != None:
    fig.savefig(save_directory)
  plt.show()
  
plot_test(test_accuracy_stats)

# %% [markdown]
# #### Confusion Matrix

# %%
for run in range(len(RANDOM_SEED)):
  targets = np.array(true_labels[run])
  preds = np.array(predictions[run])

  plot_confusion_matrix(targets, preds, RANDOM_SEED[run], 'iCaRL')
