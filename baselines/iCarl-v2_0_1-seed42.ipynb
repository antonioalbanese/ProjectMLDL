# %% [markdown]
# <a href="https://colab.research.google.com/github/cosminnedescu/ProjectMLDL/blob/main/baselines/iCarl-v2_0_1-seed42.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import random

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable

import torchvision
from torchvision import transforms, datasets, models
from torch.utils.data import Subset, DataLoader

from PIL import Image

import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
from copy import copy
from copy import deepcopy

# %% [markdown]
# #### Cloning the Git repository

# %%
# !rm -rf ProjectMLDL
if not os.path.isdir('/content/ProjectMLDL'):
  # !git clone https://github.com/antonioalbanese/ProjectMLDL.git
  # %cd /content/ProjectMLDL
  # !rm -rf LICENSE README.md
# Out:
# Cloning into 'ProjectMLDL'...
# remote: Enumerating objects: 1474, done.
# remote: Counting objects: 100% (204/204), done.
# remote: Compressing objects: 100% (142/142), done.
# remote: Total 1474 (delta 162), reused 62 (delta 62), pack-reused 1270
# Receiving objects: 100% (1474/1474), 24.06 MiB | 22.33 MiB/s, done.
# Resolving deltas: 100% (888/888), done.
# /content/ProjectMLDL

# %%
from data.cifar100 import CIFAR100
from model.resnet32 import resnet32
import data.utils
from model.icarl import icarl

# %% [markdown]
# #### Downloading data from Cifar100

# %%
# True mean and std of Cifar100 dataset (src="https://gist.github.com/weiaicunzai/e623931921efefd4c331622c344d8151")
mean = [0.5071, 0.4867, 0.4408]
std = [0.2675, 0.2565, 0.2761]

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])
test_transform = transforms.Compose(
    [transforms.ToTensor(), 
     transforms.Normalize(mean, std),
     ])

# %%
train_data = CIFAR100("dataset", train=True, transform=train_transform, download=True)
test_data = CIFAR100("dataset", train=False, transform=test_transform, download=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to dataset/cifar-100-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting dataset/cifar-100-python.tar.gz to dataset
# Files already downloaded and verified

# %%
#check images and labels after shuffle
#https://github.com/keras-team/keras/issues/2653#issuecomment-450133996
import matplotlib.pyplot as plt

plt.imshow(train_data.data[6])
print("classe: {}".format(train_data.targets[6]))
# Out:
# classe: 90

# %% [markdown]
# ## Learning Without Forgetting

# %% [markdown]
# ### Defining hyperparameters according to iCarl paper

# %%
# Settings
DEVICE = 'cuda'
NUM_CLASSES = 100         # Total number of classes
VAL_SIZE = 0.2            # Proportion of validation set with respect to training set (between 0 and 1)

# Training
BATCH_SIZE = 128          # Batch size
LR = 2                    # Initial learning rate
                       
MOMENTUM = 0.9            # Momentum for stochastic gradient descent (SGD)
WEIGHT_DECAY = 1e-5       # Weight decay from iCaRL

RANDOM_SEED = [42]  # Random seeds defining the runs of every method
                          # Note: this should be at least 3 to have a fair benchmark

NUM_EPOCHS = 70           # Total number of training epochs
MILESTONES = [49, 63]     # Step down policy from iCaRL (MultiStepLR)
                          # Decrease the learning rate by gamma at each milestone
GAMMA = 0.2               # Gamma factor from iCaRL (1/5)

# %% [markdown]
# ### Definition of `do_shuffle` and `do_group_classes`
# `do_shuffle` and `do_group_classes` are two functions that rispectively shuffle data downloaded from Cifar100 and get the incremental classes division for the incremental learning phase.

# %%
def do_shuffle(train_d, test_d):
  train_d.__shuffle_seed__(RANDOM_SEED[run])
  test_d.__shuffle_seed__(RANDOM_SEED[run])
  return train_d, test_d

def do_group_classes(train_d, test_d):
  indexes_train_data = train_d.__incremental_indexes__(True)
  indexes_test_data = test_d.__incremental_indexes__(False)


  train_dataloader = [[] for i in range(10)]
  val_dataloader = [[] for i in range(10)]
  test_dataloader = [[] for i in range(10)]
  for i in range(10):
    train_dataset = Subset(train_d, indexes_train_data[i])
    train_set, val_set = torch.utils.data.random_split(train_dataset, 
                                                       [int((1-VAL_SIZE)*len(indexes_train_data[i])), int(VAL_SIZE*len(indexes_train_data[i]))])
    tmp_dl = DataLoader(train_set, 
                        batch_size=BATCH_SIZE,
                        shuffle=True,
                        num_workers=4,
                        drop_last=True)
    train_dataloader[i] = copy(tmp_dl) # gruppi di 10 classi 
    tmp_dl = DataLoader(val_set, 
                        batch_size=BATCH_SIZE,
                        shuffle=True,
                        num_workers=4,
                        drop_last=True)
    val_dataloader[i] = copy(tmp_dl) # gruppi di 10 classi


    test_dataset = Subset(test_d, indexes_test_data[i])
    tmp_dl = DataLoader(test_dataset,
                        batch_size=BATCH_SIZE,
                        shuffle=True,
                        num_workers=4,
                        drop_last=True)
    test_dataloader[i] = copy(tmp_dl) # classi incrementali: 0:0-9, 1:0-19, 2:0-29, ..., 9:0-99
    
  return train_dataloader, val_dataloader, test_dataloader

# %% [markdown]
# ### Going on with the model
# This is the main LWF step.
#
# This step is run 3 times with different `RANDOM_SEED`.
# Here the model is instantiated, trained and tested.
#
# Results and some statistics are then stored in the variable `logs`.

# %%
logs = [[] for i in range(len(RANDOM_SEED))]
best_net_tot_classes = [None for i in range(len(RANDOM_SEED))]


for run in range(len(RANDOM_SEED)):
  random.seed(RANDOM_SEED[run])
  print("#################################")
  print(f"Radom seed: {RANDOM_SEED[run]}")
  print("")

  K = 2000 #tot number of exemplars

  #shuffle data
  train_data, test_data = do_shuffle(train_data, test_data)
  #get dataloader separated in incremental groups of 10 classes
  train_dl, val_dl, test_dl = do_group_classes(train_data, test_data)

  #create the resnet
  net = resnet32()

  #define criterion, parameters, optimizer and scheduler
  criterion = nn.BCEWithLogitsLoss()
  parameters_to_optimize = net.parameters()
  optimizer = optim.SGD(parameters_to_optimize, 
                        lr=LR, 
                        momentum=MOMENTUM, 
                        weight_decay=WEIGHT_DECAY)
  scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
                                             milestones=MILESTONES, 
                                             gamma=GAMMA)
  
  trainer = icarl(DEVICE,
                  net,
                  LR,
                  MOMENTUM,
                  WEIGHT_DECAY,
                  MILESTONES,
                  GAMMA,
                  train_dl,
                  val_dl,
                  test_dl,
                  K)

  #train and evaluate the model
  logs[run] = trainer.train_model(NUM_EPOCHS)

  best_net_tot_classes[run] = deepcopy(trainer.best_net)

  print("#################################")
  print("")
  print("")
# Out:
# #################################
# Radom seed: 42
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch 1/70 LR: [2]
# Epoch loss: 0.4177216839405798
# Randomly extracting exemplars from class 0 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 200 exemplars.
# Calculating mean of exemplars
# tot corrects:  111
# Validation accuracy on group 1/10: 0.12
# Best model updated
#
# Epoch 2/70 LR: [2]
# Epoch loss: 0.32439426883407263
# Calculating mean of exemplars
# tot corrects:  108
# Validation accuracy on group 1/10: 0.12
#
# Epoch 3/70 LR: [2]
# Epoch loss: 0.32205397538516833
# Calculating mean of exemplars
# tot corrects:  99
# Validation accuracy on group 1/10: 0.11
#
# Epoch 4/70 LR: [2]
# Epoch loss: 0.321018912869951
# Calculating mean of exemplars
# tot corrects:  103
# Validation accuracy on group 1/10: 0.11
#
# Epoch 5/70 LR: [2]
# Epoch loss: 0.31853407945321954
# Calculating mean of exemplars
# tot corrects:  95
# Validation accuracy on group 1/10: 0.11
#
# Epoch 6/70 LR: [2]
# Epoch loss: 0.31482106512007507
# Calculating mean of exemplars
# tot corrects:  102
# Validation accuracy on group 1/10: 0.11
#
# Epoch 7/70 LR: [2]
# Epoch loss: 0.30975573931051337
# Calculating mean of exemplars
# tot corrects:  133
# Validation accuracy on group 1/10: 0.15
# Best model updated
#
# Epoch 8/70 LR: [2]
# Epoch loss: 0.3046479853598968
# Calculating mean of exemplars
# tot corrects:  161
# Validation accuracy on group 1/10: 0.18
# Best model updated
#
# Epoch 9/70 LR: [2]
# Epoch loss: 0.29297955334186554
# Calculating mean of exemplars
# tot corrects:  205
# Validation accuracy on group 1/10: 0.23
# Best model updated
#
# Epoch 10/70 LR: [2]
# Epoch loss: 0.2833631932735443
# Calculating mean of exemplars
# tot corrects:  216
# Validation accuracy on group 1/10: 0.24
# Best model updated
#
# Epoch 11/70 LR: [2]
# Epoch loss: 0.27014303920061694
# Calculating mean of exemplars
# tot corrects:  243
# Validation accuracy on group 1/10: 0.27
# Best model updated
#
# Epoch 12/70 LR: [2]
# Epoch loss: 0.26526828563731647
# Calculating mean of exemplars
# tot corrects:  199
# Validation accuracy on group 1/10: 0.22
#
# Epoch 13/70 LR: [2]
# Epoch loss: 0.25380433383195294
# Calculating mean of exemplars
# tot corrects:  242
# Validation accuracy on group 1/10: 0.27
#
# Epoch 14/70 LR: [2]
# Epoch loss: 0.2417958475973295
# Calculating mean of exemplars
# tot corrects:  328
# Validation accuracy on group 1/10: 0.37
# Best model updated
#
# Epoch 15/70 LR: [2]
# Epoch loss: 0.22937640256207922
# Calculating mean of exemplars
# tot corrects:  265
# Validation accuracy on group 1/10: 0.30
#
# Epoch 16/70 LR: [2]
# Epoch loss: 0.21726496906384177
# Calculating mean of exemplars
# tot corrects:  273
# Validation accuracy on group 1/10: 0.30
#
# Epoch 17/70 LR: [2]
# Epoch loss: 0.20603820875934933
# Calculating mean of exemplars
# tot corrects:  289
# Validation accuracy on group 1/10: 0.32
#
# Epoch 18/70 LR: [2]
# Epoch loss: 0.1992288066641144
# Calculating mean of exemplars
# tot corrects:  321
# Validation accuracy on group 1/10: 0.36
#
# Epoch 19/70 LR: [2]
# Epoch loss: 0.19486875475748724
# Calculating mean of exemplars
# tot corrects:  350
# Validation accuracy on group 1/10: 0.39
# Best model updated
#
# Epoch 20/70 LR: [2]
# Epoch loss: 0.18580549404672955
# Calculating mean of exemplars
# tot corrects:  307
# Validation accuracy on group 1/10: 0.34
#
# Epoch 21/70 LR: [2]
# Epoch loss: 0.17347708085308905
# Calculating mean of exemplars
# tot corrects:  375
# Validation accuracy on group 1/10: 0.42
# Best model updated
#
# Epoch 22/70 LR: [2]
# Epoch loss: 0.1669818137003028
# Calculating mean of exemplars
# tot corrects:  417
# Validation accuracy on group 1/10: 0.47
# Best model updated
#
# Epoch 23/70 LR: [2]
# Epoch loss: 0.16085059649270514
# Calculating mean of exemplars
# tot corrects:  394
# Validation accuracy on group 1/10: 0.44
#
# Epoch 24/70 LR: [2]
# Epoch loss: 0.15428418487958287
# Calculating mean of exemplars
# tot corrects:  356
# Validation accuracy on group 1/10: 0.40
#
# Epoch 25/70 LR: [2]
# Epoch loss: 0.14710667729377747
# Calculating mean of exemplars
# tot corrects:  420
# Validation accuracy on group 1/10: 0.47
# Best model updated
#
# Epoch 26/70 LR: [2]
# Epoch loss: 0.13990501006660255
# Calculating mean of exemplars
# tot corrects:  455
# Validation accuracy on group 1/10: 0.51
# Best model updated
#
# Epoch 27/70 LR: [2]
# Epoch loss: 0.13491175631466118
# Calculating mean of exemplars
# tot corrects:  453
# Validation accuracy on group 1/10: 0.51
#
# Epoch 28/70 LR: [2]
# Epoch loss: 0.12993931252023447
# Calculating mean of exemplars
# tot corrects:  489
# Validation accuracy on group 1/10: 0.55
# Best model updated
#
# Epoch 29/70 LR: [2]
# Epoch loss: 0.12266971187099167
# Calculating mean of exemplars
# tot corrects:  350
# Validation accuracy on group 1/10: 0.39
#
# Epoch 30/70 LR: [2]
# Epoch loss: 0.11671195454571558
# Calculating mean of exemplars
# tot corrects:  500
# Validation accuracy on group 1/10: 0.56
# Best model updated
#
# Epoch 31/70 LR: [2]
# Epoch loss: 0.11161445081233978
# Calculating mean of exemplars
# tot corrects:  435
# Validation accuracy on group 1/10: 0.49
#
# Epoch 32/70 LR: [2]
# Epoch loss: 0.11103645987484766
# Calculating mean of exemplars
# tot corrects:  470
# Validation accuracy on group 1/10: 0.52
#
# Epoch 33/70 LR: [2]
# Epoch loss: 0.10737232183632643
# Calculating mean of exemplars
# tot corrects:  462
# Validation accuracy on group 1/10: 0.52
#
# Epoch 34/70 LR: [2]
# Epoch loss: 0.09893161722499391
# Calculating mean of exemplars
# tot corrects:  488
# Validation accuracy on group 1/10: 0.54
#
# Epoch 35/70 LR: [2]
# Epoch loss: 0.09724767246971959
# Calculating mean of exemplars
# tot corrects:  527
# Validation accuracy on group 1/10: 0.59
# Best model updated
#
# Epoch 36/70 LR: [2]
# Epoch loss: 0.09763356913690982
# Calculating mean of exemplars
# tot corrects:  558
# Validation accuracy on group 1/10: 0.62
# Best model updated
#
# Epoch 37/70 LR: [2]
# Epoch loss: 0.08616419128425744
# Calculating mean of exemplars
# tot corrects:  509
# Validation accuracy on group 1/10: 0.57
#
# Epoch 38/70 LR: [2]
# Epoch loss: 0.08583407525135123
# Calculating mean of exemplars
# tot corrects:  520
# Validation accuracy on group 1/10: 0.58
#
# Epoch 39/70 LR: [2]
# Epoch loss: 0.0800343184205501
# Calculating mean of exemplars
# tot corrects:  589
# Validation accuracy on group 1/10: 0.66
# Best model updated
#
# Epoch 40/70 LR: [2]
# Epoch loss: 0.07918052909814793
# Calculating mean of exemplars
# tot corrects:  489
# Validation accuracy on group 1/10: 0.55
#
# Epoch 41/70 LR: [2]
# Epoch loss: 0.07214784549306268
# Calculating mean of exemplars
# tot corrects:  554
# Validation accuracy on group 1/10: 0.62
#
# Epoch 42/70 LR: [2]
# Epoch loss: 0.07119771514249884
# Calculating mean of exemplars
# tot corrects:  574
# Validation accuracy on group 1/10: 0.64
#
# Epoch 43/70 LR: [2]
# Epoch loss: 0.07230168370449025
# Calculating mean of exemplars
# tot corrects:  579
# Validation accuracy on group 1/10: 0.65
#
# Epoch 44/70 LR: [2]
# Epoch loss: 0.06799773726126422
# Calculating mean of exemplars
# tot corrects:  572
# Validation accuracy on group 1/10: 0.64
#
# Epoch 45/70 LR: [2]
# Epoch loss: 0.06621708097341268
# Calculating mean of exemplars
# tot corrects:  519
# Validation accuracy on group 1/10: 0.58
#
# Epoch 46/70 LR: [2]
# Epoch loss: 0.06343305572543455
# Calculating mean of exemplars
# tot corrects:  552
# Validation accuracy on group 1/10: 0.62
#
# Epoch 47/70 LR: [2]
# Epoch loss: 0.060076253812598145
# Calculating mean of exemplars
# tot corrects:  558
# Validation accuracy on group 1/10: 0.62
#
# Epoch 48/70 LR: [2]
# Epoch loss: 0.057500131752180016
# Calculating mean of exemplars
# tot corrects:  597
# Validation accuracy on group 1/10: 0.67
# Best model updated
#
# Epoch 49/70 LR: [2]
# Epoch loss: 0.06067226851439994
# Calculating mean of exemplars
# tot corrects:  614
# Validation accuracy on group 1/10: 0.69
# Best model updated
#
# Epoch 50/70 LR: [0.4]
# Epoch loss: 0.039306839442123535
# Calculating mean of exemplars
# tot corrects:  690
# Validation accuracy on group 1/10: 0.77
# Best model updated
#
# Epoch 51/70 LR: [0.4]
# Epoch loss: 0.027969716683678005
# Calculating mean of exemplars
# tot corrects:  675
# Validation accuracy on group 1/10: 0.75
#
# Epoch 52/70 LR: [0.4]
# Epoch loss: 0.02518623642137517
# Calculating mean of exemplars
# tot corrects:  697
# Validation accuracy on group 1/10: 0.78
# Best model updated
#
# Epoch 53/70 LR: [0.4]
# Epoch loss: 0.023938752042696528
# Calculating mean of exemplars
# tot corrects:  699
# Validation accuracy on group 1/10: 0.78
# Best model updated
#
# Epoch 54/70 LR: [0.4]
# Epoch loss: 0.021777030748679586
# Calculating mean of exemplars
# tot corrects:  693
# Validation accuracy on group 1/10: 0.77
#
# Epoch 55/70 LR: [0.4]
# Epoch loss: 0.019948618071477697
# Calculating mean of exemplars
# tot corrects:  654
# Validation accuracy on group 1/10: 0.73
#
# Epoch 56/70 LR: [0.4]
# Epoch loss: 0.01848745773262952
# Calculating mean of exemplars
# tot corrects:  689
# Validation accuracy on group 1/10: 0.77
#
# Epoch 57/70 LR: [0.4]
# Epoch loss: 0.018440109363797565
# Calculating mean of exemplars
# tot corrects:  668
# Validation accuracy on group 1/10: 0.75
#
# Epoch 58/70 LR: [0.4]
# Epoch loss: 0.017143115542991007
# Calculating mean of exemplars
# tot corrects:  676
# Validation accuracy on group 1/10: 0.75
#
# Epoch 59/70 LR: [0.4]
# Epoch loss: 0.014947455528232715
# Calculating mean of exemplars
# tot corrects:  683
# Validation accuracy on group 1/10: 0.76
#
# Epoch 60/70 LR: [0.4]
# Epoch loss: 0.014678038474496292
# Calculating mean of exemplars
# tot corrects:  676
# Validation accuracy on group 1/10: 0.75
#
# Epoch 61/70 LR: [0.4]
# Epoch loss: 0.014175573323407898
# Calculating mean of exemplars
# tot corrects:  681
# Validation accuracy on group 1/10: 0.76
#
# Epoch 62/70 LR: [0.4]
# Epoch loss: 0.012848421850282213
# Calculating mean of exemplars
# tot corrects:  702
# Validation accuracy on group 1/10: 0.78
# Best model updated
#
# Epoch 63/70 LR: [0.4]
# Epoch loss: 0.012708410559950964
# Calculating mean of exemplars
# tot corrects:  685
# Validation accuracy on group 1/10: 0.76
#
# Epoch 64/70 LR: [0.08000000000000002]
# Epoch loss: 0.010263927493487363
# Calculating mean of exemplars
# tot corrects:  699
# Validation accuracy on group 1/10: 0.78
#
# Epoch 65/70 LR: [0.08000000000000002]
# Epoch loss: 0.009521759368236299
# Calculating mean of exemplars
# tot corrects:  684
# Validation accuracy on group 1/10: 0.76
#
# Epoch 66/70 LR: [0.08000000000000002]
# Epoch loss: 0.008886101974538811
# Calculating mean of exemplars
# tot corrects:  686
# Validation accuracy on group 1/10: 0.77
#
# Epoch 67/70 LR: [0.08000000000000002]
# Epoch loss: 0.009568897329027886
# Calculating mean of exemplars
# tot corrects:  698
# Validation accuracy on group 1/10: 0.78
#
# Epoch 68/70 LR: [0.08000000000000002]
# Epoch loss: 0.009026341302239376
# Calculating mean of exemplars
# tot corrects:  684
# Validation accuracy on group 1/10: 0.76
#
# Epoch 69/70 LR: [0.08000000000000002]
# Epoch loss: 0.008342263592488092
# Calculating mean of exemplars
# tot corrects:  692
# Validation accuracy on group 1/10: 0.77
#
# Epoch 70/70 LR: [0.08000000000000002]
# Epoch loss: 0.008126631525912038
# Calculating mean of exemplars
# tot corrects:  696
# Validation accuracy on group 1/10: 0.78
#
# Group 1 Finished!
# Best accuracy found at epoch 62: 0.78
# Calculating mean of exemplars with the best net found.
# tot corrects:  739
# Testing classes seen so far, accuracy: 0.82
#
# =============================================
#
# Epoch 1/70 LR: [2]
# Epoch loss: 0.2495088856066427
# Randomly extracting exemplars from class 0 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 100 exemplars.
# Calculating mean of exemplars
# tot corrects:  274
# Validation accuracy on group 2/10: 0.31
# Best model updated
#
# Epoch 2/70 LR: [2]
# Epoch loss: 0.16563433141280443
# Calculating mean of exemplars
# tot corrects:  291
# Validation accuracy on group 2/10: 0.32
# Best model updated
#
# Epoch 3/70 LR: [2]
# Epoch loss: 0.15144690298117125
# Calculating mean of exemplars
# tot corrects:  339
# Validation accuracy on group 2/10: 0.38
# Best model updated
#
# Epoch 4/70 LR: [2]
# Epoch loss: 0.13927359917224982
# Calculating mean of exemplars
# tot corrects:  331
# Validation accuracy on group 2/10: 0.37
#
# Epoch 5/70 LR: [2]
# Epoch loss: 0.1320024570211386
# Calculating mean of exemplars
# tot corrects:  333
# Validation accuracy on group 2/10: 0.37
#
# Epoch 6/70 LR: [2]
# Epoch loss: 0.12484219078070079
# Calculating mean of exemplars
# tot corrects:  320
# Validation accuracy on group 2/10: 0.36
#
# Epoch 7/70 LR: [2]
# Epoch loss: 0.12299921516424571
# Calculating mean of exemplars
# tot corrects:  390
# Validation accuracy on group 2/10: 0.44
# Best model updated
#
# Epoch 8/70 LR: [2]
# Epoch loss: 0.11549129738257481
# Calculating mean of exemplars
# tot corrects:  386
# Validation accuracy on group 2/10: 0.43
#
# Epoch 9/70 LR: [2]
# Epoch loss: 0.11484654648945881
# Calculating mean of exemplars
# tot corrects:  385
# Validation accuracy on group 2/10: 0.43
#
# Epoch 10/70 LR: [2]
# Epoch loss: 0.11072770238686831
# Calculating mean of exemplars
# tot corrects:  393
# Validation accuracy on group 2/10: 0.44
# Best model updated
#
# Epoch 11/70 LR: [2]
# Epoch loss: 0.1050394846078677
# Calculating mean of exemplars
# tot corrects:  432
# Validation accuracy on group 2/10: 0.48
# Best model updated
#
# Epoch 12/70 LR: [2]
# Epoch loss: 0.10341805334274586
# Calculating mean of exemplars
# tot corrects:  344
# Validation accuracy on group 2/10: 0.38
#
# Epoch 13/70 LR: [2]
# Epoch loss: 0.0994355055766228
# Calculating mean of exemplars
# tot corrects:  426
# Validation accuracy on group 2/10: 0.48
#
# Epoch 14/70 LR: [2]
# Epoch loss: 0.09522768148244956
# Calculating mean of exemplars
# tot corrects:  443
# Validation accuracy on group 2/10: 0.49
# Best model updated
#
# Epoch 15/70 LR: [2]
# Epoch loss: 0.09418029605578153
# Calculating mean of exemplars
# tot corrects:  438
# Validation accuracy on group 2/10: 0.49
#
# Epoch 16/70 LR: [2]
# Epoch loss: 0.09354774386454852
# Calculating mean of exemplars
# tot corrects:  433
# Validation accuracy on group 2/10: 0.48
#
# Epoch 17/70 LR: [2]
# Epoch loss: 0.09056163770266068
# Calculating mean of exemplars
# tot corrects:  396
# Validation accuracy on group 2/10: 0.44
#
# Epoch 18/70 LR: [2]
# Epoch loss: 0.08821253268382488
# Calculating mean of exemplars
# tot corrects:  448
# Validation accuracy on group 2/10: 0.50
# Best model updated
#
# Epoch 19/70 LR: [2]
# Epoch loss: 0.08583410982138072
# Calculating mean of exemplars
# tot corrects:  434
# Validation accuracy on group 2/10: 0.48
#
# Epoch 20/70 LR: [2]
# Epoch loss: 0.08403121871061814
# Calculating mean of exemplars
# tot corrects:  445
# Validation accuracy on group 2/10: 0.50
#
# Epoch 21/70 LR: [2]
# Epoch loss: 0.08388445106072304
# Calculating mean of exemplars
# tot corrects:  431
# Validation accuracy on group 2/10: 0.48
#
# Epoch 22/70 LR: [2]
# Epoch loss: 0.08502457099847305
# Calculating mean of exemplars
# tot corrects:  496
# Validation accuracy on group 2/10: 0.55
# Best model updated
#
# Epoch 23/70 LR: [2]
# Epoch loss: 0.07966367117105386
# Calculating mean of exemplars
# tot corrects:  403
# Validation accuracy on group 2/10: 0.45
#
# Epoch 24/70 LR: [2]
# Epoch loss: 0.08441643416881561
# Calculating mean of exemplars
# tot corrects:  348
# Validation accuracy on group 2/10: 0.39
#
# Epoch 25/70 LR: [2]
# Epoch loss: 0.08048760088590476
# Calculating mean of exemplars
# tot corrects:  457
# Validation accuracy on group 2/10: 0.51
#
# Epoch 26/70 LR: [2]
# Epoch loss: 0.0807344825604023
# Calculating mean of exemplars
# tot corrects:  409
# Validation accuracy on group 2/10: 0.46
#
# Epoch 27/70 LR: [2]
# Epoch loss: 0.07887489921771564
# Calculating mean of exemplars
# tot corrects:  398
# Validation accuracy on group 2/10: 0.44
#
# Epoch 28/70 LR: [2]
# Epoch loss: 0.07591937577877289
# Calculating mean of exemplars
# tot corrects:  489
# Validation accuracy on group 2/10: 0.55
#
# Epoch 29/70 LR: [2]
# Epoch loss: 0.0730958206531329
# Calculating mean of exemplars
# tot corrects:  415
# Validation accuracy on group 2/10: 0.46
#
# Epoch 30/70 LR: [2]
# Epoch loss: 0.07260631445126656
# Calculating mean of exemplars
# tot corrects:  414
# Validation accuracy on group 2/10: 0.46
#
# Epoch 31/70 LR: [2]
# Epoch loss: 0.0742798058841473
# Calculating mean of exemplars
# tot corrects:  388
# Validation accuracy on group 2/10: 0.43
#
# Epoch 32/70 LR: [2]
# Epoch loss: 0.07201673892828134
# Calculating mean of exemplars
# tot corrects:  425
# Validation accuracy on group 2/10: 0.47
#
# Epoch 33/70 LR: [2]
# Epoch loss: 0.06938928126906738
# Calculating mean of exemplars
# tot corrects:  463
# Validation accuracy on group 2/10: 0.52
#
# Epoch 34/70 LR: [2]
# Epoch loss: 0.07105396086206803
# Calculating mean of exemplars
# tot corrects:  367
# Validation accuracy on group 2/10: 0.41
#
# Epoch 35/70 LR: [2]
# Epoch loss: 0.07107406778213306
# Calculating mean of exemplars
# tot corrects:  361
# Validation accuracy on group 2/10: 0.40
#
# Epoch 36/70 LR: [2]
# Epoch loss: 0.07147505631049474
# Calculating mean of exemplars
# tot corrects:  413
# Validation accuracy on group 2/10: 0.46
#
# Epoch 37/70 LR: [2]
# Epoch loss: 0.07052560303455745
# Calculating mean of exemplars
# tot corrects:  496
# Validation accuracy on group 2/10: 0.55
#
# Epoch 38/70 LR: [2]
# Epoch loss: 0.06752233092601483
# Calculating mean of exemplars
# tot corrects:  435
# Validation accuracy on group 2/10: 0.49
#
# Epoch 39/70 LR: [2]
# Epoch loss: 0.07047355700379763
# Calculating mean of exemplars
# tot corrects:  487
# Validation accuracy on group 2/10: 0.54
#
# Epoch 40/70 LR: [2]
# Epoch loss: 0.06924002025371943
# Calculating mean of exemplars
# tot corrects:  474
# Validation accuracy on group 2/10: 0.53
#
# Epoch 41/70 LR: [2]
# Epoch loss: 0.06706432100289907
# Calculating mean of exemplars
# tot corrects:  454
# Validation accuracy on group 2/10: 0.51
#
# Epoch 42/70 LR: [2]
# Epoch loss: 0.06628218302742028
# Calculating mean of exemplars
# tot corrects:  471
# Validation accuracy on group 2/10: 0.53
#
# Epoch 43/70 LR: [2]
# Epoch loss: 0.06357312336181983
# Calculating mean of exemplars
# tot corrects:  419
# Validation accuracy on group 2/10: 0.47
#
# Epoch 44/70 LR: [2]
# Epoch loss: 0.06405185163021088
# Calculating mean of exemplars
# tot corrects:  456
# Validation accuracy on group 2/10: 0.51
#
# Epoch 45/70 LR: [2]
# Epoch loss: 0.06632567006043899
# Calculating mean of exemplars
# tot corrects:  505
# Validation accuracy on group 2/10: 0.56
# Best model updated
#
# Epoch 46/70 LR: [2]
# Epoch loss: 0.06298857268232566
# Calculating mean of exemplars
# tot corrects:  507
# Validation accuracy on group 2/10: 0.57
# Best model updated
#
# Epoch 47/70 LR: [2]
# Epoch loss: 0.06506011682825211
# Calculating mean of exemplars
# tot corrects:  499
# Validation accuracy on group 2/10: 0.56
#
# Epoch 48/70 LR: [2]
# Epoch loss: 0.06499603104132873
# Calculating mean of exemplars
# tot corrects:  534
# Validation accuracy on group 2/10: 0.60
# Best model updated
#
# Epoch 49/70 LR: [2]
# Epoch loss: 0.06381626455829693
# Calculating mean of exemplars
# tot corrects:  529
# Validation accuracy on group 2/10: 0.59
#
# Epoch 50/70 LR: [0.4]
# Epoch loss: 0.056052771516335316
# Calculating mean of exemplars
# tot corrects:  442
# Validation accuracy on group 2/10: 0.49
#
# Epoch 51/70 LR: [0.4]
# Epoch loss: 0.049925740044086404
# Calculating mean of exemplars
# tot corrects:  445
# Validation accuracy on group 2/10: 0.50
#
# Epoch 52/70 LR: [0.4]
# Epoch loss: 0.04897909687879758
# Calculating mean of exemplars
# tot corrects:  469
# Validation accuracy on group 2/10: 0.52
#
# Epoch 53/70 LR: [0.4]
# Epoch loss: 0.04767911575543575
# Calculating mean of exemplars
# tot corrects:  489
# Validation accuracy on group 2/10: 0.55
#
# Epoch 54/70 LR: [0.4]
# Epoch loss: 0.04628197008218521
# Calculating mean of exemplars
# tot corrects:  479
# Validation accuracy on group 2/10: 0.53
#
# Epoch 55/70 LR: [0.4]
# Epoch loss: 0.04594653777969189
# Calculating mean of exemplars
# tot corrects:  490
# Validation accuracy on group 2/10: 0.55
#
# Epoch 56/70 LR: [0.4]
# Epoch loss: 0.04620654814136334
# Calculating mean of exemplars
# tot corrects:  498
# Validation accuracy on group 2/10: 0.56
#
# Epoch 57/70 LR: [0.4]
# Epoch loss: 0.04653255125650993
# Calculating mean of exemplars
# tot corrects:  463
# Validation accuracy on group 2/10: 0.52
#
# Epoch 58/70 LR: [0.4]
# Epoch loss: 0.04617378430870863
# Calculating mean of exemplars
# tot corrects:  474
# Validation accuracy on group 2/10: 0.53
#
# Epoch 59/70 LR: [0.4]
# Epoch loss: 0.044575676608544126
# Calculating mean of exemplars
# tot corrects:  477
# Validation accuracy on group 2/10: 0.53
#
# Epoch 60/70 LR: [0.4]
# Epoch loss: 0.04455846882401369
# Calculating mean of exemplars
# tot corrects:  489
# Validation accuracy on group 2/10: 0.55
#
# Epoch 61/70 LR: [0.4]
# Epoch loss: 0.04441746668173717
# Calculating mean of exemplars
# tot corrects:  460
# Validation accuracy on group 2/10: 0.51
#
# Epoch 62/70 LR: [0.4]
# Epoch loss: 0.04451865979876274
# Calculating mean of exemplars
# tot corrects:  476
# Validation accuracy on group 2/10: 0.53
#
# Epoch 63/70 LR: [0.4]
# Epoch loss: 0.04464345893416649
# Calculating mean of exemplars
# tot corrects:  501
# Validation accuracy on group 2/10: 0.56
#
# Epoch 64/70 LR: [0.08000000000000002]
# Epoch loss: 0.04460813983892783
# Calculating mean of exemplars
# tot corrects:  494
# Validation accuracy on group 2/10: 0.55
#
# Epoch 65/70 LR: [0.08000000000000002]
# Epoch loss: 0.042947159841274604
# Calculating mean of exemplars
# tot corrects:  499
# Validation accuracy on group 2/10: 0.56
#
# Epoch 66/70 LR: [0.08000000000000002]
# Epoch loss: 0.043635131361392826
# Calculating mean of exemplars
# tot corrects:  485
# Validation accuracy on group 2/10: 0.54
#
# Epoch 67/70 LR: [0.08000000000000002]
# Epoch loss: 0.043835501067149334
# Calculating mean of exemplars
# tot corrects:  483
# Validation accuracy on group 2/10: 0.54
#
# Epoch 68/70 LR: [0.08000000000000002]
# Epoch loss: 0.04265787204106649
# Calculating mean of exemplars
# tot corrects:  476
# Validation accuracy on group 2/10: 0.53
#
# Epoch 69/70 LR: [0.08000000000000002]
# Epoch loss: 0.04257090743153523
# Calculating mean of exemplars
# tot corrects:  477
# Validation accuracy on group 2/10: 0.53
#
# Epoch 70/70 LR: [0.08000000000000002]
# Epoch loss: 0.04342552943107409
# Calculating mean of exemplars
# tot corrects:  468
# Validation accuracy on group 2/10: 0.52
#
# Group 2 Finished!
# Best accuracy found at epoch 48: 0.60
# Calculating mean of exemplars with the best net found.
# tot corrects:  1268
# Testing classes seen so far, accuracy: 0.66
#
# =============================================
#
# Epoch 1/70 LR: [2]
# Epoch loss: 0.24852274646682124
# Randomly extracting exemplars from class 0 of current split... Extracted 67 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 67 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 67 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 67 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 67 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 67 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 67 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 67 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 67 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 67 exemplars.
# Calculating mean of exemplars
# tot corrects:  412
# Validation accuracy on group 3/10: 0.46
# Best model updated
#
# Epoch 2/70 LR: [2]
# Epoch loss: 0.14028889768653446
# Calculating mean of exemplars
# tot corrects:  467
# Validation accuracy on group 3/10: 0.52
# Best model updated
#
# Epoch 3/70 LR: [2]
# Epoch loss: 0.12545449369483525
# Calculating mean of exemplars
# tot corrects:  507
# Validation accuracy on group 3/10: 0.57
# Best model updated
#
# Epoch 4/70 LR: [2]
# Epoch loss: 0.11824111081659794
# Calculating mean of exemplars
# tot corrects:  502
# Validation accuracy on group 3/10: 0.56
#
# Epoch 5/70 LR: [2]
# Epoch loss: 0.11367527043653859
# Calculating mean of exemplars
# tot corrects:  496
# Validation accuracy on group 3/10: 0.55
#
# Epoch 6/70 LR: [2]
# Epoch loss: 0.11034648803373177
# Calculating mean of exemplars
# tot corrects:  505
# Validation accuracy on group 3/10: 0.56
#
# Epoch 7/70 LR: [2]
# Epoch loss: 0.10781180734435718
# Calculating mean of exemplars
# tot corrects:  524
# Validation accuracy on group 3/10: 0.58
# Best model updated
#
# Epoch 8/70 LR: [2]
# Epoch loss: 0.1055882651772764
# Calculating mean of exemplars
# tot corrects:  547
# Validation accuracy on group 3/10: 0.61
# Best model updated
#
# Epoch 9/70 LR: [2]
# Epoch loss: 0.10204327147867945
# Calculating mean of exemplars
# tot corrects:  540
# Validation accuracy on group 3/10: 0.60
#
# Epoch 10/70 LR: [2]
# Epoch loss: 0.10238719379736318
# Calculating mean of exemplars
# tot corrects:  535
# Validation accuracy on group 3/10: 0.60
#
# Epoch 11/70 LR: [2]
# Epoch loss: 0.10046878912382656
# Calculating mean of exemplars
# tot corrects:  544
# Validation accuracy on group 3/10: 0.61
#
# Epoch 12/70 LR: [2]
# Epoch loss: 0.09781020196775596
# Calculating mean of exemplars
# tot corrects:  548
# Validation accuracy on group 3/10: 0.61
# Best model updated
#
# Epoch 13/70 LR: [2]
# Epoch loss: 0.09745459217164251
# Calculating mean of exemplars
# tot corrects:  532
# Validation accuracy on group 3/10: 0.59
#
# Epoch 14/70 LR: [2]
# Epoch loss: 0.09478569568859206
# Calculating mean of exemplars
# tot corrects:  559
# Validation accuracy on group 3/10: 0.62
# Best model updated
#
# Epoch 15/70 LR: [2]
# Epoch loss: 0.09203883591625425
# Calculating mean of exemplars
# tot corrects:  580
# Validation accuracy on group 3/10: 0.65
# Best model updated
#
# Epoch 16/70 LR: [2]
# Epoch loss: 0.09349655504855844
# Calculating mean of exemplars
# tot corrects:  543
# Validation accuracy on group 3/10: 0.61
#
# Epoch 17/70 LR: [2]
# Epoch loss: 0.09192968222002189
# Calculating mean of exemplars
# tot corrects:  543
# Validation accuracy on group 3/10: 0.61
#
# Epoch 18/70 LR: [2]
# Epoch loss: 0.09293404366407129
# Calculating mean of exemplars
# tot corrects:  538
# Validation accuracy on group 3/10: 0.60
#
# Epoch 19/70 LR: [2]
# Epoch loss: 0.09047744981944561
# Calculating mean of exemplars
# tot corrects:  589
# Validation accuracy on group 3/10: 0.66
# Best model updated
#
# Epoch 20/70 LR: [2]
# Epoch loss: 0.09049510914418432
# Calculating mean of exemplars
# tot corrects:  531
# Validation accuracy on group 3/10: 0.59
#
# Epoch 21/70 LR: [2]
# Epoch loss: 0.0894052493903372
# Calculating mean of exemplars
# tot corrects:  553
# Validation accuracy on group 3/10: 0.62
#
# Epoch 22/70 LR: [2]
# Epoch loss: 0.08928026114073065
# Calculating mean of exemplars
# tot corrects:  565
# Validation accuracy on group 3/10: 0.63
#
# Epoch 23/70 LR: [2]
# Epoch loss: 0.08891257974836561
# Calculating mean of exemplars
# tot corrects:  502
# Validation accuracy on group 3/10: 0.56
#
# Epoch 24/70 LR: [2]
# Epoch loss: 0.08787994376487201
# Calculating mean of exemplars
# tot corrects:  516
# Validation accuracy on group 3/10: 0.58
#
# Epoch 25/70 LR: [2]
# Epoch loss: 0.08649791549477312
# Calculating mean of exemplars
# tot corrects:  560
# Validation accuracy on group 3/10: 0.62
#
# Epoch 26/70 LR: [2]
# Epoch loss: 0.08480322071247631
# Calculating mean of exemplars
# tot corrects:  525
# Validation accuracy on group 3/10: 0.59
#
# Epoch 27/70 LR: [2]
# Epoch loss: 0.08571396271387736
# Calculating mean of exemplars
# tot corrects:  513
# Validation accuracy on group 3/10: 0.57
#
# Epoch 28/70 LR: [2]
# Epoch loss: 0.08617002972298199
# Calculating mean of exemplars
# tot corrects:  567
# Validation accuracy on group 3/10: 0.63
#
# Epoch 29/70 LR: [2]
# Epoch loss: 0.08437814418640402
# Calculating mean of exemplars
# tot corrects:  559
# Validation accuracy on group 3/10: 0.62
#
# Epoch 30/70 LR: [2]
# Epoch loss: 0.08393482263717386
# Calculating mean of exemplars
# tot corrects:  563
# Validation accuracy on group 3/10: 0.63
#
# Epoch 31/70 LR: [2]
# Epoch loss: 0.0833862175544103
# Calculating mean of exemplars
# tot corrects:  533
# Validation accuracy on group 3/10: 0.59
#
# Epoch 32/70 LR: [2]
# Epoch loss: 0.08231846201750967
# Calculating mean of exemplars
# tot corrects:  526
# Validation accuracy on group 3/10: 0.59
#
# Epoch 33/70 LR: [2]
# Epoch loss: 0.08317953306767675
# Calculating mean of exemplars
# tot corrects:  566
# Validation accuracy on group 3/10: 0.63
#
# Epoch 34/70 LR: [2]
# Epoch loss: 0.08213851745757791
# Calculating mean of exemplars
# tot corrects:  603
# Validation accuracy on group 3/10: 0.67
# Best model updated
#
# Epoch 35/70 LR: [2]
# Epoch loss: 0.0823907336841027
# Calculating mean of exemplars
# tot corrects:  546
# Validation accuracy on group 3/10: 0.61
#
# Epoch 36/70 LR: [2]
# Epoch loss: 0.0817370300905572
# Calculating mean of exemplars
# tot corrects:  545
# Validation accuracy on group 3/10: 0.61
#
# Epoch 37/70 LR: [2]
# Epoch loss: 0.08235061582591799
# Calculating mean of exemplars
# tot corrects:  497
# Validation accuracy on group 3/10: 0.55
#
# Epoch 38/70 LR: [2]
# Epoch loss: 0.08318151388731268
# Calculating mean of exemplars
# tot corrects:  567
# Validation accuracy on group 3/10: 0.63
#
# Epoch 39/70 LR: [2]
# Epoch loss: 0.08166054843200578
# Calculating mean of exemplars
# tot corrects:  556
# Validation accuracy on group 3/10: 0.62
#
# Epoch 40/70 LR: [2]
# Epoch loss: 0.08071673288941383
# Calculating mean of exemplars
# tot corrects:  506
# Validation accuracy on group 3/10: 0.56
#
# Epoch 41/70 LR: [2]
# Epoch loss: 0.08072631226645575
# Calculating mean of exemplars
# tot corrects:  562
# Validation accuracy on group 3/10: 0.63
#
# Epoch 42/70 LR: [2]
# Epoch loss: 0.08143450609511799
# Calculating mean of exemplars
# tot corrects:  527
# Validation accuracy on group 3/10: 0.59
#
# Epoch 43/70 LR: [2]
# Epoch loss: 0.08094022712773746
# Calculating mean of exemplars
# tot corrects:  505
# Validation accuracy on group 3/10: 0.56
#
# Epoch 44/70 LR: [2]
# Epoch loss: 0.07968985703256395
# Calculating mean of exemplars
# tot corrects:  514
# Validation accuracy on group 3/10: 0.57
#
# Epoch 45/70 LR: [2]
# Epoch loss: 0.08024387992918491
# Calculating mean of exemplars
# tot corrects:  589
# Validation accuracy on group 3/10: 0.66
#
# Epoch 46/70 LR: [2]
# Epoch loss: 0.08132087977396117
# Calculating mean of exemplars
# tot corrects:  541
# Validation accuracy on group 3/10: 0.60
#
# Epoch 47/70 LR: [2]
# Epoch loss: 0.08337788263128863
# Calculating mean of exemplars
# tot corrects:  562
# Validation accuracy on group 3/10: 0.63
#
# Epoch 48/70 LR: [2]
# Epoch loss: 0.0812350283894274
# Calculating mean of exemplars
# tot corrects:  569
# Validation accuracy on group 3/10: 0.64
#
# Epoch 49/70 LR: [2]
# Epoch loss: 0.07831941089696354
# Calculating mean of exemplars
# tot corrects:  630
# Validation accuracy on group 3/10: 0.70
# Best model updated
#
# Epoch 50/70 LR: [0.4]
# Epoch loss: 0.0733561430954271
# Calculating mean of exemplars
# tot corrects:  613
# Validation accuracy on group 3/10: 0.68
#
# Epoch 51/70 LR: [0.4]
# Epoch loss: 0.07073596720066336
# Calculating mean of exemplars
# tot corrects:  614
# Validation accuracy on group 3/10: 0.69
#
# Epoch 52/70 LR: [0.4]
# Epoch loss: 0.07043797357214822
# Calculating mean of exemplars
# tot corrects:  602
# Validation accuracy on group 3/10: 0.67
#
# Epoch 53/70 LR: [0.4]
# Epoch loss: 0.07027489029698902
# Calculating mean of exemplars
# tot corrects:  554
# Validation accuracy on group 3/10: 0.62
#
# Epoch 54/70 LR: [0.4]
# Epoch loss: 0.06957178045478132
# Calculating mean of exemplars
# tot corrects:  599
# Validation accuracy on group 3/10: 0.67
#
# Epoch 55/70 LR: [0.4]
# Epoch loss: 0.06896726000640127
# Calculating mean of exemplars
# tot corrects:  560
# Validation accuracy on group 3/10: 0.62
#
# Epoch 56/70 LR: [0.4]
# Epoch loss: 0.06898304923541015
# Calculating mean of exemplars
# tot corrects:  574
# Validation accuracy on group 3/10: 0.64
#
# Epoch 57/70 LR: [0.4]
# Epoch loss: 0.06878266255888674
# Calculating mean of exemplars
# tot corrects:  573
# Validation accuracy on group 3/10: 0.64
#
# Epoch 58/70 LR: [0.4]
# Epoch loss: 0.06902481491367023
# Calculating mean of exemplars
# tot corrects:  575
# Validation accuracy on group 3/10: 0.64
#
# Epoch 59/70 LR: [0.4]
# Epoch loss: 0.06812229007482529
# Calculating mean of exemplars
# tot corrects:  559
# Validation accuracy on group 3/10: 0.62
#
# Epoch 60/70 LR: [0.4]
# Epoch loss: 0.06762649926046531
# Calculating mean of exemplars
# tot corrects:  550
# Validation accuracy on group 3/10: 0.61
#
# Epoch 61/70 LR: [0.4]
# Epoch loss: 0.06815354919268025
# Calculating mean of exemplars
# tot corrects:  589
# Validation accuracy on group 3/10: 0.66
#
# Epoch 62/70 LR: [0.4]
# Epoch loss: 0.06734438137047821
# Calculating mean of exemplars
# tot corrects:  569
# Validation accuracy on group 3/10: 0.64
#
# Epoch 63/70 LR: [0.4]
# Epoch loss: 0.06815327652212647
# Calculating mean of exemplars
# tot corrects:  575
# Validation accuracy on group 3/10: 0.64
#
# Epoch 64/70 LR: [0.08000000000000002]
# Epoch loss: 0.067224044042329
# Calculating mean of exemplars
# tot corrects:  569
# Validation accuracy on group 3/10: 0.64
#
# Epoch 65/70 LR: [0.08000000000000002]
# Epoch loss: 0.06672760513093737
# Calculating mean of exemplars
# tot corrects:  572
# Validation accuracy on group 3/10: 0.64
#
# Epoch 66/70 LR: [0.08000000000000002]
# Epoch loss: 0.06639255759202772
# Calculating mean of exemplars
# tot corrects:  571
# Validation accuracy on group 3/10: 0.64
#
# Epoch 67/70 LR: [0.08000000000000002]
# Epoch loss: 0.06626955130034023
# Calculating mean of exemplars
# tot corrects:  557
# Validation accuracy on group 3/10: 0.62
#
# Epoch 68/70 LR: [0.08000000000000002]
# Epoch loss: 0.06720895051128334
# Calculating mean of exemplars
# tot corrects:  563
# Validation accuracy on group 3/10: 0.63
#
# Epoch 69/70 LR: [0.08000000000000002]
# Epoch loss: 0.06680840336614186
# Calculating mean of exemplars
# tot corrects:  576
# Validation accuracy on group 3/10: 0.64
#
# Epoch 70/70 LR: [0.08000000000000002]
# Epoch loss: 0.06653804031925069
# Calculating mean of exemplars
# tot corrects:  570
# Validation accuracy on group 3/10: 0.64
#
# Group 3 Finished!
# Best accuracy found at epoch 49: 0.70
# Calculating mean of exemplars with the best net found.
# tot corrects:  1722
# Testing classes seen so far, accuracy: 0.58
#
# =============================================
#
# Epoch 1/70 LR: [2]
# Epoch loss: 0.24853145691656298
# Randomly extracting exemplars from class 0 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 50 exemplars.
# Calculating mean of exemplars
# tot corrects:  265
# Validation accuracy on group 4/10: 0.30
# Best model updated
#
# Epoch 2/70 LR: [2]
# Epoch loss: 0.14490606103624618
# Calculating mean of exemplars
# tot corrects:  302
# Validation accuracy on group 4/10: 0.34
# Best model updated
#
# Epoch 3/70 LR: [2]
# Epoch loss: 0.12824264530624663
# Calculating mean of exemplars
# tot corrects:  292
# Validation accuracy on group 4/10: 0.33
#
# Epoch 4/70 LR: [2]
# Epoch loss: 0.12353687030928476
# Calculating mean of exemplars
# tot corrects:  286
# Validation accuracy on group 4/10: 0.32
#
# Epoch 5/70 LR: [2]
# Epoch loss: 0.11808441515479769
# Calculating mean of exemplars
# tot corrects:  297
# Validation accuracy on group 4/10: 0.33
#
# Epoch 6/70 LR: [2]
# Epoch loss: 0.11420675473553794
# Calculating mean of exemplars
# tot corrects:  316
# Validation accuracy on group 4/10: 0.35
# Best model updated
#
# Epoch 7/70 LR: [2]
# Epoch loss: 0.11187856176069805
# Calculating mean of exemplars
# tot corrects:  264
# Validation accuracy on group 4/10: 0.29
#
# Epoch 8/70 LR: [2]
# Epoch loss: 0.11141366000686373
# Calculating mean of exemplars
# tot corrects:  256
# Validation accuracy on group 4/10: 0.29
#
# Epoch 9/70 LR: [2]
# Epoch loss: 0.10869940327746527
# Calculating mean of exemplars
# tot corrects:  316
# Validation accuracy on group 4/10: 0.35
#
# Epoch 10/70 LR: [2]
# Epoch loss: 0.10655614393098013
# Calculating mean of exemplars
# tot corrects:  352
# Validation accuracy on group 4/10: 0.39
# Best model updated
#
# Epoch 11/70 LR: [2]
# Epoch loss: 0.1071128242782184
# Calculating mean of exemplars
# tot corrects:  281
# Validation accuracy on group 4/10: 0.31
#
# Epoch 12/70 LR: [2]
# Epoch loss: 0.10514480641910008
# Calculating mean of exemplars
# tot corrects:  300
# Validation accuracy on group 4/10: 0.33
#
# Epoch 13/70 LR: [2]
# Epoch loss: 0.10434256196022033
# Calculating mean of exemplars
# tot corrects:  323
# Validation accuracy on group 4/10: 0.36
#
# Epoch 14/70 LR: [2]
# Epoch loss: 0.1035280704498291
# Calculating mean of exemplars
# tot corrects:  283
# Validation accuracy on group 4/10: 0.32
#
# Epoch 15/70 LR: [2]
# Epoch loss: 0.10173806867429189
# Calculating mean of exemplars
# tot corrects:  292
# Validation accuracy on group 4/10: 0.33
#
# Epoch 16/70 LR: [2]
# Epoch loss: 0.10034036700214659
# Calculating mean of exemplars
# tot corrects:  331
# Validation accuracy on group 4/10: 0.37
#
# Epoch 17/70 LR: [2]
# Epoch loss: 0.10054189498935427
# Calculating mean of exemplars
# tot corrects:  299
# Validation accuracy on group 4/10: 0.33
#
# Epoch 18/70 LR: [2]
# Epoch loss: 0.10026525493179049
# Calculating mean of exemplars
# tot corrects:  248
# Validation accuracy on group 4/10: 0.28
#
# Epoch 19/70 LR: [2]
# Epoch loss: 0.0982892496245248
# Calculating mean of exemplars
# tot corrects:  207
# Validation accuracy on group 4/10: 0.23
#
# Epoch 20/70 LR: [2]
# Epoch loss: 0.0995296488915171
# Calculating mean of exemplars
# tot corrects:  267
# Validation accuracy on group 4/10: 0.30
#
# Epoch 21/70 LR: [2]
# Epoch loss: 0.09790754126650947
# Calculating mean of exemplars
# tot corrects:  281
# Validation accuracy on group 4/10: 0.31
#
# Epoch 22/70 LR: [2]
# Epoch loss: 0.09700281875474112
# Calculating mean of exemplars
# tot corrects:  323
# Validation accuracy on group 4/10: 0.36
#
# Epoch 23/70 LR: [2]
# Epoch loss: 0.0960290510739599
# Calculating mean of exemplars
# tot corrects:  311
# Validation accuracy on group 4/10: 0.35
#
# Epoch 24/70 LR: [2]
# Epoch loss: 0.09584628279720034
# Calculating mean of exemplars
# tot corrects:  260
# Validation accuracy on group 4/10: 0.29
#
# Epoch 25/70 LR: [2]
# Epoch loss: 0.09476807756083352
# Calculating mean of exemplars
# tot corrects:  268
# Validation accuracy on group 4/10: 0.30
#
# Epoch 26/70 LR: [2]
# Epoch loss: 0.09497507406132562
# Calculating mean of exemplars
# tot corrects:  287
# Validation accuracy on group 4/10: 0.32
#
# Epoch 27/70 LR: [2]
# Epoch loss: 0.09517872674124582
# Calculating mean of exemplars
# tot corrects:  254
# Validation accuracy on group 4/10: 0.28
#
# Epoch 28/70 LR: [2]
# Epoch loss: 0.09462418002741678
# Calculating mean of exemplars
# tot corrects:  307
# Validation accuracy on group 4/10: 0.34
#
# Epoch 29/70 LR: [2]
# Epoch loss: 0.09179335215262004
# Calculating mean of exemplars
# tot corrects:  244
# Validation accuracy on group 4/10: 0.27
#
# Epoch 30/70 LR: [2]
# Epoch loss: 0.0920319601893425
# Calculating mean of exemplars
# tot corrects:  267
# Validation accuracy on group 4/10: 0.30
#
# Epoch 31/70 LR: [2]
# Epoch loss: 0.09320588154452188
# Calculating mean of exemplars
# tot corrects:  325
# Validation accuracy on group 4/10: 0.36
#
# Epoch 32/70 LR: [2]
# Epoch loss: 0.09134392440319061
# Calculating mean of exemplars
# tot corrects:  293
# Validation accuracy on group 4/10: 0.33
#
# Epoch 33/70 LR: [2]
# Epoch loss: 0.09130324763911112
# Calculating mean of exemplars
# tot corrects:  305
# Validation accuracy on group 4/10: 0.34
#
# Epoch 34/70 LR: [2]
# Epoch loss: 0.09147251695394516
# Calculating mean of exemplars
# tot corrects:  259
# Validation accuracy on group 4/10: 0.29
#
# Epoch 35/70 LR: [2]
# Epoch loss: 0.09203364721366337
# Calculating mean of exemplars
# tot corrects:  324
# Validation accuracy on group 4/10: 0.36
#
# Epoch 36/70 LR: [2]
# Epoch loss: 0.09252575508185795
# Calculating mean of exemplars
# tot corrects:  321
# Validation accuracy on group 4/10: 0.36
#
# Epoch 37/70 LR: [2]
# Epoch loss: 0.09306352117231914
# Calculating mean of exemplars
# tot corrects:  315
# Validation accuracy on group 4/10: 0.35
#
# Epoch 38/70 LR: [2]
# Epoch loss: 0.09071410085473741
# Calculating mean of exemplars
# tot corrects:  319
# Validation accuracy on group 4/10: 0.36
#
# Epoch 39/70 LR: [2]
# Epoch loss: 0.0911137187055179
# Calculating mean of exemplars
# tot corrects:  355
# Validation accuracy on group 4/10: 0.40
# Best model updated
#
# Epoch 40/70 LR: [2]
# Epoch loss: 0.09104381884847368
# Calculating mean of exemplars
# tot corrects:  366
# Validation accuracy on group 4/10: 0.41
# Best model updated
#
# Epoch 41/70 LR: [2]
# Epoch loss: 0.09115732312202454
# Calculating mean of exemplars
# tot corrects:  308
# Validation accuracy on group 4/10: 0.34
#
# Epoch 42/70 LR: [2]
# Epoch loss: 0.0896291162286486
# Calculating mean of exemplars
# tot corrects:  309
# Validation accuracy on group 4/10: 0.34
#
# Epoch 43/70 LR: [2]
# Epoch loss: 0.08982502136911664
# Calculating mean of exemplars
# tot corrects:  323
# Validation accuracy on group 4/10: 0.36
#
# Epoch 44/70 LR: [2]
# Epoch loss: 0.09013246446847915
# Calculating mean of exemplars
# tot corrects:  328
# Validation accuracy on group 4/10: 0.37
#
# Epoch 45/70 LR: [2]
# Epoch loss: 0.08976949559790748
# Calculating mean of exemplars
# tot corrects:  293
# Validation accuracy on group 4/10: 0.33
#
# Epoch 46/70 LR: [2]
# Epoch loss: 0.09083276242017746
# Calculating mean of exemplars
# tot corrects:  335
# Validation accuracy on group 4/10: 0.37
#
# Epoch 47/70 LR: [2]
# Epoch loss: 0.08932503546987261
# Calculating mean of exemplars
# tot corrects:  365
# Validation accuracy on group 4/10: 0.41
#
# Epoch 48/70 LR: [2]
# Epoch loss: 0.08840320557355881
# Calculating mean of exemplars
# tot corrects:  288
# Validation accuracy on group 4/10: 0.32
#
# Epoch 49/70 LR: [2]
# Epoch loss: 0.0881491795182228
# Calculating mean of exemplars
# tot corrects:  255
# Validation accuracy on group 4/10: 0.28
#
# Epoch 50/70 LR: [0.4]
# Epoch loss: 0.0833185851573944
# Calculating mean of exemplars
# tot corrects:  285
# Validation accuracy on group 4/10: 0.32
#
# Epoch 51/70 LR: [0.4]
# Epoch loss: 0.08108048545462744
# Calculating mean of exemplars
# tot corrects:  290
# Validation accuracy on group 4/10: 0.32
#
# Epoch 52/70 LR: [0.4]
# Epoch loss: 0.0799639003617423
# Calculating mean of exemplars
# tot corrects:  298
# Validation accuracy on group 4/10: 0.33
#
# Epoch 53/70 LR: [0.4]
# Epoch loss: 0.07940674679619926
# Calculating mean of exemplars
# tot corrects:  308
# Validation accuracy on group 4/10: 0.34
#
# Epoch 54/70 LR: [0.4]
# Epoch loss: 0.07927377266543252
# Calculating mean of exemplars
# tot corrects:  331
# Validation accuracy on group 4/10: 0.37
#
# Epoch 55/70 LR: [0.4]
# Epoch loss: 0.07903305121830531
# Calculating mean of exemplars
# tot corrects:  322
# Validation accuracy on group 4/10: 0.36
#
# Epoch 56/70 LR: [0.4]
# Epoch loss: 0.07849847333771842
# Calculating mean of exemplars
# tot corrects:  323
# Validation accuracy on group 4/10: 0.36
#
# Epoch 57/70 LR: [0.4]
# Epoch loss: 0.07824931506599699
# Calculating mean of exemplars
# tot corrects:  349
# Validation accuracy on group 4/10: 0.39
#
# Epoch 58/70 LR: [0.4]
# Epoch loss: 0.07791464009455272
# Calculating mean of exemplars
# tot corrects:  301
# Validation accuracy on group 4/10: 0.34
#
# Epoch 59/70 LR: [0.4]
# Epoch loss: 0.07789374909230641
# Calculating mean of exemplars
# tot corrects:  329
# Validation accuracy on group 4/10: 0.37
#
# Epoch 60/70 LR: [0.4]
# Epoch loss: 0.07812720856496266
# Calculating mean of exemplars
# tot corrects:  328
# Validation accuracy on group 4/10: 0.37
#
# Epoch 61/70 LR: [0.4]
# Epoch loss: 0.07816970199346543
# Calculating mean of exemplars
# tot corrects:  321
# Validation accuracy on group 4/10: 0.36
#
# Epoch 62/70 LR: [0.4]
# Epoch loss: 0.07744175727878298
# Calculating mean of exemplars
# tot corrects:  313
# Validation accuracy on group 4/10: 0.35
#
# Epoch 63/70 LR: [0.4]
# Epoch loss: 0.07803287122930799
# Calculating mean of exemplars
# tot corrects:  312
# Validation accuracy on group 4/10: 0.35
#
# Epoch 64/70 LR: [0.08000000000000002]
# Epoch loss: 0.07781093120574951
# Calculating mean of exemplars
# tot corrects:  307
# Validation accuracy on group 4/10: 0.34
#
# Epoch 65/70 LR: [0.08000000000000002]
# Epoch loss: 0.07771703813757215
# Calculating mean of exemplars
# tot corrects:  321
# Validation accuracy on group 4/10: 0.36
#
# Epoch 66/70 LR: [0.08000000000000002]
# Epoch loss: 0.07720981453146253
# Calculating mean of exemplars
# tot corrects:  313
# Validation accuracy on group 4/10: 0.35
#
# Epoch 67/70 LR: [0.08000000000000002]
# Epoch loss: 0.07693873707737242
# Calculating mean of exemplars
# tot corrects:  298
# Validation accuracy on group 4/10: 0.33
#
# Epoch 68/70 LR: [0.08000000000000002]
# Epoch loss: 0.07693814507552556
# Calculating mean of exemplars
# tot corrects:  315
# Validation accuracy on group 4/10: 0.35
#
# Epoch 69/70 LR: [0.08000000000000002]
# Epoch loss: 0.07686848321131297
# Calculating mean of exemplars
# tot corrects:  313
# Validation accuracy on group 4/10: 0.35
#
# Epoch 70/70 LR: [0.08000000000000002]
# Epoch loss: 0.07641033338648932
# Calculating mean of exemplars
# tot corrects:  334
# Validation accuracy on group 4/10: 0.37
#
# Group 4 Finished!
# Best accuracy found at epoch 40: 0.41
# Calculating mean of exemplars with the best net found.
# tot corrects:  1995
# Testing classes seen so far, accuracy: 0.50
#
# =============================================
#
# Epoch 1/70 LR: [2]
# Epoch loss: 0.25438007423954623
# Randomly extracting exemplars from class 0 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 40 exemplars.
# Calculating mean of exemplars
# tot corrects:  259
# Validation accuracy on group 5/10: 0.29
# Best model updated
#
# Epoch 2/70 LR: [2]
# Epoch loss: 0.1429636991199325
# Calculating mean of exemplars
# tot corrects:  287
# Validation accuracy on group 5/10: 0.32
# Best model updated
#
# Epoch 3/70 LR: [2]
# Epoch loss: 0.1268995960845667
# Calculating mean of exemplars
# tot corrects:  326
# Validation accuracy on group 5/10: 0.36
# Best model updated
#
# Epoch 4/70 LR: [2]
# Epoch loss: 0.12024284702013521
# Calculating mean of exemplars
# tot corrects:  303
# Validation accuracy on group 5/10: 0.34
#
# Epoch 5/70 LR: [2]
# Epoch loss: 0.11756948644624036
# Calculating mean of exemplars
# tot corrects:  325
# Validation accuracy on group 5/10: 0.36
#
# Epoch 6/70 LR: [2]
# Epoch loss: 0.11567445822498378
# Calculating mean of exemplars
# tot corrects:  296
# Validation accuracy on group 5/10: 0.33
#
# ...
# Calculating mean of exemplars
# tot corrects:  282
# Validation accuracy on group 9/10: 0.31
#
# Epoch 60/70 LR: [0.4]
# Epoch loss: 0.0858708590720639
# Calculating mean of exemplars
# tot corrects:  285
# Validation accuracy on group 9/10: 0.32
#
# Epoch 61/70 LR: [0.4]
# Epoch loss: 0.08598602811495464
# Calculating mean of exemplars
# tot corrects:  292
# Validation accuracy on group 9/10: 0.33
#
# Epoch 62/70 LR: [0.4]
# Epoch loss: 0.08569163422692906
# Calculating mean of exemplars
# tot corrects:  280
# Validation accuracy on group 9/10: 0.31
#
# Epoch 63/70 LR: [0.4]
# Epoch loss: 0.08564864053870692
# Calculating mean of exemplars
# tot corrects:  290
# Validation accuracy on group 9/10: 0.32
#
# Epoch 64/70 LR: [0.08000000000000002]
# Epoch loss: 0.08569350387110855
# Calculating mean of exemplars
# tot corrects:  304
# Validation accuracy on group 9/10: 0.34
#
# Epoch 65/70 LR: [0.08000000000000002]
# Epoch loss: 0.08514501109267726
# Calculating mean of exemplars
# tot corrects:  302
# Validation accuracy on group 9/10: 0.34
#
# Epoch 66/70 LR: [0.08000000000000002]
# Epoch loss: 0.08533535220406273
# Calculating mean of exemplars
# tot corrects:  297
# Validation accuracy on group 9/10: 0.33
#
# Epoch 67/70 LR: [0.08000000000000002]
# Epoch loss: 0.0853472887115045
# Calculating mean of exemplars
# tot corrects:  292
# Validation accuracy on group 9/10: 0.33
#
# Epoch 68/70 LR: [0.08000000000000002]
# Epoch loss: 0.08496048865896283
# Calculating mean of exemplars
# tot corrects:  300
# Validation accuracy on group 9/10: 0.33
#
# Epoch 69/70 LR: [0.08000000000000002]
# Epoch loss: 0.0851196978579868
# Calculating mean of exemplars
# tot corrects:  311
# Validation accuracy on group 9/10: 0.35
#
# Epoch 70/70 LR: [0.08000000000000002]
# Epoch loss: 0.08525605702942068
# Calculating mean of exemplars
# tot corrects:  296
# Validation accuracy on group 9/10: 0.33
#
# Group 9 Finished!
# Best accuracy found at epoch 29: 0.37
# Calculating mean of exemplars with the best net found.
# tot corrects:  3037
# Testing classes seen so far, accuracy: 0.34
#
# =============================================
#
# Epoch 1/70 LR: [2]
# Epoch loss: 0.22547903945369105
# Randomly extracting exemplars from class 0 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 20 exemplars.
# Calculating mean of exemplars
# tot corrects:  158
# Validation accuracy on group 10/10: 0.18
# Best model updated
#
# Epoch 2/70 LR: [2]
# Epoch loss: 0.12712250906042755
# Calculating mean of exemplars
# tot corrects:  263
# Validation accuracy on group 10/10: 0.29
# Best model updated
#
# Epoch 3/70 LR: [2]
# Epoch loss: 0.1137511853594333
# Calculating mean of exemplars
# tot corrects:  356
# Validation accuracy on group 10/10: 0.40
# Best model updated
#
# Epoch 4/70 LR: [2]
# Epoch loss: 0.10723101999610662
# Calculating mean of exemplars
# tot corrects:  346
# Validation accuracy on group 10/10: 0.39
#
# Epoch 5/70 LR: [2]
# Epoch loss: 0.10392398899421096
# Calculating mean of exemplars
# tot corrects:  344
# Validation accuracy on group 10/10: 0.38
#
# Epoch 6/70 LR: [2]
# Epoch loss: 0.10153507837094367
# Calculating mean of exemplars
# tot corrects:  358
# Validation accuracy on group 10/10: 0.40
# Best model updated
#
# Epoch 7/70 LR: [2]
# Epoch loss: 0.09889259515330195
# Calculating mean of exemplars
# tot corrects:  360
# Validation accuracy on group 10/10: 0.40
# Best model updated
#
# Epoch 8/70 LR: [2]
# Epoch loss: 0.09805054939351976
# Calculating mean of exemplars
# tot corrects:  410
# Validation accuracy on group 10/10: 0.46
# Best model updated
#
# Epoch 9/70 LR: [2]
# Epoch loss: 0.09634290053509176
# Calculating mean of exemplars
# tot corrects:  357
# Validation accuracy on group 10/10: 0.40
#
# Epoch 10/70 LR: [2]
# Epoch loss: 0.09568173717707396
# Calculating mean of exemplars
# tot corrects:  403
# Validation accuracy on group 10/10: 0.45
#
# Epoch 11/70 LR: [2]
# Epoch loss: 0.09497175016440451
# Calculating mean of exemplars
# tot corrects:  420
# Validation accuracy on group 10/10: 0.47
# Best model updated
#
# Epoch 12/70 LR: [2]
# Epoch loss: 0.09434102242812514
# Calculating mean of exemplars
# tot corrects:  402
# Validation accuracy on group 10/10: 0.45
#
# Epoch 13/70 LR: [2]
# Epoch loss: 0.0943703968077898
# Calculating mean of exemplars
# tot corrects:  412
# Validation accuracy on group 10/10: 0.46
#
# Epoch 14/70 LR: [2]
# Epoch loss: 0.093248400837183
# Calculating mean of exemplars
# tot corrects:  367
# Validation accuracy on group 10/10: 0.41
#
# Epoch 15/70 LR: [2]
# Epoch loss: 0.09298220579512417
# Calculating mean of exemplars
# tot corrects:  429
# Validation accuracy on group 10/10: 0.48
# Best model updated
#
# Epoch 16/70 LR: [2]
# Epoch loss: 0.09240604960359633
# Calculating mean of exemplars
# tot corrects:  399
# Validation accuracy on group 10/10: 0.45
#
# Epoch 17/70 LR: [2]
# Epoch loss: 0.09231036040000618
# Calculating mean of exemplars
# tot corrects:  404
# Validation accuracy on group 10/10: 0.45
#
# Epoch 18/70 LR: [2]
# Epoch loss: 0.09168356750160456
# Calculating mean of exemplars
# tot corrects:  404
# Validation accuracy on group 10/10: 0.45
#
# Epoch 19/70 LR: [2]
# Epoch loss: 0.0914080401416868
# Calculating mean of exemplars
# tot corrects:  403
# Validation accuracy on group 10/10: 0.45
#
# Epoch 20/70 LR: [2]
# Epoch loss: 0.09123800555244088
# Calculating mean of exemplars
# tot corrects:  373
# Validation accuracy on group 10/10: 0.42
#
# Epoch 21/70 LR: [2]
# Epoch loss: 0.09122202475555241
# Calculating mean of exemplars
# tot corrects:  347
# Validation accuracy on group 10/10: 0.39
#
# Epoch 22/70 LR: [2]
# Epoch loss: 0.09065368887968361
# Calculating mean of exemplars
# tot corrects:  386
# Validation accuracy on group 10/10: 0.43
#
# Epoch 23/70 LR: [2]
# Epoch loss: 0.09123637690208852
# Calculating mean of exemplars
# tot corrects:  364
# Validation accuracy on group 10/10: 0.41
#
# Epoch 24/70 LR: [2]
# Epoch loss: 0.08999685663729906
# Calculating mean of exemplars
# tot corrects:  377
# Validation accuracy on group 10/10: 0.42
#
# Epoch 25/70 LR: [2]
# Epoch loss: 0.09046329208649695
# Calculating mean of exemplars
# tot corrects:  384
# Validation accuracy on group 10/10: 0.43
#
# Epoch 26/70 LR: [2]
# Epoch loss: 0.0904042727779597
# Calculating mean of exemplars
# tot corrects:  401
# Validation accuracy on group 10/10: 0.45
#
# Epoch 27/70 LR: [2]
# Epoch loss: 0.09043731749989092
# Calculating mean of exemplars
# tot corrects:  368
# Validation accuracy on group 10/10: 0.41
#
# Epoch 28/70 LR: [2]
# Epoch loss: 0.08998318947851658
# Calculating mean of exemplars
# tot corrects:  330
# Validation accuracy on group 10/10: 0.37
#
# Epoch 29/70 LR: [2]
# Epoch loss: 0.08992754784412682
# Calculating mean of exemplars
# tot corrects:  350
# Validation accuracy on group 10/10: 0.39
#
# Epoch 30/70 LR: [2]
# Epoch loss: 0.08929563593119383
# Calculating mean of exemplars
# tot corrects:  367
# Validation accuracy on group 10/10: 0.41
#
# Epoch 31/70 LR: [2]
# Epoch loss: 0.08933891542255878
# Calculating mean of exemplars
# tot corrects:  417
# Validation accuracy on group 10/10: 0.47
#
# Epoch 32/70 LR: [2]
# Epoch loss: 0.08959923777729273
# Calculating mean of exemplars
# tot corrects:  413
# Validation accuracy on group 10/10: 0.46
#
# Epoch 33/70 LR: [2]
# Epoch loss: 0.0893802591599524
# Calculating mean of exemplars
# tot corrects:  310
# Validation accuracy on group 10/10: 0.35
#
# Epoch 34/70 LR: [2]
# Epoch loss: 0.08913915534503758
# Calculating mean of exemplars
# tot corrects:  436
# Validation accuracy on group 10/10: 0.49
# Best model updated
#
# Epoch 35/70 LR: [2]
# Epoch loss: 0.08926476258784533
# Calculating mean of exemplars
# tot corrects:  389
# Validation accuracy on group 10/10: 0.43
#
# Epoch 36/70 LR: [2]
# Epoch loss: 0.0887292071711272
# Calculating mean of exemplars
# tot corrects:  338
# Validation accuracy on group 10/10: 0.38
#
# Epoch 37/70 LR: [2]
# Epoch loss: 0.08904419862665236
# Calculating mean of exemplars
# tot corrects:  381
# Validation accuracy on group 10/10: 0.43
#
# Epoch 38/70 LR: [2]
# Epoch loss: 0.08880799845792353
# Calculating mean of exemplars
# tot corrects:  356
# Validation accuracy on group 10/10: 0.40
#
# Epoch 39/70 LR: [2]
# Epoch loss: 0.08866884605959058
# Calculating mean of exemplars
# tot corrects:  410
# Validation accuracy on group 10/10: 0.46
#
# Epoch 40/70 LR: [2]
# Epoch loss: 0.08831589831970632
# Calculating mean of exemplars
# tot corrects:  357
# Validation accuracy on group 10/10: 0.40
#
# Epoch 41/70 LR: [2]
# Epoch loss: 0.08797344053164124
# Calculating mean of exemplars
# tot corrects:  444
# Validation accuracy on group 10/10: 0.50
# Best model updated
#
# Epoch 42/70 LR: [2]
# Epoch loss: 0.08838669420219958
# Calculating mean of exemplars
# tot corrects:  378
# Validation accuracy on group 10/10: 0.42
#
# Epoch 43/70 LR: [2]
# Epoch loss: 0.08855411224067211
# Calculating mean of exemplars
# tot corrects:  375
# Validation accuracy on group 10/10: 0.42
#
# Epoch 44/70 LR: [2]
# Epoch loss: 0.08809057297185063
# Calculating mean of exemplars
# tot corrects:  395
# Validation accuracy on group 10/10: 0.44
#
# Epoch 45/70 LR: [2]
# Epoch loss: 0.08779376256279647
# Calculating mean of exemplars
# tot corrects:  323
# Validation accuracy on group 10/10: 0.36
#
# Epoch 46/70 LR: [2]
# Epoch loss: 0.08808959810994565
# Calculating mean of exemplars
# tot corrects:  379
# Validation accuracy on group 10/10: 0.42
#
# Epoch 47/70 LR: [2]
# Epoch loss: 0.08756833430379629
# Calculating mean of exemplars
# tot corrects:  377
# Validation accuracy on group 10/10: 0.42
#
# Epoch 48/70 LR: [2]
# Epoch loss: 0.087710065767169
# Calculating mean of exemplars
# tot corrects:  377
# Validation accuracy on group 10/10: 0.42
#
# Epoch 49/70 LR: [2]
# Epoch loss: 0.08784724678844213
# Calculating mean of exemplars
# tot corrects:  424
# Validation accuracy on group 10/10: 0.47
#
# Epoch 50/70 LR: [0.4]
# Epoch loss: 0.08618836500681937
# Calculating mean of exemplars
# tot corrects:  412
# Validation accuracy on group 10/10: 0.46
#
# Epoch 51/70 LR: [0.4]
# Epoch loss: 0.08470594370737672
# Calculating mean of exemplars
# tot corrects:  427
# Validation accuracy on group 10/10: 0.48
#
# Epoch 52/70 LR: [0.4]
# Epoch loss: 0.08438701834529638
# Calculating mean of exemplars
# tot corrects:  431
# Validation accuracy on group 10/10: 0.48
#
# Epoch 53/70 LR: [0.4]
# Epoch loss: 0.08446203521452844
# Calculating mean of exemplars
# tot corrects:  428
# Validation accuracy on group 10/10: 0.48
#
# Epoch 54/70 LR: [0.4]
# Epoch loss: 0.08454510127194226
# Calculating mean of exemplars
# tot corrects:  445
# Validation accuracy on group 10/10: 0.50
# Best model updated
#
# Epoch 55/70 LR: [0.4]
# Epoch loss: 0.08445608499459922
# Calculating mean of exemplars
# tot corrects:  448
# Validation accuracy on group 10/10: 0.50
# Best model updated
#
# Epoch 56/70 LR: [0.4]
# Epoch loss: 0.08405957790091634
# Calculating mean of exemplars
# tot corrects:  430
# Validation accuracy on group 10/10: 0.48
#
# Epoch 57/70 LR: [0.4]
# Epoch loss: 0.08422610303387046
# Calculating mean of exemplars
# tot corrects:  407
# Validation accuracy on group 10/10: 0.45
#
# Epoch 58/70 LR: [0.4]
# Epoch loss: 0.08371213963255286
# Calculating mean of exemplars
# tot corrects:  425
# Validation accuracy on group 10/10: 0.47
#
# Epoch 59/70 LR: [0.4]
# Epoch loss: 0.08405658300034702
# Calculating mean of exemplars
# tot corrects:  440
# Validation accuracy on group 10/10: 0.49
#
# Epoch 60/70 LR: [0.4]
# Epoch loss: 0.08392794989049435
# Calculating mean of exemplars
# tot corrects:  428
# Validation accuracy on group 10/10: 0.48
#
# Epoch 61/70 LR: [0.4]
# Epoch loss: 0.08391366549767554
# Calculating mean of exemplars
# tot corrects:  415
# Validation accuracy on group 10/10: 0.46
#
# Epoch 62/70 LR: [0.4]
# Epoch loss: 0.0836397900711745
# Calculating mean of exemplars
# tot corrects:  407
# Validation accuracy on group 10/10: 0.45
#
# Epoch 63/70 LR: [0.4]
# Epoch loss: 0.08361813216470182
# Calculating mean of exemplars
# tot corrects:  411
# Validation accuracy on group 10/10: 0.46
#
# Epoch 64/70 LR: [0.08000000000000002]
# Epoch loss: 0.08355224342085421
# Calculating mean of exemplars
# tot corrects:  399
# Validation accuracy on group 10/10: 0.45
#
# Epoch 65/70 LR: [0.08000000000000002]
# Epoch loss: 0.08349486696533859
# Calculating mean of exemplars
# tot corrects:  415
# Validation accuracy on group 10/10: 0.46
#
# Epoch 66/70 LR: [0.08000000000000002]
# Epoch loss: 0.08339762641116977
# Calculating mean of exemplars
# tot corrects:  419
# Validation accuracy on group 10/10: 0.47
#
# Epoch 67/70 LR: [0.08000000000000002]
# Epoch loss: 0.08352571213617921
# Calculating mean of exemplars
# tot corrects:  410
# Validation accuracy on group 10/10: 0.46
#
# Epoch 68/70 LR: [0.08000000000000002]
# Epoch loss: 0.08340533100999892
# Calculating mean of exemplars
# tot corrects:  418
# Validation accuracy on group 10/10: 0.47
#
# Epoch 69/70 LR: [0.08000000000000002]
# Epoch loss: 0.08332680468447506
# Calculating mean of exemplars
# tot corrects:  433
# Validation accuracy on group 10/10: 0.48
#
# Epoch 70/70 LR: [0.08000000000000002]
# Epoch loss: 0.0835950868204236
# Calculating mean of exemplars
# tot corrects:  417
# Validation accuracy on group 10/10: 0.47
#
# Group 10 Finished!
# Best accuracy found at epoch 55: 0.50
# Calculating mean of exemplars with the best net found.
# tot corrects:  3154
# Testing classes seen so far, accuracy: 0.32
#
# =============================================
#
# #################################
#
#
# #################################
# Radom seed: 13
#
# Epoch 1/70 LR: [2]
# Epoch loss: 0.39964533332855473
# Randomly extracting exemplars from class 0 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 200 exemplars.
# Calculating mean of exemplars
# tot corrects:  98
# Validation accuracy on group 1/10: 0.11
# Best model updated
#
# Epoch 2/70 LR: [2]
# Epoch loss: 0.32323788236016815
# Calculating mean of exemplars
# tot corrects:  120
# Validation accuracy on group 1/10: 0.13
# Best model updated
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-03957fa3fc54> in <module>()
#      43
#      44   #train and evaluate the model
# ---> 45   logs[run] = trainer.train_model(NUM_EPOCHS)
#      46
#      47   best_net_tot_classes[run] = deepcopy(trainer.best_net)
#
# /content/ProjectMLDL/model/icarl.py in train_model(self, num_epochs)
#      46
#      47       for epoch in range(num_epochs):
# ---> 48         combined_dataset = self.combine_dataset_with_exemplars(self.train_dl[g].dataset, g)
#      49         self.combined_dl = DataLoader(combined_dataset, batch_size=128, shuffle=True, num_workers=4, drop_last=True) #128 = BATCH_SIZE
#      50         e_loss, e_acc = self.train_epoch(g)
#
# /content/ProjectMLDL/model/icarl.py in combine_dataset_with_exemplars(self, dataset_to_combine, classes_group_idx)
#     251     for cl in range(classes_group_idx*10, classes_group_idx*10+10):
#     252       for idx in self.exemplars_indexes[cl]:
# --> 253         data_idx = data_indexes.index(idx)
#     254         adding.append(dataset_to_combine[data_idx])
#     255     res = ConcatDataset([dataset_to_combine, adding])
#
# KeyboardInterrupt:

# %% [markdown]
# ### Store logs in more usable dtype

# %%
train_loss = [[logs[run_i]['group_train_loss'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
train_accuracy = [[logs[run_i]['group_train_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
#val_loss = [[logs[run_i]['val_losses'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
val_accuracy = [[logs[run_i]['val_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
test_accuracy = [[logs[run_i]['test_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
predictions = [logs[run_i]['predictions'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]
true_labels = [logs[run_i]['true_labels'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]

# %% [markdown]
# ### Save the model

# %% [markdown]
# #### Saving logs in JSON files

# %%
import json

with open('states/icarl_train_loss.json', 'w') as f:
  json.dump(train_loss, f)
f.close
with open('states/icarl_train_accuracy.json', 'w') as f:
  json.dump(train_accuracy, f)
f.close
#with open('states/LWF_val_loss.json', 'w') as f:
  #json.dump(val_loss, f)
f.close  
with open('states/icarl_val_accuracy.json', 'w') as f:
  json.dump(val_accuracy, f)
f.close
with open('states/icarl_test_accuracy.json', 'w') as f:
  json.dump(test_accuracy, f)
f.close
with open('states/icarl_predictions.json', 'w') as f:
  json.dump(predictions, f)
f.close
with open('states/icarl_targets.json', 'w') as f:
  json.dump(true_labels, f)
f.close
# Out:
# <function TextIOWrapper.close>

# %% [markdown]
# #### Saving best resnet on 100 classes for each seed

# %%
for i in range(len(RANDOM_SEED)):
  torch.save(best_net_tot_classes[i].state_dict(), "states/icarl_bestnet_seed[{}]".format(RANDOM_SEED[i]))

# %% [markdown]
# ### Print some graphs

# %%
from data.utils_plot import plot_train_val, plot_test_accuracies, plot_confusion_matrix

# %%
train_loss = np.array(train_loss)
train_accuracy = np.array(train_accuracy)
#val_loss = np.array(val_loss)
val_accuracy = np.array(val_accuracy)
test_accuracy = np.array(test_accuracy)

train_loss_stats = np.array([train_loss.mean(0), train_loss.std(0)]).transpose()
train_accuracy_stats = np.array([train_accuracy.mean(0), train_accuracy.std(0)]).transpose()
#val_loss_stats = np.array([val_loss.mean(0), val_loss.std(0)]).transpose()
val_accuracy_stats = np.array([val_accuracy.mean(0), val_accuracy.std(0)]).transpose()
test_accuracy_stats = np.array([test_accuracy.mean(0), test_accuracy.std(0)]).transpose()

# %% [markdown]
# #### Train validation loss

# %%
plot_train_val(train_loss_stats, val_loss_stats, loss = True)

# %% [markdown]
# #### Train validation accuracy

# %%
plot_train_val(train_accuracy_stats, val_accuracy_stats, loss = False)

# %% [markdown]
# #### Test accuracy

# %%
plot_test_accuracies(test_accuracy_stats)

# %% [markdown]
# #### Confusion Matrix

# %%
for run in range(len(RANDOM_SEED)):
  targets = np.array(true_labels[run])
  preds = np.array(predictions[run])

  plot_confusion_matrix(targets, preds, RANDOM_SEED[run], 'icarl')
