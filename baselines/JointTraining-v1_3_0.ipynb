# %% [markdown]
# <a href="https://colab.research.google.com/github/cosminnedescu/ProjectMLDL/blob/main/baselines/JointTraining-v1_3_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import random

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable

import torchvision
from torchvision import transforms, datasets, models
from torch.utils.data import Subset, DataLoader

from PIL import Image

import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
from copy import copy
from copy import deepcopy

# %% [markdown]
# #### Cloning the Git repository

# %%
# !rm -rf ProjectMLDL
if not os.path.isdir('/content/ProjectMLDL'):
  # !git clone https://github.com/cosminnedescu/ProjectMLDL.git
  # %cd /content/ProjectMLDL
  # !rm -rf LICENSE README.md
# Out:
# Cloning into 'ProjectMLDL'...
# remote: Enumerating objects: 1118, done.
# remote: Counting objects: 100% (270/270), done.
# remote: Compressing objects: 100% (196/196), done.
# remote: Total 1118 (delta 175), reused 71 (delta 71), pack-reused 848
# Receiving objects: 100% (1118/1118), 27.93 MiB | 38.60 MiB/s, done.
# Resolving deltas: 100% (579/579), done.
# /content/ProjectMLDL

# %%
from data.cifar100 import CIFAR100
from model.resnet32 import resnet32
import data.utils
from model.trainer import Trainer

# %% [markdown]
# #### Downloading data from Cifar100

# %%
# True mean and std of Cifar100 dataset (src="https://gist.github.com/weiaicunzai/e623931921efefd4c331622c344d8151")
mean = [0.5071, 0.4867, 0.4408]
std = [0.2675, 0.2565, 0.2761]

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])
test_transform = transforms.Compose(
    [transforms.ToTensor(), 
     transforms.Normalize(mean, std),
     ])

# %% [markdown]
# ## Fine Tuning

# %% [markdown]
# ### Defining hyperparameters according to iCarl paper

# %%
# Settings
DEVICE = 'cuda'
NUM_CLASSES = 100         # Total number of classes
VAL_SIZE = 0.2            # Proportion of validation set with respect to training set (between 0 and 1)

# Training
BATCH_SIZE = 128          # Batch size
LR = 2                    # Initial learning rate
                       
MOMENTUM = 0.9            # Momentum for stochastic gradient descent (SGD)
WEIGHT_DECAY = 1e-5       # Weight decay from iCaRL

RANDOM_SEED = [42]  # Random seeds defining the runs of every method
                          # Note: this should be at least 3 to have a fair benchmark

NUM_EPOCHS = 70           # Total number of training epochs
MILESTONES = [49, 63]     # Step down policy from iCaRL (MultiStepLR)
                          # Decrease the learning rate by gamma at each milestone
GAMMA = 0.2               # Gamma factor from iCaRL (1/5)

# %% [markdown]
# ### Going on with the model
# This is the main FineTuning step.
#
# This step is run 3 times with different `RANDOM_SEED`.
# Here the model is instantiated, trained and tested.
#
# Results and some statistics are then stored in the variable `logs`.

# %%
def do_group_classes(run):

  train_dataloader = [[] for i in range(10)]
  val_dataloader = [[] for i in range(10)]
  test_dataloader = [[] for i in range(10)]

  for i in range(10):
    train_data = CIFAR100("dataset", 
                          train=True, 
                          transform=train_transform, 
                          download=(run+i==0),
                          random_state=RANDOM_SEED[run])
    test_data = CIFAR100("dataset", 
                         train=False, 
                         transform=test_transform, 
                         download=False,
                         random_state=RANDOM_SEED[run])
    
    train_data.set_index_map([train_data.splits[j] for j in range(0, i+1)])
    test_data.set_index_map([test_data.splits[j] for j in range(0, i+1)])
    
    train_indices, val_indices = train_data.train_val_split(VAL_SIZE, RANDOM_SEED[run])
    
    train_subset = Subset(train_data, train_indices)
    val_subset = Subset(train_data, val_indices)

    tmp_dl = DataLoader(train_subset,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    train_dataloader[i] = copy(tmp_dl)
    
    tmp_dl = DataLoader(val_subset,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    val_dataloader[i] = copy(tmp_dl)

    tmp_dl = DataLoader(test_data,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    test_dataloader[i] = copy(tmp_dl)

  return train_dataloader, val_dataloader, test_dataloader

# %%
logs = [[] for i in range(len(RANDOM_SEED))]
best_net_tot_classes = [None for i in range(len(RANDOM_SEED))]

for run in range(len(RANDOM_SEED)):
  random.seed(RANDOM_SEED[run])
  print("#################################")
  print(f"Radom seed: {RANDOM_SEED[run]}")
  print("")

  #get dataloader separated in incremental groups of 10 classes
  train_dl, val_dl, test_dl = do_group_classes(run)

  #create the resnet
  net = resnet32()
  
  trainer = Trainer(DEVICE,
                    net,
                    LR,
                    MOMENTUM,
                    WEIGHT_DECAY,
                    MILESTONES,
                    GAMMA,
                    train_dl,
                    val_dl,
                    test_dl)

  #train and evaluate the model
  logs[run] = trainer.train_model(NUM_EPOCHS)

  best_net_tot_classes[run] = deepcopy(trainer.best_net)

  print("#################################")
  print("")
  print("")
# Out:
# #################################
# Radom seed: 42
#
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to dataset/cifar-100-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=169001437.0), HTML(value='')))
# Extracting dataset/cifar-100-python.tar.gz to dataset
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch 1/70 LR: [2]
# Validation accuracy on group 1/10: 0.19
# Best model updated
#
# Epoch 2/70 LR: [2]
# Validation accuracy on group 1/10: 0.19
# Best model updated
#
# Epoch 3/70 LR: [2]
# Validation accuracy on group 1/10: 0.20
# Best model updated
#
# Epoch 4/70 LR: [2]
# Validation accuracy on group 1/10: 0.22
# Best model updated
#
# Epoch 5/70 LR: [2]
# Validation accuracy on group 1/10: 0.27
# Best model updated
#
# Epoch 6/70 LR: [2]
# Validation accuracy on group 1/10: 0.28
# Best model updated
#
# Epoch 7/70 LR: [2]
# Validation accuracy on group 1/10: 0.27
#
# Epoch 8/70 LR: [2]
# Validation accuracy on group 1/10: 0.31
# Best model updated
#
# Epoch 9/70 LR: [2]
# Validation accuracy on group 1/10: 0.31
# Best model updated
#
# Epoch 10/70 LR: [2]
# Validation accuracy on group 1/10: 0.30
#
# Epoch 11/70 LR: [2]
# Validation accuracy on group 1/10: 0.32
# Best model updated
#
# Epoch 12/70 LR: [2]
# Validation accuracy on group 1/10: 0.34
# Best model updated
#
# Epoch 13/70 LR: [2]
# Validation accuracy on group 1/10: 0.33
#
# Epoch 14/70 LR: [2]
# Validation accuracy on group 1/10: 0.30
#
# Epoch 15/70 LR: [2]
# Validation accuracy on group 1/10: 0.31
#
# Epoch 16/70 LR: [2]
# Validation accuracy on group 1/10: 0.33
#
# Epoch 17/70 LR: [2]
# Validation accuracy on group 1/10: 0.36
# Best model updated
#
# Epoch 18/70 LR: [2]
# Validation accuracy on group 1/10: 0.36
# Best model updated
#
# Epoch 19/70 LR: [2]
# Validation accuracy on group 1/10: 0.34
#
# Epoch 20/70 LR: [2]
# Validation accuracy on group 1/10: 0.35
#
# Epoch 21/70 LR: [2]
# Validation accuracy on group 1/10: 0.34
#
# Epoch 22/70 LR: [2]
# Validation accuracy on group 1/10: 0.39
# Best model updated
#
# Epoch 23/70 LR: [2]
# Validation accuracy on group 1/10: 0.39
#
# Epoch 24/70 LR: [2]
# Validation accuracy on group 1/10: 0.39
#
# Epoch 25/70 LR: [2]
# Validation accuracy on group 1/10: 0.39
#
# Epoch 26/70 LR: [2]
# Validation accuracy on group 1/10: 0.43
# Best model updated
#
# Epoch 27/70 LR: [2]
# Validation accuracy on group 1/10: 0.40
#
# Epoch 28/70 LR: [2]
# Validation accuracy on group 1/10: 0.43
#
# Epoch 29/70 LR: [2]
# Validation accuracy on group 1/10: 0.46
# Best model updated
#
# Epoch 30/70 LR: [2]
# Validation accuracy on group 1/10: 0.44
#
# Epoch 31/70 LR: [2]
# Validation accuracy on group 1/10: 0.40
#
# Epoch 32/70 LR: [2]
# Validation accuracy on group 1/10: 0.40
#
# Epoch 33/70 LR: [2]
# Validation accuracy on group 1/10: 0.45
#
# Epoch 34/70 LR: [2]
# Validation accuracy on group 1/10: 0.46
# Best model updated
#
# Epoch 35/70 LR: [2]
# Validation accuracy on group 1/10: 0.45
#
# Epoch 36/70 LR: [2]
# Validation accuracy on group 1/10: 0.46
#
# Epoch 37/70 LR: [2]
# Validation accuracy on group 1/10: 0.43
#
# Epoch 38/70 LR: [2]
# Validation accuracy on group 1/10: 0.42
#
# Epoch 39/70 LR: [2]
# Validation accuracy on group 1/10: 0.46
#
# Epoch 40/70 LR: [2]
# Validation accuracy on group 1/10: 0.45
#
# Epoch 41/70 LR: [2]
# Validation accuracy on group 1/10: 0.47
# Best model updated
#
# Epoch 42/70 LR: [2]
# Validation accuracy on group 1/10: 0.53
# Best model updated
#
# Epoch 43/70 LR: [2]
# Validation accuracy on group 1/10: 0.45
#
# Epoch 44/70 LR: [2]
# Validation accuracy on group 1/10: 0.53
# Best model updated
#
# Epoch 45/70 LR: [2]
# Validation accuracy on group 1/10: 0.52
#
# Epoch 46/70 LR: [2]
# Validation accuracy on group 1/10: 0.52
#
# Epoch 47/70 LR: [2]
# Validation accuracy on group 1/10: 0.53
# Best model updated
#
# Epoch 48/70 LR: [2]
# Validation accuracy on group 1/10: 0.52
#
# Epoch 49/70 LR: [2]
# Validation accuracy on group 1/10: 0.53
#
# Epoch 50/70 LR: [0.4]
# Validation accuracy on group 1/10: 0.59
# Best model updated
#
# Epoch 51/70 LR: [0.4]
# Validation accuracy on group 1/10: 0.60
# Best model updated
#
# Epoch 52/70 LR: [0.4]
# Validation accuracy on group 1/10: 0.64
# Best model updated
#
# Epoch 53/70 LR: [0.4]
# Validation accuracy on group 1/10: 0.62
#
# Epoch 54/70 LR: [0.4]
# Validation accuracy on group 1/10: 0.59
#
# Epoch 55/70 LR: [0.4]
# Validation accuracy on group 1/10: 0.64
# Best model updated
#
# Epoch 56/70 LR: [0.4]
# Validation accuracy on group 1/10: 0.60
#
# Epoch 57/70 LR: [0.4]
# Validation accuracy on group 1/10: 0.64
# Best model updated
#
# Epoch 58/70 LR: [0.4]
# Validation accuracy on group 1/10: 0.64
# Best model updated
#
# Epoch 59/70 LR: [0.4]
# Validation accuracy on group 1/10: 0.64
#
# Epoch 60/70 LR: [0.4]
# Validation accuracy on group 1/10: 0.61
#
# Epoch 61/70 LR: [0.4]
# Validation accuracy on group 1/10: 0.61
#
# Epoch 62/70 LR: [0.4]
# Validation accuracy on group 1/10: 0.61
#
# Epoch 63/70 LR: [0.4]
# Validation accuracy on group 1/10: 0.64
# Best model updated
#
# Epoch 64/70 LR: [0.08000000000000002]
# Validation accuracy on group 1/10: 0.63
#
# Epoch 65/70 LR: [0.08000000000000002]
# Validation accuracy on group 1/10: 0.66
# Best model updated
#
# Epoch 66/70 LR: [0.08000000000000002]
# Validation accuracy on group 1/10: 0.66
# Best model updated
#
# Epoch 67/70 LR: [0.08000000000000002]
# Validation accuracy on group 1/10: 0.65
#
# Epoch 68/70 LR: [0.08000000000000002]
# Validation accuracy on group 1/10: 0.65
#
# Epoch 69/70 LR: [0.08000000000000002]
# Validation accuracy on group 1/10: 0.65
#
# Epoch 70/70 LR: [0.08000000000000002]
# Validation accuracy on group 1/10: 0.66
#
# Group 1 Finished!
# Best accuracy found at epoch 66: 0.66
# Testing classes seen so far, accuracy: 0.63
#
# =============================================
#
# Epoch 1/70 LR: [2]
# Validation accuracy on group 2/10: 0.37
# Best model updated
#
# Epoch 2/70 LR: [2]
# Validation accuracy on group 2/10: 0.41
# Best model updated
#
# Epoch 3/70 LR: [2]
# Validation accuracy on group 2/10: 0.41
# Best model updated
#
# Epoch 4/70 LR: [2]
# Validation accuracy on group 2/10: 0.43
# Best model updated
#
# Epoch 5/70 LR: [2]
# Validation accuracy on group 2/10: 0.44
# Best model updated
#
# Epoch 6/70 LR: [2]
# Validation accuracy on group 2/10: 0.46
# Best model updated
#
# Epoch 7/70 LR: [2]
# Validation accuracy on group 2/10: 0.47
# Best model updated
#
# Epoch 8/70 LR: [2]
# Validation accuracy on group 2/10: 0.53
# Best model updated
#
# Epoch 9/70 LR: [2]
# Validation accuracy on group 2/10: 0.54
# Best model updated
#
# Epoch 10/70 LR: [2]
# Validation accuracy on group 2/10: 0.44
#
# Epoch 11/70 LR: [2]
# Validation accuracy on group 2/10: 0.54
# Best model updated
#
# Epoch 12/70 LR: [2]
# Validation accuracy on group 2/10: 0.52
#
# Epoch 13/70 LR: [2]
# Validation accuracy on group 2/10: 0.51
#
# Epoch 14/70 LR: [2]
# Validation accuracy on group 2/10: 0.57
# Best model updated
#
# Epoch 15/70 LR: [2]
# Validation accuracy on group 2/10: 0.53
#
# Epoch 16/70 LR: [2]
# Validation accuracy on group 2/10: 0.55
#
# Epoch 17/70 LR: [2]
# Validation accuracy on group 2/10: 0.54
#
# Epoch 18/70 LR: [2]
# Validation accuracy on group 2/10: 0.57
#
# Epoch 19/70 LR: [2]
# Validation accuracy on group 2/10: 0.55
#
# Epoch 20/70 LR: [2]
# Validation accuracy on group 2/10: 0.59
# Best model updated
#
# Epoch 21/70 LR: [2]
# Validation accuracy on group 2/10: 0.58
#
# Epoch 22/70 LR: [2]
# Validation accuracy on group 2/10: 0.58
#
# Epoch 23/70 LR: [2]
# Validation accuracy on group 2/10: 0.56
#
# Epoch 24/70 LR: [2]
# Validation accuracy on group 2/10: 0.56
#
# Epoch 25/70 LR: [2]
# Validation accuracy on group 2/10: 0.59
# Best model updated
#
# Epoch 26/70 LR: [2]
# Validation accuracy on group 2/10: 0.60
# Best model updated
#
# Epoch 27/70 LR: [2]
# Validation accuracy on group 2/10: 0.59
#
# Epoch 28/70 LR: [2]
# Validation accuracy on group 2/10: 0.56
#
# Epoch 29/70 LR: [2]
# Validation accuracy on group 2/10: 0.61
# Best model updated
#
# Epoch 30/70 LR: [2]
# Validation accuracy on group 2/10: 0.58
#
# Epoch 31/70 LR: [2]
# Validation accuracy on group 2/10: 0.61
# Best model updated
#
# Epoch 32/70 LR: [2]
# Validation accuracy on group 2/10: 0.57
#
# Epoch 33/70 LR: [2]
# Validation accuracy on group 2/10: 0.61
#
# Epoch 34/70 LR: [2]
# Validation accuracy on group 2/10: 0.61
#
# Epoch 35/70 LR: [2]
# Validation accuracy on group 2/10: 0.62
# Best model updated
#
# Epoch 36/70 LR: [2]
# Validation accuracy on group 2/10: 0.58
#
# Epoch 37/70 LR: [2]
# Validation accuracy on group 2/10: 0.60
#
# Epoch 38/70 LR: [2]
# Validation accuracy on group 2/10: 0.57
#
# Epoch 39/70 LR: [2]
# Validation accuracy on group 2/10: 0.63
# Best model updated
#
# Epoch 40/70 LR: [2]
# Validation accuracy on group 2/10: 0.62
#
# Epoch 41/70 LR: [2]
# Validation accuracy on group 2/10: 0.60
#
# Epoch 42/70 LR: [2]
# Validation accuracy on group 2/10: 0.60
#
# Epoch 43/70 LR: [2]
# Validation accuracy on group 2/10: 0.61
#
# Epoch 44/70 LR: [2]
# Validation accuracy on group 2/10: 0.60
#
# Epoch 45/70 LR: [2]
# Validation accuracy on group 2/10: 0.59
#
# Epoch 46/70 LR: [2]
# Validation accuracy on group 2/10: 0.59
#
# Epoch 47/70 LR: [2]
# Validation accuracy on group 2/10: 0.58
#
# Epoch 48/70 LR: [2]
# Validation accuracy on group 2/10: 0.61
#
# Epoch 49/70 LR: [2]
# Validation accuracy on group 2/10: 0.63
# Best model updated
#
# Epoch 50/70 LR: [0.4]
# Validation accuracy on group 2/10: 0.71
# Best model updated
#
# Epoch 51/70 LR: [0.4]
# Validation accuracy on group 2/10: 0.70
#
# Epoch 52/70 LR: [0.4]
# Validation accuracy on group 2/10: 0.70
#
# Epoch 53/70 LR: [0.4]
# Validation accuracy on group 2/10: 0.70
#
# Epoch 54/70 LR: [0.4]
# Validation accuracy on group 2/10: 0.69
#
# Epoch 55/70 LR: [0.4]
# Validation accuracy on group 2/10: 0.71
# Best model updated
#
# Epoch 56/70 LR: [0.4]
# Validation accuracy on group 2/10: 0.70
#
# Epoch 57/70 LR: [0.4]
# Validation accuracy on group 2/10: 0.72
# Best model updated
#
# Epoch 58/70 LR: [0.4]
# Validation accuracy on group 2/10: 0.70
#
# Epoch 59/70 LR: [0.4]
# Validation accuracy on group 2/10: 0.71
#
# Epoch 60/70 LR: [0.4]
# Validation accuracy on group 2/10: 0.71
#
# Epoch 61/70 LR: [0.4]
# Validation accuracy on group 2/10: 0.69
#
# Epoch 62/70 LR: [0.4]
# Validation accuracy on group 2/10: 0.71
#
# Epoch 63/70 LR: [0.4]
# Validation accuracy on group 2/10: 0.69
#
# Epoch 64/70 LR: [0.08000000000000002]
# Validation accuracy on group 2/10: 0.72
#
# Epoch 65/70 LR: [0.08000000000000002]
# Validation accuracy on group 2/10: 0.70
#
# Epoch 66/70 LR: [0.08000000000000002]
# Validation accuracy on group 2/10: 0.70
#
# Epoch 67/70 LR: [0.08000000000000002]
# Validation accuracy on group 2/10: 0.70
#
# Epoch 68/70 LR: [0.08000000000000002]
# Validation accuracy on group 2/10: 0.71
#
# Epoch 69/70 LR: [0.08000000000000002]
# Validation accuracy on group 2/10: 0.70
#
# Epoch 70/70 LR: [0.08000000000000002]
# Validation accuracy on group 2/10: 0.71
#
# Group 2 Finished!
# Best accuracy found at epoch 57: 0.72
# Testing classes seen so far, accuracy: 0.69
#
# =============================================
#
# Epoch 1/70 LR: [2]
# Validation accuracy on group 3/10: 0.57
# Best model updated
#
# Epoch 2/70 LR: [2]
# Validation accuracy on group 3/10: 0.57
# Best model updated
#
# Epoch 3/70 LR: [2]
# Validation accuracy on group 3/10: 0.59
# Best model updated
#
# Epoch 4/70 LR: [2]
# Validation accuracy on group 3/10: 0.58
#
# Epoch 5/70 LR: [2]
# Validation accuracy on group 3/10: 0.55
#
# Epoch 6/70 LR: [2]
# Validation accuracy on group 3/10: 0.61
# Best model updated
#
# Epoch 7/70 LR: [2]
# Validation accuracy on group 3/10: 0.57
#
# Epoch 8/70 LR: [2]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 9/70 LR: [2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 10/70 LR: [2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 11/70 LR: [2]
# Validation accuracy on group 3/10: 0.57
#
# Epoch 12/70 LR: [2]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 13/70 LR: [2]
# Validation accuracy on group 3/10: 0.57
#
# Epoch 14/70 LR: [2]
# Validation accuracy on group 3/10: 0.61
# Best model updated
#
# Epoch 15/70 LR: [2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 16/70 LR: [2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 17/70 LR: [2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 18/70 LR: [2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 19/70 LR: [2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 20/70 LR: [2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 21/70 LR: [2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 22/70 LR: [2]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 23/70 LR: [2]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 24/70 LR: [2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 25/70 LR: [2]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 26/70 LR: [2]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 27/70 LR: [2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 28/70 LR: [2]
# Validation accuracy on group 3/10: 0.61
# Best model updated
#
# Epoch 29/70 LR: [2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 30/70 LR: [2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 31/70 LR: [2]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 32/70 LR: [2]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 33/70 LR: [2]
# Validation accuracy on group 3/10: 0.55
#
# Epoch 34/70 LR: [2]
# Validation accuracy on group 3/10: 0.61
#
# Epoch 35/70 LR: [2]
# Validation accuracy on group 3/10: 0.56
#
# Epoch 36/70 LR: [2]
# Validation accuracy on group 3/10: 0.58
#
# Epoch 37/70 LR: [2]
# Validation accuracy on group 3/10: 0.62
# Best model updated
#
# Epoch 38/70 LR: [2]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 39/70 LR: [2]
# Validation accuracy on group 3/10: 0.62
# Best model updated
#
# Epoch 40/70 LR: [2]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 41/70 LR: [2]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 42/70 LR: [2]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 43/70 LR: [2]
# Validation accuracy on group 3/10: 0.62
#
# Epoch 44/70 LR: [2]
# Validation accuracy on group 3/10: 0.60
#
# Epoch 45/70 LR: [2]
# Validation accuracy on group 3/10: 0.61
#
# Epoch 46/70 LR: [2]
# Validation accuracy on group 3/10: 0.59
#
# Epoch 47/70 LR: [2]
# Validation accuracy on group 3/10: 0.58
#
# Epoch 48/70 LR: [2]
# Validation accuracy on group 3/10: 0.61
#
# Epoch 49/70 LR: [2]
# Validation accuracy on group 3/10: 0.63
# Best model updated
#
# Epoch 50/70 LR: [0.4]
# Validation accuracy on group 3/10: 0.67
# Best model updated
#
# Epoch 51/70 LR: [0.4]
# Validation accuracy on group 3/10: 0.68
# Best model updated
#
# Epoch 52/70 LR: [0.4]
# Validation accuracy on group 3/10: 0.69
# Best model updated
#
# Epoch 53/70 LR: [0.4]
# Validation accuracy on group 3/10: 0.67
#
# Epoch 54/70 LR: [0.4]
# Validation accuracy on group 3/10: 0.69
# Best model updated
#
# Epoch 55/70 LR: [0.4]
# Validation accuracy on group 3/10: 0.68
#
# Epoch 56/70 LR: [0.4]
# Validation accuracy on group 3/10: 0.69
#
# Epoch 57/70 LR: [0.4]
# Validation accuracy on group 3/10: 0.69
# Best model updated
#
# Epoch 58/70 LR: [0.4]
# Validation accuracy on group 3/10: 0.70
# Best model updated
#
# Epoch 59/70 LR: [0.4]
# Validation accuracy on group 3/10: 0.69
#
# Epoch 60/70 LR: [0.4]
# Validation accuracy on group 3/10: 0.68
#
# Epoch 61/70 LR: [0.4]
# Validation accuracy on group 3/10: 0.69
#
# Epoch 62/70 LR: [0.4]
# Validation accuracy on group 3/10: 0.67
#
# Epoch 63/70 LR: [0.4]
# Validation accuracy on group 3/10: 0.68
#
# Epoch 64/70 LR: [0.08000000000000002]
# Validation accuracy on group 3/10: 0.69
#
# Epoch 65/70 LR: [0.08000000000000002]
# Validation accuracy on group 3/10: 0.70
# Best model updated
#
# Epoch 66/70 LR: [0.08000000000000002]
# Validation accuracy on group 3/10: 0.69
#
# Epoch 67/70 LR: [0.08000000000000002]
# Validation accuracy on group 3/10: 0.69
#
# Epoch 68/70 LR: [0.08000000000000002]
# Validation accuracy on group 3/10: 0.69
#
# Epoch 69/70 LR: [0.08000000000000002]
# Validation accuracy on group 3/10: 0.69
#
# Epoch 70/70 LR: [0.08000000000000002]
# Validation accuracy on group 3/10: 0.69
#
# Group 3 Finished!
# Best accuracy found at epoch 65: 0.70
# Testing classes seen so far, accuracy: 0.67
#
# =============================================
#
# Epoch 1/70 LR: [2]
# Validation accuracy on group 4/10: 0.61
# Best model updated
#
# Epoch 2/70 LR: [2]
# Validation accuracy on group 4/10: 0.63
# Best model updated
#
# Epoch 3/70 LR: [2]
# Validation accuracy on group 4/10: 0.62
#
# Epoch 4/70 LR: [2]
# Validation accuracy on group 4/10: 0.63
# Best model updated
#
# Epoch 5/70 LR: [2]
# Validation accuracy on group 4/10: 0.62
#
# Epoch 6/70 LR: [2]
# Validation accuracy on group 4/10: 0.61
#
# Epoch 7/70 LR: [2]
# Validation accuracy on group 4/10: 0.61
#
# Epoch 8/70 LR: [2]
# Validation accuracy on group 4/10: 0.62
#
# Epoch 9/70 LR: [2]
# Validation accuracy on group 4/10: 0.57
#
# Epoch 10/70 LR: [2]
# Validation accuracy on group 4/10: 0.60
#
# Epoch 11/70 LR: [2]
# Validation accuracy on group 4/10: 0.61
#
# Epoch 12/70 LR: [2]
# Validation accuracy on group 4/10: 0.60
#
# Epoch 13/70 LR: [2]
# Validation accuracy on group 4/10: 0.62
#
# Epoch 14/70 LR: [2]
# Validation accuracy on group 4/10: 0.62
#
# Epoch 15/70 LR: [2]
# Validation accuracy on group 4/10: 0.61
#
# Epoch 16/70 LR: [2]
# Validation accuracy on group 4/10: 0.63
# Best model updated
#
# Epoch 17/70 LR: [2]
# Validation accuracy on group 4/10: 0.59
#
# Epoch 18/70 LR: [2]
# Validation accuracy on group 4/10: 0.61
#
# Epoch 19/70 LR: [2]
# Validation accuracy on group 4/10: 0.63
#
# Epoch 20/70 LR: [2]
# Validation accuracy on group 4/10: 0.62
#
# Epoch 21/70 LR: [2]
# Validation accuracy on group 4/10: 0.62
#
# Epoch 22/70 LR: [2]
# Validation accuracy on group 4/10: 0.60
#
# Epoch 23/70 LR: [2]
# Validation accuracy on group 4/10: 0.62
#
# Epoch 24/70 LR: [2]
# Validation accuracy on group 4/10: 0.61
#
# Epoch 25/70 LR: [2]
# Validation accuracy on group 4/10: 0.59
#
# Epoch 26/70 LR: [2]
# Validation accuracy on group 4/10: 0.59
#
# Epoch 27/70 LR: [2]
# Validation accuracy on group 4/10: 0.58
#
# Epoch 28/70 LR: [2]
# Validation accuracy on group 4/10: 0.60
#
# Epoch 29/70 LR: [2]
# Validation accuracy on group 4/10: 0.60
#
# Epoch 30/70 LR: [2]
# Validation accuracy on group 4/10: 0.59
#
# Epoch 31/70 LR: [2]
# Validation accuracy on group 4/10: 0.60
#
# Epoch 32/70 LR: [2]
# Validation accuracy on group 4/10: 0.58
#
# Epoch 33/70 LR: [2]
# Validation accuracy on group 4/10: 0.61
#
# Epoch 34/70 LR: [2]
# Validation accuracy on group 4/10: 0.63
#
# Epoch 35/70 LR: [2]
# Validation accuracy on group 4/10: 0.58
#
# Epoch 36/70 LR: [2]
# Validation accuracy on group 4/10: 0.60
#
# Epoch 37/70 LR: [2]
# Validation accuracy on group 4/10: 0.59
#
# Epoch 38/70 LR: [2]
# Validation accuracy on group 4/10: 0.60
#
# Epoch 39/70 LR: [2]
# Validation accuracy on group 4/10: 0.56
#
# Epoch 40/70 LR: [2]
# Validation accuracy on group 4/10: 0.62
#
# Epoch 41/70 LR: [2]
# Validation accuracy on group 4/10: 0.60
#
# Epoch 42/70 LR: [2]
# Validation accuracy on group 4/10: 0.59
#
# Epoch 43/70 LR: [2]
# Validation accuracy on group 4/10: 0.62
#
# Epoch 44/70 LR: [2]
# Validation accuracy on group 4/10: 0.62
#
# Epoch 45/70 LR: [2]
# Validation accuracy on group 4/10: 0.59
#
# Epoch 46/70 LR: [2]
# Validation accuracy on group 4/10: 0.63
# Best model updated
#
# Epoch 47/70 LR: [2]
# Validation accuracy on group 4/10: 0.59
#
# Epoch 48/70 LR: [2]
# Validation accuracy on group 4/10: 0.61
#
# Epoch 49/70 LR: [2]
# Validation accuracy on group 4/10: 0.58
#
# Epoch 50/70 LR: [0.4]
# Validation accuracy on group 4/10: 0.68
# Best model updated
#
# Epoch 51/70 LR: [0.4]
# Validation accuracy on group 4/10: 0.70
# Best model updated
#
# Epoch 52/70 LR: [0.4]
# Validation accuracy on group 4/10: 0.69
#
# Epoch 53/70 LR: [0.4]
# Validation accuracy on group 4/10: 0.69
#
# Epoch 54/70 LR: [0.4]
# Validation accuracy on group 4/10: 0.70
# Best model updated
#
# Epoch 55/70 LR: [0.4]
# Validation accuracy on group 4/10: 0.69
#
# Epoch 56/70 LR: [0.4]
# Validation accuracy on group 4/10: 0.70
# Best model updated
#
# Epoch 57/70 LR: [0.4]
# Validation accuracy on group 4/10: 0.70
# Best model updated
#
# Epoch 58/70 LR: [0.4]
# Validation accuracy on group 4/10: 0.69
#
# Epoch 59/70 LR: [0.4]
# Validation accuracy on group 4/10: 0.69
#
# Epoch 60/70 LR: [0.4]
# Validation accuracy on group 4/10: 0.69
#
# Epoch 61/70 LR: [0.4]
# Validation accuracy on group 4/10: 0.69
#
# Epoch 62/70 LR: [0.4]
# Validation accuracy on group 4/10: 0.69
#
# Epoch 63/70 LR: [0.4]
# Validation accuracy on group 4/10: 0.69
#
# Epoch 64/70 LR: [0.08000000000000002]
# Validation accuracy on group 4/10: 0.69
#
# Epoch 65/70 LR: [0.08000000000000002]
# Validation accuracy on group 4/10: 0.70
# Best model updated
#
# Epoch 66/70 LR: [0.08000000000000002]
# Validation accuracy on group 4/10: 0.69
#
# Epoch 67/70 LR: [0.08000000000000002]
# Validation accuracy on group 4/10: 0.69
#
# Epoch 68/70 LR: [0.08000000000000002]
# Validation accuracy on group 4/10: 0.69
#
# Epoch 69/70 LR: [0.08000000000000002]
# Validation accuracy on group 4/10: 0.70
# Best model updated
#
# Epoch 70/70 LR: [0.08000000000000002]
# Validation accuracy on group 4/10: 0.69
#
# Group 4 Finished!
# Best accuracy found at epoch 69: 0.70
# Testing classes seen so far, accuracy: 0.68
#
# =============================================
#
# Epoch 1/70 LR: [2]
# Validation accuracy on group 5/10: 0.64
# Best model updated
#
# Epoch 2/70 LR: [2]
# Validation accuracy on group 5/10: 0.61
#
# Epoch 3/70 LR: [2]
# Validation accuracy on group 5/10: 0.62
#
# Epoch 4/70 LR: [2]
# Validation accuracy on group 5/10: 0.61
#
# Epoch 5/70 LR: [2]
# Validation accuracy on group 5/10: 0.64
# Best model updated
#
# Epoch 6/70 LR: [2]
# Validation accuracy on group 5/10: 0.62
#
# Epoch 7/70 LR: [2]
# Validation accuracy on group 5/10: 0.61
#
# Epoch 8/70 LR: [2]
# Validation accuracy on group 5/10: 0.59
#
# Epoch 9/70 LR: [2]
# Validation accuracy on group 5/10: 0.62
#
# Epoch 10/70 LR: [2]
# Validation accuracy on group 5/10: 0.60
#
# Epoch 11/70 LR: [2]
# Validation accuracy on group 5/10: 0.60
#
# Epoch 12/70 LR: [2]
# Validation accuracy on group 5/10: 0.61
#
# Epoch 13/70 LR: [2]
# Validation accuracy on group 5/10: 0.63
#
# Epoch 14/70 LR: [2]
# Validation accuracy on group 5/10: 0.59
#
# Epoch 15/70 LR: [2]
# Validation accuracy on group 5/10: 0.61
#
# Epoch 16/70 LR: [2]
# Validation accuracy on group 5/10: 0.57
#
# Epoch 17/70 LR: [2]
# Validation accuracy on group 5/10: 0.61
#
# Epoch 18/70 LR: [2]
# Validation accuracy on group 5/10: 0.61
#
# Epoch 19/70 LR: [2]
# Validation accuracy on group 5/10: 0.61
#
# Epoch 20/70 LR: [2]
# Validation accuracy on group 5/10: 0.63
#
# Epoch 21/70 LR: [2]
# Validation accuracy on group 5/10: 0.60
#
# Epoch 22/70 LR: [2]
# Validation accuracy on group 5/10: 0.61
#
# Epoch 23/70 LR: [2]
# Validation accuracy on group 5/10: 0.60
#
# Epoch 24/70 LR: [2]
# Validation accuracy on group 5/10: 0.58
#
# Epoch 25/70 LR: [2]
# Validation accuracy on group 5/10: 0.61
#
# Epoch 26/70 LR: [2]
# Validation accuracy on group 5/10: 0.62
#
# Epoch 27/70 LR: [2]
# Validation accuracy on group 5/10: 0.61
#
# Epoch 28/70 LR: [2]
# Validation accuracy on group 5/10: 0.59
#
# Epoch 29/70 LR: [2]
# Validation accuracy on group 5/10: 0.62
#
# Epoch 30/70 LR: [2]
# Validation accuracy on group 5/10: 0.59
#
# Epoch 31/70 LR: [2]
# Validation accuracy on group 5/10: 0.60
#
# Epoch 32/70 LR: [2]
# Validation accuracy on group 5/10: 0.59
#
# Epoch 33/70 LR: [2]
# Validation accuracy on group 5/10: 0.59
#
# Epoch 34/70 LR: [2]
# Validation accuracy on group 5/10: 0.60
#
# Epoch 35/70 LR: [2]
# Validation accuracy on group 5/10: 0.62
#
# Epoch 36/70 LR: [2]
# Validation accuracy on group 5/10: 0.60
#
# Epoch 37/70 LR: [2]
# Validation accuracy on group 5/10: 0.59
#
# Epoch 38/70 LR: [2]
# Validation accuracy on group 5/10: 0.62
#
# Epoch 39/70 LR: [2]
# Validation accuracy on group 5/10: 0.56
#
# Epoch 40/70 LR: [2]
# Validation accuracy on group 5/10: 0.62
#
# Epoch 41/70 LR: [2]
# Validation accuracy on group 5/10: 0.59
#
# Epoch 42/70 LR: [2]
# Validation accuracy on group 5/10: 0.57
#
# Epoch 43/70 LR: [2]
# Validation accuracy on group 5/10: 0.58
#
# Epoch 44/70 LR: [2]
# Validation accuracy on group 5/10: 0.58
#
# Epoch 45/70 LR: [2]
# Validation accuracy on group 5/10: 0.59
#
# Epoch 46/70 LR: [2]
# Validation accuracy on group 5/10: 0.62
#
# Epoch 47/70 LR: [2]
# Validation accuracy on group 5/10: 0.61
#
# Epoch 48/70 LR: [2]
# Validation accuracy on group 5/10: 0.54
#
# Epoch 49/70 LR: [2]
# Validation accuracy on group 5/10: 0.60
#
# Epoch 50/70 LR: [0.4]
# Validation accuracy on group 5/10: 0.69
# Best model updated
#
# Epoch 51/70 LR: [0.4]
# Validation accuracy on group 5/10: 0.70
# Best model updated
#
# Epoch 52/70 LR: [0.4]
# Validation accuracy on group 5/10: 0.70
#
# Epoch 53/70 LR: [0.4]
# Validation accuracy on group 5/10: 0.70
# Best model updated
#
# Epoch 54/70 LR: [0.4]
# Validation accuracy on group 5/10: 0.70
#
# Epoch 55/70 LR: [0.4]
# Validation accuracy on group 5/10: 0.70
#
# Epoch 56/70 LR: [0.4]
# Validation accuracy on group 5/10: 0.71
# Best model updated
#
# Epoch 57/70 LR: [0.4]
# Validation accuracy on group 5/10: 0.70
#
# Epoch 58/70 LR: [0.4]
# Validation accuracy on group 5/10: 0.71
#
# Epoch 59/70 LR: [0.4]
# Validation accuracy on group 5/10: 0.71
#
# Epoch 60/70 LR: [0.4]
# Validation accuracy on group 5/10: 0.70
#
# Epoch 61/70 LR: [0.4]
# Validation accuracy on group 5/10: 0.70
#
# Epoch 62/70 LR: [0.4]
# Validation accuracy on group 5/10: 0.70
#
# Epoch 63/70 LR: [0.4]
# Validation accuracy on group 5/10: 0.70
#
# Epoch 64/70 LR: [0.08000000000000002]
# Validation accuracy on group 5/10: 0.70
#
# Epoch 65/70 LR: [0.08000000000000002]
# Validation accuracy on group 5/10: 0.71
#
# Epoch 66/70 LR: [0.08000000000000002]
# Validation accuracy on group 5/10: 0.71
#
# Epoch 67/70 LR: [0.08000000000000002]
# Validation accuracy on group 5/10: 0.71
#
# Epoch 68/70 LR: [0.08000000000000002]
# Validation accuracy on group 5/10: 0.71
#
# Epoch 69/70 LR: [0.08000000000000002]
# Validation accuracy on group 5/10: 0.71
#
# Epoch 70/70 LR: [0.08000000000000002]
# Validation accuracy on group 5/10: 0.71
#
# Group 5 Finished!
# Best accuracy found at epoch 56: 0.71
# Testing classes seen so far, accuracy: 0.68
#
# =============================================
#
# Epoch 1/70 LR: [2]
# Validation accuracy on group 6/10: 0.61
# Best model updated
#
# Epoch 2/70 LR: [2]
# Validation accuracy on group 6/10: 0.61
#
# Epoch 3/70 LR: [2]
# Validation accuracy on group 6/10: 0.60
#
# Epoch 4/70 LR: [2]
# Validation accuracy on group 6/10: 0.63
# Best model updated
#
# Epoch 5/70 LR: [2]
# Validation accuracy on group 6/10: 0.57
#
# Epoch 6/70 LR: [2]
# Validation accuracy on group 6/10: 0.57
#
# Epoch 7/70 LR: [2]
# Validation accuracy on group 6/10: 0.58
#
# Epoch 8/70 LR: [2]
# Validation accuracy on group 6/10: 0.60
#
# Epoch 9/70 LR: [2]
# Validation accuracy on group 6/10: 0.58
#
# Epoch 10/70 LR: [2]
# Validation accuracy on group 6/10: 0.60
#
# Epoch 11/70 LR: [2]
# Validation accuracy on group 6/10: 0.61
#
# Epoch 12/70 LR: [2]
# Validation accuracy on group 6/10: 0.60
#
# Epoch 13/70 LR: [2]
# Validation accuracy on group 6/10: 0.60
#
# Epoch 14/70 LR: [2]
# Validation accuracy on group 6/10: 0.60
#
# Epoch 15/70 LR: [2]
# Validation accuracy on group 6/10: 0.60
#
# Epoch 16/70 LR: [2]
# Validation accuracy on group 6/10: 0.57
#
# Epoch 17/70 LR: [2]
# Validation accuracy on group 6/10: 0.59
#
# Epoch 18/70 LR: [2]
# Validation accuracy on group 6/10: 0.58
#
# Epoch 19/70 LR: [2]
# Validation accuracy on group 6/10: 0.62
#
# Epoch 20/70 LR: [2]
# Validation accuracy on group 6/10: 0.58
#
# Epoch 21/70 LR: [2]
# Validation accuracy on group 6/10: 0.59
#
# Epoch 22/70 LR: [2]
# Validation accuracy on group 6/10: 0.59
#
# Epoch 23/70 LR: [2]
# Validation accuracy on group 6/10: 0.58
#
# Epoch 24/70 LR: [2]
# Validation accuracy on group 6/10: 0.58
#
# Epoch 25/70 LR: [2]
# Validation accuracy on group 6/10: 0.59
#
# Epoch 26/70 LR: [2]
# Validation accuracy on group 6/10: 0.61
#
# Epoch 27/70 LR: [2]
# Validation accuracy on group 6/10: 0.59
#
# Epoch 28/70 LR: [2]
# Validation accuracy on group 6/10: 0.57
#
# Epoch 29/70 LR: [2]
# Validation accuracy on group 6/10: 0.57
#
# Epoch 30/70 LR: [2]
# Validation accuracy on group 6/10: 0.56
#
# Epoch 31/70 LR: [2]
# Validation accuracy on group 6/10: 0.59
#
# Epoch 32/70 LR: [2]
# Validation accuracy on group 6/10: 0.57
#
# Epoch 33/70 LR: [2]
# Validation accuracy on group 6/10: 0.59
#
# Epoch 34/70 LR: [2]
# Validation accuracy on group 6/10: 0.57
#
# Epoch 35/70 LR: [2]
# Validation accuracy on group 6/10: 0.60
#
# Epoch 36/70 LR: [2]
# Validation accuracy on group 6/10: 0.56
#
# Epoch 37/70 LR: [2]
# Validation accuracy on group 6/10: 0.60
#
# Epoch 38/70 LR: [2]
# Validation accuracy on group 6/10: 0.59
#
# Epoch 39/70 LR: [2]
# Validation accuracy on group 6/10: 0.58
#
# Epoch 40/70 LR: [2]
# Validation accuracy on group 6/10: 0.60
#
# Epoch 41/70 LR: [2]
# Validation accuracy on group 6/10: 0.57
#
# Epoch 42/70 LR: [2]
# Validation accuracy on group 6/10: 0.60
#
# Epoch 43/70 LR: [2]
# Validation accuracy on group 6/10: 0.62
#
# Epoch 44/70 LR: [2]
# Validation accuracy on group 6/10: 0.55
#
# Epoch 45/70 LR: [2]
# Validation accuracy on group 6/10: 0.59
#
# Epoch 46/70 LR: [2]
# Validation accuracy on group 6/10: 0.59
#
# Epoch 47/70 LR: [2]
# Validation accuracy on group 6/10: 0.58
#
# Epoch 48/70 LR: [2]
# Validation accuracy on group 6/10: 0.57
#
# Epoch 49/70 LR: [2]
# Validation accuracy on group 6/10: 0.58
#
# Epoch 50/70 LR: [0.4]
# Validation accuracy on group 6/10: 0.69
# Best model updated
#
# Epoch 51/70 LR: [0.4]
# Validation accuracy on group 6/10: 0.69
#
# Epoch 52/70 LR: [0.4]
# Validation accuracy on group 6/10: 0.70
# Best model updated
#
# Epoch 53/70 LR: [0.4]
# Validation accuracy on group 6/10: 0.69
#
# Epoch 54/70 LR: [0.4]
# Validation accuracy on group 6/10: 0.69
#
# Epoch 55/70 LR: [0.4]
# Validation accuracy on group 6/10: 0.70
#
# Epoch 56/70 LR: [0.4]
# Validation accuracy on group 6/10: 0.69
#
# Epoch 57/70 LR: [0.4]
# Validation accuracy on group 6/10: 0.70
#
# Epoch 58/70 LR: [0.4]
# Validation accuracy on group 6/10: 0.69
#
# Epoch 59/70 LR: [0.4]
# Validation accuracy on group 6/10: 0.69
#
# Epoch 60/70 LR: [0.4]
# Validation accuracy on group 6/10: 0.69
#
# Epoch 61/70 LR: [0.4]
# Validation accuracy on group 6/10: 0.69
#
# Epoch 62/70 LR: [0.4]
# Validation accuracy on group 6/10: 0.69
#
# Epoch 63/70 LR: [0.4]
# Validation accuracy on group 6/10: 0.69
#
# Epoch 64/70 LR: [0.08000000000000002]
# Validation accuracy on group 6/10: 0.71
# Best model updated
#
# Epoch 65/70 LR: [0.08000000000000002]
# Validation accuracy on group 6/10: 0.70
#
# Epoch 66/70 LR: [0.08000000000000002]
# Validation accuracy on group 6/10: 0.70
#
# Epoch 67/70 LR: [0.08000000000000002]
# Validation accuracy on group 6/10: 0.71
#
# Epoch 68/70 LR: [0.08000000000000002]
# Validation accuracy on group 6/10: 0.70
#
# Epoch 69/70 LR: [0.08000000000000002]
# Validation accuracy on group 6/10: 0.70
#
# Epoch 70/70 LR: [0.08000000000000002]
# Validation accuracy on group 6/10: 0.70
#
# Group 6 Finished!
# Best accuracy found at epoch 64: 0.71
# Testing classes seen so far, accuracy: 0.69
#
# =============================================
#
# Epoch 1/70 LR: [2]
# Validation accuracy on group 7/10: 0.62
# Best model updated
#
# Epoch 2/70 LR: [2]
# Validation accuracy on group 7/10: 0.60
#
# Epoch 3/70 LR: [2]
# Validation accuracy on group 7/10: 0.60
#
# Epoch 4/70 LR: [2]
# Validation accuracy on group 7/10: 0.61
#
# Epoch 5/70 LR: [2]
# Validation accuracy on group 7/10: 0.64
# Best model updated
#
# Epoch 6/70 LR: [2]
# Validation accuracy on group 7/10: 0.61
#
# Epoch 7/70 LR: [2]
# Validation accuracy on group 7/10: 0.57
#
# Epoch 8/70 LR: [2]
# Validation accuracy on group 7/10: 0.58
#
# Epoch 9/70 LR: [2]
# Validation accuracy on group 7/10: 0.59
#
# Epoch 10/70 LR: [2]
# Validation accuracy on group 7/10: 0.60
#
# Epoch 11/70 LR: [2]
# Validation accuracy on group 7/10: 0.60
#
# Epoch 12/70 LR: [2]
# Validation accuracy on group 7/10: 0.59
#
# Epoch 13/70 LR: [2]
# Validation accuracy on group 7/10: 0.59
#
# Epoch 14/70 LR: [2]
# Validation accuracy on group 7/10: 0.60
#
# Epoch 15/70 LR: [2]
# Validation accuracy on group 7/10: 0.60
#
# Epoch 16/70 LR: [2]
# Validation accuracy on group 7/10: 0.58
#
# Epoch 17/70 LR: [2]
# Validation accuracy on group 7/10: 0.59
#
# Epoch 18/70 LR: [2]
# Validation accuracy on group 7/10: 0.54
#
# Epoch 19/70 LR: [2]
# Validation accuracy on group 7/10: 0.58
#
# Epoch 20/70 LR: [2]
# Validation accuracy on group 7/10: 0.60
#
# Epoch 21/70 LR: [2]
# Validation accuracy on group 7/10: 0.63
#
# Epoch 22/70 LR: [2]
# Validation accuracy on group 7/10: 0.59
#
# Epoch 23/70 LR: [2]
# Validation accuracy on group 7/10: 0.61
#
# Epoch 24/70 LR: [2]
# Validation accuracy on group 7/10: 0.59
#
# Epoch 25/70 LR: [2]
# Validation accuracy on group 7/10: 0.59
#
# Epoch 26/70 LR: [2]
# Validation accuracy on group 7/10: 0.60
#
# Epoch 27/70 LR: [2]
# Validation accuracy on group 7/10: 0.59
#
# Epoch 28/70 LR: [2]
# Validation accuracy on group 7/10: 0.60
#
# Epoch 29/70 LR: [2]
# Validation accuracy on group 7/10: 0.58
#
# Epoch 30/70 LR: [2]
# Validation accuracy on group 7/10: 0.56
#
# Epoch 31/70 LR: [2]
# Validation accuracy on group 7/10: 0.58
#
# Epoch 32/70 LR: [2]
# Validation accuracy on group 7/10: 0.56
#
# Epoch 33/70 LR: [2]
# Validation accuracy on group 7/10: 0.58
#
# Epoch 34/70 LR: [2]
# Validation accuracy on group 7/10: 0.57
#
# Epoch 35/70 LR: [2]
# Validation accuracy on group 7/10: 0.58
#
# Epoch 36/70 LR: [2]
# Validation accuracy on group 7/10: 0.57
#
# Epoch 37/70 LR: [2]
# Validation accuracy on group 7/10: 0.61
#
# Epoch 38/70 LR: [2]
# Validation accuracy on group 7/10: 0.57
#
# Epoch 39/70 LR: [2]
# Validation accuracy on group 7/10: 0.58
#
# Epoch 40/70 LR: [2]
# Validation accuracy on group 7/10: 0.57
#
# Epoch 41/70 LR: [2]
# Validation accuracy on group 7/10: 0.58
#
# Epoch 42/70 LR: [2]
# Validation accuracy on group 7/10: 0.61
#
# Epoch 43/70 LR: [2]
# Validation accuracy on group 7/10: 0.59
#
# Epoch 44/70 LR: [2]
# Validation accuracy on group 7/10: 0.56
#
# Epoch 45/70 LR: [2]
# Validation accuracy on group 7/10: 0.61
#
# Epoch 46/70 LR: [2]
# Validation accuracy on group 7/10: 0.59
#
# Epoch 47/70 LR: [2]
# Validation accuracy on group 7/10: 0.60
#
# Epoch 48/70 LR: [2]
# Validation accuracy on group 7/10: 0.61
#
# Epoch 49/70 LR: [2]
# Validation accuracy on group 7/10: 0.59
#
# Epoch 50/70 LR: [0.4]
# Validation accuracy on group 7/10: 0.70
# Best model updated
#
# Epoch 51/70 LR: [0.4]
# Validation accuracy on group 7/10: 0.71
# Best model updated
#
# Epoch 52/70 LR: [0.4]
# Validation accuracy on group 7/10: 0.71
# Best model updated
#
# Epoch 53/70 LR: [0.4]
# Validation accuracy on group 7/10: 0.70
#
# Epoch 54/70 LR: [0.4]
# Validation accuracy on group 7/10: 0.70
#
# Epoch 55/70 LR: [0.4]
# Validation accuracy on group 7/10: 0.70
#
# Epoch 56/70 LR: [0.4]
# Validation accuracy on group 7/10: 0.71
#
# Epoch 57/70 LR: [0.4]
# Validation accuracy on group 7/10: 0.70
#
# Epoch 58/70 LR: [0.4]
# Validation accuracy on group 7/10: 0.70
#
# Epoch 59/70 LR: [0.4]
# Validation accuracy on group 7/10: 0.70
#
# Epoch 60/70 LR: [0.4]
# Validation accuracy on group 7/10: 0.69
#
# Epoch 61/70 LR: [0.4]
# Validation accuracy on group 7/10: 0.69
#
# Epoch 62/70 LR: [0.4]
# Validation accuracy on group 7/10: 0.69
#
# Epoch 63/70 LR: [0.4]
# Validation accuracy on group 7/10: 0.70
#
# Epoch 64/70 LR: [0.08000000000000002]
# Validation accuracy on group 7/10: 0.71
#
# Epoch 65/70 LR: [0.08000000000000002]
# Validation accuracy on group 7/10: 0.72
# Best model updated
#
# Epoch 66/70 LR: [0.08000000000000002]
# Validation accuracy on group 7/10: 0.71
#
# Epoch 67/70 LR: [0.08000000000000002]
# Validation accuracy on group 7/10: 0.71
#
# Epoch 68/70 LR: [0.08000000000000002]
# Validation accuracy on group 7/10: 0.71
#
# Epoch 69/70 LR: [0.08000000000000002]
# Validation accuracy on group 7/10: 0.71
#
# Epoch 70/70 LR: [0.08000000000000002]
# Validation accuracy on group 7/10: 0.71
#
# Group 7 Finished!
# Best accuracy found at epoch 65: 0.72
# Testing classes seen so far, accuracy: 0.69
#
# =============================================
#
# Epoch 1/70 LR: [2]
# Validation accuracy on group 8/10: 0.03
# Best model updated
#
# Epoch 2/70 LR: [2]
# Validation accuracy on group 8/10: 0.06
# Best model updated
#
# Epoch 3/70 LR: [2]
# Validation accuracy on group 8/10: 0.11
# Best model updated
#
# Epoch 4/70 LR: [2]
# Validation accuracy on group 8/10: 0.17
# Best model updated
#
# Epoch 5/70 LR: [2]
# Validation accuracy on group 8/10: 0.22
# Best model updated
#
# Epoch 6/70 LR: [2]
# Validation accuracy on group 8/10: 0.29
# Best model updated
#
# Epoch 7/70 LR: [2]
# Validation accuracy on group 8/10: 0.34
# Best model updated
#
# Epoch 8/70 LR: [2]
# Validation accuracy on group 8/10: 0.43
# Best model updated
#
# Epoch 9/70 LR: [2]
# Validation accuracy on group 8/10: 0.47
# Best model updated
#
# Epoch 10/70 LR: [2]
# Validation accuracy on group 8/10: 0.51
# Best model updated
#
# Epoch 11/70 LR: [2]
# Validation accuracy on group 8/10: 0.52
# Best model updated
#
# Epoch 12/70 LR: [2]
# Validation accuracy on group 8/10: 0.54
# Best model updated
#
# Epoch 13/70 LR: [2]
# Validation accuracy on group 8/10: 0.55
# Best model updated
#
# Epoch 14/70 LR: [2]
# Validation accuracy on group 8/10: 0.53
#
# Epoch 15/70 LR: [2]
# Validation accuracy on group 8/10: 0.55
#
# Epoch 16/70 LR: [2]
# Validation accuracy on group 8/10: 0.54
#
# Epoch 17/70 LR: [2]
# Validation accuracy on group 8/10: 0.58
# Best model updated
#
# Epoch 18/70 LR: [2]
# Validation accuracy on group 8/10: 0.53
#
# Epoch 19/70 LR: [2]
# Validation accuracy on group 8/10: 0.56
#
# Epoch 20/70 LR: [2]
# Validation accuracy on group 8/10: 0.55
#
# Epoch 21/70 LR: [2]
# Validation accuracy on group 8/10: 0.59
# Best model updated
#
# Epoch 22/70 LR: [2]
# Validation accuracy on group 8/10: 0.57
#
# Epoch 23/70 LR: [2]
# Validation accuracy on group 8/10: 0.58
#
# Epoch 24/70 LR: [2]
# Validation accuracy on group 8/10: 0.58
#
# Epoch 25/70 LR: [2]
# Validation accuracy on group 8/10: 0.57
#
# Epoch 26/70 LR: [2]
# Validation accuracy on group 8/10: 0.52
#
# Epoch 27/70 LR: [2]
# Validation accuracy on group 8/10: 0.56
#
# Epoch 28/70 LR: [2]
# Validation accuracy on group 8/10: 0.58
#
# Epoch 29/70 LR: [2]
# Validation accuracy on group 8/10: 0.60
# Best model updated
#
# Epoch 30/70 LR: [2]
# Validation accuracy on group 8/10: 0.58
#
# Epoch 31/70 LR: [2]
# Validation accuracy on group 8/10: 0.57
#
# Epoch 32/70 LR: [2]
# Validation accuracy on group 8/10: 0.60
# Best model updated
#
# Epoch 33/70 LR: [2]
# Validation accuracy on group 8/10: 0.59
#
# Epoch 34/70 LR: [2]
# Validation accuracy on group 8/10: 0.55
#
# Epoch 35/70 LR: [2]
# Validation accuracy on group 8/10: 0.56
#
# Epoch 36/70 LR: [2]
# Validation accuracy on group 8/10: 0.59
#
# Epoch 37/70 LR: [2]
# Validation accuracy on group 8/10: 0.58
#
# Epoch 38/70 LR: [2]
# Validation accuracy on group 8/10: 0.57
#
# Epoch 39/70 LR: [2]
# Validation accuracy on group 8/10: 0.59
#
# Epoch 40/70 LR: [2]
# Validation accuracy on group 8/10: 0.54
#
# Epoch 41/70 LR: [2]
# Validation accuracy on group 8/10: 0.58
#
# Epoch 42/70 LR: [2]
# Validation accuracy on group 8/10: 0.58
#
# Epoch 43/70 LR: [2]
# Validation accuracy on group 8/10: 0.57
#
# Epoch 44/70 LR: [2]
# Validation accuracy on group 8/10: 0.60
# Best model updated
#
# Epoch 45/70 LR: [2]
# Validation accuracy on group 8/10: 0.59
#
# Epoch 46/70 LR: [2]
# Validation accuracy on group 8/10: 0.61
# Best model updated
#
# Epoch 47/70 LR: [2]
# Validation accuracy on group 8/10: 0.59
#
# Epoch 48/70 LR: [2]
# Validation accuracy on group 8/10: 0.56
#
# Epoch 49/70 LR: [2]
# Validation accuracy on group 8/10: 0.59
#
# Epoch 50/70 LR: [0.4]
# Validation accuracy on group 8/10: 0.69
# Best model updated
#
# Epoch 51/70 LR: [0.4]
# Validation accuracy on group 8/10: 0.69
# Best model updated
#
# Epoch 52/70 LR: [0.4]
# Validation accuracy on group 8/10: 0.69
#
# Epoch 53/70 LR: [0.4]
# Validation accuracy on group 8/10: 0.69
# Best model updated
#
# Epoch 54/70 LR: [0.4]
# Validation accuracy on group 8/10: 0.70
# Best model updated
#
# Epoch 55/70 LR: [0.4]
# Validation accuracy on group 8/10: 0.69
#
# Epoch 56/70 LR: [0.4]
# Validation accuracy on group 8/10: 0.69
#
# Epoch 57/70 LR: [0.4]
# Validation accuracy on group 8/10: 0.68
#
# Epoch 58/70 LR: [0.4]
# Validation accuracy on group 8/10: 0.69
#
# Epoch 59/70 LR: [0.4]
# Validation accuracy on group 8/10: 0.69
#
# Epoch 60/70 LR: [0.4]
# Validation accuracy on group 8/10: 0.68
#
# Epoch 61/70 LR: [0.4]
# Validation accuracy on group 8/10: 0.68
#
# Epoch 62/70 LR: [0.4]
# Validation accuracy on group 8/10: 0.69
#
# Epoch 63/70 LR: [0.4]
# Validation accuracy on group 8/10: 0.68
#
# Epoch 64/70 LR: [0.08000000000000002]
# Validation accuracy on group 8/10: 0.70
# Best model updated
#
# Epoch 65/70 LR: [0.08000000000000002]
# Validation accuracy on group 8/10: 0.70
# Best model updated
#
# Epoch 66/70 LR: [0.08000000000000002]
# Validation accuracy on group 8/10: 0.71
# Best model updated
#
# Epoch 67/70 LR: [0.08000000000000002]
# Validation accuracy on group 8/10: 0.70
#
# Epoch 68/70 LR: [0.08000000000000002]
# Validation accuracy on group 8/10: 0.71
#
# Epoch 69/70 LR: [0.08000000000000002]
# Validation accuracy on group 8/10: 0.70
#
# Epoch 70/70 LR: [0.08000000000000002]
# Validation accuracy on group 8/10: 0.69
#
# Group 8 Finished!
# Best accuracy found at epoch 66: 0.71
# Testing classes seen so far, accuracy: 0.70
#
# =============================================
#
# Epoch 1/70 LR: [2]
# Validation accuracy on group 9/10: 0.03
# Best model updated
#
# Epoch 2/70 LR: [2]
# Validation accuracy on group 9/10: 0.07
# Best model updated
#
# Epoch 3/70 LR: [2]
# Validation accuracy on group 9/10: 0.15
# Best model updated
#
# Epoch 4/70 LR: [2]
# Validation accuracy on group 9/10: 0.17
# Best model updated
#
# Epoch 5/70 LR: [2]
# Validation accuracy on group 9/10: 0.20
# Best model updated
#
# Epoch 6/70 LR: [2]
# Validation accuracy on group 9/10: 0.18
#
# Epoch 7/70 LR: [2]
# Validation accuracy on group 9/10: 0.31
# Best model updated
#
# Epoch 8/70 LR: [2]
# Validation accuracy on group 9/10: 0.31
#
# Epoch 9/70 LR: [2]
# Validation accuracy on group 9/10: 0.38
# Best model updated
#
# Epoch 10/70 LR: [2]
# Validation accuracy on group 9/10: 0.38
#
# Epoch 11/70 LR: [2]
# Validation accuracy on group 9/10: 0.41
# Best model updated
#
# Epoch 12/70 LR: [2]
# Validation accuracy on group 9/10: 0.40
#
# Epoch 13/70 LR: [2]
# Validation accuracy on group 9/10: 0.45
# Best model updated
#
# Epoch 14/70 LR: [2]
# Validation accuracy on group 9/10: 0.47
# Best model updated
#
# Epoch 15/70 LR: [2]
# Validation accuracy on group 9/10: 0.45
#
# Epoch 16/70 LR: [2]
# Validation accuracy on group 9/10: 0.49
# Best model updated
#
# Epoch 17/70 LR: [2]
# Validation accuracy on group 9/10: 0.49
#
# Epoch 18/70 LR: [2]
# Validation accuracy on group 9/10: 0.49
#
# Epoch 19/70 LR: [2]
# Validation accuracy on group 9/10: 0.46
#
# Epoch 20/70 LR: [2]
# Validation accuracy on group 9/10: 0.50
# Best model updated
#
# Epoch 21/70 LR: [2]
# Validation accuracy on group 9/10: 0.50
# Best model updated
#
# Epoch 22/70 LR: [2]
# Validation accuracy on group 9/10: 0.49
#
# Epoch 23/70 LR: [2]
# Validation accuracy on group 9/10: 0.53
# Best model updated
#
# Epoch 24/70 LR: [2]
# Validation accuracy on group 9/10: 0.52
#
# Epoch 25/70 LR: [2]
# Validation accuracy on group 9/10: 0.54
# Best model updated
#
# Epoch 26/70 LR: [2]
# Validation accuracy on group 9/10: 0.54
#
# Epoch 27/70 LR: [2]
# Validation accuracy on group 9/10: 0.49
#
# Epoch 28/70 LR: [2]
# Validation accuracy on group 9/10: 0.53
#
# Epoch 29/70 LR: [2]
# Validation accuracy on group 9/10: 0.52
#
# Epoch 30/70 LR: [2]
# Validation accuracy on group 9/10: 0.52
#
# Epoch 31/70 LR: [2]
# Validation accuracy on group 9/10: 0.54
# Best model updated
#
# Epoch 32/70 LR: [2]
# Validation accuracy on group 9/10: 0.55
# Best model updated
#
# Epoch 33/70 LR: [2]
# Validation accuracy on group 9/10: 0.52
#
# Epoch 34/70 LR: [2]
# Validation accuracy on group 9/10: 0.54
#
# Epoch 35/70 LR: [2]
# Validation accuracy on group 9/10: 0.52
#
# Epoch 36/70 LR: [2]
# Validation accuracy on group 9/10: 0.54
#
# Epoch 37/70 LR: [2]
# Validation accuracy on group 9/10: 0.49
#
# Epoch 38/70 LR: [2]
# Validation accuracy on group 9/10: 0.52
#
# Epoch 39/70 LR: [2]
# Validation accuracy on group 9/10: 0.55
#
# Epoch 40/70 LR: [2]
# Validation accuracy on group 9/10: 0.54
#
# Epoch 41/70 LR: [2]
# Validation accuracy on group 9/10: 0.54
#
# Epoch 42/70 LR: [2]
# Validation accuracy on group 9/10: 0.54
#
# Epoch 43/70 LR: [2]
# Validation accuracy on group 9/10: 0.50
#
# Epoch 44/70 LR: [2]
# Validation accuracy on group 9/10: 0.54
#
# Epoch 45/70 LR: [2]
# Validation accuracy on group 9/10: 0.53
#
# Epoch 46/70 LR: [2]
# Validation accuracy on group 9/10: 0.53
#
# Epoch 47/70 LR: [2]
# Validation accuracy on group 9/10: 0.55
#
# Epoch 48/70 LR: [2]
# Validation accuracy on group 9/10: 0.49
#
# Epoch 49/70 LR: [2]
# Validation accuracy on group 9/10: 0.55
#
# Epoch 50/70 LR: [0.4]
# Validation accuracy on group 9/10: 0.65
# Best model updated
#
# Epoch 51/70 LR: [0.4]
# Validation accuracy on group 9/10: 0.66
# Best model updated
#
# Epoch 52/70 LR: [0.4]
# Validation accuracy on group 9/10: 0.66
#
# Epoch 53/70 LR: [0.4]
# Validation accuracy on group 9/10: 0.66
#
# Epoch 54/70 LR: [0.4]
# Validation accuracy on group 9/10: 0.66
# Best model updated
#
# Epoch 55/70 LR: [0.4]
# Validation accuracy on group 9/10: 0.66
#
# Epoch 56/70 LR: [0.4]
# Validation accuracy on group 9/10: 0.66
#
# Epoch 57/70 LR: [0.4]
# Validation accuracy on group 9/10: 0.65
#
# Epoch 58/70 LR: [0.4]
# Validation accuracy on group 9/10: 0.65
#
# Epoch 59/70 LR: [0.4]
# Validation accuracy on group 9/10: 0.65
#
# Epoch 60/70 LR: [0.4]
# Validation accuracy on group 9/10: 0.65
#
# Epoch 61/70 LR: [0.4]
# Validation accuracy on group 9/10: 0.64
#
# Epoch 62/70 LR: [0.4]
# Validation accuracy on group 9/10: 0.64
#
# Epoch 63/70 LR: [0.4]
# Validation accuracy on group 9/10: 0.64
#
# Epoch 64/70 LR: [0.08000000000000002]
# Validation accuracy on group 9/10: 0.67
# Best model updated
#
# Epoch 65/70 LR: [0.08000000000000002]
# Validation accuracy on group 9/10: 0.67
#
# Epoch 66/70 LR: [0.08000000000000002]
# Validation accuracy on group 9/10: 0.67
#
# Epoch 67/70 LR: [0.08000000000000002]
# Validation accuracy on group 9/10: 0.67
#
# Epoch 68/70 LR: [0.08000000000000002]
# Validation accuracy on group 9/10: 0.67
#
# Epoch 69/70 LR: [0.08000000000000002]
# Validation accuracy on group 9/10: 0.67
#
# Epoch 70/70 LR: [0.08000000000000002]
# Validation accuracy on group 9/10: 0.67
# Best model updated
#
# Group 9 Finished!
# Best accuracy found at epoch 70: 0.67
# Testing classes seen so far, accuracy: 0.68
#
# =============================================
#
# Epoch 1/70 LR: [2]
# Validation accuracy on group 10/10: 0.03
# Best model updated
#
# Epoch 2/70 LR: [2]
# Validation accuracy on group 10/10: 0.07
# Best model updated
#
# Epoch 3/70 LR: [2]
# Validation accuracy on group 10/10: 0.08
# Best model updated
#
# Epoch 4/70 LR: [2]
# Validation accuracy on group 10/10: 0.12
# Best model updated
#
# Epoch 5/70 LR: [2]
# Validation accuracy on group 10/10: 0.15
# Best model updated
#
# Epoch 6/70 LR: [2]
# Validation accuracy on group 10/10: 0.15
# Best model updated
#
# Epoch 7/70 LR: [2]
# Validation accuracy on group 10/10: 0.19
# Best model updated
#
# Epoch 8/70 LR: [2]
# Validation accuracy on group 10/10: 0.23
# Best model updated
#
# Epoch 9/70 LR: [2]
# Validation accuracy on group 10/10: 0.25
# Best model updated
#
# Epoch 10/70 LR: [2]
# Validation accuracy on group 10/10: 0.29
# Best model updated
#
# Epoch 11/70 LR: [2]
# Validation accuracy on group 10/10: 0.34
# Best model updated
#
# Epoch 12/70 LR: [2]
# Validation accuracy on group 10/10: 0.31
#
# Epoch 13/70 LR: [2]
# Validation accuracy on group 10/10: 0.35
# Best model updated
#
# Epoch 14/70 LR: [2]
# Validation accuracy on group 10/10: 0.36
# Best model updated
#
# Epoch 15/70 LR: [2]
# Validation accuracy on group 10/10: 0.39
# Best model updated
#
# Epoch 16/70 LR: [2]
# Validation accuracy on group 10/10: 0.40
# Best model updated
#
# Epoch 17/70 LR: [2]
# Validation accuracy on group 10/10: 0.41
# Best model updated
#
# Epoch 18/70 LR: [2]
# Validation accuracy on group 10/10: 0.44
# Best model updated
#
# Epoch 19/70 LR: [2]
# Validation accuracy on group 10/10: 0.44
# Best model updated
#
# Epoch 20/70 LR: [2]
# Validation accuracy on group 10/10: 0.45
# Best model updated
#
# Epoch 21/70 LR: [2]
# Validation accuracy on group 10/10: 0.44
#
# Epoch 22/70 LR: [2]
# Validation accuracy on group 10/10: 0.43
#
# Epoch 23/70 LR: [2]
# Validation accuracy on group 10/10: 0.49
# Best model updated
#
# Epoch 24/70 LR: [2]
# Validation accuracy on group 10/10: 0.49
# Best model updated
#
# Epoch 25/70 LR: [2]
# Validation accuracy on group 10/10: 0.48
#
# Epoch 26/70 LR: [2]
# Validation accuracy on group 10/10: 0.46
#
# Epoch 27/70 LR: [2]
# Validation accuracy on group 10/10: 0.47
#
# Epoch 28/70 LR: [2]
# Validation accuracy on group 10/10: 0.47
#
# Epoch 29/70 LR: [2]
# Validation accuracy on group 10/10: 0.48
#
# Epoch 30/70 LR: [2]
# Validation accuracy on group 10/10: 0.48
#
# Epoch 31/70 LR: [2]
# Validation accuracy on group 10/10: 0.50
# Best model updated
#
# Epoch 32/70 LR: [2]
# Validation accuracy on group 10/10: 0.52
# Best model updated
#
# Epoch 33/70 LR: [2]
# Validation accuracy on group 10/10: 0.50
#
# Epoch 34/70 LR: [2]
# Validation accuracy on group 10/10: 0.52
#
# Epoch 35/70 LR: [2]
# Validation accuracy on group 10/10: 0.50
#
# Epoch 36/70 LR: [2]
# Validation accuracy on group 10/10: 0.49
#
# Epoch 37/70 LR: [2]
# Validation accuracy on group 10/10: 0.52
#
# Epoch 38/70 LR: [2]
# Validation accuracy on group 10/10: 0.50
#
# Epoch 39/70 LR: [2]
# Validation accuracy on group 10/10: 0.50
#
# Epoch 40/70 LR: [2]
# Validation accuracy on group 10/10: 0.51
#
# Epoch 41/70 LR: [2]
# Validation accuracy on group 10/10: 0.50
#
# Epoch 42/70 LR: [2]
# Validation accuracy on group 10/10: 0.48
#
# Epoch 43/70 LR: [2]
# Validation accuracy on group 10/10: 0.51
#
# Epoch 44/70 LR: [2]
# Validation accuracy on group 10/10: 0.48
#
# Epoch 45/70 LR: [2]
# Validation accuracy on group 10/10: 0.52
#
# Epoch 46/70 LR: [2]
# Validation accuracy on group 10/10: 0.53
# Best model updated
#
# Epoch 47/70 LR: [2]
# Validation accuracy on group 10/10: 0.49
#
# Epoch 48/70 LR: [2]
# Validation accuracy on group 10/10: 0.50
#
# Epoch 49/70 LR: [2]
# Validation accuracy on group 10/10: 0.53
#
# Epoch 50/70 LR: [0.4]
# Validation accuracy on group 10/10: 0.63
# Best model updated
#
# Epoch 51/70 LR: [0.4]
# Validation accuracy on group 10/10: 0.63
# Best model updated
#
# Epoch 52/70 LR: [0.4]
# Validation accuracy on group 10/10: 0.62
#
# Epoch 53/70 LR: [0.4]
# Validation accuracy on group 10/10: 0.63
# Best model updated
#
# Epoch 54/70 LR: [0.4]
# Validation accuracy on group 10/10: 0.63
#
# Epoch 55/70 LR: [0.4]
# Validation accuracy on group 10/10: 0.63
# Best model updated
#
# Epoch 56/70 LR: [0.4]
# Validation accuracy on group 10/10: 0.63
#
# Epoch 57/70 LR: [0.4]
# Validation accuracy on group 10/10: 0.63
#
# Epoch 58/70 LR: [0.4]
# Validation accuracy on group 10/10: 0.62
#
# Epoch 59/70 LR: [0.4]
# Validation accuracy on group 10/10: 0.62
#
# Epoch 60/70 LR: [0.4]
# Validation accuracy on group 10/10: 0.62
#
# Epoch 61/70 LR: [0.4]
# Validation accuracy on group 10/10: 0.62
#
# Epoch 62/70 LR: [0.4]
# Validation accuracy on group 10/10: 0.62
#
# Epoch 63/70 LR: [0.4]
# Validation accuracy on group 10/10: 0.61
#
# Epoch 64/70 LR: [0.08000000000000002]
# Validation accuracy on group 10/10: 0.65
# Best model updated
#
# Epoch 65/70 LR: [0.08000000000000002]
# Validation accuracy on group 10/10: 0.65
# Best model updated
#
# Epoch 66/70 LR: [0.08000000000000002]
# Validation accuracy on group 10/10: 0.65
#
# Epoch 67/70 LR: [0.08000000000000002]
# Validation accuracy on group 10/10: 0.65
# Best model updated
#
# Epoch 68/70 LR: [0.08000000000000002]
# Validation accuracy on group 10/10: 0.65
#
# Epoch 69/70 LR: [0.08000000000000002]
# Validation accuracy on group 10/10: 0.64
#
# Epoch 70/70 LR: [0.08000000000000002]
# Validation accuracy on group 10/10: 0.65
#
# Group 10 Finished!
# Best accuracy found at epoch 67: 0.65
# Testing classes seen so far, accuracy: 0.65
#
# =============================================
#
# #################################

# %% [markdown]
# ### Store logs in more usable dtype

# %%
train_loss = [[logs[run_i]['group_train_loss'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
train_accuracy = [[logs[run_i]['group_train_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
val_loss = [[logs[run_i]['val_losses'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
val_accuracy = [[logs[run_i]['val_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
test_accuracy = [[logs[run_i]['test_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
predictions = [logs[run_i]['predictions'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]
true_labels = [logs[run_i]['true_labels'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]

# %% [markdown]
# ### Save the model

# %% [markdown]
# #### Saving logs in JSON files

# %%
import json

with open('states/FineTuning_train_loss.json', 'w') as f:
  json.dump(train_loss, f)
f.close
with open('states/FineTuning_train_accuracy.json', 'w') as f:
  json.dump(train_accuracy, f)
f.close
with open('states/FineTuning_val_loss.json', 'w') as f:
  json.dump(val_loss, f)
f.close  
with open('states/FineTuning_val_accuracy.json', 'w') as f:
  json.dump(val_accuracy, f)
f.close
with open('states/FineTuning_test_accuracy.json', 'w') as f:
  json.dump(test_accuracy, f)
f.close
with open('states/FineTuning_predictions.json', 'w') as f:
  json.dump(predictions, f)
f.close
with open('states/FineTuning_true_labels.json', 'w') as f:
  json.dump(true_labels, f)
f.close
# Out:
# <function TextIOWrapper.close>

# %% [markdown]
# #### Saving best resnet on 100 classes for each seed

# %%
for i in range(len(RANDOM_SEED)):
  torch.save(best_net_tot_classes[i].state_dict(), "states/FineTuning_bestnet_seed[{}]".format(RANDOM_SEED[i]))

# %% [markdown]
# ### Print some graphs

# %%
from data.utils_plot import plot_train_val, plot_test_accuracies, plot_confusion_matrix

# %%
train_loss = np.array(train_loss)
train_accuracy = np.array(train_accuracy)
val_loss = np.array(val_loss)
val_accuracy = np.array(val_accuracy)
test_accuracy = np.array(test_accuracy)

train_loss_stats = np.array([train_loss.mean(0), train_loss.std(0)]).transpose()
train_accuracy_stats = np.array([train_accuracy.mean(0), train_accuracy.std(0)]).transpose()
val_loss_stats = np.array([val_loss.mean(0), val_loss.std(0)]).transpose()
val_accuracy_stats = np.array([val_accuracy.mean(0), val_accuracy.std(0)]).transpose()
test_accuracy_stats = np.array([test_accuracy.mean(0), test_accuracy.std(0)]).transpose()

# %% [markdown]
# #### Train validation loss

# %%
plot_train_val(train_loss_stats, val_loss_stats, loss = True)

# %% [markdown]
# #### Train validation accuracy

# %%
plot_train_val(train_accuracy_stats, val_accuracy_stats, loss = False)

# %% [markdown]
# #### Test accuracy

# %%
plot_test_accuracies(test_accuracy_stats)

# %% [markdown]
# #### Confusion Matrix

# %%
for run in range(len(RANDOM_SEED)):
  targets = logs[run]['true_labels'].cpu().data.numpy()
  preds = logs[run]['predictions'].cpu().data.numpy()

  plot_confusion_matrix(targets, preds, RANDOM_SEED[run], 'FineTuning')
