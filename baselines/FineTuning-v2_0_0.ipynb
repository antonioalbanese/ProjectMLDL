# %% [markdown]
# <a href="https://colab.research.google.com/github/cosminnedescu/ProjectMLDL/blob/main/baselines/FineTuning-v2_0_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun Jul  4 16:12:54 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P8    12W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import random

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable

import torchvision
from torchvision import transforms, datasets, models
from torch.utils.data import Subset, DataLoader

from PIL import Image

import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
from copy import copy
from copy import deepcopy

# %% [markdown]
# #### Cloning the Git repository

# %%
# !rm -rf ProjectMLDL
if not os.path.isdir('/content/ProjectMLDL'):
  # !git clone https://github.com/cosminnedescu/ProjectMLDL.git
  # %cd /content/ProjectMLDL
  # !rm -rf LICENSE README.md
# Out:
# Cloning into 'ProjectMLDL'...
# remote: Enumerating objects: 1914, done.
# remote: Counting objects: 100% (400/400), done.
# remote: Compressing objects: 100% (326/326), done.
# remote: Total 1914 (delta 271), reused 73 (delta 73), pack-reused 1514
# Receiving objects: 100% (1914/1914), 77.65 MiB | 32.29 MiB/s, done.
# Resolving deltas: 100% (1017/1017), done.
# /content/ProjectMLDL

# %%
from data.cifar100 import CIFAR100
from model.resnet32 import resnet32
import data.utils
from model.trainer import Trainer

# %% [markdown]
# #### Downloading data from Cifar100

# %%
# True mean and std of Cifar100 dataset (src="https://gist.github.com/weiaicunzai/e623931921efefd4c331622c344d8151")
mean = [0.5071, 0.4867, 0.4408]
std = [0.2675, 0.2565, 0.2761]

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])
test_transform = transforms.Compose(
    [transforms.ToTensor(), 
     transforms.Normalize(mean, std),
     ])

# %% [markdown]
# ## Fine Tuning

# %% [markdown]
# ### Defining hyperparameters according to iCarl paper

# %%
# Settings
DEVICE = 'cuda'
NUM_CLASSES = 100         # Total number of classes
VAL_SIZE = 0.2            # Proportion of validation set with respect to training set (between 0 and 1)

# Training
BATCH_SIZE = 128          # Batch size
LR = 1 #2                    # Initial learning rate
                       
MOMENTUM = 0.9            # Momentum for stochastic gradient descent (SGD)
WEIGHT_DECAY = 1e-5       # Weight decay from iCaRL

RANDOM_SEED = [24,66,32]  # Random seeds defining the runs of every method
                          # Note: this should be at least 3 to have a fair benchmark

NUM_EPOCHS = 70           # Total number of training epochs
MILESTONES = [27, 49, 63]#[49, 63]     # Step down policy from iCaRL (MultiStepLR)
                          # Decrease the learning rate by gamma at each milestone
GAMMA = 0.25               # Gamma factor from iCaRL (1/5)

# %% [markdown]
# ### Going on with the model
# This is the main FineTuning step.
#
# This step is run 3 times with different `RANDOM_SEED`.
# Here the model is instantiated, trained and tested.
#
# Results and some statistics are then stored in the variable `logs`.

# %%
def do_group_classes(run):

  train_dataloader = [[] for i in range(10)]
  val_dataloader = [[] for i in range(10)]
  test_dataloader = [[] for i in range(10)]

  for i in range(10):
    train_data = CIFAR100("dataset", 
                          train=True, 
                          transform=train_transform, 
                          download=(run+i==0),
                          random_state=RANDOM_SEED[run])
    test_data = CIFAR100("dataset", 
                         train=False, 
                         transform=test_transform, 
                         download=False,
                         random_state=RANDOM_SEED[run])
    
    train_data.set_index_map(train_data.splits[i])
    test_data.set_index_map([test_data.splits[j] for j in range(0, i+1)])
    
    train_indices, val_indices = train_data.train_val_split(VAL_SIZE, RANDOM_SEED[run])
    
    train_subset = Subset(train_data, train_indices)
    val_subset = Subset(train_data, val_indices)

    tmp_dl = DataLoader(train_subset,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    train_dataloader[i] = copy(tmp_dl)
    
    tmp_dl = DataLoader(val_subset,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    val_dataloader[i] = copy(tmp_dl)

    tmp_dl = DataLoader(test_data,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    test_dataloader[i] = copy(tmp_dl)

  return train_dataloader, val_dataloader, test_dataloader

# %%
logs = [[] for i in range(len(RANDOM_SEED))]
best_net_tot_classes = [None for i in range(len(RANDOM_SEED))]

for run in range(len(RANDOM_SEED)):
  random.seed(RANDOM_SEED[run])
  print("#################################")
  print(f"Radom seed: {RANDOM_SEED[run]}")
  print("")

  #get dataloader separated in incremental groups of 10 classes
  train_dl, val_dl, test_dl = do_group_classes(run)

  #create the resnet
  net = resnet32()
  
  trainer = Trainer(DEVICE,
                    net,
                    LR,
                    MOMENTUM,
                    WEIGHT_DECAY,
                    MILESTONES,
                    GAMMA,
                    train_dl,
                    val_dl,
                    test_dl)

  #train and evaluate the model
  logs[run] = trainer.train_model(NUM_EPOCHS)

  best_net_tot_classes[run] = deepcopy(trainer.best_net)

  print("#################################")
  print("")
  print("")
# Out:
# #################################
# Radom seed: 24
#
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to dataset/cifar-100-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=169001437.0), HTML(value='')))
# Extracting dataset/cifar-100-python.tar.gz to dataset
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Output streaming troncato alle ultime 5000 righe.
# Epoch 36/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.79
#
# Epoch 37/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.79
#
# Epoch 38/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.80
#
# Epoch 39/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.78
#
# Epoch 40/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.79
#
# Epoch 41/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.80
#
# Epoch 42/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.79
#
# Epoch 43/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.80
#
# Epoch 44/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.80
#
# Epoch 45/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.80
#
# Epoch 46/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.79
#
# Epoch 47/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.80
#
# Epoch 48/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.79
#
# Epoch 49/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.79
#
# Epoch 50/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.80
#
# Epoch 51/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.80
#
# Epoch 52/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.80
#
# Epoch 53/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.79
#
# Epoch 54/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.81
#
# Epoch 55/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.79
#
# Epoch 56/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.81
# Best model updated
#
# Epoch 57/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.81
#
# Epoch 58/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.82
# Best model updated
#
# Epoch 59/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.81
#
# Epoch 60/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.81
#
# Epoch 61/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.79
#
# Epoch 62/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.80
#
# Epoch 63/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.80
#
# Epoch 64/70 LR: [0.015625]
# Validation accuracy on group 9/10: 0.81
#
# Epoch 65/70 LR: [0.015625]
# Validation accuracy on group 9/10: 0.81
#
# Epoch 66/70 LR: [0.015625]
# Validation accuracy on group 9/10: 0.81
#
# Epoch 67/70 LR: [0.015625]
# Validation accuracy on group 9/10: 0.80
#
# Epoch 68/70 LR: [0.015625]
# Validation accuracy on group 9/10: 0.81
#
# Epoch 69/70 LR: [0.015625]
# Validation accuracy on group 9/10: 0.81
#
# Epoch 70/70 LR: [0.015625]
# Validation accuracy on group 9/10: 0.81
#
# Group 9 Finished!
# Best accuracy found at epoch 58: 0.82
# Testing classes seen so far, accuracy: 0.09
#
# =============================================
#
# Epoch 1/70 LR: [1]
# Validation accuracy on group 10/10: 0.57
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 10/10: 0.64
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 10/10: 0.66
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 10/10: 0.73
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 10/10: 0.76
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 10/10: 0.75
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 10/10: 0.75
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 10/10: 0.78
# Best model updated
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 10/10: 0.79
# Best model updated
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 10/10: 0.78
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 10/10: 0.79
# Best model updated
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 10/10: 0.76
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 10/10: 0.77
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 10/10: 0.71
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 10/10: 0.79
# Best model updated
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 10/10: 0.81
# Best model updated
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 10/10: 0.78
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 10/10: 0.78
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 10/10: 0.78
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 10/10: 0.80
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 10/10: 0.81
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 10/10: 0.80
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 10/10: 0.79
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 10/10: 0.79
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 10/10: 0.77
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 10/10: 0.80
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 10/10: 0.77
#
# Epoch 28/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.83
# Best model updated
#
# Epoch 29/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.84
# Best model updated
#
# Epoch 30/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.85
# Best model updated
#
# Epoch 31/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.84
#
# Epoch 32/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.84
#
# Epoch 33/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.84
#
# Epoch 34/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.86
# Best model updated
#
# Epoch 35/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.84
#
# Epoch 36/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.84
#
# Epoch 37/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.85
#
# Epoch 38/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.84
#
# Epoch 39/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.84
#
# Epoch 40/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.84
#
# Epoch 41/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.83
#
# Epoch 42/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.83
#
# Epoch 43/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.85
#
# Epoch 44/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.82
#
# Epoch 45/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.84
#
# Epoch 46/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.84
#
# Epoch 47/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.86
# Best model updated
#
# Epoch 48/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.83
#
# Epoch 49/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.84
#
# Epoch 50/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.83
#
# Epoch 51/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.84
#
# Epoch 52/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.85
#
# Epoch 53/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.84
#
# Epoch 54/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.85
#
# Epoch 55/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.85
#
# Epoch 56/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.85
#
# Epoch 57/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.86
#
# Epoch 58/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.84
#
# Epoch 59/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.85
#
# Epoch 60/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.85
#
# Epoch 61/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.84
#
# Epoch 62/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.84
#
# Epoch 63/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.84
#
# Epoch 64/70 LR: [0.015625]
# Validation accuracy on group 10/10: 0.84
#
# Epoch 65/70 LR: [0.015625]
# Validation accuracy on group 10/10: 0.85
#
# Epoch 66/70 LR: [0.015625]
# Validation accuracy on group 10/10: 0.84
#
# Epoch 67/70 LR: [0.015625]
# Validation accuracy on group 10/10: 0.85
#
# Epoch 68/70 LR: [0.015625]
# Validation accuracy on group 10/10: 0.85
#
# Epoch 69/70 LR: [0.015625]
# Validation accuracy on group 10/10: 0.83
#
# Epoch 70/70 LR: [0.015625]
# Validation accuracy on group 10/10: 0.85
#
# Group 10 Finished!
# Best accuracy found at epoch 47: 0.86
# Testing classes seen so far, accuracy: 0.09
#
# =============================================
#
# #################################
#
#
# #################################
# Radom seed: 66
#
# Epoch 1/70 LR: [1]
# Validation accuracy on group 1/10: 0.17
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 1/10: 0.14
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 1/10: 0.21
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 1/10: 0.31
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 1/10: 0.30
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 1/10: 0.33
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 1/10: 0.34
# Best model updated
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 1/10: 0.35
# Best model updated
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 1/10: 0.36
# Best model updated
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 1/10: 0.44
# Best model updated
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 1/10: 0.38
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 1/10: 0.43
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 1/10: 0.49
# Best model updated
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 1/10: 0.48
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 1/10: 0.43
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 1/10: 0.53
# Best model updated
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 1/10: 0.57
# Best model updated
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 1/10: 0.56
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 1/10: 0.59
# Best model updated
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 1/10: 0.63
# Best model updated
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 1/10: 0.57
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 1/10: 0.65
# Best model updated
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 1/10: 0.63
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 1/10: 0.66
# Best model updated
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 1/10: 0.63
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 1/10: 0.65
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 1/10: 0.69
# Best model updated
#
# Epoch 28/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.73
# Best model updated
#
# Epoch 29/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.75
# Best model updated
#
# Epoch 30/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.73
#
# Epoch 31/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.73
#
# Epoch 32/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.74
#
# Epoch 33/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.74
#
# Epoch 34/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.73
#
# Epoch 35/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.74
#
# Epoch 36/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.74
#
# Epoch 37/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.73
#
# Epoch 38/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.75
#
# Epoch 39/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.75
# Best model updated
#
# Epoch 40/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.75
#
# Epoch 41/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.76
# Best model updated
#
# Epoch 42/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.74
#
# Epoch 43/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.75
#
# Epoch 44/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.76
#
# Epoch 45/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.73
#
# Epoch 46/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.76
#
# Epoch 47/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.75
#
# Epoch 48/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.75
#
# Epoch 49/70 LR: [0.25]
# Validation accuracy on group 1/10: 0.76
#
# Epoch 50/70 LR: [0.0625]
# Validation accuracy on group 1/10: 0.78
# Best model updated
#
# Epoch 51/70 LR: [0.0625]
# Validation accuracy on group 1/10: 0.77
#
# Epoch 52/70 LR: [0.0625]
# Validation accuracy on group 1/10: 0.78
# Best model updated
#
# Epoch 53/70 LR: [0.0625]
# Validation accuracy on group 1/10: 0.78
#
# Epoch 54/70 LR: [0.0625]
# Validation accuracy on group 1/10: 0.78
#
# Epoch 55/70 LR: [0.0625]
# Validation accuracy on group 1/10: 0.78
#
# Epoch 56/70 LR: [0.0625]
# Validation accuracy on group 1/10: 0.79
# Best model updated
#
# Epoch 57/70 LR: [0.0625]
# Validation accuracy on group 1/10: 0.76
#
# Epoch 58/70 LR: [0.0625]
# Validation accuracy on group 1/10: 0.80
# Best model updated
#
# Epoch 59/70 LR: [0.0625]
# Validation accuracy on group 1/10: 0.78
#
# Epoch 60/70 LR: [0.0625]
# Validation accuracy on group 1/10: 0.78
#
# Epoch 61/70 LR: [0.0625]
# Validation accuracy on group 1/10: 0.79
#
# Epoch 62/70 LR: [0.0625]
# Validation accuracy on group 1/10: 0.78
#
# Epoch 63/70 LR: [0.0625]
# Validation accuracy on group 1/10: 0.79
#
# Epoch 64/70 LR: [0.015625]
# Validation accuracy on group 1/10: 0.78
#
# Epoch 65/70 LR: [0.015625]
# Validation accuracy on group 1/10: 0.79
#
# Epoch 66/70 LR: [0.015625]
# Validation accuracy on group 1/10: 0.81
# Best model updated
#
# Epoch 67/70 LR: [0.015625]
# Validation accuracy on group 1/10: 0.79
#
# Epoch 68/70 LR: [0.015625]
# Validation accuracy on group 1/10: 0.81
# Best model updated
#
# Epoch 69/70 LR: [0.015625]
# Validation accuracy on group 1/10: 0.82
# Best model updated
#
# Epoch 70/70 LR: [0.015625]
# Validation accuracy on group 1/10: 0.79
#
# Group 1 Finished!
# Best accuracy found at epoch 69: 0.82
# Testing classes seen so far, accuracy: 0.80
#
# =============================================
#
# Epoch 1/70 LR: [1]
# Validation accuracy on group 2/10: 0.32
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 2/10: 0.41
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 2/10: 0.41
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 2/10: 0.44
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 2/10: 0.42
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 2/10: 0.44
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 2/10: 0.45
# Best model updated
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 2/10: 0.48
# Best model updated
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 2/10: 0.47
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 2/10: 0.50
# Best model updated
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 2/10: 0.50
# Best model updated
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 2/10: 0.51
# Best model updated
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 2/10: 0.43
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 2/10: 0.49
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 2/10: 0.55
# Best model updated
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 2/10: 0.55
# Best model updated
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 2/10: 0.54
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 2/10: 0.53
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 2/10: 0.62
# Best model updated
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 2/10: 0.56
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 2/10: 0.55
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 2/10: 0.57
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 2/10: 0.54
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 2/10: 0.53
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 2/10: 0.56
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 2/10: 0.59
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 2/10: 0.59
#
# Epoch 28/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.63
# Best model updated
#
# Epoch 29/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.65
# Best model updated
#
# Epoch 30/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.66
# Best model updated
#
# Epoch 31/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.65
#
# Epoch 32/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.64
#
# Epoch 33/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.64
#
# Epoch 34/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.67
# Best model updated
#
# Epoch 35/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.64
#
# Epoch 36/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.64
#
# Epoch 37/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.62
#
# Epoch 38/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.64
#
# Epoch 39/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.64
#
# Epoch 40/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.63
#
# Epoch 41/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.62
#
# Epoch 42/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.64
#
# Epoch 43/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.64
#
# Epoch 44/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.67
# Best model updated
#
# Epoch 45/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.63
#
# Epoch 46/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.65
#
# Epoch 47/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.63
#
# Epoch 48/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.66
#
# Epoch 49/70 LR: [0.25]
# Validation accuracy on group 2/10: 0.63
#
# Epoch 50/70 LR: [0.0625]
# Validation accuracy on group 2/10: 0.66
#
# Epoch 51/70 LR: [0.0625]
# Validation accuracy on group 2/10: 0.68
# Best model updated
#
# Epoch 52/70 LR: [0.0625]
# Validation accuracy on group 2/10: 0.65
#
# Epoch 53/70 LR: [0.0625]
# Validation accuracy on group 2/10: 0.66
#
# Epoch 54/70 LR: [0.0625]
# Validation accuracy on group 2/10: 0.65
#
# Epoch 55/70 LR: [0.0625]
# Validation accuracy on group 2/10: 0.66
#
# Epoch 56/70 LR: [0.0625]
# Validation accuracy on group 2/10: 0.66
#
# Epoch 57/70 LR: [0.0625]
# Validation accuracy on group 2/10: 0.64
#
# Epoch 58/70 LR: [0.0625]
# Validation accuracy on group 2/10: 0.65
#
# Epoch 59/70 LR: [0.0625]
# Validation accuracy on group 2/10: 0.67
#
# Epoch 60/70 LR: [0.0625]
# Validation accuracy on group 2/10: 0.65
#
# Epoch 61/70 LR: [0.0625]
# Validation accuracy on group 2/10: 0.68
#
# Epoch 62/70 LR: [0.0625]
# Validation accuracy on group 2/10: 0.64
#
# Epoch 63/70 LR: [0.0625]
# Validation accuracy on group 2/10: 0.67
#
# Epoch 64/70 LR: [0.015625]
# Validation accuracy on group 2/10: 0.66
#
# Epoch 65/70 LR: [0.015625]
# Validation accuracy on group 2/10: 0.67
#
# Epoch 66/70 LR: [0.015625]
# Validation accuracy on group 2/10: 0.65
#
# Epoch 67/70 LR: [0.015625]
# Validation accuracy on group 2/10: 0.66
#
# Epoch 68/70 LR: [0.015625]
# Validation accuracy on group 2/10: 0.66
#
# Epoch 69/70 LR: [0.015625]
# Validation accuracy on group 2/10: 0.64
#
# Epoch 70/70 LR: [0.015625]
# Validation accuracy on group 2/10: 0.66
#
# Group 2 Finished!
# Best accuracy found at epoch 51: 0.68
# Testing classes seen so far, accuracy: 0.34
#
# =============================================
#
# Epoch 1/70 LR: [1]
# Validation accuracy on group 3/10: 0.58
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 3/10: 0.66
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 3/10: 0.70
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 3/10: 0.70
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 3/10: 0.70
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 3/10: 0.75
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 3/10: 0.73
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 3/10: 0.72
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 3/10: 0.72
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 3/10: 0.73
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 3/10: 0.76
# Best model updated
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 3/10: 0.77
# Best model updated
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 3/10: 0.75
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 3/10: 0.78
# Best model updated
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 3/10: 0.72
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 3/10: 0.77
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 3/10: 0.77
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 3/10: 0.77
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 3/10: 0.75
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 3/10: 0.77
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 3/10: 0.77
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 3/10: 0.79
# Best model updated
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 3/10: 0.79
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 3/10: 0.77
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 3/10: 0.74
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 3/10: 0.72
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 3/10: 0.73
#
# Epoch 28/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.81
# Best model updated
#
# Epoch 29/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.81
#
# Epoch 30/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.81
#
# Epoch 31/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.81
#
# Epoch 32/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.82
# Best model updated
#
# Epoch 33/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.82
#
# Epoch 34/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.83
# Best model updated
#
# Epoch 35/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.83
# Best model updated
#
# Epoch 36/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.82
#
# Epoch 37/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.82
#
# Epoch 38/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.82
#
# Epoch 39/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.84
# Best model updated
#
# Epoch 40/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.81
#
# Epoch 41/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.82
#
# Epoch 42/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.82
#
# Epoch 43/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.82
#
# Epoch 44/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.81
#
# Epoch 45/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.82
#
# Epoch 46/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.81
#
# Epoch 47/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.81
#
# Epoch 48/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.82
#
# Epoch 49/70 LR: [0.25]
# Validation accuracy on group 3/10: 0.82
#
# Epoch 50/70 LR: [0.0625]
# Validation accuracy on group 3/10: 0.82
#
# Epoch 51/70 LR: [0.0625]
# Validation accuracy on group 3/10: 0.83
#
# Epoch 52/70 LR: [0.0625]
# Validation accuracy on group 3/10: 0.82
#
# Epoch 53/70 LR: [0.0625]
# Validation accuracy on group 3/10: 0.82
#
# Epoch 54/70 LR: [0.0625]
# Validation accuracy on group 3/10: 0.83
#
# Epoch 55/70 LR: [0.0625]
# Validation accuracy on group 3/10: 0.81
#
# Epoch 56/70 LR: [0.0625]
# Validation accuracy on group 3/10: 0.84
# Best model updated
#
# Epoch 57/70 LR: [0.0625]
# Validation accuracy on group 3/10: 0.82
#
# Epoch 58/70 LR: [0.0625]
# Validation accuracy on group 3/10: 0.81
#
# Epoch 59/70 LR: [0.0625]
# Validation accuracy on group 3/10: 0.82
#
# Epoch 60/70 LR: [0.0625]
# Validation accuracy on group 3/10: 0.82
#
# Epoch 61/70 LR: [0.0625]
# Validation accuracy on group 3/10: 0.83
#
# Epoch 62/70 LR: [0.0625]
# Validation accuracy on group 3/10: 0.81
#
# Epoch 63/70 LR: [0.0625]
# Validation accuracy on group 3/10: 0.83
#
# Epoch 64/70 LR: [0.015625]
# Validation accuracy on group 3/10: 0.82
#
# Epoch 65/70 LR: [0.015625]
# Validation accuracy on group 3/10: 0.82
#
# Epoch 66/70 LR: [0.015625]
# Validation accuracy on group 3/10: 0.82
#
# Epoch 67/70 LR: [0.015625]
# Validation accuracy on group 3/10: 0.83
#
# Epoch 68/70 LR: [0.015625]
# Validation accuracy on group 3/10: 0.83
#
# Epoch 69/70 LR: [0.015625]
# Validation accuracy on group 3/10: 0.82
#
# Epoch 70/70 LR: [0.015625]
# Validation accuracy on group 3/10: 0.81
#
# Group 3 Finished!
# Best accuracy found at epoch 56: 0.84
# Testing classes seen so far, accuracy: 0.28
#
# =============================================
#
# Epoch 1/70 LR: [1]
# Validation accuracy on group 4/10: 0.49
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 4/10: 0.60
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 4/10: 0.64
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 4/10: 0.64
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 4/10: 0.67
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 4/10: 0.66
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 4/10: 0.68
# Best model updated
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 4/10: 0.71
# Best model updated
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 4/10: 0.69
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 4/10: 0.67
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 4/10: 0.71
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 4/10: 0.70
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 4/10: 0.70
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 4/10: 0.70
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 4/10: 0.75
# Best model updated
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 4/10: 0.74
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 4/10: 0.71
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 4/10: 0.73
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 4/10: 0.77
# Best model updated
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 4/10: 0.75
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 4/10: 0.74
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 4/10: 0.77
# Best model updated
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 4/10: 0.76
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 4/10: 0.75
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 4/10: 0.71
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 4/10: 0.75
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 4/10: 0.73
#
# Epoch 28/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.80
# Best model updated
#
# Epoch 29/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.80
# Best model updated
#
# Epoch 30/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.80
# Best model updated
#
# Epoch 31/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.80
#
# Epoch 32/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.80
#
# Epoch 33/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.79
#
# Epoch 34/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.80
#
# Epoch 35/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.81
# Best model updated
#
# Epoch 36/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.79
#
# Epoch 37/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.80
#
# Epoch 38/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.80
#
# Epoch 39/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.80
#
# Epoch 40/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.81
# Best model updated
#
# Epoch 41/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.82
# Best model updated
#
# Epoch 42/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.80
#
# Epoch 43/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.80
#
# Epoch 44/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.81
#
# Epoch 45/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.79
#
# Epoch 46/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.81
#
# Epoch 47/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.81
#
# Epoch 48/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.79
#
# Epoch 49/70 LR: [0.25]
# Validation accuracy on group 4/10: 0.80
#
# Epoch 50/70 LR: [0.0625]
# Validation accuracy on group 4/10: 0.81
#
# Epoch 51/70 LR: [0.0625]
# Validation accuracy on group 4/10: 0.80
#
# Epoch 52/70 LR: [0.0625]
# Validation accuracy on group 4/10: 0.80
#
# Epoch 53/70 LR: [0.0625]
# Validation accuracy on group 4/10: 0.81
#
# Epoch 54/70 LR: [0.0625]
# Validation accuracy on group 4/10: 0.81
#
# Epoch 55/70 LR: [0.0625]
# Validation accuracy on group 4/10: 0.81
#
# Epoch 56/70 LR: [0.0625]
# Validation accuracy on group 4/10: 0.82
#
# Epoch 57/70 LR: [0.0625]
# Validation accuracy on group 4/10: 0.81
#
# Epoch 58/70 LR: [0.0625]
# Validation accuracy on group 4/10: 0.81
#
# Epoch 59/70 LR: [0.0625]
# Validation accuracy on group 4/10: 0.82
# Best model updated
#
# Epoch 60/70 LR: [0.0625]
# Validation accuracy on group 4/10: 0.79
#
# Epoch 61/70 LR: [0.0625]
# Validation accuracy on group 4/10: 0.81
#
# Epoch 62/70 LR: [0.0625]
# Validation accuracy on group 4/10: 0.81
#
# Epoch 63/70 LR: [0.0625]
# Validation accuracy on group 4/10: 0.80
#
# Epoch 64/70 LR: [0.015625]
# Validation accuracy on group 4/10: 0.81
#
# Epoch 65/70 LR: [0.015625]
# Validation accuracy on group 4/10: 0.82
#
# Epoch 66/70 LR: [0.015625]
# Validation accuracy on group 4/10: 0.80
#
# Epoch 67/70 LR: [0.015625]
# Validation accuracy on group 4/10: 0.82
#
# Epoch 68/70 LR: [0.015625]
# Validation accuracy on group 4/10: 0.81
#
# Epoch 69/70 LR: [0.015625]
# Validation accuracy on group 4/10: 0.79
#
# Epoch 70/70 LR: [0.015625]
# Validation accuracy on group 4/10: 0.82
#
# Group 4 Finished!
# Best accuracy found at epoch 59: 0.82
# Testing classes seen so far, accuracy: 0.20
#
# =============================================
#
# Epoch 1/70 LR: [1]
# Validation accuracy on group 5/10: 0.51
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 5/10: 0.63
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 5/10: 0.66
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 5/10: 0.67
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 5/10: 0.72
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 5/10: 0.69
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 5/10: 0.71
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 5/10: 0.73
# Best model updated
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 5/10: 0.70
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 5/10: 0.74
# Best model updated
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 5/10: 0.73
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 5/10: 0.71
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 5/10: 0.73
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 5/10: 0.72
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 5/10: 0.76
# Best model updated
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 5/10: 0.68
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 5/10: 0.73
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 5/10: 0.76
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 5/10: 0.74
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 5/10: 0.76
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 5/10: 0.76
# Best model updated
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 5/10: 0.70
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 5/10: 0.74
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 5/10: 0.75
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 5/10: 0.73
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 5/10: 0.78
# Best model updated
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 5/10: 0.72
#
# Epoch 28/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.79
# Best model updated
#
# Epoch 29/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.79
# Best model updated
#
# Epoch 30/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.78
#
# Epoch 31/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.79
#
# Epoch 32/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.79
#
# Epoch 33/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.78
#
# Epoch 34/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.78
#
# Epoch 35/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.80
# Best model updated
#
# Epoch 36/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.79
#
# Epoch 37/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.80
#
# Epoch 38/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.79
#
# Epoch 39/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.79
#
# Epoch 40/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.79
#
# Epoch 41/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.79
#
# Epoch 42/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.79
#
# Epoch 43/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.80
#
# Epoch 44/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.79
#
# Epoch 45/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.79
#
# Epoch 46/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.80
#
# Epoch 47/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.80
# Best model updated
#
# Epoch 48/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.78
#
# Epoch 49/70 LR: [0.25]
# Validation accuracy on group 5/10: 0.79
#
# Epoch 50/70 LR: [0.0625]
# Validation accuracy on group 5/10: 0.80
#
# Epoch 51/70 LR: [0.0625]
# Validation accuracy on group 5/10: 0.80
#
# Epoch 52/70 LR: [0.0625]
# Validation accuracy on group 5/10: 0.80
#
# Epoch 53/70 LR: [0.0625]
# Validation accuracy on group 5/10: 0.79
#
# Epoch 54/70 LR: [0.0625]
# Validation accuracy on group 5/10: 0.78
#
# Epoch 55/70 LR: [0.0625]
# Validation accuracy on group 5/10: 0.81
# Best model updated
#
# Epoch 56/70 LR: [0.0625]
# Validation accuracy on group 5/10: 0.79
#
# Epoch 57/70 LR: [0.0625]
# Validation accuracy on group 5/10: 0.79
#
# Epoch 58/70 LR: [0.0625]
# Validation accuracy on group 5/10: 0.78
#
# Epoch 59/70 LR: [0.0625]
# Validation accuracy on group 5/10: 0.81
#
# Epoch 60/70 LR: [0.0625]
# Validation accuracy on group 5/10: 0.81
#
# Epoch 61/70 LR: [0.0625]
# Validation accuracy on group 5/10: 0.79
#
# Epoch 62/70 LR: [0.0625]
# Validation accuracy on group 5/10: 0.79
#
# Epoch 63/70 LR: [0.0625]
# Validation accuracy on group 5/10: 0.80
#
# Epoch 64/70 LR: [0.015625]
# Validation accuracy on group 5/10: 0.81
#
# Epoch 65/70 LR: [0.015625]
# Validation accuracy on group 5/10: 0.81
#
# Epoch 66/70 LR: [0.015625]
# Validation accuracy on group 5/10: 0.81
#
# Epoch 67/70 LR: [0.015625]
# Validation accuracy on group 5/10: 0.79
#
# Epoch 68/70 LR: [0.015625]
# Validation accuracy on group 5/10: 0.79
#
# Epoch 69/70 LR: [0.015625]
# Validation accuracy on group 5/10: 0.78
#
# Epoch 70/70 LR: [0.015625]
# Validation accuracy on group 5/10: 0.82
# Best model updated
#
# Group 5 Finished!
# Best accuracy found at epoch 70: 0.82
# Testing classes seen so far, accuracy: 0.16
#
# =============================================
#
# Epoch 1/70 LR: [1]
# Validation accuracy on group 6/10: 0.58
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 6/10: 0.70
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 6/10: 0.76
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 6/10: 0.78
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 6/10: 0.79
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 6/10: 0.78
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 6/10: 0.78
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 6/10: 0.81
# Best model updated
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 6/10: 0.81
# Best model updated
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 6/10: 0.82
# Best model updated
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 6/10: 0.77
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 6/10: 0.80
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 6/10: 0.78
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 6/10: 0.80
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 6/10: 0.81
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 6/10: 0.82
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 6/10: 0.81
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 6/10: 0.77
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 6/10: 0.81
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 6/10: 0.79
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 6/10: 0.81
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 6/10: 0.79
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 6/10: 0.77
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 6/10: 0.81
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 6/10: 0.81
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 6/10: 0.79
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 6/10: 0.81
#
# Epoch 28/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.83
# Best model updated
#
# Epoch 29/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.85
# Best model updated
#
# Epoch 30/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.84
#
# Epoch 31/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.85
#
# Epoch 32/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.84
#
# Epoch 33/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.84
#
# Epoch 34/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.85
#
# Epoch 35/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.85
#
# Epoch 36/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.85
#
# Epoch 37/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.85
#
# Epoch 38/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.84
#
# Epoch 39/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.83
#
# Epoch 40/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.86
# Best model updated
#
# Epoch 41/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.84
#
# Epoch 42/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.84
#
# Epoch 43/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.85
#
# Epoch 44/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.85
#
# Epoch 45/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.84
#
# Epoch 46/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.85
#
# Epoch 47/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.85
#
# Epoch 48/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.84
#
# Epoch 49/70 LR: [0.25]
# Validation accuracy on group 6/10: 0.85
#
# Epoch 50/70 LR: [0.0625]
# Validation accuracy on group 6/10: 0.85
#
# Epoch 51/70 LR: [0.0625]
# Validation accuracy on group 6/10: 0.85
#
# Epoch 52/70 LR: [0.0625]
# Validation accuracy on group 6/10: 0.86
#
# Epoch 53/70 LR: [0.0625]
# Validation accuracy on group 6/10: 0.84
#
# Epoch 54/70 LR: [0.0625]
# Validation accuracy on group 6/10: 0.86
# Best model updated
#
# Epoch 55/70 LR: [0.0625]
# Validation accuracy on group 6/10: 0.86
#
# Epoch 56/70 LR: [0.0625]
# Validation accuracy on group 6/10: 0.85
#
# Epoch 57/70 LR: [0.0625]
# Validation accuracy on group 6/10: 0.86
#
# Epoch 58/70 LR: [0.0625]
# Validation accuracy on group 6/10: 0.85
#
# Epoch 59/70 LR: [0.0625]
# Validation accuracy on group 6/10: 0.84
#
# Epoch 60/70 LR: [0.0625]
# Validation accuracy on group 6/10: 0.86
#
# Epoch 61/70 LR: [0.0625]
# Validation accuracy on group 6/10: 0.86
#
# Epoch 62/70 LR: [0.0625]
# Validation accuracy on group 6/10: 0.85
#
# Epoch 63/70 LR: [0.0625]
# Validation accuracy on group 6/10: 0.84
#
# Epoch 64/70 LR: [0.015625]
# Validation accuracy on group 6/10: 0.84
#
# Epoch 65/70 LR: [0.015625]
# Validation accuracy on group 6/10: 0.85
#
# Epoch 66/70 LR: [0.015625]
# Validation accuracy on group 6/10: 0.85
#
# Epoch 67/70 LR: [0.015625]
# Validation accuracy on group 6/10: 0.86
#
# Epoch 68/70 LR: [0.015625]
# Validation accuracy on group 6/10: 0.84
#
# Epoch 69/70 LR: [0.015625]
# Validation accuracy on group 6/10: 0.85
#
# Epoch 70/70 LR: [0.015625]
# Validation accuracy on group 6/10: 0.87
# Best model updated
#
# Group 6 Finished!
# Best accuracy found at epoch 70: 0.87
# Testing classes seen so far, accuracy: 0.14
#
# =============================================
#
# Epoch 1/70 LR: [1]
# Validation accuracy on group 7/10: 0.49
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 7/10: 0.59
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 7/10: 0.63
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 7/10: 0.64
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 7/10: 0.66
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 7/10: 0.71
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 7/10: 0.65
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 7/10: 0.68
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 7/10: 0.68
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 7/10: 0.71
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 7/10: 0.70
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 7/10: 0.62
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 7/10: 0.65
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 7/10: 0.69
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 7/10: 0.72
# Best model updated
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 7/10: 0.68
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 7/10: 0.70
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 7/10: 0.70
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 7/10: 0.72
# Best model updated
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 7/10: 0.72
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 7/10: 0.73
# Best model updated
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 7/10: 0.71
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 7/10: 0.72
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 7/10: 0.68
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 7/10: 0.70
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 7/10: 0.70
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 7/10: 0.68
#
# Epoch 28/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.75
# Best model updated
#
# Epoch 29/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.76
# Best model updated
#
# Epoch 30/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.75
#
# Epoch 31/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.76
# Best model updated
#
# Epoch 32/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.76
#
# Epoch 33/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.77
# Best model updated
#
# Epoch 34/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.76
#
# Epoch 35/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.76
#
# Epoch 36/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.75
#
# Epoch 37/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.75
#
# Epoch 38/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.76
#
# Epoch 39/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.77
#
# Epoch 40/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.77
#
# Epoch 41/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.77
#
# Epoch 42/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.76
#
# Epoch 43/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.76
#
# Epoch 44/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.74
#
# Epoch 45/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.76
#
# Epoch 46/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.76
#
# Epoch 47/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.75
#
# Epoch 48/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.76
#
# Epoch 49/70 LR: [0.25]
# Validation accuracy on group 7/10: 0.76
#
# Epoch 50/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.76
#
# Epoch 51/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.76
#
# Epoch 52/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.77
#
# Epoch 53/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.76
#
# Epoch 54/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.76
#
# Epoch 55/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.74
#
# Epoch 56/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.74
#
# Epoch 57/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.77
#
# Epoch 58/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.76
#
# Epoch 59/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.75
#
# Epoch 60/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.76
#
# Epoch 61/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.74
#
# Epoch 62/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.75
#
# Epoch 63/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.75
#
# Epoch 64/70 LR: [0.015625]
# Validation accuracy on group 7/10: 0.78
# Best model updated
#
# Epoch 65/70 LR: [0.015625]
# Validation accuracy on group 7/10: 0.77
#
# Epoch 66/70 LR: [0.015625]
# Validation accuracy on group 7/10: 0.78
#
# Epoch 67/70 LR: [0.015625]
# Validation accuracy on group 7/10: 0.75
#
# Epoch 68/70 LR: [0.015625]
# Validation accuracy on group 7/10: 0.76
#
# Epoch 69/70 LR: [0.015625]
# Validation accuracy on group 7/10: 0.77
#
# Epoch 70/70 LR: [0.015625]
# Validation accuracy on group 7/10: 0.75
#
# Group 7 Finished!
# Best accuracy found at epoch 64: 0.78
# Testing classes seen so far, accuracy: 0.11
#
# =============================================
#
# Epoch 1/70 LR: [1]
# Validation accuracy on group 8/10: 0.52
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 8/10: 0.66
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 8/10: 0.67
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 8/10: 0.74
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 8/10: 0.76
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 8/10: 0.76
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 8/10: 0.75
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 8/10: 0.76
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 8/10: 0.78
# Best model updated
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 8/10: 0.78
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 8/10: 0.77
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 8/10: 0.81
# Best model updated
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 8/10: 0.81
# Best model updated
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 8/10: 0.81
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 8/10: 0.79
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 8/10: 0.78
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 8/10: 0.78
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 8/10: 0.79
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 8/10: 0.78
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 8/10: 0.75
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 8/10: 0.78
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 8/10: 0.79
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 8/10: 0.73
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 8/10: 0.82
# Best model updated
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 8/10: 0.79
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 8/10: 0.81
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 8/10: 0.81
#
# Epoch 28/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.84
# Best model updated
#
# Epoch 29/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.85
# Best model updated
#
# Epoch 30/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.83
#
# Epoch 31/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.85
#
# Epoch 32/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.84
#
# Epoch 33/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.84
#
# Epoch 34/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.85
# Best model updated
#
# Epoch 35/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.84
#
# Epoch 36/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.84
#
# Epoch 37/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.85
# Best model updated
#
# Epoch 38/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.84
#
# Epoch 39/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.84
#
# Epoch 40/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.85
#
# Epoch 41/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.83
#
# Epoch 42/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.85
#
# Epoch 43/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.84
#
# Epoch 44/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.84
#
# Epoch 45/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.84
#
# Epoch 46/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.84
#
# Epoch 47/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.84
#
# Epoch 48/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.83
#
# Epoch 49/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.85
#
# Epoch 50/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.84
#
# Epoch 51/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.84
#
# Epoch 52/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.85
#
# Epoch 53/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.84
#
# Epoch 54/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.85
#
# Epoch 55/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.86
# Best model updated
#
# Epoch 56/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.84
#
# Epoch 57/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.85
#
# Epoch 58/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.84
#
# Epoch 59/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.85
#
# Epoch 60/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.83
#
# Epoch 61/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.83
#
# Epoch 62/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.85
#
# Epoch 63/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.84
#
# Epoch 64/70 LR: [0.015625]
# Validation accuracy on group 8/10: 0.85
#
# Epoch 65/70 LR: [0.015625]
# Validation accuracy on group 8/10: 0.84
#
# Epoch 66/70 LR: [0.015625]
# Validation accuracy on group 8/10: 0.85
#
# Epoch 67/70 LR: [0.015625]
# Validation accuracy on group 8/10: 0.85
#
# Epoch 68/70 LR: [0.015625]
# Validation accuracy on group 8/10: 0.84
#
# Epoch 69/70 LR: [0.015625]
# Validation accuracy on group 8/10: 0.85
#
# Epoch 70/70 LR: [0.015625]
# Validation accuracy on group 8/10: 0.84
#
# Group 8 Finished!
# Best accuracy found at epoch 55: 0.86
# Testing classes seen so far, accuracy: 0.11
#
# =============================================
#
# Epoch 1/70 LR: [1]
# Validation accuracy on group 9/10: 0.49
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 9/10: 0.70
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 9/10: 0.73
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 9/10: 0.77
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 9/10: 0.76
#
# Epoch 6/70 LR: [1]
# ...
#
# Epoch 56/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.80
#
# Epoch 57/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.81
# Best model updated
#
# Epoch 58/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.78
#
# Epoch 59/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.79
#
# Epoch 60/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.79
#
# Epoch 61/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.81
# Best model updated
#
# Epoch 62/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.79
#
# Epoch 63/70 LR: [0.0625]
# Validation accuracy on group 7/10: 0.80
#
# Epoch 64/70 LR: [0.015625]
# Validation accuracy on group 7/10: 0.80
#
# Epoch 65/70 LR: [0.015625]
# Validation accuracy on group 7/10: 0.78
#
# Epoch 66/70 LR: [0.015625]
# Validation accuracy on group 7/10: 0.80
#
# Epoch 67/70 LR: [0.015625]
# Validation accuracy on group 7/10: 0.78
#
# Epoch 68/70 LR: [0.015625]
# Validation accuracy on group 7/10: 0.79
#
# Epoch 69/70 LR: [0.015625]
# Validation accuracy on group 7/10: 0.79
#
# Epoch 70/70 LR: [0.015625]
# Validation accuracy on group 7/10: 0.81
#
# Group 7 Finished!
# Best accuracy found at epoch 61: 0.81
# Testing classes seen so far, accuracy: 0.12
#
# =============================================
#
# Epoch 1/70 LR: [1]
# Validation accuracy on group 8/10: 0.52
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 8/10: 0.66
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 8/10: 0.65
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 8/10: 0.68
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 8/10: 0.72
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 8/10: 0.70
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 8/10: 0.69
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 8/10: 0.72
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 8/10: 0.73
# Best model updated
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 8/10: 0.72
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 8/10: 0.75
# Best model updated
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 8/10: 0.73
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 8/10: 0.76
# Best model updated
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 8/10: 0.75
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 8/10: 0.73
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 8/10: 0.73
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 8/10: 0.73
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 8/10: 0.72
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 8/10: 0.72
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 8/10: 0.76
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 8/10: 0.75
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 8/10: 0.68
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 8/10: 0.74
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 8/10: 0.74
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 8/10: 0.72
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 8/10: 0.75
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 8/10: 0.74
#
# Epoch 28/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.78
# Best model updated
#
# Epoch 29/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.79
# Best model updated
#
# Epoch 30/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.79
#
# Epoch 31/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.80
# Best model updated
#
# Epoch 32/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.79
#
# Epoch 33/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.77
#
# Epoch 34/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.80
# Best model updated
#
# Epoch 35/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.80
#
# Epoch 36/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.78
#
# Epoch 37/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.80
#
# Epoch 38/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.79
#
# Epoch 39/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.80
# Best model updated
#
# Epoch 40/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.79
#
# Epoch 41/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.80
# Best model updated
#
# Epoch 42/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.79
#
# Epoch 43/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.79
#
# Epoch 44/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.79
#
# Epoch 45/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.77
#
# Epoch 46/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.80
#
# Epoch 47/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.79
#
# Epoch 48/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.80
#
# Epoch 49/70 LR: [0.25]
# Validation accuracy on group 8/10: 0.79
#
# Epoch 50/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.79
#
# Epoch 51/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.78
#
# Epoch 52/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.78
#
# Epoch 53/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.81
# Best model updated
#
# Epoch 54/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.78
#
# Epoch 55/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.79
#
# Epoch 56/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.79
#
# Epoch 57/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.80
#
# Epoch 58/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.81
#
# Epoch 59/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.81
# Best model updated
#
# Epoch 60/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.78
#
# Epoch 61/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.80
#
# Epoch 62/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.81
#
# Epoch 63/70 LR: [0.0625]
# Validation accuracy on group 8/10: 0.78
#
# Epoch 64/70 LR: [0.015625]
# Validation accuracy on group 8/10: 0.80
#
# Epoch 65/70 LR: [0.015625]
# Validation accuracy on group 8/10: 0.78
#
# Epoch 66/70 LR: [0.015625]
# Validation accuracy on group 8/10: 0.80
#
# Epoch 67/70 LR: [0.015625]
# Validation accuracy on group 8/10: 0.80
#
# Epoch 68/70 LR: [0.015625]
# Validation accuracy on group 8/10: 0.80
#
# Epoch 69/70 LR: [0.015625]
# Validation accuracy on group 8/10: 0.80
#
# Epoch 70/70 LR: [0.015625]
# Validation accuracy on group 8/10: 0.78
#
# Group 8 Finished!
# Best accuracy found at epoch 59: 0.81
# Testing classes seen so far, accuracy: 0.10
#
# =============================================
#
# Epoch 1/70 LR: [1]
# Validation accuracy on group 9/10: 0.51
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 9/10: 0.58
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 9/10: 0.63
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 9/10: 0.68
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 9/10: 0.68
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 9/10: 0.70
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 9/10: 0.68
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 9/10: 0.68
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 9/10: 0.65
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 9/10: 0.70
# Best model updated
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 9/10: 0.71
# Best model updated
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 9/10: 0.71
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 9/10: 0.71
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 9/10: 0.69
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 9/10: 0.68
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 9/10: 0.69
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 9/10: 0.72
# Best model updated
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 9/10: 0.73
# Best model updated
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 9/10: 0.66
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 9/10: 0.72
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 9/10: 0.71
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 9/10: 0.66
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 9/10: 0.73
# Best model updated
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 9/10: 0.70
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 9/10: 0.75
# Best model updated
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 9/10: 0.72
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 9/10: 0.67
#
# Epoch 28/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.77
# Best model updated
#
# Epoch 29/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.76
#
# Epoch 30/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.78
# Best model updated
#
# Epoch 31/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.78
# Best model updated
#
# Epoch 32/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.78
#
# Epoch 33/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.79
# Best model updated
#
# Epoch 34/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.77
#
# Epoch 35/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.78
#
# Epoch 36/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.78
#
# Epoch 37/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.77
#
# Epoch 38/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.77
#
# Epoch 39/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.78
#
# Epoch 40/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.79
#
# Epoch 41/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.78
#
# Epoch 42/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.77
#
# Epoch 43/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.76
#
# Epoch 44/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.78
#
# Epoch 45/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.78
#
# Epoch 46/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.77
#
# Epoch 47/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.79
#
# Epoch 48/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.77
#
# Epoch 49/70 LR: [0.25]
# Validation accuracy on group 9/10: 0.79
#
# Epoch 50/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.79
# Best model updated
#
# Epoch 51/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.80
# Best model updated
#
# Epoch 52/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.78
#
# Epoch 53/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.78
#
# Epoch 54/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.79
#
# Epoch 55/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.79
#
# Epoch 56/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.77
#
# Epoch 57/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.78
#
# Epoch 58/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.78
#
# Epoch 59/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.79
#
# Epoch 60/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.79
#
# Epoch 61/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.80
#
# Epoch 62/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.77
#
# Epoch 63/70 LR: [0.0625]
# Validation accuracy on group 9/10: 0.80
# Best model updated
#
# Epoch 64/70 LR: [0.015625]
# Validation accuracy on group 9/10: 0.80
#
# Epoch 65/70 LR: [0.015625]
# Validation accuracy on group 9/10: 0.79
#
# Epoch 66/70 LR: [0.015625]
# Validation accuracy on group 9/10: 0.78
#
# Epoch 67/70 LR: [0.015625]
# Validation accuracy on group 9/10: 0.77
#
# Epoch 68/70 LR: [0.015625]
# Validation accuracy on group 9/10: 0.79
#
# Epoch 69/70 LR: [0.015625]
# Validation accuracy on group 9/10: 0.79
#
# Epoch 70/70 LR: [0.015625]
# Validation accuracy on group 9/10: 0.79
#
# Group 9 Finished!
# Best accuracy found at epoch 63: 0.80
# Testing classes seen so far, accuracy: 0.09
#
# =============================================
#
# Epoch 1/70 LR: [1]
# Validation accuracy on group 10/10: 0.59
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 10/10: 0.63
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 10/10: 0.74
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 10/10: 0.78
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 10/10: 0.76
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 10/10: 0.78
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 10/10: 0.78
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 10/10: 0.77
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 10/10: 0.79
# Best model updated
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 10/10: 0.80
# Best model updated
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 10/10: 0.77
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 10/10: 0.81
# Best model updated
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 10/10: 0.79
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 10/10: 0.81
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 10/10: 0.80
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 10/10: 0.80
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 10/10: 0.75
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 10/10: 0.80
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 10/10: 0.80
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 10/10: 0.83
# Best model updated
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 10/10: 0.83
# Best model updated
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 10/10: 0.80
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 10/10: 0.79
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 10/10: 0.83
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 10/10: 0.76
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 10/10: 0.76
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 10/10: 0.83
#
# Epoch 28/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.87
# Best model updated
#
# Epoch 29/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.85
#
# Epoch 30/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.85
#
# Epoch 31/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.87
#
# Epoch 32/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.87
#
# Epoch 33/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.86
#
# Epoch 34/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.86
#
# Epoch 35/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.87
#
# Epoch 36/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.86
#
# Epoch 37/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.87
# Best model updated
#
# Epoch 38/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.86
#
# Epoch 39/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.86
#
# Epoch 40/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.88
# Best model updated
#
# Epoch 41/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.88
#
# Epoch 42/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.85
#
# Epoch 43/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.87
#
# Epoch 44/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.87
#
# Epoch 45/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.88
# Best model updated
#
# Epoch 46/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.86
#
# Epoch 47/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.86
#
# Epoch 48/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.86
#
# Epoch 49/70 LR: [0.25]
# Validation accuracy on group 10/10: 0.87
#
# Epoch 50/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.88
#
# Epoch 51/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.88
#
# Epoch 52/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.88
#
# Epoch 53/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.88
#
# Epoch 54/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.86
#
# Epoch 55/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.87
#
# Epoch 56/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.87
#
# Epoch 57/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.88
#
# Epoch 58/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.87
#
# Epoch 59/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.88
#
# Epoch 60/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.88
#
# Epoch 61/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.87
#
# Epoch 62/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.85
#
# Epoch 63/70 LR: [0.0625]
# Validation accuracy on group 10/10: 0.86
#
# Epoch 64/70 LR: [0.015625]
# Validation accuracy on group 10/10: 0.86
#
# Epoch 65/70 LR: [0.015625]
# Validation accuracy on group 10/10: 0.88
#
# Epoch 66/70 LR: [0.015625]
# Validation accuracy on group 10/10: 0.86
#
# Epoch 67/70 LR: [0.015625]
# Validation accuracy on group 10/10: 0.87
#
# Epoch 68/70 LR: [0.015625]
# Validation accuracy on group 10/10: 0.87
#
# Epoch 69/70 LR: [0.015625]
# Validation accuracy on group 10/10: 0.88
#
# Epoch 70/70 LR: [0.015625]
# Validation accuracy on group 10/10: 0.87
#
# Group 10 Finished!
# Best accuracy found at epoch 45: 0.88
# Testing classes seen so far, accuracy: 0.09
#
# =============================================
#
# #################################

# %% [markdown]
# ### Store logs in more usable dtype

# %%
train_loss = [[logs[run_i]['group_train_loss'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
train_accuracy = [[logs[run_i]['group_train_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
val_loss = [[logs[run_i]['val_losses'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
val_accuracy = [[logs[run_i]['val_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
test_accuracy = [[logs[run_i]['test_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
predictions = [logs[run_i]['predictions'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]
true_labels = [logs[run_i]['true_labels'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]

# %% [markdown]
# ### Save the model

# %% [markdown]
# #### Saving logs in JSON files

# %%
import json

with open('states/FineTuning_train_loss.json', 'w') as f:
  json.dump(train_loss, f)
f.close
with open('states/FineTuning_train_accuracy.json', 'w') as f:
  json.dump(train_accuracy, f)
f.close
with open('states/FineTuning_val_loss.json', 'w') as f:
  json.dump(val_loss, f)
f.close  
with open('states/FineTuning_val_accuracy.json', 'w') as f:
  json.dump(val_accuracy, f)
f.close
with open('states/FineTuning_test_accuracy.json', 'w') as f:
  json.dump(test_accuracy, f)
f.close
with open('states/FineTuning_predictions.json', 'w') as f:
  json.dump(predictions, f)
f.close
with open('states/FineTuning_true_labels.json', 'w') as f:
  json.dump(true_labels, f)
f.close
# Out:
# <function TextIOWrapper.close>

# %% [markdown]
# #### Saving best resnet on 100 classes for each seed

# %%
for i in range(len(RANDOM_SEED)):
  torch.save(best_net_tot_classes[i].state_dict(), "states/FineTuning_bestnet_seed[{}]".format(RANDOM_SEED[i]))

# %%
from google.colab import files
files.download('states/FineTuning_train_loss.json')
files.download('states/FineTuning_train_accuracy.json')
files.download('states/FineTuning_val_loss.json')
files.download('states/FineTuning_val_accuracy.json')
files.download('states/FineTuning_test_accuracy.json')
files.download('states/FineTuning_predictions.json')
files.download('states/FineTuning_true_labels.json')
files.download('states/FineTuning_bestnet_seed[24]')
files.download('states/FineTuning_bestnet_seed[66]')
files.download('states/FineTuning_bestnet_seed[32]')

# %% [markdown]
# ### Print some graphs

# %%
from data.utils_plot import plot_train_val, plot_test_accuracies, plot_confusion_matrix

# %%
train_loss = np.array(train_loss)
train_accuracy = np.array(train_accuracy)
val_loss = np.array(val_loss)
val_accuracy = np.array(val_accuracy)
test_accuracy = np.array(test_accuracy)

train_loss_stats = np.array([train_loss.mean(0), train_loss.std(0)]).transpose()
train_accuracy_stats = np.array([train_accuracy.mean(0), train_accuracy.std(0)]).transpose()
val_loss_stats = np.array([val_loss.mean(0), val_loss.std(0)]).transpose()
val_accuracy_stats = np.array([val_accuracy.mean(0), val_accuracy.std(0)]).transpose()
test_accuracy_stats = np.array([test_accuracy.mean(0), test_accuracy.std(0)]).transpose()

# %% [markdown]
# #### Train validation loss

# %%
plot_train_val(train_loss_stats, val_loss_stats, loss = True)

# %% [markdown]
# #### Train validation accuracy

# %%
plot_train_val(train_accuracy_stats, val_accuracy_stats, loss = False)

# %% [markdown]
# #### Test accuracy

# %%
plot_test_accuracies(test_accuracy_stats)

# %% [markdown]
# #### Confusion Matrix

# %%
for run in range(len(RANDOM_SEED)):
  targets = logs[run]['true_labels'].cpu().data.numpy()
  preds = logs[run]['predictions'].cpu().data.numpy()

  plot_confusion_matrix(targets, preds, RANDOM_SEED[run], 'FineTuning')
