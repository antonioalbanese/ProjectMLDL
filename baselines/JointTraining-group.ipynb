# %% [markdown]
# <a href="https://colab.research.google.com/github/cosminnedescu/ProjectMLDL/blob/main/baselines/JointTraining-group.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable

import torchvision
from torchvision import transforms, datasets, models
from torch.utils.data import Subset, DataLoader

from PIL import Image

import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# %%
# %cd ../
# Out:
# /

# %%
# %cd content/
# Out:
# /content

# %%
# !rm -rf ProjectMLDL

# %%
# !ls
# Out:
# sample_data

# %%
if not os.path.isdir('/content/ProjectMLDL'):
  # !git clone https://github.com/cosminnedescu/ProjectMLDL.git
  # %cd /content/ProjectMLDL
  # !rm -rf LICENSE README.md
# Out:
# Cloning into 'ProjectMLDL'...
# remote: Enumerating objects: 90, done.
# remote: Counting objects: 100% (90/90), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 90 (delta 26), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (90/90), done.
# /content/ProjectMLDL

# %%
from data.cifar100 import CIFAR100
from model.resnet32 import resnet32
import data.utils
from model.trainer import Trainer
from copy import copy

# %%
# True mean and std of Cifar100 dataset (src="https://gist.github.com/weiaicunzai/e623931921efefd4c331622c344d8151")
mean = [0.5071, 0.4867, 0.4408]
std = [0.2675, 0.2565, 0.2761]

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])
test_transform = transforms.Compose(
    [transforms.ToTensor(), 
     transforms.Normalize(mean, std),
     ])

# %%
train_data = CIFAR100("dataset", train=True, transform=train_transform, download=True)
test_data = CIFAR100("dataset", train=False, transform=test_transform, download=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to dataset/cifar-100-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting dataset/cifar-100-python.tar.gz to dataset
# Files already downloaded and verified

# %%
#check images and labels after shuffle
#https://github.com/keras-team/keras/issues/2653#issuecomment-450133996
import matplotlib.pyplot as plt

plt.imshow(train_data.data[6])
print("classe: {}".format(train_data.targets[6]))
# Out:
# classe: 90

# %%
RANDOM_SEED = [42,13,10]
# Settings
DEVICE = 'cuda'

NUM_CLASSES = 100       # Total number of classes

VAL_SIZE = 0.1          # Proportion of validation set with respect to training set (between 0 and 1)

# Training
BATCH_SIZE = 128        # Batch size
LR = 2               # Initial learning rate
                       
MOMENTUM = 0.9          # Momentum for stochastic gradient descent (SGD)
WEIGHT_DECAY = 1e-5     # Weight decay from iCaRL

NUM_RUNS = 3            # Number of runs of every method
                        # Note: this should be at least 3 to have a fair benchmark

NUM_EPOCHS = 70         # Total number of training epochs
MILESTONES = [49, 63]   # Step down policy from iCaRL (MultiStepLR)
                        # Decrease the learning rate by gamma at each milestone
GAMMA = 0.2             # Gamma factor from iCaRL

# %% [markdown]
# ## Joint Training

# %%
  train_data.__shuffle_seed__(RANDOM_SEED[0])
  test_data.__shuffle_seed__(RANDOM_SEED[0])
  

  indexes_train_data = train_data.__incremental_indexes__(False)
  indexes_test_data = test_data.__incremental_indexes__(False)

# %%
train_dataloader = [[] for i in range(10)]
val_dataloader = [[] for i in range(10)]
test_dataloader = [[] for i in range(10)]
for i in range(10):
  train_dataset = Subset(train_data, indexes_train_data[i])
  train_set, val_set = torch.utils.data.random_split(train_dataset, [int(0.8*len(indexes_train_data[i])), int(0.2*len(indexes_train_data[i]))])
  tmp_dl = DataLoader(train_set, 
                      batch_size=BATCH_SIZE,
                      shuffle=True,
                      num_workers=4,
                      drop_last=True)
  train_dataloader[i] = copy(tmp_dl) # gruppi di 10 classi 
  tmp_dl = DataLoader(val_set, 
                      batch_size=BATCH_SIZE,
                      shuffle=True,
                      num_workers=4,
                      drop_last=True)
  val_dataloader[i] = copy(tmp_dl) # gruppi di 10 classi


  test_dataset = Subset(test_data, indexes_test_data[i])
  tmp_dl = DataLoader(test_dataset,
                      batch_size=BATCH_SIZE,
                      shuffle=True,
                      num_workers=4,
                      drop_last=True)
  test_dataloader[i] = copy(tmp_dl) # classi incrementali: 0:0-9, 1:0-19, 2:0-29, ..., 9:0-99
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
import torch
import torch.nn as nn
from torch.backends import cudnn
from copy import deepcopy

# %%
def to_onehot(net, targets, device): 
  '''
  Args:
  targets : dataloader.dataset.targets of the new task images
  '''
  num_classes = net.fc.out_features
  one_hot_targets = torch.eye(num_classes)[targets]

  return one_hot_targets.to(device)

# %%
def train(net, criterion, optimizer, train_dl, device):
  net.train()

  running_loss = 0
  # per ogni gruppo di classi in train mi prendo le labels e le immagini
  # azzero i gradienti, mi sposto sulla gpu e faccio onehot delle labels
  # calcolo output, loss, etc.
  # alla fine di tutti i batches aggiorno la epoch_loss
  for batch in train_dl:
    labels = batch[2]
    images = batch[1]
    optimizer.zero_grad()

    images = images.to(DEVICE)
    labels = labels.to(DEVICE)

    one_hot_labels = to_onehot(net, labels, device) 

    output = net(images)
    loss = criterion(output, one_hot_labels)
    loss.backward()
    optimizer.step()
    
    running_loss += loss.item()
  else:
    epoch_loss = running_loss/len(train_dl)
  return epoch_loss

# %%
#### VALIDATION

def validate(net, criterion, optimizer, validation_dl, device):
  net.train(False)
  running_loss=0
  running_corrects = 0
  total = 0
  # come train(), ma prendo anche le predictions per fare qualche statistica
  for batch in validation_dl:
    labels = batch[2]
    images = batch[1]
    total += labels.size(0)
    optimizer.zero_grad()

    images = images.to(DEVICE)
    labels = labels.to(DEVICE)

    one_hot_labels = to_onehot(net, labels, device) 

    output = net(images)
    loss = criterion(output, one_hot_labels)
    
    running_loss += loss.item()
    _, preds = torch.max(output.data, 1)
    running_corrects += torch.sum(preds == labels.data).data.item()
  else:
    val_loss = running_loss/len(validation_dl)
    

  val_accuracy = running_corrects / float(total)
  

  return val_loss, val_accuracy

# %%
def test(best_net, test_dl, device):
  """Test the model.
  Returns:
      accuracy (float): accuracy of the model on the test set
  """

  best_net.train(False)  # Set Network to evaluation mode

  running_corrects = 0
  total = 0

  all_preds = torch.tensor([]) # to store all predictions
  all_preds = all_preds.type(torch.LongTensor)
  all_targets = torch.tensor([])
  all_targets = all_targets.type(torch.LongTensor)
  # solito ciclo
  for _, images, labels in test_dl:
      images = images.to(device)
      labels = labels.to(device)
      total += labels.size(0)

      # Forward Pass
      outputs = best_net(images)

      # Get predictions
      _, preds = torch.max(outputs.data, 1)

      # Update Corrects
      running_corrects += torch.sum(preds == labels.data).data.item()

      # Append batch predictions and labels
      all_targets = torch.cat(
          (all_targets.to(device), labels.to(device)), dim=0
      )
      all_preds = torch.cat(
          (all_preds.to(device), preds.to(device)), dim=0
      )

  # Calculate accuracy
  accuracy = running_corrects / float(total)  


  return accuracy, all_targets, all_preds

# %%
def increment_classes(net, n=10):
  """Add n classes in the final fully connected layer."""

  in_features = net.fc.in_features  # size of each input sample
  out_features = net.fc.out_features  # size of each output sample
  weight = net.fc.weight.data

  net.fc = nn.Linear(in_features, out_features+n)
  net.fc.weight.data[:out_features] = weight

# %%
net = resnet32()
criterion = nn.BCEWithLogitsLoss()



net.to(DEVICE)
cudnn.benchmark
num_epochs = 80

epoch_losses = [[] for i in range(10)]
for i in range(10):
  net.to(DEVICE)
  parameters_to_optimize = net.parameters()
  optimizer = optim.SGD(parameters_to_optimize, lr=LR, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)
  scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=MILESTONES, gamma=GAMMA)

  best_acc = 0
  best_net = deepcopy(net)

  # ad ogni epoca chiamo il train, salvo le loss e trovo il modello migliore con l'evaluation
  for epoch in range(num_epochs):
    e_loss = train(net, criterion, optimizer, train_dataloader[i], DEVICE)
    epoch_losses[i].append(e_loss)
    print(f"Epoch[{epoch}] loss: {e_loss} LR: {scheduler.get_last_lr()}")
    validate_loss, validate_acc = validate(net, criterion, optimizer, val_dataloader[i], DEVICE)
    print(f"Validation on group[{i}] of 10 classes")
    print(f"val loss: {validate_loss}")
    print(f"val acc: {validate_acc}")
    scheduler.step()
    if validate_acc > best_acc:
      best_acc = validate_acc
      best_net = deepcopy(net)
      best_epoch = epoch
      print("Best model updated")
    print("")

  print(f"Group[{i}]Finished!")
  print(f"Best model at epoch {best_epoch}, best accuracy: {best_acc:.2f}")
  print("")
  acc_all, all_targets, all_preds = test(best_net, test_dataloader[i], DEVICE)
  print(f"Testing classes seen so far, accuracy: {acc_all}")
  print("")
  print("=============================================")
  print("")

  if i < 9:
    increment_classes(net)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch[0] loss: 0.4083198530058707 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.3511537398610796
# val acc: 0.11607142857142858
# Best model updated
#
# Epoch[1] loss: 0.3272863943730631 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.3272265110697065
# val acc: 0.10044642857142858
#
# Epoch[2] loss: 0.32799004547057614 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.32581288473946707
# val acc: 0.09598214285714286
#
# Epoch[3] loss: 0.3247734067901488 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.32287689617701937
# val acc: 0.1171875
# Best model updated
#
# Epoch[4] loss: 0.32309070902486003 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.3210684529372624
# val acc: 0.140625
# Best model updated
#
# Epoch[5] loss: 0.3199788245462602 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.32324467812265667
# val acc: 0.11272321428571429
#
# Epoch[6] loss: 0.3143641035402975 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.31731865235737394
# val acc: 0.15178571428571427
# Best model updated
#
# Epoch[7] loss: 0.309224723808227 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.30743891426495146
# val acc: 0.21651785714285715
# Best model updated
#
# Epoch[8] loss: 0.3035455903699321 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.3093726336956024
# val acc: 0.21205357142857142
#
# Epoch[9] loss: 0.29157627109558354 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.29994156530925203
# val acc: 0.2544642857142857
# Best model updated
#
# Epoch[10] loss: 0.2863734470259759 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.28065407276153564
# val acc: 0.32700892857142855
# Best model updated
#
# Epoch[11] loss: 0.27486293162069014 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.2770222893783024
# val acc: 0.3392857142857143
# Best model updated
#
# Epoch[12] loss: 0.2690504260601536 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.2706390789576939
# val acc: 0.359375
# Best model updated
#
# Epoch[13] loss: 0.2614848426272792 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.26944211551121305
# val acc: 0.33482142857142855
#
# Epoch[14] loss: 0.2561798730204182 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.
LR: [0.08000000000000002]
# Validation on group[3] of 10 classes
# val loss: 0.03648033233419541
# val acc: 0.7676411290322581
#
# Epoch[65] loss: 0.002695653973147273 LR: [0.08000000000000002]
# Validation on group[3] of 10 classes
# val loss: 0.0376715142760546
# val acc: 0.7704133064516129
#
# Epoch[66] loss: 0.0027271888852119447 LR: [0.08000000000000002]
# Validation on group[3] of 10 classes
# val loss: 0.037320693353972124
# val acc: 0.7764616935483871
# Best model updated
#
# Epoch[67] loss: 0.002679729271680117 LR: [0.08000000000000002]
# Validation on group[3] of 10 classes
# val loss: 0.036478037014603615
# val acc: 0.7734375
#
# Epoch[68] loss: 0.002615592804737389 LR: [0.08000000000000002]
# Validation on group[3] of 10 classes
# val loss: 0.036731996423294465
# val acc: 0.7721774193548387
#
# Epoch[69] loss: 0.0026556148659437895 LR: [0.08000000000000002]
# Validation on group[3] of 10 classes
# val loss: 0.03689415933143708
# val acc: 0.7668850806451613
#
# Epoch[70] loss: 0.002466233500279486 LR: [0.08000000000000002]
# Validation on group[3] of 10 classes
# val loss: 0.03780081693924243
# val acc: 0.7694052419354839
#
# Epoch[71] loss: 0.002443483540788293 LR: [0.08000000000000002]
# Validation on group[3] of 10 classes
# val loss: 0.0370028225044089
# val acc: 0.7754536290322581
#
# Epoch[72] loss: 0.00245417005289346 LR: [0.08000000000000002]
# Validation on group[3] of 10 classes
# val loss: 0.037504918452712796
# val acc: 0.7729334677419355
#
# Epoch[73] loss: 0.002486140408553183 LR: [0.08000000000000002]
# Validation on group[3] of 10 classes
# val loss: 0.03763806501463536
# val acc: 0.7701612903225806
#
# Epoch[74] loss: 0.002387602487578988 LR: [0.08000000000000002]
# Validation on group[3] of 10 classes
# val loss: 0.03697285560830947
# val acc: 0.7794858870967742
# Best model updated
#
# Epoch[75] loss: 0.0023343335976824166 LR: [0.08000000000000002]
# Validation on group[3] of 10 classes
# val loss: 0.037527629985444004
# val acc: 0.7777217741935484
#
# Epoch[76] loss: 0.0023528023529797793 LR: [0.08000000000000002]
# Validation on group[3] of 10 classes
# val loss: 0.03722690166004242
# val acc: 0.7721774193548387
#
# Epoch[77] loss: 0.002258782759308815 LR: [0.08000000000000002]
# Validation on group[3] of 10 classes
# val loss: 0.03742133056925189
# val acc: 0.7686491935483871
#
# Epoch[78] loss: 0.0023048621620982883 LR: [0.08000000000000002]
# Validation on group[3] of 10 classes
# val loss: 0.03677191747532737
# val acc: 0.7726814516129032
#
# Epoch[79] loss: 0.002224028610624373 LR: [0.08000000000000002]
# Validation on group[3] of 10 classes
# val loss: 0.03771246002326088
# val acc: 0.7721774193548387
#
# Group[3]Finished!
# Best model at epoch 74, best accuracy: 0.78
#
# ...
# val acc: 0.6248301630434783
#
# Epoch[39] loss: 0.01832129599098216 LR: [2]
# Validation on group[5] of 10 classes
# val loss: 0.04189219819786756
# val acc: 0.5679347826086957
#
# Epoch[40] loss: 0.01810967760349818 LR: [2]
# Validation on group[5] of 10 classes
# val loss: 0.04113814680148726
# val acc: 0.5782948369565217
#
# Epoch[41] loss: 0.017796149377755942 LR: [2]
# Validation on group[5] of 10 classes
# val loss: 0.03779078416688287
# val acc: 0.6061480978260869
#
# Epoch[42] loss: 0.017807574369969534 LR: [2]
# Validation on group[5] of 10 classes
# val loss: 0.03717880169658557
# val acc: 0.6078464673913043
#
# Epoch[43] loss: 0.017782503664294347 LR: [2]
# Validation on group[5] of 10 classes
# val loss: 0.038028558351747364
# val acc: 0.6122622282608695
#
# Epoch[44] loss: 0.0178448032577806 LR: [2]
# Validation on group[5] of 10 classes
# val loss: 0.03403154671516107
# val acc: 0.6457201086956522
#
# Epoch[45] loss: 0.01770295483622959 LR: [2]
# Validation on group[5] of 10 classes
# val loss: 0.036499042347397495
# val acc: 0.6039402173913043
#
# Epoch[46] loss: 0.017832444721763145 LR: [2]
# Validation on group[5] of 10 classes
# val loss: 0.034531725246621216
# val acc: 0.6358695652173914
#
# Epoch[47] loss: 0.017640275875714054 LR: [2]
# Validation on group[5] of 10 classes
# val loss: 0.03575621946188419
# val acc: 0.6278872282608695
#
# Epoch[48] loss: 0.017502853761422126 LR: [2]
# Validation on group[5] of 10 classes
# val loss: 0.04139487461551376
# val acc: 0.5776154891304348
#
# Epoch[49] loss: 0.011443520171498073 LR: [0.4]
# Validation on group[5] of 10 classes
# val loss: 0.024086084783725117
# val acc: 0.7365828804347826
# Best model updated
#
# Epoch[50] loss: 0.009155013952105441 LR: [0.4]
# Validation on group[5] of 10 classes
# val loss: 0.02413461329010518
# val acc: 0.7394701086956522
# Best model updated
#
# Epoch[51] loss: 0.008209165511901845 LR: [0.4]
# Validation on group[5] of 10 classes
# val loss: 0.024176371243336926
# val acc: 0.7411684782608695
# Best model updated
#
# Epoch[52] loss: 0.007662494121527768 LR: [0.4]
# Validation on group[5] of 10 classes
# val loss: 0.02437588438877593
# val acc: 0.7432065217391305
# Best model updated
#
# Epoch[53] loss: 0.007242975836211347 LR: [0.4]
# Validation on group[5] of 10 classes
# val loss: 0.02478731241401123
# val acc: 0.7479619565217391
# Best model updated
#
# Epoch[54] loss: 0.006968016358949045 LR: [0.4]
# Validation on group[5] of 10 classes
# val loss: 0.024412123607876507
# val acc: 0.747452445652174
#
# Epoch[55] loss: 0.006624595809947042 LR: [0.4]
# Validation on group[5] of 10 classes
# val loss: 0.025029816887462916
# val acc: 0.7443953804347826
#
# Epoch[56] loss: 0.006349142645809421 LR: [0.4]
# Validation on group[5] of 10 classes
# val loss: 0.02511198187003965
# val acc: 0.7464334239130435
#
# Epoch[57] loss: 0.006131206640356126 LR: [0.4]
# Validation on group[5] of 10 classes
# val loss: 0.025691548605328022
# val acc: 0.7316576086956522
#
# Epoch[58] loss: 0.005938917000025989 LR: [0.4]
# Validation on group[5] of 10 classes
# val loss: 0.02579784020781517
# val acc: 0.7449048913043478
#
# Epoch[59] loss: 0.0056370725783016435 LR: [0.4]
# Validation on group[5] of 10 classes
# val loss: 0.026307999237400036
# val acc: 0.7367527173913043
#
# Epoch[60] loss: 0.005697905586504522 LR: [0.4]
# Validation on group[5] of 10 classes
# val loss: 0.02636978536358346
# val acc: 0.7393002717391305
#
# Epoch[61] loss: 0.005570640127587924 LR: [0.4]
# Validation on group[5] of 10 classes
# val loss: 0.026911192492622395
# val acc: 0.735733695652174
#
# Epoch[62] loss: 0.005328913042471211 LR: [0.4]
# Validation on group[5] of 10 classes
# val loss: 0.026354800666803898
# val acc: 0.7376019021739131
#
# Epoch[63] loss: 0.0044659740592846095 LR: [0.08000000000000002]
# Validation on group[5] of 10 classes
# val loss: 0.02529652108964713
# val acc: 0.7440557065217391
#
# Epoch[64] loss: 0.004135798692782932 LR: [0.08000000000000002]
# Validation on group[5] of 10 classes
# val loss: 0.025626122587076996
# val acc: 0.744735054347826
#
# Epoch[65] loss: 0.00402148889955432 LR: [0.08000000000000002]
# Validation on group[5] of 10 classes
# val loss: 0.025178558922008328
# val acc: 0.751358695652174
# Best model updated
#
# Epoch[66] loss: 0.003962873440126286 LR: [0.08000000000000002]
# Validation on group[5] of 10 classes
# val loss: 0.02492741884096809
# val acc: 0.7508491847826086
#
# Epoch[67] loss: 0.003802598473356967 LR: [0.08000000000000002]
# Validation on group[5] of 10 classes
# val loss: 0.024969621885405933
# val acc: 0.7544157608695652
# Best model updated
#
# Epoch[68] loss: 0.003682954672644323 LR: [0.08000000000000002]
# Validation on group[5] of 10 classes
# val loss: 0.025850847201502842
# val acc: 0.7494904891304348
#
# Epoch[69] loss: 0.003783716074375306 LR: [0.08000000000000002]
# Validation on group[5] of 10 classes
# val loss: 0.025727046329690063
# val acc: 0.7489809782608695
#
# Epoch[70] loss: 0.0035863090262942534 LR: [0.08000000000000002]
# Validation on group[5] of 10 classes
# val loss: 0.026013825939077397
# val acc: 0.7520380434782609
#
# Epoch[71] loss: 0.003655412376305477 LR: [0.08000000000000002]
# Validation on group[5] of 10 classes
# val loss: 0.025910363816048786
# val acc: 0.7464334239130435
#
# Epoch[72] loss: 0.0036093156104957196 LR: [0.08000000000000002]
# Validation on group[5] of 10 classes
# val loss: 0.02583267369672008
# val acc: 0.7518682065217391
#
# Epoch[73] loss: 0.0035041755931900145 LR: [0.08000000000000002]
# Validation on group[5] of 10 classes
# val loss: 0.026136245254589165
# val acc: 0.7471127717391305
#
# Epoch[74] loss: 0.003511585625147517 LR: [0.08000000000000002]
# Validation on group[5] of 10 classes
# val loss: 0.02598897092368292
# val acc: 0.7420176630434783
#
# Epoch[75] loss: 0.003460088030081541 LR: [0.08000000000000002]
# Validation on group[5] of 10 classes
# val loss: 0.025610369913603947
# val acc: 0.7528872282608695
#
# Epoch[76] loss: 0.003396615821165954 LR: [0.08000000000000002]
# Validation on group[5] of 10 classes
# val loss: 0.026103782346067222
# val acc: 0.7540760869565217
#
# Epoch[77] loss: 0.003358805690329263 LR: [0.08000000000000002]
# Validation on group[5] of 10 classes
# val loss: 0.026133305271682533
# val acc: 0.7520380434782609
#
# Epoch[78] loss: 0.0032996440649948975 LR: [0.08000000000000002]
# Validation on group[5] of 10 classes
# val loss: 0.025920283535252445
# val acc: 0.7455842391304348
#
# Epoch[79] loss: 0.0033039830707232744 LR: [0.08000000000000002]
# Validation on group[5] of 10 classes
# val loss: 0.025757117075440678
# val acc: 0.7489809782608695
#
# Group[5]Finished!
# Best model at epoch 67, best accuracy: 0.75
#
# Testing classes seen so far, accuracy: 0.733016304347826
#
# =============================================
#
# Epoch[0] loss: 0.030463330644191405 LR: [2]
# Validation on group[6] of 10 classes
# val loss: 0.029952925905861235
# val acc: 0.6184895833333334
# Best model updated
#
# Epoch[1] loss: 0.022238238227613474 LR: [2]
# Validation on group[6] of 10 classes
# val loss: 0.029364650827591068
# val acc: 0.6248553240740741
# Best model updated
#
# Epoch[2] loss: 0.02126488531298867 LR: [2]
# Validation on group[6] of 10 classes
# val loss: 0.03102422605648085
# val acc: 0.609375
#
# Epoch[3] loss: 0.020679393437169832 LR: [2]
# Validation on group[6] of 10 classes
# val loss: 0.028856828705304198
# val acc: 0.6354166666666666
# Best model updated
#
# Epoch[4] loss: 0.019976048726041657 LR: [2]
# Validation on group[6] of 10 classes
# val loss: 0.02928831621452614
# val acc: 0.6291956018518519
#
# Epoch[5] loss: 0.02010277772766598 LR: [2]
# Validation on group[6] of 10 classes
# val loss: 0.025730153614724124
# val acc: 0.6711516203703703
# Best model updated
#
# Epoch[6] loss: 0.019464525060916164 LR: [2]
# Validation on group[6] of 10 classes
# val loss: 0.031081774789426062
# val acc: 0.61328125
#
# Epoch[7] loss: 0.01962061335307059 LR: [2]
# Validation on group[6] of 10 classes
# val loss: 0.033636631478589994
# val acc: 0.5946180555555556
#
# Epoch[8] loss: 0.01935520980917259 LR: [2]
# Validation on group[6] of 10 classes
# val loss: 0.031079796970718436
# val acc: 0.6189236111111112
#
# Epoch[9] loss: 0.01933646502417572 LR: [2]
# Validation on group[6] of 10 classes
# val loss: 0.03075155788273723
# val acc: 0.6141493055555556
#
# Epoch[10] loss: 0.01893183309157644 LR: [2]
# Validation on group[6] of 10 classes
# val loss: 0
LR: [2]
# Validation on group[6] of 10 classes
# val loss: 0.03608031846858837
# val acc: 0.5630787037037037
#
# Epoch[45] loss: 0.017104578635937305 LR: [2]
# Validation on group[6] of 10 classes
# val loss: 0.029896633182134893
# val acc: 0.6342592592592593
#
# Epoch[46] loss: 0.017320896204082517 LR: [2]
# Validation on group[6] of 10 classes
# val loss: 0.030092695072569228
# val acc: 0.6325231481481481
#
# Epoch[47] loss: 0.016994668213530965 LR: [2]
# Validation on group[6] of 10 classes
# val loss: 0.0319872533350631
# val acc: 0.6021412037037037
#
# Epoch[48] loss: 0.0168319554239033 LR: [2]
# Validation on group[6] of 10 classes
# val loss: 0.03425872839849304
# val acc: 0.5872395833333334
#
# Epoch[49] loss: 0.011419777672977076 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.020991679332736466
# val acc: 0.7378472222222222
# Best model updated
#
# Epoch[50] loss: 0.009385945583018689 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.02165220646808545
# val acc: 0.7287326388888888
#
# Epoch[51] loss: 0.008622253817771005 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.021472341346519964
# val acc: 0.7364004629629629
#
# Epoch[52] loss: 0.00811323612595165 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.02184990665840882
# val acc: 0.7293113425925926
#
# Epoch[53] loss: 0.007711139103876205 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.02159764679769675
# val acc: 0.7377025462962963
#
# Epoch[54] loss: 0.007409626455687055 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.021307543885928613
# val acc: 0.7390046296296297
# Best model updated
#
# Epoch[55] loss: 0.007156082381998454 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.021835795810653105
# val acc: 0.7374131944444444
#
# Epoch[56] loss: 0.006916897956692024 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.02232373843866366
# val acc: 0.7333622685185185
#
# Epoch[57] loss: 0.006783057677072533 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.022277451413511125
# val acc: 0.7333622685185185
#
# Epoch[58] loss: 0.006553616726113091 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.023250861507323053
# val acc: 0.7204861111111112
#
# Epoch[59] loss: 0.006297451557181434 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.02266861146522893
# val acc: 0.7297453703703703
#
# Epoch[60] loss: 0.006388375071014081 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.023209354805725592
# val acc: 0.7320601851851852
#
# Epoch[61] loss: 0.006162206353961464 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.024200572252825455
# val acc: 0.7186053240740741
#
# Epoch[62] loss: 0.0059488573220532835 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.0233075055466206
# val acc: 0.7265625
#
# Epoch[63] loss: 0.004975197084863252 LR: [0.08000000000000002]
# Validation on group[6] of 10 classes
# val loss: 0.021732011999658966
# val acc: 0.7410300925925926
# Best model updated
#
# Epoch[64] loss: 0.004617232843216748 LR: [0.08000000000000002]
# Validation on group[6] of 10 classes
# val loss: 0.02192766978232949
# val acc: 0.7394386574074074
#
# Epoch[65] loss: 0.004484344248172887 LR: [0.08000000000000002]
# Validation on group[6] of 10 classes
# val loss: 0.02194134880685144
# val acc: 0.7423321759259259
# Best model updated

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
def plotConfusionMatrix(confusionMatrixData, seed):
	fig,ax=plt.subplots(figsize=(10,10))
	sns.heatmap(confusionMatrixData,cmap='terrain',ax=ax)
	plt.ylabel('True label')
	plt.xlabel('Predicted label')
	plt.title("Confusion Matrix - seed: {}".format(seed))

	#filename = "cm_{}_{}.jpg".format(method, seed) # ex. cm_lwf_30
	#plt.savefig(filename, format='png', dpi=300)
	plt.show()
 
 
t = all_targets.cpu().data.numpy()
p = all_preds.cpu().data.numpy()
confusionMatrixData = confusion_matrix(t, p)
plotConfusionMatrix(confusionMatrixData, RANDOM_SEED[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f0abbfa74876> in <module>()
#      13
#      14
# ---> 15 t = all_targets.cpu().data.numpy()
#      16 p = all_preds.cpu().data.numpy()
#      17 confusionMatrixData = confusion_matrix(t, p)
#
# NameError: name 'all_targets' is not defined
