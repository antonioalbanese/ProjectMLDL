# %% [markdown]
# <a href="https://colab.research.google.com/github/cosminnedescu/ProjectMLDL/blob/main/baselines/iCaRL-v1_3_0-ablation-CE_L2_seed13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Avoid K80
# !nvidia-smi
# Out:
# Thu Jul  1 12:06:49 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import random

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
from torch.autograd import Variable

import torchvision
from torchvision import transforms, datasets, models
from torch.utils.data import Subset, DataLoader

from PIL import Image

import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
from copy import copy
from copy import deepcopy

# %% [markdown]
# #### Cloning the Git repository

# %%
# !rm -rf ProjectMLDL
if not os.path.isdir('/content/ProjectMLDL'):
  # !git clone https://github.com/cosminnedescu/ProjectMLDL.git
  # %cd /content/ProjectMLDL
  # !rm -rf LICENSE README.md

# %%
from data.cifar100 import CIFAR100
from model.resnet32 import resnet32
import data.utils
from model.icarl_ablation import iCaRL

# %%
# True mean and std of Cifar100 dataset (src="https://gist.github.com/weiaicunzai/e623931921efefd4c331622c344d8151")
mean = [0.5071, 0.4867, 0.4408]
std = [0.2675, 0.2565, 0.2761]

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])
test_transform = transforms.Compose(
    [transforms.ToTensor(), 
     transforms.Normalize(mean, std),
     ])

# %% [markdown]
# ## Incremental Classifier and Representation Learning

# %% [markdown]
# ### Defining hyperparameters according to iCarl paper

# %%
# Settings
DEVICE = 'cuda'
NUM_CLASSES = 100         # Total number of classes
VAL_SIZE = 0.2            # Proportion of validation set with respect to training set (between 0 and 1)

# Training
BATCH_SIZE = 128          # Batch size
LR = 0.1                    # Initial learning rate
                       
MOMENTUM = 0.9            # Momentum for stochastic gradient descent (SGD)
WEIGHT_DECAY = 1e-5       # Weight decay from iCaRL

RANDOM_SEED = [13]  # Random seeds defining the runs of every method
                          # Note: this should be at least 3 to have a fair benchmark

NUM_EPOCHS = 70          # Total number of training epochs
MILESTONES = [49, 63]     # Step down policy from iCaRL (MultiStepLR)
                          # Decrease the learning rate by gamma at each milestone
GAMMA = 1 #0.2               # Gamma factor from iCaRL (1/5)

HERDING = False           # True to perform prioritized selection, False to perform random selection
CLASSIFY = True           # True to use mean-of-exemplar classifier, False to use network's output directly for classification

# %%
def do_group_classes(run):

  train_subset = [[] for i in range(10)]
  train_dataloader = [[] for i in range(10)]
  val_dataloader = [[] for i in range(10)]
  test_dataloader = [[] for i in range(10)]

  for i in range(10):
    train_data = CIFAR100("dataset", 
                          train=True, 
                          transform=train_transform, 
                          download=(run+i==0),
                          random_state=RANDOM_SEED[run])
    test_data = CIFAR100("dataset", 
                         train=False, 
                         transform=test_transform, 
                         download=False,
                         random_state=RANDOM_SEED[run])
    
    train_data.set_index_map(train_data.splits[i])
    test_data.set_index_map([test_data.splits[j] for j in range(0, i+1)])
    
    train_indices, val_indices = train_data.train_val_split(VAL_SIZE, RANDOM_SEED[run])
    
    train_subset[i] = copy(Subset(train_data, train_indices))
    val_subset = Subset(train_data, val_indices)

    tmp_dl = DataLoader(val_subset,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    val_dataloader[i] = copy(tmp_dl)

    tmp_dl = DataLoader(test_data,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    test_dataloader[i] = copy(tmp_dl)

  return train_dataloader, val_dataloader, test_dataloader, train_subset

# %% [markdown]
# ### Going on with the model
# This is the main iCaRL step.
#
# This step is run 3 times with different `RANDOM_SEED`.
# Here the model is instantiated, trained and tested.
#
# Results and some statistics are then stored in the variable `logs`.

# %%
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
logs = [[] for i in range(len(RANDOM_SEED))]
best_net_tot_classes = [None for i in range(len(RANDOM_SEED))]

for run in range(len(RANDOM_SEED)):
  print("#################################")
  print(f"Radom seed: {RANDOM_SEED[run]}")
  print("")

  # get data_subsets separated in incremental groups of 10 classes
  train_dl, val_dl, test_dl, train_set = do_group_classes(run)

  #create the resnet
  net = resnet32()
  
  trainer = iCaRL(DEVICE,
                  net,
                  LR,
                  MOMENTUM,
                  WEIGHT_DECAY,
                  MILESTONES,
                  GAMMA,
                  train_dl,
                  val_dl,
                  test_dl,
                  BATCH_SIZE,
                  train_set,
                  train_transform,
                  test_transform, 2)

  #train and evaluate the model
  logs[run] = trainer.train_model(NUM_EPOCHS, HERDING, CLASSIFY)

  best_net_tot_classes[run] = deepcopy(trainer.best_net)

  print("#################################")
  print("")
  print("")
# Out:
# #################################
# Radom seed: 13
#
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Length of exemplars set: 0
# traing_loss = 2.085807265773896
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.19
# Best model updated
#
# traing_loss = 1.653128166352549
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.39
# Best model updated
#
# traing_loss = 1.506819725036621
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.45
# Best model updated
#
# traing_loss = 1.4699652502613683
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.45
#
# traing_loss = 1.4271606937531502
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.50
# Best model updated
#
# traing_loss = 1.3324284438164002
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.52
# Best model updated
#
# traing_loss = 1.3247365374718942
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.52
# Best model updated
#
# traing_loss = 1.2650979603490522
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.56
# Best model updated
#
# traing_loss = 1.2196254038041638
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.55
#
# traing_loss = 1.1544192952494468
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.55
#
# traing_loss = 1.1158095059856292
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.56
#
# traing_loss = 1.1086799848464228
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.55
#
# traing_loss = 1.0499049598170864
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.57
# Best model updated
#
# traing_loss = 0.9965101691984362
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.59
# Best model updated
#
# traing_loss = 0.9354420958026763
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.62
# Best model updated
#
# traing_loss = 0.8960718089534391
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.62
#
# traing_loss = 0.8934510215636222
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.60
#
# traing_loss = 0.8374432998318826
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.60
#
# traing_loss = 0.7985888046603049
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.65
# Best model updated
#
# traing_loss = 0.7648951353565339
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.63
#
# traing_loss = 0.7619415252439438
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.64
#
# traing_loss = 0.7291352691188935
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.65
#
# traing_loss = 0.6524343740555548
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.66
# Best model updated
#
# traing_loss = 0.6452140173604411
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.69
# Best model updated
#
# traing_loss = 0.6280107257827636
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.69
# Best model updated
#
# traing_loss = 0.5644118872381025
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.68
#
# traing_loss = 0.5652664678712045
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.69
#
# traing_loss = 0.578109597967517
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.66
#
# traing_loss = 0.5236901265959586
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.72
# Best model updated
#
# traing_loss = 0.48823061969972426
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.69
#
# traing_loss = 0.474003741337407
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.67
#
# traing_loss = 0.4666703006913585
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.70
#
# traing_loss = 0.45625105980903874
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.75
# Best model updated
#
# traing_loss = 0.4095586720974215
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.67
#
# traing_loss = 0.3860453165346576
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.68
#
# traing_loss = 0.41354716785492435
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.74
#
# traing_loss = 0.38249206254559176
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.76
# Best model updated
#
# traing_loss = 0.35380018814917535
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.72
#
# traing_loss = 0.3340866262874296
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.73
#
# traing_loss = 0.34181760251522064
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.74
#
# traing_loss = 0.3215167777192208
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.69
#
# traing_loss = 0.31602717503424615
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.72
#
# traing_loss = 0.2949646432553568
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.74
#
# traing_loss = 0.27318493204732097
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.69
#
# traing_loss = 0.2794811658320888
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.74
#
# traing_loss = 0.2633110313646255
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.76
#
# traing_loss = 0.24850327257187135
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.70
#
# traing_loss = 0.26352093104393254
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.73
#
# traing_loss = 0.24368837043162314
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.74
#
# traing_loss = 0.20759079220794863
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.77
# Best model updated
#
# traing_loss = 0.20689028597647144
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.74
#
# traing_loss = 0.21322456026269543
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.75
#
# traing_loss = 0.17805503717353266
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.73
#
# traing_loss = 0.2077086587106028
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.76
#
# traing_loss = 0.22125340565558402
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.75
#
# traing_loss = 0.1786962757187505
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.76
#
# traing_loss = 0.17772005642614058
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.77
#
# traing_loss = 0.1769421951424691
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.70
#
# traing_loss = 0.196177854893669
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.74
#
# traing_loss = 0.16475778385516135
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.75
#
# traing_loss = 0.13698388443839166
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.75
#
# traing_loss = 0.13408768104930077
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.77
#
# traing_loss = 0.13850639568221185
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.73
#
# traing_loss = 0.129311601841642
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.78
# Best model updated
#
# traing_loss = 0.14097973488030896
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.77
#
# traing_loss = 0.13589681084117583
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.77
#
# traing_loss = 0.13230997720553028
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.72
#
# traing_loss = 0.13850193771143113
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.74
#
# traing_loss = 0.1346942789612278
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.78
# Best model updated
#
# traing_loss = 0.1044716804979309
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.78
# Best model updated
#
# Group 1 Finished!
# Best accuracy found at epoch 70: 0.78
# Target number of exemplars: 200
# Randomly extracting exemplars from class 0 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 200 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.77
#
# =============================================
#
# Length of exemplars set: 2000
# traing_loss = 2.193978485853776
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.63
# Best model updated
#
# traing_loss = 1.5342806474022244
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.67
# Best model updated
#
# traing_loss = 1.364669893098914
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.69
# Best model updated
#
# traing_loss = 1.2612518771834995
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.71
# Best model updated
#
# traing_loss = 1.1762061624423317
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.74
# Best model updated
#
# traing_loss = 1.1266221106052399
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.68
#
# traing_loss = 1.0850180555944857
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.76
# Best model updated
#
# traing_loss = 1.0300228984459587
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.75
#
# traing_loss = 0.9868592930876691
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.75
#
# traing_loss = 0.970621794462204
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.75
#
# traing_loss = 0.9353365042935247
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.76
#
# traing_loss = 0.9128024953862895
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.77
# Best model updated
#
# traing_loss = 0.8796119741771532
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.75
#
# traing_loss = 0.853813578253207
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.76
#
# traing_loss = 0.8448497717795165
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.77
#
# traing_loss = 0.7956256140833315
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.77
# Best model updated
#
# traing_loss = 0.8006209355333577
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.77
#
# traing_loss = 0.7577338218688965
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.77
#
# traing_loss = 0.7863555019316466
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.75
#
# traing_loss = 0.7568936956965405
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.75
#
# traing_loss = 0.7267739889414414
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.75
#
# traing_loss = 0.7088366772817529
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.76
#
# traing_loss = 0.6818192938099736
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.80
# Best model updated
#
# traing_loss = 0.6725970765818721
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.76
#
# traing_loss = 0.6982571055059847
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.75
#
# traing_loss = 0.6903814634551173
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.77
#
# traing_loss = 0.6610927115315977
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.77
#
# traing_loss = 0.6529525829398114
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.653935388378475
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.76
#
# traing_loss = 0.611495483180751
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.79
#
# traing_loss = 0.6106628976438356
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.72
#
# traing_loss = 0.6196787759013798
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.5990298908689747
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.5913809408312258
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.79
#
# traing_loss = 0.5802716768306234
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.79
#
# traing_loss = 0.5592215087102808
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.80
# Best model updated
#
# traing_loss = 0.5722722469464593
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.75
#
# traing_loss = 0.5521070348179858
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.76
#
# traing_loss = 0.5297106802463531
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.76
#
# traing_loss = 0.5376014787217845
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.74
#
# traing_loss = 0.5534330139989438
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.77
#
# traing_loss = 0.527164862855621
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.73
#
# traing_loss = 0.5246390726255334
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.81
# Best model updated
#
# traing_loss = 0.5257631890151812
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.74
#
# traing_loss = 0.5362685296846472
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.79
#
# traing_loss = 0.5188552653012068
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.76
#
# traing_loss = 0.5218425555073697
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.75
#
# traing_loss = 0.5115371948998907
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.79
#
# traing_loss = 0.5231628877961118
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.73
#
# traing_loss = 0.514182051886683
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.5133831708327584
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.79
#
# traing_loss = 0.5085041296222935
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.79
#
# traing_loss = 0.5014079271451287
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.79
#
# traing_loss = 0.5087255343146946
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.47347600434137427
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.77
#
# traing_loss = 0.477731672965962
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.80
#
# traing_loss = 0.4766461622455846
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.79
#
# traing_loss = 0.48555316484492755
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.48097022396066913
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.76
#
# traing_loss = 0.48604571041853534
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.75
#
# traing_loss = 0.47511922665264295
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.4521675388450208
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.80
#
# traing_loss = 0.44780242767023004
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.81
#
# traing_loss = 0.44143314789170807
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.80
#
# traing_loss = 0.43429687943147577
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.4329996951248335
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.45278799533843994
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.4572870750790057
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.80
#
# traing_loss = 0.46281361709470337
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.77
#
# traing_loss = 0.4672006899895875
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.77
#
# Group 2 Finished!
# Best accuracy found at epoch 43: 0.81
# Target number of exemplars: 100
# Randomly extracting exemplars from class 0 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 100 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.74
#
# =============================================
#
# Length of exemplars set: 2000
# traing_loss = 2.3620065113772517
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.55
# Best model updated
#
# traing_loss = 1.6328629281209863
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.58
# Best model updated
#
# traing_loss = 1.4696310965911201
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.60
# Best model updated
#
# traing_loss = 1.3658111017683279
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.61
# Best model updated
#
# traing_loss = 1.31151559041894
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.63
# Best model updated
#
# traing_loss = 1.2304230021393818
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.64
# Best model updated
#
# traing_loss = 1.1799980648185895
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.64
#
# traing_loss = 1.1223760882149572
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
# Best model updated
#
# traing_loss = 1.095622086006662
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.63
#
# traing_loss = 1.0765766592129418
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 1.0377117732296819
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.64
#
# traing_loss = 1.0084148438080498
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.64
#
# traing_loss = 0.9730121078698531
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.63
#
# traing_loss = 0.9370289600413778
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.62
#
# traing_loss = 0.9205298281234243
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 0.905307430288066
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
# Best model updated
#
# traing_loss = 0.8759813801102017
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.64
#
# traing_loss = 0.8861690176569897
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.8504362508006718
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.62
#
# traing_loss = 0.8444107278533604
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 0.8317984161169633
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 0.8032946806886921
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.7722128370533818
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.64
#
# traing_loss = 0.7816106366074603
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.60
#
# traing_loss = 0.7769614237806072
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.7574259418508281
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.63
#
# traing_loss = 0.7528138432813727
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 0.6948573900305707
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.62
#
# traing_loss = 0.6871067415113035
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.63
#
# traing_loss = 0.6805519306141398
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
# Best model updated
#
# traing_loss = 0.696809832168662
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.63
#
# traing_loss = 0.6859338115090909
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.62
#
# traing_loss = 0.6986168985781462
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
# Best model updated
#
# traing_loss = 0.6559248838735663
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.6373583298662434
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.70
# Best model updated
#
# traing_loss = 0.6130823343992233
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.62
#
# traing_loss = 0.6342210938101229
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.6123187684494517
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.62
#
# traing_loss = 0.5953308991763903
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.64
#
# traing_loss = 0.6112906246081643
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 0.5879179355890854
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.5817830173865609
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.67
#
# traing_loss = 0.5834184995164042
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.64
#
# traing_loss = 0.5667236116917237
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.5504804350759672
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.67
#
# traing_loss = 0.5498101283674655
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.67
#
# traing_loss = 0.547196085686269
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.5814518708249797
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.67
#
# traing_loss = 0.5591486109339673
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.573499695762344
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.64
#
# traing_loss = 0.5536581783191018
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.5167730301618576
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.64
#
# traing_loss = 0.5112891877474992
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.67
#
# traing_loss = 0.5322517687859742
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.519049452698749
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.62
#
# traing_loss = 0.5302723957144696
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.5233436991339144
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.5181794341491617
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.4939886694369109
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.4976209512223368
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 0.5149001997450123
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.5033267788265062
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.47907257533591724
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.4910287986630979
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.4849919216788333
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 0.4909235180720039
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.505979716129925
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.4906354429929153
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 0.4578416256800942
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.4627054327208063
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
#
# Group 3 Finished!
# Best accuracy found at epoch 35: 0.70
# Target number of exemplars: 66
# Randomly extracting exemplars from class 0 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 66 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.63
#
# =============================================
#
# Length of exemplars set: 1980
# traing_loss = 2.4867614404014917
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.66
# Best model updated
#
# traing_loss = 1.5651551148165828
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.69
# Best model updated
#
# traing_loss = 1.3691515093264373
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.73
# Best model updated
#
# traing_loss = 1.22212313828261
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.73
#
# traing_loss = 1.1244558264379916
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.73
#
# traing_loss = 1.079678782950277
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
# Best model updated
#
# traing_loss = 1.0055056926996813
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.71
#
# traing_loss = 0.9526668048423269
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
# Best model updated
#
# traing_loss = 0.9051786233549532
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.72
#
# traing_loss = 0.8644198347692904
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
#
# traing_loss = 0.8485855252846427
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.73
#
# traing_loss = 0.8256097889464834
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
# Best model updated
#
# traing_loss = 0.7859537394150443
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.73
#
# traing_loss = 0.7740213508191316
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
#
# traing_loss = 0.7229583483675251
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
#
# traing_loss = 0.7055340746174688
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.77
# Best model updated
#
# traing_loss = 0.7036174030407615
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.77
#
# traing_loss = 0.6729888332926709
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.77
#
# traing_loss = 0.6769534129163494
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
#
# traing_loss = 0.668831494839295
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
#
# traing_loss = 0.6451150295527085
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.77
#
# traing_loss = 0.6089234449293303
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
#
# traing_loss = 0.6292676238910012
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.73
#
# traing_loss = 0.6226307814535887
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.77
# Best model updated
#
# traing_loss = 0.5928463786840439
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.79
# Best model updated
#
# traing_loss = 0.5477139891489692
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.78
#
# traing_loss = 0.5618806993183882
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.79
# Best model updated
#
# traing_loss = 0.5682739136011704
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.80
# Best model updated
#
# traing_loss = 0.547282623855964
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.79
#
# traing_loss = 0.5548920145501262
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.81
# Best model updated
#
# traing_loss = 0.5550648421049118
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.78
#
# traing_loss = 0.563789536771567
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.73
#
# traing_loss = 0.5420960077772969
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.79
#
# traing_loss = 0.5315200990956762
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.77
#
# traing_loss = 0.5421973700108735
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
#
# traing_loss = 0.5007892205663349
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
#
# traing_loss = 0.5097699942796127
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.79
#
# traing_loss = 0.49883344251176587
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.78
#
# traing_loss = 0.47480560968751495
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.78
#
# traing_loss = 0.4916866829861765
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.80
#
# traing_loss = 0.4818012351575105
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.78
#
# traing_loss = 0.4776290149792381
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.77
#
# traing_loss = 0.501956208244614
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.79
#
# traing_loss = 0.47121022058569867
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.79
#
# traing_loss = 0.4548689781323723
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.79
#
# traing_loss = 0.45664178482864215
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.80
#
# traing_loss = 0.4484187798655551
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.79
#
# traing_loss = 0.4494494115528853
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.80
#
# traing_loss = 0.46434361649596173
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.77
#
# traing_loss = 0.466465576187424
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.80
#
# traing_loss = 0.4973992005638454
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.80
#
# traing_loss = 0.47568630135577655
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.78
#
# traing_loss = 0.46286785732144897
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.80
#
# traing_loss = 0.4486773098292558
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.78
#
# traing_loss = 0.42240115546661877
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.81
# Best model updated
#
# traing_loss = 0.40544593398985657
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.80
#
# traing_loss = 0.41938488055830414
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.84
# Best model updated
#
# traing_loss = 0.40589875695498095
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.82
#
# traing_loss = 0.3935529168533242
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.79
#
# traing_loss = 0.4010731798151265
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.77
#
# traing_loss = 0.4048032274712687
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.81
#
# traing_loss = 0.39405051521632983
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.81
#
# traing_loss = 0.39924172797928686
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.82
#
# traing_loss = 0.39819186601949774
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.81
#
# traing_loss = 0.39995434361955395
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.82
#
# traing_loss = 0.39540304308352264
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.84
#
# traing_loss = 0.4193848682486493
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.78
#
# traing_loss = 0.4435683760953986
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.77
#
# traing_loss = 0.45625562771506933
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.79
#
# traing_loss = 0.4129099904195122
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.79
#
# Group 4 Finished!
# Best accuracy found at epoch 57: 0.84
# Target number of exemplars: 50
# Randomly extracting exemplars from class 0 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 50 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.58
#
# =============================================
#
# Length of exemplars set: 2000
# traing_loss = 2.4341894932415173
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.66
# Best model updated
#
# traing_loss = 1.4561229944229126
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
# Best model updated
#
# traing_loss = 1.2698234656582708
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.71
#
# traing_loss = 1.1961317554764126
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.68
#
# traing_loss = 1.0872831733330437
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
# Best model updated
#
# traing_loss = 1.0613917643609254
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 1.0173547825087672
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.71
#
# traing_loss = 0.9462005120256672
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
# Best model updated
#
# traing_loss = 0.9198091341101605
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.71
#
# traing_loss = 0.8649413080319114
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.8190920067870099
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.70
#
# traing_loss = 0.7944857400396595
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.7978590143763501
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.70
#
# traing_loss = 0.7680673819521199
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
# Best model updated
#
# traing_loss = 0.7169063765069713
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.75
# Best model updated
#
# traing_loss = 0.7524433110071265
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.69
#
# traing_loss = 0.7221223077048426
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.70
#
# traing_loss = 0.6678427276404008
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.6551484672919564
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.6741918623447418
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.69
#
# traing_loss = 0.6273274629012399
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.70
#
# traing_loss = 0.6582023812376935
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.71
#
# traing_loss = 0.6557966179173925
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.71
#
# traing_loss = 0.6091338713531909
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.68
#
# traing_loss = 0.5898026396398959
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.71
#
# traing_loss = 0.5817177567792975
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.5625903288955274
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.69
#
# traing_loss = 0.5514086031395456
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.77
# Best model updated
#
# traing_loss = 0.5396717333275339
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.5523513451866482
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.71
#
# traing_loss = 0.5569844576327697
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.5477584328340448
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.5552923109220422
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.70
#
# traing_loss = 0.5227099125799926
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.5070988982915878
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.5013845355614371
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.69
#
# traing_loss = 0.49109030612137006
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.4803065923245057
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.75
#
# traing_loss = 0.4835125162549641
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.4551567940608315
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.75
#
# traing_loss = 0.4796794743641563
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.4957706345164258
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.45782819714235223
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.75
#
# traing_loss = 0.46373094618320465
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.463492579434229
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.4757690449123797
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.70
#
# traing_loss = 0.46735906860102777
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.70
#
# traing_loss = 0.4717646519774976
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.75
#
# traing_loss = 0.4541199654340744
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.45047503321067145
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.4278219802224118
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.4265255928039551
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.77
#
# traing_loss = 0.4143283406029577
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
# Best model updated
#
# traing_loss = 0.4210592223250348
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.4059322197800097
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
# Best model updated
#
# traing_loss = 0.4166139772404795
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.75
#
# traing_loss = 0.41446171506591467
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.42371462415093963
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.41258985516817676
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.4255750360696212
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.4237032189317372
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.75
#
# traing_loss = 0.4250118674143501
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.410584533992021
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.75
#
# traing_loss = 0.38681795739609265
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.38684575518836145
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.38369379354559857
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.75
#
# traing_loss = 0.37266938647498254
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
# Best model updated
#
# traing_loss = 0.3710105769012285
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.38324066478273144
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.71
#
# traing_loss = 0.3868520778158437
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.74
#
# Group 5 Finished!
# Best accuracy found at epoch 67: 0.78
# Target number of exemplars: 40
# Randomly extracting exemplars from class 0 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 40 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.52
#
# =============================================
#
# Length of exemplars set: 2000
# traing_loss = 2.5321011361868484
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.68
# Best model updated
#
# traing_loss = 1.4779760371083799
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.71
# Best model updated
#
# traing_loss = 1.2954736118731291
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.70
#
# traing_loss = 1.1653759920078774
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.72
# Best model updated
#
# traing_loss = 1.0728784747745679
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.70
#
# traing_loss = 1.0182206371556157
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
# Best model updated
#
# traing_loss = 0.968766934197882
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.9189712793930717
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.8881343940029973
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.8544252501881641
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
# Best model updated
#
# traing_loss = 0.8251438918321029
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.7826840255571448
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.69
#
# traing_loss = 0.7773716475652612
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.73
#
# traing_loss = 0.7658206742742787
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.7335076889266139
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
# Best model updated
#
# traing_loss = 0.6805248888938323
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.662863358207371
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.73
#
# traing_loss = 0.661279083594032
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.6742564919202224
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.73
#
# traing_loss = 0.625547192018965
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.6335097363461619
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.62125363945961
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.5921303856631984
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.5995829183122386
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.588471779356832
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.5610202887783879
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.72
#
# traing_loss = 0.5595470057881397
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.72
#
# traing_loss = 0.545409680708595
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.5464620117260062
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
# Best model updated
#
# traing_loss = 0.5642416859450547
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.5199243529983189
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.79
# Best model updated
#
# traing_loss = 0.51303064564
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.73
#
# traing_loss = 0.5023975177951481
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.4898848851089892
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.4722115539986154
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.44888543564340344
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.4740095520796983
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.46869234157645184
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.45995388406774274
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
#
# traing_loss = 0.47613002878168353
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.45382131053053815
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.48738833030928735
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.47605600693951483
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.45824450578378595
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.4383464902639389
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.43768809930137964
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.4379284064406934
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.79
#
# traing_loss = 0.4182663456253383
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.40724949020406476
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.40927340479000757
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.41431384501249896
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.45064067581425543
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.42665792548138165
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.41581670356833417
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.4098240953424703
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.4105243248784024
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.79
#
# traing_loss = 0.4054864612610444
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.3845881806767505
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.4045908451080322
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.39548424598963366
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.79
# Best model updated
#
# traing_loss = 0.3795042880203413
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.36842964589595795
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.36045958490475366
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.37138299708781036
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.3739325410645941
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.381386355213497
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.38857808320418646
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.38953530010969745
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.38055595820364746
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.37046508296676306
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.79
#
# Group 6 Finished!
# Best accuracy found at epoch 60: 0.79
# ...
#
# traing_loss = 1.3306767085324163
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.67
#
# traing_loss = 1.1945811678533969
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.72
# Best model updated
#
# traing_loss = 1.0994396468867427
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
# Best model updated
#
# traing_loss = 1.0329649824163187
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
# Best model updated
#
# traing_loss = 0.9709680663502734
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.925171655157338
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.72
#
# traing_loss = 0.8828026885571687
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
# Best model updated
#
# traing_loss = 0.8558415640955386
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.72
#
# traing_loss = 0.8134160702643187
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.72
#
# traing_loss = 0.7729076017504153
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.776124735241351
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.7483363410700923
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.7220897817093394
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
# Best model updated
#
# traing_loss = 0.690497636795044
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.691144752761592
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.6805408596992493
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.6734206404374994
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.6736262570256772
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
# Best model updated
#
# traing_loss = 0.6459811394629271
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.6401499030382737
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.6205280928508096
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
# Best model updated
#
# traing_loss = 0.6198909269726794
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.611914543353993
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.5702209569837736
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.5611066254584686
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.5774834965882094
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.5831680252500202
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.582907911228097
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.5395913700694623
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.5336613162704136
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.5264068997424581
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.5375176992105402
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
# Best model updated
#
# traing_loss = 0.521364380484042
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.5219514169122862
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.4956881475189458
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.50241519510746
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.5003439511941827
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.4957045614719391
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.5175472174001776
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.4917644346537797
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.47872248875058215
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.46362108380898187
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.4577914929908255
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.454792980266654
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.4819133508464564
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.47034281945746875
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.44305023421411927
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.4509389763293059
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.4573545902967453
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.4349576085805893
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.4560745241849319
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.46928521472474805
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.45395667527032935
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.4372683238724004
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.4374467549116715
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.42699758319751074
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.43844451982042065
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.4352641954370167
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
# Best model updated
#
# traing_loss = 0.4196443350418754
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.4148529845735301
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.4278708035531251
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.4283605321593907
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.42089593216128973
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
# Best model updated
#
# traing_loss = 0.4234266391266947
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.80
# Best model updated
#
# traing_loss = 0.4104097569766252
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.40347311742927716
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.39989055887512537
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.3893819943718288
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.79
#
# Group 9 Finished!
# Best accuracy found at epoch 66: 0.80
# Target number of exemplars: 22
# Randomly extracting exemplars from class 0 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 22 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.35
#
# =============================================
#
# Length of exemplars set: 1980
# traing_loss = 2.864233138768569
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.70
# Best model updated
#
# traing_loss = 1.537566109843876
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.73
# Best model updated
#
# traing_loss = 1.2622151659882588
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
# Best model updated
#
# traing_loss = 1.1363923342331597
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
# Best model updated
#
# traing_loss = 1.0633103186669557
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.9924806758113529
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
# Best model updated
#
# traing_loss = 0.9516082755897356
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
# Best model updated
#
# traing_loss = 0.8880864511365476
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.72
#
# traing_loss = 0.8539247694222823
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.8259212478347446
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.8374914889750273
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.8268439588339432
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.7726591501546942
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.7284409442673558
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.7087904007538505
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.7345954309339109
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.6890877303869828
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.6864873974219613
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.6603866828524548
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.630186242253884
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.6121273235134457
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.6279974651077519
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.6267112338024637
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
# Best model updated
#
# traing_loss = 0.5873085538978162
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
# Best model updated
#
# traing_loss = 0.5907726430374644
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.6086500455503878
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.82
# Best model updated
#
# traing_loss = 0.5827462731496148
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.5889119654893875
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.5684059838885847
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.5764020668423694
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.5854981820220533
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.5755083288835443
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.5542830325987028
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.5380704875873483
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.5267043968905574
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.5194737528977187
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.5146102846964545
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.5064196981813597
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.49684618219085364
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.4999342742173568
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.4929966609115186
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.5237996118224185
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.5170570216749025
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.5104336855204209
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.4991333517043487
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.48035942989846936
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.47109341362248297
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.46061429316582886
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.82
# Best model updated
#
# traing_loss = 0.4683858097895332
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.4700947825027549
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.4889564546553985
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.49349178762539575
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.49629139252330945
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.49254648970521014
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.4780479987030444
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.4534198738958525
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.83
# Best model updated
#
# traing_loss = 0.4534357293792393
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.4421769646198853
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.44074449591014697
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.4655899982089582
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.4485012636236522
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.4433740992908892
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.42699494050896686
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.42341729933800903
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.83
# Best model updated
#
# traing_loss = 0.42152646572693536
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.41625264092631964
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.4287859356921652
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.430359550792238
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.42145521679650183
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.4167549409296202
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
#
# Group 10 Finished!
# Best accuracy found at epoch 64: 0.83
# Target number of exemplars: 20
# Randomly extracting exemplars from class 0 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 20 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.33
#
# =============================================
#
# #################################

# %% [markdown]
# ### Store logs in more usable dtype

# %%
train_loss = [[logs[run_i]['group_train_loss'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
train_accuracy = [[logs[run_i]['group_train_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
val_loss = [[logs[run_i]['val_losses'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
val_accuracy = [[logs[run_i]['val_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
test_accuracy = [[logs[run_i]['test_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
predictions = [logs[run_i]['predictions'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]
true_labels = [logs[run_i]['true_labels'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]

# %% [markdown]
# ### Save the model

# %% [markdown]
# #### Saving logs in JSON files

# %%
import json

with open('states/iCaRL_ablationCE+L2_train_loss_seed13.json', 'w') as f:
  json.dump(train_loss, f)
f.close
with open('states/iCaRL_ablationCE+L2_train_accuracy_seed13.json', 'w') as f:
  json.dump(train_accuracy, f)
f.close
with open('states/iCaRL_ablationCE+L2_val_loss_seed13.json', 'w') as f:
  json.dump(val_loss, f)
f.close  
with open('states/iCaRL_ablationCE+L2_val_accuracy_seed13.json', 'w') as f:
  json.dump(val_accuracy, f)
f.close
with open('states/iCaRL_ablationCE+L2_test_accuracy_seed13.json', 'w') as f:
  json.dump(test_accuracy, f)
f.close
with open('states/iCaRL_ablationCE+L2_predictions_seed13.json', 'w') as f:
  json.dump(predictions, f)
f.close
with open('states/iCaRL_ablationCE+L2_true_labels_seed13.json', 'w') as f:
  json.dump(true_labels, f)
f.close
# Out:
# <function TextIOWrapper.close>

# %% [markdown]
# #### Saving best resnet on 100 classes for each seed

# %%
for i in range(len(RANDOM_SEED)):
  torch.save(best_net_tot_classes[i].state_dict(), "states/iCaRL_ablationCE+L2_bestnet_seed[{}]".format(RANDOM_SEED[i]))

# %%
from google.colab import files
files.download('states/iCaRL_ablationCE+L2_train_loss_seed13.json')
files.download('states/iCaRL_ablationCE+L2_train_accuracy_seed13.json')
files.download('states/iCaRL_ablationCE+L2_val_loss_seed13.json')
files.download('states/iCaRL_ablationCE+L2_val_accuracy_seed13.json')
files.download('states/iCaRL_ablationCE+L2_test_accuracy_seed13.json')
files.download('states/iCaRL_ablationCE+L2_predictions_seed13.json')
files.download('states/iCaRL_ablationCE+L2_true_labels_seed13.json')
for i in range(len(RANDOM_SEED)):
  files.download('states/iCaRL_ablationCE+L2_bestnet_seed[{}]'.format(RANDOM_SEED[i]))

# %% [markdown]
# ### Print some graphs

# %%
from data.utils_plot import plot_train_val, plot_test_accuracies, plot_confusion_matrix

# %%
train_loss = np.array(train_loss)
train_accuracy = np.array(train_accuracy)
val_loss = np.array(val_loss)
val_accuracy = np.array(val_accuracy)
test_accuracy = np.array(test_accuracy)

train_loss_stats = np.array([train_loss.mean(0), train_loss.std(0)]).transpose()
train_accuracy_stats = np.array([train_accuracy.mean(0), train_accuracy.std(0)]).transpose()
val_loss_stats = np.array([val_loss.mean(0), val_loss.std(0)]).transpose()
val_accuracy_stats = np.array([val_accuracy.mean(0), val_accuracy.std(0)]).transpose()
test_accuracy_stats = np.array([test_accuracy.mean(0), test_accuracy.std(0)]).transpose()

# %% [markdown]
# #### Train validation loss

# %%
plot_train_val(train_loss_stats, val_loss_stats, loss = True)

# %% [markdown]
# #### Train validation accuracy

# %%
plot_train_val(train_accuracy_stats, val_accuracy_stats, loss = False)

# %% [markdown]
# #### Test accuracy

# %%
plot_test_accuracies(test_accuracy_stats)

# %% [markdown]
# #### Confusion Matrix

# %%
for run in range(len(RANDOM_SEED)):
  targets = np.array(true_labels[run])
  preds = np.array(predictions[run])

  plot_confusion_matrix(targets, preds, RANDOM_SEED[run], 'iCaRL')
