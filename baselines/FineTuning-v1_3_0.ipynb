# %% [markdown]
# <a href="https://colab.research.google.com/github/cosminnedescu/ProjectMLDL/blob/main/baselines/FineTuning-v1_3_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import random

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable

import torchvision
from torchvision import transforms, datasets, models
from torch.utils.data import Subset, DataLoader

from PIL import Image

import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
from copy import copy
from copy import deepcopy

# %% [markdown]
# #### Cloning the Git repository

# %%
# !rm -rf ProjectMLDL
if not os.path.isdir('/content/ProjectMLDL'):
  # !git clone https://github.com/cosminnedescu/ProjectMLDL.git
  # %cd /content/ProjectMLDL
  # !rm -rf LICENSE README.md
# Out:
# Cloning into 'ProjectMLDL'...
# remote: Enumerating objects: 319, done.
# remote: Counting objects: 100% (319/319), done.
# remote: Compressing objects: 100% (308/308), done.
# remote: Total 319 (delta 141), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (319/319), 4.51 MiB | 9.84 MiB/s, done.
# Resolving deltas: 100% (141/141), done.
# /content/ProjectMLDL

# %%
from data.cifar100 import CIFAR100
from model.resnet32 import resnet32
import data.utils
from model.trainer import Trainer

# %% [markdown]
# #### Downloading data from Cifar100

# %%
# True mean and std of Cifar100 dataset (src="https://gist.github.com/weiaicunzai/e623931921efefd4c331622c344d8151")
mean = [0.5071, 0.4867, 0.4408]
std = [0.2675, 0.2565, 0.2761]

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])
test_transform = transforms.Compose(
    [transforms.ToTensor(), 
     transforms.Normalize(mean, std),
     ])

# %% [markdown]
# ## Fine Tuning

# %% [markdown]
# ### Defining hyperparameters according to iCarl paper

# %%
# Settings
DEVICE = 'cuda'
NUM_CLASSES = 100         # Total number of classes
VAL_SIZE = 0.2            # Proportion of validation set with respect to training set (between 0 and 1)

# Training
BATCH_SIZE = 128          # Batch size
LR = 2                    # Initial learning rate
                       
MOMENTUM = 0.9            # Momentum for stochastic gradient descent (SGD)
WEIGHT_DECAY = 1e-5       # Weight decay from iCaRL

RANDOM_SEED = [42,13,10]  # Random seeds defining the runs of every method
                          # Note: this should be at least 3 to have a fair benchmark

NUM_EPOCHS = 70           # Total number of training epochs
MILESTONES = [49, 63]     # Step down policy from iCaRL (MultiStepLR)
                          # Decrease the learning rate by gamma at each milestone
GAMMA = 0.2               # Gamma factor from iCaRL (1/5)

# %% [markdown]
# ### Going on with the model
# This is the main FineTuning step.
#
# This step is run 3 times with different `RANDOM_SEED`.
# Here the model is instantiated, trained and tested.
#
# Results and some statistics are then stored in the variable `logs`.

# %%
def do_group_classes(run):

  train_dataloader = [[] for i in range(10)]
  val_dataloader = [[] for i in range(10)]
  test_dataloader = [[] for i in range(10)]

  for i in range(10):
    train_data = CIFAR100("dataset", 
                          train=True, 
                          transform=train_transform, 
                          download=(run+i==0),
                          random_state=RANDOM_SEED[run])
    test_data = CIFAR100("dataset", 
                         train=False, 
                         transform=test_transform, 
                         download=False,
                         random_state=RANDOM_SEED[run])
    
    train_data.set_index_map(train_data.splits[i])
    test_data.set_index_map([test_data.splits[j] for j in range(0, i+1)])
    
    train_indices, val_indices = train_data.train_val_split(VAL_SIZE, RANDOM_SEED[run])
    
    train_subset = Subset(train_data, train_indices)
    val_subset = Subset(train_data, val_indices)

    tmp_dl = DataLoader(train_subset,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    train_dataloader[i] = copy(tmp_dl)
    
    tmp_dl = DataLoader(val_subset,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    val_dataloader[i] = copy(tmp_dl)

    tmp_dl = DataLoader(test_data,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    test_dataloader[i] = copy(tmp_dl)

  return train_dataloader, val_dataloader, test_dataloader

# %%
logs = [[] for i in range(len(RANDOM_SEED))]
best_net_tot_classes = [None for i in range(len(RANDOM_SEED))]

for run in range(len(RANDOM_SEED)):
  random.seed(RANDOM_SEED[run])
  print("#################################")
  print(f"Radom seed: {RANDOM_SEED[run]}")
  print("")

  #get dataloader separated in incremental groups of 10 classes
  train_dl, val_dl, test_dl = do_group_classes(train_data, test_data)

  #create the resnet
  net = resnet32()
  
  trainer = Trainer(DEVICE,
                    net,
                    LR,
                    MOMENTUM,
                    WEIGHT_DECAY,
                    MILESTONES,
                    GAMMA,
                    train_dl,
                    val_dl,
                    test_dl)

  #train and evaluate the model
  logs[run] = trainer.train_model(NUM_EPOCHS)

  best_net_tot_classes[run] = deepcopy(trainer.best_net)

  print("#################################")
  print("")
  print("")
# Out:
# #################################
# Radom seed: 42
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Output streaming troncato alle ultime 5000 righe.
#
# Epoch[48] loss: 0.001842786526052101 LR: [2]
# Validation on group[6] of 10 classes
# val loss: 0.017489440872200897
# val acc: 0.8113839285714286
#
# Epoch[49] loss: 0.001338948861831018 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.015018569704677378
# val acc: 0.8493303571428571
# Best model updated
#
# Epoch[50] loss: 0.0008605023444209608 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.01208402615572725
# val acc: 0.8694196428571429
# Best model updated
#
# Epoch[51] loss: 0.0006751352414158323 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.012799098422484738
# val acc: 0.8716517857142857
# Best model updated
#
# Epoch[52] loss: 0.0005804388887143784 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.012426983964230334
# val acc: 0.8738839285714286
# Best model updated
#
# Epoch[53] loss: 0.0005530289471930553 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.01349614148161241
# val acc: 0.8616071428571429
#
# Epoch[54] loss: 0.00042802752878126355 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.01262974486287151
# val acc: 0.8638392857142857
#
# Epoch[55] loss: 0.0004377533862885508 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.012807484716176987
# val acc: 0.8705357142857143
#
# Epoch[56] loss: 0.00048079309401087344 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.0138246374470847
# val acc: 0.8616071428571429
#
# Epoch[57] loss: 0.0003859922003504189 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.013326169124671392
# val acc: 0.8616071428571429
#
# Epoch[58] loss: 0.0003954218282747353 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.013146665612501758
# val acc: 0.8504464285714286
#
# Epoch[59] loss: 0.0003663168665239467 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.01344933919608593
# val acc: 0.8627232142857143
#
# Epoch[60] loss: 0.00033484042139588703 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.012852879906339305
# val acc: 0.8616071428571429
#
# Epoch[61] loss: 0.0003536831481464868 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.013045371110950197
# val acc: 0.8727678571428571
#
# Epoch[62] loss: 0.00031796419587466984 LR: [0.4]
# Validation on group[6] of 10 classes
# val loss: 0.014088176190853119
# val acc: 0.8571428571428571
#
# Epoch[63] loss: 0.0002573515943837382 LR: [0.08000000000000002]
# Validation on group[6] of 10 classes
# val loss: 0.012684357751693045
# val acc: 0.8705357142857143
#
# Epoch[64] loss: 0.00032857613686862735 LR: [0.08000000000000002]
# Validation on group[6] of 10 classes
# val loss: 0.012937658200306552
# val acc: 0.8828125
# Best model updated
#
# Epoch[65] loss: 0.00027021905994080306 LR: [0.08000000000000002]
# Validation on group[6] of 10 classes
# val loss: 0.013480570965579577
# val acc: 0.8571428571428571
#
# Epoch[66] loss: 0.0003127034522608043 LR: [0.08000000000000002]
# Validation on group[6] of 10 classes
# val loss: 0.012423231931669372
# val acc: 0.8839285714285714
# Best model updated
#
# Epoch[67] loss: 0.00031166966260981656 LR: [0.08000000000000002]
# Validation on group[6] of 10 classes
# val loss: 0.012962171541793006
# val acc: 0.8638392857142857
#
# Epoch[68] loss: 0.0003031394068872736 LR: [0.08000000000000002]
# Validation on group[6] of 10 classes
# val loss: 0.012783192696848087
# val acc: 0.8716517857142857
#
# Epoch[69] loss: 0.00026959101265792046 LR: [0.08000000000000002]
# Validation on group[6] of 10 classes
# val loss: 0.011980707890221052
# val acc: 0.8794642857142857
#
# Group[6]Finished!
# Best model at epoch 66, best accuracy: 0.88
#
# Testing classes seen so far, accuracy: 0.12254050925925926
#
# =============================================
#
# Epoch[0] loss: 0.04702719216865878 LR: [2]
# Validation on group[7] of 10 classes
# val loss: 0.029156948838915144
# val acc: 0.5111607142857143
# Best model updated
#
# Epoch[1] loss: 0.02465872664845759 LR: [2]
# Validation on group[7] of 10 classes
# val loss: 0.02294932385640485
# val acc: 0.6037946428571429
# Best model updated
#
# Epoch[2] loss: 0.01936279714948708 LR: [2]
# Validation on group[7] of 10 classes
# val loss: 0.019457751352872168
# val acc: 0.6752232142857143
# Best model updated
#
# Epoch[3] loss: 0.016828179599777345 LR: [2]
# Validation on group[7] of 10 classes
# val loss: 0.01952845390353884
# val acc: 0.6707589285714286
#
# Epoch[4] loss: 0.014936374800820504 LR: [2]
# Validation on group[7] of 10 classes
# val loss: 0.016767637405012335
# val acc: 0.7220982142857143
# Best model updated
#
# Epoch[5] loss: 0.013147131930435858 LR: [2]
# Validation on group[7] of 10 classes
# val loss: 0.018221622865114893
# val acc: 0.7165178571428571
#
# Epoch[6] loss: 0.011933003071575396 LR: [2]
# Validation on group[7] of 10 classes
# val loss: 0.015673216565379074
# val acc: 0.7410714285714286
# Best model updated
#
# Epoch[7] loss: 0.010615187276515269 LR: [2]
# Validation on group[7] of 10 classes
# val loss: 0.01583926672382014
# val acc: 0.7544642857142857
# Best model updated
#
# Epoch[8] loss: 0.010399952741159547 LR: [2]
# Validation on group[7] of 10 classes
# val loss: 0.01678359042853117
# val acc: 0.7332589285714286
#
# Epoch[9] loss: 0.00998616864484164 LR: [2]
# Validation on group[7] of 10 classes
# val loss: 0.018168676245425428
# val acc: 0.7176339285714286
#
# Epoch[10] loss: 0.00965512225464467 LR: [2]
# Validation on group[7] of 10 classes
# val loss: 0.01738734543323517
# val acc: 0.7410714285714286
#
# Epoch[11] loss: 0.009117139908935755 LR: [2]
# Validation on group[7] of 10 classes
# val loss: 0.017091232085866586
# val acc: 0.7433035714285714
#
# Epoch[12] loss: 0.008259181008343735 LR: [2]
# Validation on group[7] of 10 classes
# val loss: 0.01901207465146269
# val acc: 0.7265625
#
# Epoch[13] loss: 0.008287175693699429 LR: [2]
# Validation on group[7] of 10 classes
# val loss: 0.022341080009937286
# val acc: 0.6863839285714286
#
# Epoch[14] loss: 0.007857040171661684 LR: [2]
# Validation on group[7] of 10 classes
# val loss: 0
LR: [2]
# Validation on group[7] of 10 classes
# val loss: 0.019676888627665385
# val acc: 0.7678571428571429
#
# Epoch[47] loss: 0.002956112414868849 LR: [2]
# Validation on group[7] of 10 classes
# val loss: 0.020967711162354265
# val acc: 0.7667410714285714
#
# Epoch[48] loss: 0.002427730664250351 LR: [2]
# Validation on group[7] of 10 classes
# val loss: 0.01866899204573461
# val acc: 0.7801339285714286
#
# Epoch[49] loss: 0.0016592676608612942 LR: [0.4]
# Validation on group[7] of 10 classes
# val loss: 0.013430796430579253
# val acc: 0.8292410714285714
# Best model updated
#
# Epoch[50] loss: 0.0010313313931316858 LR: [0.4]
# Validation on group[7] of 10 classes
# val loss: 0.012931927905551024
# val acc: 0.8270089285714286
#
# Epoch[51] loss: 0.0008886991389801786 LR: [0.4]
# Validation on group[7] of 10 classes
# val loss: 0.01393000768231494
# val acc: 0.8292410714285714
#
# Epoch[52] loss: 0.0007182311214086028 LR: [0.4]
# Validation on group[7] of 10 classes
# val loss: 0.012521818546312196
# val acc: 0.8370535714285714
# Best model updated
#
# Epoch[53] loss: 0.0007630066585636908 LR: [0.4]
# Validation on group[7] of 10 classes
# val loss: 0.012425196623163564
# val acc: 0.8337053571428571
#
# Epoch[54] loss: 0.0005709368532763854 LR: [0.4]
# Validation on group[7] of 10 classes
# val loss: 0.013010738417506218
# val acc: 0.8270089285714286
#
# Epoch[55] loss: 0.0005536470998777077 LR: [0.4]
# Validation on group[7] of 10 classes
# val loss: 0.013068825538669313
# val acc: 0.8359375
#
# Epoch[56] loss: 0.0005547410645146644 LR: [0.4]
# Validation on group[7] of 10 classes
# val loss: 0.013638669891016824
# val acc: 0.8203125
#
# Epoch[57] loss: 0.0005856912203824088 LR: [0.4]
# Validation on group[7] of 10 classes
# val loss: 0.012817236195717539
# val acc: 0.8370535714285714
#
# Epoch[58] loss: 0.0005016955223137272 LR: [0.4]
# Validation on group[7] of 10 classes
# val loss: 0.013634319949362959
# val acc: 0.828125
#
# Epoch[59] loss: 0.0005175910294882112 LR: [0.4]
# Validation on group[7] of 10 classes
# val loss: 0.014836011853601252
# val acc: 0.8191964285714286
#
# Epoch[60] loss: 0.00046570625788937774 LR: [0.4]
# Validation on group[7] of 10 classes
# val loss: 0.01327445384647165
# val acc: 0.8348214285714286
#
# Epoch[61] loss: 0.0004453812401944531 LR: [0.4]
# Validation on group[7] of 10 classes
# val loss: 0.013258276241166251
# val acc: 0.8348214285714286
#
# Epoch[62] loss: 0.00044119205971759174 LR: [0.4]
# Validation on group[7] of 10 classes
# val loss: 0.013255659357777663
# val acc: 0.8348214285714286
#
# Epoch[63] loss: 0.00040729599535435196 LR: [0.08000000000000002]
# Validation on group[7] of 10 classes
# val loss: 0.012583717703819275
# val acc: 0.8348214285714286
#
# Epoch[64] loss: 0.00038432114290058494 LR: [0.08000000000000002]
# Validation on group[7] of 10 classes
# val loss: 0.0122709312875356
# val acc: 0.8515625
# Best model updated
#
# Epoch[65] loss: 0.00043941414286006964 LR: [0.08000000000000002]
# Validation on group[7] of 10 classes
# val loss: 0.013311430678835936
# val acc: 0.8303571428571429
#
# Epoch[66] loss: 0.0003583462474184231 LR: [0.08000000000000002]
# Validation on group[7] of 10 classes
# val loss: 0.013362061099282332
# val acc: 0.8337053571428571
#
# Epoch[67] loss: 0.00036277004654684494 LR: [0.08000000000000002]
# Validation on group[7] of 10 classes
# val loss: 0.012762895253087794
# val acc: 0.8381696428571429
#
# Epoch[68] loss: 0.0003758345246164789 LR: [0.08000000000000002]
# Validation on group[7] of 10 classes
# val loss: 0.013578936191541808
# val acc: 0.8359375
#
# Epoch[69] loss: 0.0003786352613279896 LR: [0.08000000000000002]
# Validation on group[7] of 10 classes
# val loss: 0.011386267175631863
# val acc: 0.8493303571428571
#
# Group[7]Finished!
# Best model at epoch 64, best accuracy: 0.85
#
# Testing classes seen so far, accuracy: 0.10735887096774194
#
# =============================================
#
# Epoch[0] loss: 0.04281090506382527 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.029559927859476635
# val acc: 0.4107142857142857
# Best model updated
#
# Epoch[1] loss: 0.023584536907653653 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.02062900923192501
# val acc: 0.6227678571428571
# Best model updated
#
# Epoch[2] loss: 0.0177303641553848 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.016787354169147357
# val acc: 0.703125
# Best model updated
#
# Epoch[3] loss: 0.0139508911318356 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.015257376645292555
# val acc: 0.7377232142857143
# Best model updated
#
# Epoch[4] loss: 0.011838085859292937 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.01642838985260044
# val acc: 0.7142857142857143
#
# Epoch[5] loss: 0.010283767576179197 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.016478608096284524
# val acc: 0.7243303571428571
#
# Epoch[6] loss: 0.008901666654574295 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.01481987935091768
# val acc: 0.7533482142857143
# Best model updated
#
# Epoch[7] loss: 0.007877678865747105 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.014674645050295762
# val acc: 0.7444196428571429
#
# Epoch[8] loss: 0.00731910407663353 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.015803802758455276
# val acc: 0.7544642857142857
# Best model updated
#
# Epoch[9] loss: 0.006862764712423086 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.015964385521199023
# val acc: 0.7544642857142857
#
# Epoch[10] loss: 0.006215581835638131 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.012435565037386758
# val acc: 0.7991071428571429
# Best model updated
#
# Epoch[11] loss: 0.005597165680580562 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.014144582274769033
# val acc: 0.7734375
#
# Epoch[12] loss: 0.005630698528200868 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.011154335524354662
# val acc: 0.8303571428571429
# Best model updated
#
# Epoch[13] loss: 0.005484268317119249 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.012944228681070464
# val acc: 0.7991071428571429
#
# Epoch[14] loss: 0.0047534130994350676 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.01828556906964098
# val acc: 0.7421875
#
# Epoch[15] loss: 0.004475292847341587 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.015827056020498276
# val acc: 0.7689732142857143
#
# Epoch[16] loss: 0.003996118324838819 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.013764049192624432
# val acc: 0.7890625
#
# Epoch[17] loss: 0.004320108181526584 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.015934334668729986
# val acc: 0.7790178571428571
#
# Epoch[18] loss: 0.004614684986130845 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.013401789058532034
# val acc: 0.8203125
#
# Epoch[19] loss: 0.004079694394022226 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.014161604190511363
# val acc: 0.7912946428571429
#
# Epoch[20] loss: 0.0037735964494547054 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.013355216011404991
# val acc: 0.7935267857142857
#
# Epoch[21] loss: 0.003587637674964724 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.01083731624696936
# val acc: 0.828125
#
# Epoch[22] loss: 0.003122610426808317 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0
LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.20411961844989232
# val acc: 0.5602678571428571
#
# Epoch[35] loss: 0.1724041248521497 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.25391973342214313
# val acc: 0.45424107142857145
#
# Epoch[36] loss: 0.162199406854568 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.19784262563501084
# val acc: 0.5926339285714286
# Best model updated
#
# Epoch[37] loss: 0.1632248970770067 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.21556733122893743
# val acc: 0.5145089285714286
#
# Epoch[38] loss: 0.15355137879810027 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.18224693409034184
# val acc: 0.6104910714285714
# Best model updated
#
# Epoch[39] loss: 0.14690622038418247 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.210811225431306
# val acc: 0.5758928571428571
#
# Epoch[40] loss: 0.14800828046375705 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.17931738708700454
# val acc: 0.6316964285714286
# Best model updated
#
# Epoch[41] loss: 0.14546122882635362 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.20237632308687484
# val acc: 0.59375
#
# Epoch[42] loss: 0.14317510853851995 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.21374193472521646
# val acc: 0.6026785714285714
#
# Epoch[43] loss: 0.13963843882083893 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.1757920171533312
# val acc: 0.6361607142857143
# Best model updated
#
# Epoch[44] loss: 0.13505094931010278 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.18350882189614431
# val acc: 0.6149553571428571
#
# Epoch[45] loss: 0.1250045140904765 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.19543229043483734
# val acc: 0.5926339285714286
#
# Epoch[46] loss: 0.12294444922477968 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.18705463409423828
# val acc: 0.6216517857142857
#
# Epoch[47] loss: 0.12324465330569975 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.21359967972551072
# val acc: 0.6004464285714286
#
# Epoch[48] loss: 0.12603607076791026 LR: [2]
# Validation on group[0] of 10 classes
# val loss: 0.2031887343951634
# val acc: 0.609375
#
# Epoch[49] loss: 0.10419430247237606 LR: [0.4]
# Validation on group[0] of 10 classes
# val loss: 0.12643567259822572
# val acc: 0.7455357142857143
# Best model updated
#
# Epoch[50] loss: 0.09352957144860298 LR: [0.4]
# Validation on group[0] of 10 classes
# val loss: 0.12181026062795094
# val acc: 0.7533482142857143
# Best model updated
#
# Epoch[51] loss: 0.08742481373971508 LR: [0.4]
# Validation on group[0] of 10 classes
# val loss: 0.12009222060441971
# val acc: 0.7578125
# Best model updated
#
# Epoch[52] loss: 0.08362771811023835 LR: [0.4]
# Validation on group[0] of 10 classes
# val loss: 0.11408470358167376
# val acc: 0.7790178571428571
# Best model updated
#
# Epoch[53] loss: 0.081779055898228 LR: [0.4]
# Validation on group[0] of 10 classes
# val loss: 0.11225020033972603
# val acc: 0.7779017857142857
#
# Epoch[54] loss: 0.07910607490808733 LR: [0.4]
# Validation on group[0] of 10 classes
# val loss: 0.11587505681174141
# val acc: 0.765625
#
# Epoch[55] loss: 0.07927259141879697 LR: [0.4]
# Validation on group[0] of 10 classes
# val loss: 0.12568685625280654
# val acc: 0.7511160714285714
#
# Epoch[56] loss: 0.07552141383770973 LR: [0.4]
# Validation on group[0] of 10 classes
# val loss: 0.12255295472485679
# val acc: 0.7466517857142857
#
# Epoch[57] loss: 0.07422642854432907 LR: [0.4]
# Validation on group[0] of 10 classes
# val loss: 0.11897951258080346
# val acc: 0.7667410714285714
#
# Epoch[58] loss: 0.07325353749817418 LR: [0.4]
# Validation on group[0] of 10 classes
# val loss: 0.12009123606341225
# val acc: 0.7600446428571429
#
# Epoch[59] loss: 0.07265622613410797 LR: [0.4]
# Validation on group[0] of 10 classes
# val loss: 0.1215098106435367
# val acc: 0.765625
#
# Epoch[60] loss: 0.0699224135568065 LR: [0.4]
# Validation on group[0] of 10 classes
# val loss: 0.12034817678587777
# val acc: 0.7734375
#
# Epoch[61] loss: 0.06510465568111788 LR: [0.4]
# Validation on group[0] of 10 classes
# val loss: 0.12370540627411433
# val acc: 0.7745535714285714
#
# Epoch[62] loss: 0.06849114632894916 LR: [0.4]
# Validation on group[0] of 10 classes
# val loss: 0.1316989947642599
# val acc: 0.7477678571428571
#
# Epoch[63] loss: 0.06151554360985756 LR: [0.08000000000000002]
# Validation on group[0] of 10 classes
# val loss: 0.10727323698146003
# val acc: 0.7801339285714286
# Best model updated
#
# Epoch[64] loss: 0.05450832327046702 LR: [0.08000000000000002]
# Validation on group[0] of 10 classes
# val loss: 0.11026124762637275
# val acc: 0.8013392857142857
# Best model updated
#
# Epoch[65] loss: 0.053025401167331204 LR: [0.08000000000000002]
# Validation on group[0] of 10 classes
# val loss: 0.10803685869489398
# val acc: 0.7834821428571429
#
# Epoch[66] loss: 0.05062402244056425 LR: [0.08000000000000002]
# Validation on group[0] of 10 classes
# val loss: 0.1147124639579228
# val acc: 0.7901785714285714
#
# Epoch[67] loss: 0.051932618622818304 LR: [0.08000000000000002]
# Validation on group[0] of 10 classes
# val loss: 0.11250390431710652
# val acc: 0.7801339285714286
#
# Epoch[68] loss: 0.04977319437649942 LR: [0.08000000000000002]
# Validation on group[0] of 10 classes
# val loss: 0.11930736154317856
# val acc: 0.7734375
#
# Epoch[69] loss: 0.05001733920747234 LR: [0.08000000000000002]
# Validation on group[0] of 10 classes
# val loss: 0.11475645963634763
# val acc: 0.7689732142857143
#
# Group[0]Finished!
# Best model at epoch 64, best accuracy: 0.80
#
# Testing classes seen so far, accuracy: 0.8091517857142857
#
# =============================================
#
# Epoch[0] loss: 0.1854279810382474 LR: [2]
# Validation on group[1] of 10 classes
# val loss: 0.1383747011423111
# val acc: 0.37276785714285715
# Best model updated
#
# Epoch[1] loss: 0.1139758849336255 LR: [2]
# Validation on group[1] of 10 classes
# val loss: 0.12677428871393204
# val acc: 0.42299107142857145
# Best model updated
#
# Epoch[2] loss: 0.09846401262667871 LR: [2]
# Validation on group[1] of 10 classes
# val loss: 0.10982340148517064
# val acc: 0.5044642857142857
# Best model updated
#
# Epoch[3] loss: 0.09130618673178457 LR: [2]
# Validation on group[1] of 10 classes
# val loss: 0.10152983665466309
# val acc: 0.5513392857142857
# Best model updated
#
# Epoch[4] loss: 0.08352701245777068 LR: [2]
# Validation on group[1] of 10 classes
# val loss: 0.10753137724740165
# val acc: 0.5524553571428571
# Best model updated
#
# Epoch[5] loss: 0.07921020350148601 LR: [2]
# Validation on group[1] of 10 classes
# val loss: 0.10691240004130773
# val acc: 0.5602678571428571
# Best model updated
#
# Epoch[6] loss: 0.07713070992500551 LR: [2]
# Validation on group[1] of 10 classes
# val loss: 0.10774380713701248
# val acc: 0.5491071428571429
#
# Epoch[7] loss: 0.07409661924166064 LR: [2]
# Validation on group[1] of 10 classes
# val loss: 0.09983767569065094
# val acc: 0.5636160714285714
# Best model updated
#
# Epoch[8] loss: 0.07136897057775528 LR: [2]
# Validation on group[1] of 10 classes
# val loss: 0.08426181333405632
# val acc: 0.6439732142857143
# Best model updated
#
# Epoch[9] loss: 0.06754121809236464 LR: [2]
# Validation on group[1] of 10 classes
# val loss: 0.09458835422992706
# val acc: 0.5982142857142857
#
# Epoch[10] loss: 0.06493352666016548 LR: [2]
# Validation on group[1] of 10 classes
# val loss: 0.10433146038225719
# val acc: 0.5770089285714286
#
# Epoch[11] loss: 0.06117217531127314 LR: [2]
# Validation on group[1] of 10 classes
# val loss: 0.09351027331181935
# val acc: 0.5904017857142857
#
# Epoch[12] loss: 0.05881066247820854 LR: [2]
# Validation on group[1] of 10 classes
# val loss: 0.10625850515706199
# val acc: 0.5870535714285714
#
# ...
# val acc: 0.8270089285714286
#
# Epoch[35] loss: 0.002511483688478268 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.013073638746781009
# val acc: 0.8180803571428571
#
# Epoch[36] loss: 0.002688213976310386 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.014718952189598764
# val acc: 0.7845982142857143
#
# Epoch[37] loss: 0.0028255632665428903 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.012753227060394627
# val acc: 0.8325892857142857
#
# Epoch[38] loss: 0.003006063555667718 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.012268482175256525
# val acc: 0.8236607142857143
#
# Epoch[39] loss: 0.0023028141511003335 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.012073274302695478
# val acc: 0.8236607142857143
#
# Epoch[40] loss: 0.0019567984329055873 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.010875900142959185
# val acc: 0.8236607142857143
#
# Epoch[41] loss: 0.0022959429996028064 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.012888251138584954
# val acc: 0.8169642857142857
#
# Epoch[42] loss: 0.0018915197785733448 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.010766993210251843
# val acc: 0.8448660714285714
#
# Epoch[43] loss: 0.0015638598331039952 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.01140221394598484
# val acc: 0.8493303571428571
#
# Epoch[44] loss: 0.001680362582837622 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.0142243392765522
# val acc: 0.8102678571428571
#
# Epoch[45] loss: 0.0016703713054378186 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.011140782519110612
# val acc: 0.8459821428571429
#
# Epoch[46] loss: 0.0017852469013192721 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.013286466178085123
# val acc: 0.8180803571428571
#
# Epoch[47] loss: 0.0021205646616797294 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.015361350428845202
# val acc: 0.8024553571428571
#
# Epoch[48] loss: 0.002322098702162264 LR: [2]
# Validation on group[8] of 10 classes
# val loss: 0.014056367932685785
# val acc: 0.8214285714285714
#
# Epoch[49] loss: 0.001303399329997539 LR: [0.4]
# Validation on group[8] of 10 classes
# val loss: 0.008212978419448649
# val acc: 0.8828125
# Best model updated
#
# Epoch[50] loss: 0.0007591615815932352 LR: [0.4]
# Validation on group[8] of 10 classes
# val loss: 0.008290450221725873
# val acc: 0.8872767857142857
# Best model updated
#
# Epoch[51] loss: 0.0005696894227331805 LR: [0.4]
# Validation on group[8] of 10 classes
# val loss: 0.008323756179639272
# val acc: 0.8883928571428571
# Best model updated
#
# Epoch[52] loss: 0.00048277177378505226 LR: [0.4]
# Validation on group[8] of 10 classes
# val loss: 0.008490752295723982
# val acc: 0.8872767857142857
#
# Epoch[53] loss: 0.0005108929387549119 LR: [0.4]
# Validation on group[8] of 10 classes
# val loss: 0.007874291057565383
# val acc: 0.890625
# Best model updated
#
# Epoch[54] loss: 0.0004347421303053477 LR: [0.4]
# Validation on group[8] of 10 classes
# val loss: 0.007829860850636448
# val acc: 0.8783482142857143
#
# Epoch[55] loss: 0.0003818901074531999 LR: [0.4]
# Validation on group[8] of 10 classes
# val loss: 0.007739964872598648
# val acc: 0.8839285714285714
#
# Epoch[56] loss: 0.00040581959981336106 LR: [0.4]
# Validation on group[8] of 10 classes
# val loss: 0.008272028927292143
# val acc: 0.890625
#
# Epoch[57] loss: 0.0003483354695133805 LR: [0.4]
# Validation on group[8] of 10 classes
# val loss: 0.007660204145525183
# val acc: 0.9006696428571429
# Best model updated
#
# Epoch[58] loss: 0.00032042098210959306 LR: [0.4]
# Validation on group[8] of 10 classes
# val loss: 0.007616377701716763
# val acc: 0.9073660714285714
# Best model updated
#
# Epoch[59] loss: 0.00030446409730375897 LR: [0.4]
# Validation on group[8] of 10 classes
# val loss: 0.0082217880657741
# val acc: 0.8861607142857143
#
# Epoch[60] loss: 0.0002951984089093223 LR: [0.4]
# Validation on group[8] of 10 classes
# val loss: 0.008256998245737382
# val acc: 0.9017857142857143
#
# Epoch[61] loss: 0.0003193262692225436 LR: [0.4]
# Validation on group[8] of 10 classes
# val loss: 0.008055439285401787
# val acc: 0.8883928571428571
#
# Epoch[62] loss: 0.0003013877506037393 LR: [0.4]
# Validation on group[8] of 10 classes
# val loss: 0.008616093346582991
# val acc: 0.8850446428571429
#
# Epoch[63] loss: 0.00028700889520076736 LR: [0.08000000000000002]
# Validation on group[8] of 10 classes
# val loss: 0.0081359639630786
# val acc: 0.8895089285714286
#
# Epoch[64] loss: 0.00028754806290605975 LR: [0.08000000000000002]
# Validation on group[8] of 10 classes
# val loss: 0.007687250351799386
# val acc: 0.8872767857142857
#
# Epoch[65] loss: 0.00025840138691672756 LR: [0.08000000000000002]
# Validation on group[8] of 10 classes
# val loss: 0.008254338787602527
# val acc: 0.8973214285714286
#
# Epoch[66] loss: 0.0002586352887691089 LR: [0.08000000000000002]
# Validation on group[8] of 10 classes
# val loss: 0.0076765376475772685
# val acc: 0.90625
#
# Epoch[67] loss: 0.00024690216917905115 LR: [0.08000000000000002]
# Validation on group[8] of 10 classes
# val loss: 0.008347934444567986
# val acc: 0.8928571428571429
#
# Epoch[68] loss: 0.0002830762696835483 LR: [0.08000000000000002]
# Validation on group[8] of 10 classes
# val loss: 0.008622871379234962
# val acc: 0.8872767857142857
#
# Epoch[69] loss: 0.00026076803436397665 LR: [0.08000000000000002]
# Validation on group[8] of 10 classes
# val loss: 0.00763370083378894
# val acc: 0.90625
#
# Group[8]Finished!
# Best model at epoch 58, best accuracy: 0.91
#
# Testing classes seen so far, accuracy: 0.09955357142857142
#
# =============================================
#
# Epoch[0] loss: 0.03969087343542806 LR: [2]
# Validation on group[9] of 10 classes
# val loss: 0
LR: [0.4]
# Validation on group[9] of 10 classes
# val loss: 0.006085729392777596
# val acc: 0.9040178571428571
#
# Epoch[62] loss: 0.00023174656234914437 LR: [0.4]
# Validation on group[9] of 10 classes
# val loss: 0.006619534588285855
# val acc: 0.9073660714285714
#
# Epoch[63] loss: 0.00023217048803945222 LR: [0.08000000000000002]
# Validation on group[9] of 10 classes
# val loss: 0.006097757357305714
# val acc: 0.9040178571428571
#
# Epoch[64] loss: 0.00022642952559005108 LR: [0.08000000000000002]
# Validation on group[9] of 10 classes
# val loss: 0.006418545863458088
# val acc: 0.9073660714285714
#
# Epoch[65] loss: 0.00023826951538437918 LR: [0.08000000000000002]
# Validation on group[9] of 10 classes
# val loss: 0.006297510250338486
# val acc: 0.9040178571428571
#
# Epoch[66] loss: 0.00023844952022867097 LR: [0.08000000000000002]
# Validation on group[9] of 10 classes
# val loss: 0.006337164302489587
# val acc: 0.9017857142857143
#
# Epoch[67] loss: 0.00022397297687993774 LR: [0.08000000000000002]
# Validation on group[9] of 10 classes
# val loss: 0.00629420079556959
# val acc: 0.8973214285714286
#
# Epoch[68] loss: 0.00022136635239040778 LR: [0.08000000000000002]
# Validation on group[9] of 10 classes
# val loss: 0.0064237080514431
# val acc: 0.8973214285714286
#
# Epoch[69] loss: 0.000235669493004905 LR: [0.08000000000000002]
# Validation on group[9] of 10 classes
# val loss: 0.0064475938810833865
# val acc: 0.8962053571428571
#
# Group[9]Finished!
# Best model at epoch 55, best accuracy: 0.92
#
# Testing classes seen so far, accuracy: 0.0907451923076923
#
# =============================================
#
# #################################

# %% [markdown]
# ### Store logs in more usable dtype

# %%
train_loss = [[logs[run_i]['group_train_loss'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
train_accuracy = [[logs[run_i]['group_train_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
val_loss = [[logs[run_i]['val_losses'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
val_accuracy = [[logs[run_i]['val_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
test_accuracy = [[logs[run_i]['test_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
predictions = [logs[run_i]['predictions'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]
true_labels = [logs[run_i]['true_labels'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]

# %% [markdown]
# ### Save the model

# %% [markdown]
# #### Saving logs in JSON files

# %%
import json

with open('states/FineTuning_train_loss.json', 'w') as f:
  json.dump(train_loss, f)
f.close
with open('states/FineTuning_train_accuracy.json', 'w') as f:
  json.dump(train_accuracy, f)
f.close
with open('states/FineTuning_val_loss.json', 'w') as f:
  json.dump(val_loss, f)
f.close  
with open('states/FineTuning_val_accuracy.json', 'w') as f:
  json.dump(val_accuracy, f)
f.close
with open('states/FineTuning_test_accuracy.json', 'w') as f:
  json.dump(test_accuracy, f)
f.close
with open('states/FineTuning_predictions.json', 'w') as f:
  json.dump(predictions, f)
f.close
with open('states/FineTuning_true_labels.json', 'w') as f:
  json.dump(true_labels, f)
f.close

# %% [markdown]
# #### Saving best resnet on 100 classes for each seed

# %%
for i in range(len(RANDOM_SEED)):
  torch.save(best_net_tot_classes[i].state_dict(), "states/FineTuning_bestnet_seed[{}]".format(RANDOM_SEED[i]))

# %% [markdown]
# ### Print some graphs

# %%
from data.utils_plot import plot_train_val, plot_test_accuracies, plot_confusion_matrix

# %%
train_loss = np.array(train_loss)
train_accuracy = np.array(train_accuracy)
val_loss = np.array(val_loss)
val_accuracy = np.array(val_accuracy)
test_accuracy = np.array(test_accuracy)

train_loss_stats = np.array([train_loss.mean(0), train_loss.std(0)]).transpose()
train_accuracy_stats = np.array([train_accuracy.mean(0), train_accuracy.std(0)]).transpose()
val_loss_stats = np.array([val_loss.mean(0), val_loss.std(0)]).transpose()
val_accuracy_stats = np.array([val_accuracy.mean(0), val_accuracy.std(0)]).transpose()
test_accuracy_stats = np.array([test_accuracy.mean(0), test_accuracy.std(0)]).transpose()

# %% [markdown]
# #### Train validation loss

# %%
plot_train_val(train_loss_stats, val_loss_stats, loss = True)

# %% [markdown]
# #### Train validation accuracy

# %%
plot_train_val(train_accuracy_stats, val_accuracy_stats, loss = False)

# %% [markdown]
# #### Test accuracy

# %%
plot_test_accuracies(test_accuracy_stats)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# #### Confusion Matrix

# %%
for run in range(len(RANDOM_SEED)):
  targets = logs[run]['true_labels'].cpu().data.numpy()
  preds = logs[run]['predictions'].cpu().data.numpy()

  plot_confusion_matrix(targets, preds, RANDOM_SEED[run], 'FineTuning')

# %% [markdown]
# ### Check dataloader order

# %%
def check_cifar100_dataloader(dl): #dl: list[group_10]
  coarse_label = [
  'apple',
  'aquarium_fish',
  'baby',
  'bear',
  'beaver',
  'bed',
  'bee',
  'beetle',
  'bicycle',
  'bottle',
  'bowl',
  'boy',
  'bridge',
  'bus',
  'butterfly',
  'camel',
  'can',
  'castle',
  'caterpillar',
  'cattle',
  'chair',
  'chimpanzee',
  'clock',
  'cloud',
  'cockroach',
  'couch',
  'crab',
  'crocodile',
  'cup',
  'dinosaur',
  'dolphin',
  'elephant',
  'flatfish',
  'forest',
  'fox',
  'girl',
  'hamster',
  'house',
  'kangaroo',
  'computer_keyboard',
  'lamp',
  'lawn_mower',
  'leopard',
  'lion',
  'lizard',
  'lobster',
  'man',
  'maple_tree',
  'motorcycle',
  'mountain',
  'mouse',
  'mushroom',
  'oak_tree',
  'orange',
  'orchid',
  'otter',
  'palm_tree',
  'pear',
  'pickup_truck',
  'pine_tree',
  'plain',
  'plate',
  'poppy',
  'porcupine',
  'possum',
  'rabbit',
  'raccoon',
  'ray',
  'road',
  'rocket',
  'rose',
  'sea',
  'seal',
  'shark',
  'shrew',
  'skunk',
  'skyscraper',
  'snail',
  'snake',
  'spider',
  'squirrel',
  'streetcar',
  'sunflower',
  'sweet_pepper',
  'table',
  'tank',
  'telephone',
  'television',
  'tiger',
  'tractor',
  'train',
  'trout',
  'tulip',
  'turtle',
  'wardrobe',
  'whale',
  'willow_tree',
  'wolf',
  'woman',
  'worm',
  ]

  dataiter = iter(dl[0])
  images = dataiter.next()
  plt.imshow(np.transpose(images[1][0]))

  print(coarse_label[images[2][0].item()])

check_cifar100_dataloader(train_dl)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# bear

# %%
check_cifar100_dataloader(train_dl)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# bicycle

# %%
check_cifar100_dataloader(train_dl)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# bee

# %%
check_cifar100_dataloader(val_dl)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# bicycle

# %%
check_cifar100_dataloader(test_dl)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# bed
