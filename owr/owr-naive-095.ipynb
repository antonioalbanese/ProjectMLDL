# %% [markdown]
# <a href="https://colab.research.google.com/github/cosminnedescu/ProjectMLDL/blob/main/owr/owr-naive-095.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Avoid K80
# !nvidia-smi
# Out:
# Mon Jul 12 06:20:36 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8     7W /  75W |      0MiB /  7611MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import random

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
from torch.autograd import Variable

import torchvision
from torchvision import transforms, datasets, models
from torch.utils.data import Subset, DataLoader

from PIL import Image

import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
from copy import copy
from copy import deepcopy

# %% [markdown]
# #### Cloning the Git repository

# %%
# !rm -rf ProjectMLDL
if not os.path.isdir('/content/ProjectMLDL'):
  # !git clone https://github.com/cosminnedescu/ProjectMLDL.git
  # %cd /content/ProjectMLDL
  # !rm -rf LICENSE README.md
# Out:
# Cloning into 'ProjectMLDL'...
# remote: Enumerating objects: 3046, done.
# remote: Counting objects: 100% (462/462), done.
# remote: Compressing objects: 100% (234/234), done.
# remote: Total 3046 (delta 266), reused 397 (delta 222), pack-reused 2584
# Receiving objects: 100% (3046/3046), 160.18 MiB | 36.32 MiB/s, done.
# Resolving deltas: 100% (1651/1651), done.
# Checking out files: 100% (321/321), done.
# /content/ProjectMLDL

# %%
from data.cifar100 import CIFAR100
from model.resnet32_modified import resnet32
import data.utils
from model.OWR import owrIncremental

# %%
# True mean and std of Cifar100 dataset (src="https://gist.github.com/weiaicunzai/e623931921efefd4c331622c344d8151")
mean = [0.5071, 0.4867, 0.4408]
std = [0.2675, 0.2565, 0.2761]

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])
test_transform = transforms.Compose(
    [transforms.ToTensor(), 
     transforms.Normalize(mean, std),
     ])

# %% [markdown]
# ## Incremental Classifier and Representation Learning

# %% [markdown]
# ### Defining hyperparameters according to iCarl paper

# %%
# Settings
DEVICE = 'cuda'
NUM_CLASSES = 100         # Total number of classes
VAL_SIZE = 0.2            # Proportion of validation set with respect to training set (between 0 and 1)

# Training
BATCH_SIZE = 128          # Batch size
LR = 1                    # Initial learning rate
                       
MOMENTUM = 0.9            # Momentum for stochastic gradient descent (SGD)
WEIGHT_DECAY = 1e-5       # Weight decay from iCaRL

RANDOM_SEED = [20,24,66]  # Random seeds defining the runs of every method
                          # Note: this should be at least 3 to have a fair benchmark

NUM_EPOCHS = 70           # Total number of training epochs
MILESTONES = [43, 63]     # Step down policy from iCaRL (MultiStepLR)
                          # Decrease the learning rate by gamma at each milestone
GAMMA = 0.2               # Gamma factor from iCaRL (1/5)

HERDING = False           # True to perform prioritized selection, False to perform random selection
CLASSIFY = True           # True to use mean-of-exemplar classifier, False to use network's output directly for classification

REJECTION_THRESHOLD = 0.95
TESTING_MODE = 'harmonic' #open, closed, harmonic

# %%
def do_group_classes(run):

  train_subset = [[] for i in range(10)]
  train_dataloader = [[] for i in range(10)]
  val_dataloader = [[] for i in range(10)]
  test_dataloader = [[] for i in range(10)]

  for i in range(10):
    train_data = CIFAR100("dataset", 
                          train=True, 
                          transform=train_transform, 
                          download=(run+i==0),
                          random_state=RANDOM_SEED[run])
    test_data = CIFAR100("dataset", 
                         train=False, 
                         transform=test_transform, 
                         download=False,
                         random_state=RANDOM_SEED[run])
    
    train_data.set_index_map(train_data.splits[i])
    test_data.set_index_map([test_data.splits[j] for j in range(0, i+1)])
    
    train_indices, val_indices = train_data.train_val_split(VAL_SIZE, RANDOM_SEED[run])
    
    train_subset[i] = copy(Subset(train_data, train_indices))
    val_subset = Subset(train_data, val_indices)

    tmp_dl = DataLoader(val_subset,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    val_dataloader[i] = copy(tmp_dl)

    tmp_dl = DataLoader(test_data,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    test_dataloader[i] = copy(tmp_dl)

  return train_dataloader, val_dataloader, test_dataloader, train_subset

# %% [markdown]
# ### Going on with the model
# This is the main iCaRL step.
#
# This step is run 3 times with different `RANDOM_SEED`.
# Here the model is instantiated, trained and tested.
#
# Results and some statistics are then stored in the variable `logs`.

# %%
logs = [[] for i in range(len(RANDOM_SEED))]
best_net_tot_classes = [None for i in range(len(RANDOM_SEED))]

for run in range(len(RANDOM_SEED)):
  print("#################################")
  print(f"Radom seed: {RANDOM_SEED[run]}")
  print("")

  # get data_subsets separated in incremental groups of 10 classes
  train_dl, val_dl, test_dl, train_set = do_group_classes(run)

  #create the resnet
  net = resnet32()
  
  trainer = owrIncremental(DEVICE,
                  net,
                  LR,
                  MOMENTUM,
                  WEIGHT_DECAY,
                  MILESTONES,
                  GAMMA,
                  train_dl,
                  val_dl,
                  test_dl,
                  BATCH_SIZE,
                  train_set,
                  train_transform,
                  test_transform,
                  TESTING_MODE,
                  REJECTION_THRESHOLD) 

  #train and evaluate the model
  logs[run] = trainer.train_model(NUM_EPOCHS)

  best_net_tot_classes[run] = deepcopy(trainer.best_net)

  print("#################################")
  print("")
  print("")
# Out:
# #################################
# Radom seed: 20
#
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Length of exemplars set: 0
# Epoch 1/70 LR: [1]
# Validation accuracy on group 1/5: 0.20
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 1/5: 0.24
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 1/5: 0.29
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 1/5: 0.27
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 1/5: 0.47
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 1/5: 0.51
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 1/5: 0.44
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 1/5: 0.38
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 1/5: 0.54
# Best model updated
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 1/5: 0.51
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 1/5: 0.39
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 1/5: 0.59
# Best model updated
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 1/5: 0.63
# Best model updated
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 1/5: 0.54
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 1/5: 0.54
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 1/5: 0.63
# Best model updated
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 1/5: 0.64
# Best model updated
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 1/5: 0.62
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 1/5: 0.67
# Best model updated
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 1/5: 0.71
# Best model updated
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 1/5: 0.66
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 1/5: 0.69
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 1/5: 0.61
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 1/5: 0.71
# Best model updated
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 1/5: 0.72
# Best model updated
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 1/5: 0.67
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 1/5: 0.70
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 1/5: 0.78
# Best model updated
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 1/5: 0.74
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 1/5: 0.77
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 1/5: 0.68
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 1/5: 0.71
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 1/5: 0.78
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 1/5: 0.73
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 1/5: 0.75
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 1/5: 0.81
# Best model updated
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 1/5: 0.79
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 1/5: 0.76
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 1/5: 0.82
# Best model updated
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 1/5: 0.74
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 1/5: 0.83
# Best model updated
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 1/5: 0.74
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 1/5: 0.83
# Best model updated
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.85
# Best model updated
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.88
# Best model updated
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.87
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.86
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.86
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.88
# Best model updated
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.87
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.86
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.88
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.89
# Best model updated
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.87
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.87
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.85
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.86
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.88
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.87
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.85
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.87
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.88
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.87
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/5: 0.88
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/5: 0.88
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/5: 0.88
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/5: 0.89
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/5: 0.88
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/5: 0.88
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/5: 0.89
# Best model updated
#
# Group 1 Finished!
# Best accuracy found at epoch 70: 0.89
# Target number of exemplars: 200
# Randomly extracting exemplars from class 0 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 200 exemplars.
# Testing on both open and closed world, harmonic mean acc: 0.48
#
# =============================================
#
# Length of exemplars set: 2000
# Epoch 1/70 LR: [1]
# Validation accuracy on group 2/5: 0.06
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 2/5: 0.11
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 2/5: 0.22
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 2/5: 0.29
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 2/5: 0.24
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 2/5: 0.28
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 2/5: 0.33
# Best model updated
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 2/5: 0.36
# Best model updated
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 2/5: 0.38
# Best model updated
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 2/5: 0.35
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 2/5: 0.41
# Best model updated
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 2/5: 0.45
# Best model updated
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 2/5: 0.41
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 2/5: 0.42
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 2/5: 0.47
# Best model updated
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 2/5: 0.43
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 2/5: 0.44
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 2/5: 0.47
# Best model updated
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 2/5: 0.49
# Best model updated
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 2/5: 0.47
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 2/5: 0.51
# Best model updated
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 2/5: 0.49
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 2/5: 0.53
# Best model updated
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 2/5: 0.56
# Best model updated
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 2/5: 0.48
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 2/5: 0.49
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 2/5: 0.53
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 2/5: 0.53
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 2/5: 0.49
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 2/5: 0.53
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 2/5: 0.56
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 2/5: 0.58
# Best model updated
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 2/5: 0.53
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 2/5: 0.49
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 2/5: 0.49
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 2/5: 0.56
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 2/5: 0.50
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 2/5: 0.55
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 2/5: 0.52
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 2/5: 0.63
# Best model updated
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 2/5: 0.58
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 2/5: 0.54
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 2/5: 0.56
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.60
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.62
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.65
# Best model updated
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.64
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.62
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.60
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.60
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.65
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.60
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.61
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.61
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.62
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.62
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.63
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.61
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.63
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.61
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.62
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.62
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.61
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/5: 0.61
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/5: 0.64
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/5: 0.63
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/5: 0.62
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/5: 0.62
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/5: 0.65
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/5: 0.64
#
# Group 2 Finished!
# Best accuracy found at epoch 46: 0.65
# Target number of exemplars: 100
# Randomly extracting exemplars from class 0 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 100 exemplars.
# Testing on both open and closed world, harmonic mean acc: 0.57
#
# =============================================
#
# Length of exemplars set: 2000
# Epoch 1/70 LR: [1]
# Validation accuracy on group 3/5: 0.07
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 3/5: 0.16
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 3/5: 0.20
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 3/5: 0.25
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 3/5: 0.30
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 3/5: 0.28
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 3/5: 0.30
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 3/5: 0.39
# Best model updated
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 3/5: 0.34
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 3/5: 0.29
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 3/5: 0.36
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 3/5: 0.41
# Best model updated
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 3/5: 0.43
# Best model updated
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 3/5: 0.46
# Best model updated
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 3/5: 0.43
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 3/5: 0.39
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 3/5: 0.44
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 3/5: 0.49
# Best model updated
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 3/5: 0.42
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 3/5: 0.45
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 3/5: 0.54
# Best model updated
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 3/5: 0.47
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 3/5: 0.48
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 3/5: 0.52
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 3/5: 0.49
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 3/5: 0.48
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 3/5: 0.51
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 3/5: 0.50
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 3/5: 0.52
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 3/5: 0.53
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 3/5: 0.51
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 3/5: 0.52
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 3/5: 0.53
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 3/5: 0.54
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 3/5: 0.52
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 3/5: 0.53
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 3/5: 0.56
# Best model updated
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 3/5: 0.54
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 3/5: 0.49
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 3/5: 0.52
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 3/5: 0.53
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 3/5: 0.53
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 3/5: 0.54
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.59
# Best model updated
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.59
# Best model updated
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.59
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.59
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.61
# Best model updated
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.59
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.57
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.58
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.58
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.59
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.61
# Best model updated
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.61
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.59
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.62
# Best model updated
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.62
# Best model updated
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.62
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.61
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.61
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.61
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.61
#
# Group 3 Finished!
# Best accuracy found at epoch 62: 0.62
# Target number of exemplars: 66
# Randomly extracting exemplars from class 0 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 66 exemplars.
# Testing on both open and closed world, harmonic mean acc: 0.53
#
# =============================================
#
# Length of exemplars set: 1980
# Epoch 1/70 LR: [1]
# Validation accuracy on group 4/5: 0.11
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 4/5: 0.16
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 4/5: 0.18
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 4/5: 0.20
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 4/5: 0.24
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 4/5: 0.27
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 4/5: 0.27
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 4/5: 0.31
# Best model updated
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 4/5: 0.28
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 4/5: 0.29
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 4/5: 0.35
# Best model updated
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 4/5: 0.33
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 4/5: 0.35
# Best model updated
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 4/5: 0.38
# Best model updated
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 4/5: 0.38
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 4/5: 0.37
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 4/5: 0.38
# Best model updated
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 4/5: 0.40
# Best model updated
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 4/5: 0.42
# Best model updated
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 4/5: 0.41
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 4/5: 0.43
# Best model updated
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 4/5: 0.41
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 4/5: 0.40
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 4/5: 0.45
# Best model updated
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 4/5: 0.42
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 4/5: 0.42
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 4/5: 0.45
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 4/5: 0.45
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 4/5: 0.46
# Best model updated
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 4/5: 0.50
# Best model updated
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 4/5: 0.43
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 4/5: 0.46
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 4/5: 0.45
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 4/5: 0.48
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 4/5: 0.45
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 4/5: 0.47
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 4/5: 0.48
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 4/5: 0.49
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 4/5: 0.48
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 4/5: 0.46
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 4/5: 0.46
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 4/5: 0.51
# Best model updated
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 4/5: 0.49
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.53
# Best model updated
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.54
# Best model updated
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.50
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.51
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.51
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.54
# Best model updated
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.55
# Best model updated
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.52
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.52
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.54
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.55
# Best model updated
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.54
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.53
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.54
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.54
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.53
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.55
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.54
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.54
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.52
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/5: 0.56
# Best model updated
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/5: 0.53
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/5: 0.52
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/5: 0.54
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/5: 0.54
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/5: 0.57
# Best model updated
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/5: 0.54
#
# Group 4 Finished!
# Best accuracy found at epoch 69: 0.57
# Target number of exemplars: 50
# Randomly extracting exemplars from class 0 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 50 exemplars.
# Testing on both open and closed world, harmonic mean acc: 0.47
#
# =============================================
#
# Length of exemplars set: 2000
# Epoch 1/70 LR: [1]
# Validation accuracy on group 5/5: 0.24
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 5/5: 0.28
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 5/5: 0.30
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 5/5: 0.33
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 5/5: 0.33
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 5/5: 0.35
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 5/5: 0.34
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 5/5: 0.43
# Best model updated
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 5/5: 0.41
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 5/5: 0.41
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 5/5: 0.40
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 5/5: 0.41
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 5/5: 0.44
# Best model updated
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 5/5: 0.44
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 5/5: 0.48
# Best model updated
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 5/5: 0.49
# Best model updated
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 5/5: 0.45
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 5/5: 0.45
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 5/5: 0.48
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 5/5: 0.51
# Best model updated
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 5/5: 0.48
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 5/5: 0.53
# Best model updated
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 5/5: 0.55
# Best model updated
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 5/5: 0.53
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 5/5: 0.56
# Best model updated
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 5/5: 0.50
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 5/5: 0.55
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 5/5: 0.49
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 5/5: 0.52
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 5/5: 0.55
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 5/5: 0.53
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 5/5: 0.52
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 5/5: 0.55
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 5/5: 0.56
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 5/5: 0.54
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 5/5: 0.55
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 5/5: 0.58
# Best model updated
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 5/5: 0.59
# Best model updated
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 5/5: 0.60
# Best model updated
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 5/5: 0.51
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 5/5: 0.59
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 5/5: 0.55
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 5/5: 0.59
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.61
# Best model updated
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.59
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.61
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.60
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.60
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.62
# Best model updated
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.63
# Best model updated
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.60
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.61
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.58
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.61
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.61
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.61
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.60
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.60
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.59
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.61
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.61
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.60
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.62
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/5: 0.63
# Best model updated
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/5: 0.62
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/5: 0.62
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/5: 0.60
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/5: 0.59
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/5: 0.62
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/5: 0.63
#
# Group 5 Finished!
# Best accuracy found at epoch 64: 0.63
# Target number of exemplars: 40
# Randomly extracting exemplars from class 0 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 40 exemplars.
# Testing on both open and closed world, harmonic mean acc: 0.41
#
# =============================================
#
# #################################
#
#
# #################################
# Radom seed: 24
#
# Length of exemplars set: 0
# Epoch 1/70 LR: [1]
# Validation accuracy on group 1/5: 0.16
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 1/5: 0.22
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 1/5: 0.25
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 1/5: 0.33
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 1/5: 0.31
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 1/5: 0.45
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 1/5: 0.43
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 1/5: 0.43
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 1/5: 0.41
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 1/5: 0.55
# Best model updated
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 1/5: 0.41
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 1/5: 0.64
# Best model updated
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 1/5: 0.60
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 1/5: 0.61
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 1/5: 0.64
# Best model updated
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 1/5: 0.62
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 1/5: 0.72
# Best model updated
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 1/5: 0.72
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 1/5: 0.58
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 1/5: 0.65
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 1/5: 0.74
# Best model updated
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 1/5: 0.64
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 1/5: 0.71
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 1/5: 0.69
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 1/5: 0.64
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 1/5: 0.75
# Best model updated
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 1/5: 0.66
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 1/5: 0.68
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 1/5: 0.77
# Best model updated
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 1/5: 0.72
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 1/5: 0.71
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 1/5: 0.76
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 1/5: 0.74
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 1/5: 0.69
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 1/5: 0.75
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 1/5: 0.75
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 1/5: 0.70
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 1/5: 0.79
# Best model updated
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 1/5: 0.75
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 1/5: 0.79
# Best model updated
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 1/5: 0.80
# Best model updated
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 1/5: 0.77
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 1/5: 0.68
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.85
# Best model updated
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.84
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.84
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.88
# Best model updated
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.87
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.86
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.86
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.85
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.87
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.88
# Best model updated
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.86
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.86
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.84
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.86
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.86
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.84
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.86
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.86
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.85
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 1/5: 0.85
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/5: 0.87
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/5: 0.86
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/5: 0.86
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/5: 0.88
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/5: 0.88
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/5: 0.86
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 1/5: 0.86
#
# Group 1 Finished!
# Best accuracy found at epoch 53: 0.88
# Target number of exemplars: 200
# Randomly extracting exemplars from class 0 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 200 exemplars.
# Testing on both open and closed world, harmonic mean acc: 0.52
#
# =============================================
#
# Length of exemplars set: 2000
# Epoch 1/70 LR: [1]
# Validation accuracy on group 2/5: 0.13
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 2/5: 0.25
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 2/5: 0.31
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 2/5: 0.36
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 2/5: 0.33
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 2/5: 0.41
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 2/5: 0.37
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 2/5: 0.38
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 2/5: 0.41
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 2/5: 0.43
# Best model updated
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 2/5: 0.52
# Best model updated
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 2/5: 0.44
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 2/5: 0.52
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 2/5: 0.46
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 2/5: 0.56
# Best model updated
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 2/5: 0.49
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 2/5: 0.56
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 2/5: 0.58
# Best model updated
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 2/5: 0.53
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 2/5: 0.56
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 2/5: 0.56
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 2/5: 0.56
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 2/5: 0.53
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 2/5: 0.56
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 2/5: 0.57
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 2/5: 0.61
# Best model updated
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 2/5: 0.57
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 2/5: 0.58
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 2/5: 0.55
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 2/5: 0.63
# Best model updated
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 2/5: 0.61
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 2/5: 0.63
# Best model updated
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 2/5: 0.58
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 2/5: 0.64
# Best model updated
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 2/5: 0.55
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 2/5: 0.58
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 2/5: 0.60
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 2/5: 0.56
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 2/5: 0.65
# Best model updated
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 2/5: 0.64
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 2/5: 0.60
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 2/5: 0.65
# Best model updated
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 2/5: 0.64
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.68
# Best model updated
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.66
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.68
# Best model updated
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.68
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.68
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.69
# Best model updated
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.68
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.72
# Best model updated
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.68
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.68
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.68
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.68
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.69
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.67
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.70
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.68
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.68
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.67
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.70
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 2/5: 0.68
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/5: 0.70
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/5: 0.71
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/5: 0.69
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/5: 0.70
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/5: 0.69
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/5: 0.69
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 2/5: 0.69
#
# Group 2 Finished!
# Best accuracy found at epoch 51: 0.72
# Target number of exemplars: 100
# Randomly extracting exemplars from class 0 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 100 exemplars.
# Testing on both open and closed world, harmonic mean acc: 0.57
#
# =============================================
#
# Length of exemplars set: 2000
# Epoch 1/70 LR: [1]
# Validation accuracy on group 3/5: 0.06
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 3/5: 0.15
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 3/5: 0.21
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 3/5: 0.26
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 3/5: 0.29
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 3/5: 0.32
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 3/5: 0.36
# Best model updated
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 3/5: 0.32
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 3/5: 0.38
# Best model updated
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 3/5: 0.39
# Best model updated
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 3/5: 0.39
# Best model updated
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 3/5: 0.39
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 3/5: 0.48
# Best model updated
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 3/5: 0.40
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 3/5: 0.45
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 3/5: 0.48
# Best model updated
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 3/5: 0.46
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 3/5: 0.44
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 3/5: 0.49
# Best model updated
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 3/5: 0.53
# Best model updated
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 3/5: 0.49
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 3/5: 0.45
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 3/5: 0.53
# Best model updated
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 3/5: 0.50
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 3/5: 0.51
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 3/5: 0.52
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 3/5: 0.52
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 3/5: 0.55
# Best model updated
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 3/5: 0.53
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 3/5: 0.55
# Best model updated
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 3/5: 0.52
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 3/5: 0.57
# Best model updated
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 3/5: 0.50
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 3/5: 0.57
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 3/5: 0.56
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 3/5: 0.55
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 3/5: 0.53
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 3/5: 0.58
# Best model updated
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 3/5: 0.57
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 3/5: 0.60
# Best model updated
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 3/5: 0.57
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 3/5: 0.55
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 3/5: 0.59
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.62
# Best model updated
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.61
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.61
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.62
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.62
# Best model updated
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.59
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.61
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.61
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.62
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.62
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.62
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.61
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.63
# Best model updated
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.59
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.62
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.61
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.62
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.61
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.62
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.62
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.61
#
# Group 3 Finished!
# Best accuracy found at epoch 62: 0.63
# Target number of exemplars: 66
# Randomly extracting exemplars from class 0 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 66 exemplars.
# Testing on both open and closed world, harmonic mean acc: 0.54
#
# =============================================
#
# Length of exemplars set: 1980
# Epoch 1/70 LR: [1]
# Validation accuracy on group 4/5: 0.09
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 4/5: 0.17
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 4/5: 0.22
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 4/5: 0.25
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 4/5: 0.28
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 4/5: 0.28
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 4/5: 0.32
# ...
# Best model updated
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 3/5: 0.52
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 3/5: 0.51
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 3/5: 0.55
# Best model updated
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 3/5: 0.50
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 3/5: 0.54
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 3/5: 0.53
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 3/5: 0.53
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 3/5: 0.48
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 3/5: 0.55
# Best model updated
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 3/5: 0.55
# Best model updated
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 3/5: 0.56
# Best model updated
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 3/5: 0.54
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 3/5: 0.51
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 3/5: 0.56
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 3/5: 0.53
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 3/5: 0.56
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 3/5: 0.54
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 3/5: 0.53
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.61
# Best model updated
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.59
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.58
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.57
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.59
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.61
# Best model updated
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.59
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.62
# Best model updated
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.59
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.58
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.62
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.59
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.59
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.58
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.63
# Best model updated
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.59
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.59
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.60
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.61
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 3/5: 0.59
#
# Group 3 Finished!
# Best accuracy found at epoch 62: 0.63
# Target number of exemplars: 66
# Randomly extracting exemplars from class 0 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 66 exemplars.
# Testing on both open and closed world, harmonic mean acc: 0.52
#
# =============================================
#
# Length of exemplars set: 1980
# Epoch 1/70 LR: [1]
# Validation accuracy on group 4/5: 0.05
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 4/5: 0.13
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 4/5: 0.16
# Best model updated
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 4/5: 0.20
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 4/5: 0.16
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 4/5: 0.22
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 4/5: 0.19
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 4/5: 0.22
# Best model updated
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 4/5: 0.27
# Best model updated
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 4/5: 0.22
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 4/5: 0.29
# Best model updated
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 4/5: 0.29
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 4/5: 0.31
# Best model updated
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 4/5: 0.30
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 4/5: 0.28
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 4/5: 0.32
# Best model updated
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 4/5: 0.33
# Best model updated
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 4/5: 0.36
# Best model updated
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 4/5: 0.34
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 4/5: 0.38
# Best model updated
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 4/5: 0.38
# Best model updated
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 4/5: 0.38
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 4/5: 0.41
# Best model updated
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 4/5: 0.37
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 4/5: 0.36
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 4/5: 0.39
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 4/5: 0.39
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 4/5: 0.42
# Best model updated
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 4/5: 0.41
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 4/5: 0.40
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 4/5: 0.46
# Best model updated
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 4/5: 0.45
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 4/5: 0.46
# Best model updated
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 4/5: 0.47
# Best model updated
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 4/5: 0.42
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 4/5: 0.44
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 4/5: 0.49
# Best model updated
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 4/5: 0.41
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 4/5: 0.51
# Best model updated
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 4/5: 0.44
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 4/5: 0.47
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 4/5: 0.48
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 4/5: 0.44
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.48
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.47
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.47
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.52
# Best model updated
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.50
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.47
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.51
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.49
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.50
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.50
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.49
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.48
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.51
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.50
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.49
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.50
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.50
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.51
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.48
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 4/5: 0.51
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/5: 0.49
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/5: 0.51
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/5: 0.52
# Best model updated
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/5: 0.49
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/5: 0.50
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/5: 0.51
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 4/5: 0.50
#
# Group 4 Finished!
# Best accuracy found at epoch 66: 0.52
# Target number of exemplars: 50
# Randomly extracting exemplars from class 0 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 50 exemplars.
# Testing on both open and closed world, harmonic mean acc: 0.47
#
# =============================================
#
# Length of exemplars set: 2000
# Epoch 1/70 LR: [1]
# Validation accuracy on group 5/5: 0.12
# Best model updated
#
# Epoch 2/70 LR: [1]
# Validation accuracy on group 5/5: 0.22
# Best model updated
#
# Epoch 3/70 LR: [1]
# Validation accuracy on group 5/5: 0.20
#
# Epoch 4/70 LR: [1]
# Validation accuracy on group 5/5: 0.24
# Best model updated
#
# Epoch 5/70 LR: [1]
# Validation accuracy on group 5/5: 0.28
# Best model updated
#
# Epoch 6/70 LR: [1]
# Validation accuracy on group 5/5: 0.30
# Best model updated
#
# Epoch 7/70 LR: [1]
# Validation accuracy on group 5/5: 0.31
# Best model updated
#
# Epoch 8/70 LR: [1]
# Validation accuracy on group 5/5: 0.34
# Best model updated
#
# Epoch 9/70 LR: [1]
# Validation accuracy on group 5/5: 0.30
#
# Epoch 10/70 LR: [1]
# Validation accuracy on group 5/5: 0.36
# Best model updated
#
# Epoch 11/70 LR: [1]
# Validation accuracy on group 5/5: 0.36
# Best model updated
#
# Epoch 12/70 LR: [1]
# Validation accuracy on group 5/5: 0.38
# Best model updated
#
# Epoch 13/70 LR: [1]
# Validation accuracy on group 5/5: 0.41
# Best model updated
#
# Epoch 14/70 LR: [1]
# Validation accuracy on group 5/5: 0.39
#
# Epoch 15/70 LR: [1]
# Validation accuracy on group 5/5: 0.40
#
# Epoch 16/70 LR: [1]
# Validation accuracy on group 5/5: 0.42
# Best model updated
#
# Epoch 17/70 LR: [1]
# Validation accuracy on group 5/5: 0.43
# Best model updated
#
# Epoch 18/70 LR: [1]
# Validation accuracy on group 5/5: 0.39
#
# Epoch 19/70 LR: [1]
# Validation accuracy on group 5/5: 0.48
# Best model updated
#
# Epoch 20/70 LR: [1]
# Validation accuracy on group 5/5: 0.45
#
# Epoch 21/70 LR: [1]
# Validation accuracy on group 5/5: 0.44
#
# Epoch 22/70 LR: [1]
# Validation accuracy on group 5/5: 0.43
#
# Epoch 23/70 LR: [1]
# Validation accuracy on group 5/5: 0.50
# Best model updated
#
# Epoch 24/70 LR: [1]
# Validation accuracy on group 5/5: 0.45
#
# Epoch 25/70 LR: [1]
# Validation accuracy on group 5/5: 0.47
#
# Epoch 26/70 LR: [1]
# Validation accuracy on group 5/5: 0.49
#
# Epoch 27/70 LR: [1]
# Validation accuracy on group 5/5: 0.45
#
# Epoch 28/70 LR: [1]
# Validation accuracy on group 5/5: 0.51
# Best model updated
#
# Epoch 29/70 LR: [1]
# Validation accuracy on group 5/5: 0.52
# Best model updated
#
# Epoch 30/70 LR: [1]
# Validation accuracy on group 5/5: 0.50
#
# Epoch 31/70 LR: [1]
# Validation accuracy on group 5/5: 0.50
#
# Epoch 32/70 LR: [1]
# Validation accuracy on group 5/5: 0.47
#
# Epoch 33/70 LR: [1]
# Validation accuracy on group 5/5: 0.52
# Best model updated
#
# Epoch 34/70 LR: [1]
# Validation accuracy on group 5/5: 0.50
#
# Epoch 35/70 LR: [1]
# Validation accuracy on group 5/5: 0.48
#
# Epoch 36/70 LR: [1]
# Validation accuracy on group 5/5: 0.49
#
# Epoch 37/70 LR: [1]
# Validation accuracy on group 5/5: 0.51
#
# Epoch 38/70 LR: [1]
# Validation accuracy on group 5/5: 0.53
# Best model updated
#
# Epoch 39/70 LR: [1]
# Validation accuracy on group 5/5: 0.51
#
# Epoch 40/70 LR: [1]
# Validation accuracy on group 5/5: 0.48
#
# Epoch 41/70 LR: [1]
# Validation accuracy on group 5/5: 0.48
#
# Epoch 42/70 LR: [1]
# Validation accuracy on group 5/5: 0.54
# Best model updated
#
# Epoch 43/70 LR: [1]
# Validation accuracy on group 5/5: 0.49
#
# Epoch 44/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.54
# Best model updated
#
# Epoch 45/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.55
# Best model updated
#
# Epoch 46/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.52
#
# Epoch 47/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.56
# Best model updated
#
# Epoch 48/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.54
#
# Epoch 49/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.56
#
# Epoch 50/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.55
#
# Epoch 51/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.54
#
# Epoch 52/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.53
#
# Epoch 53/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.57
# Best model updated
#
# Epoch 54/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.54
#
# Epoch 55/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.53
#
# Epoch 56/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.56
#
# Epoch 57/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.54
#
# Epoch 58/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.54
#
# Epoch 59/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.56
#
# Epoch 60/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.57
# Best model updated
#
# Epoch 61/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.55
#
# Epoch 62/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.55
#
# Epoch 63/70 LR: [0.2]
# Validation accuracy on group 5/5: 0.54
#
# Epoch 64/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/5: 0.56
#
# Epoch 65/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/5: 0.57
# Best model updated
#
# Epoch 66/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/5: 0.54
#
# Epoch 67/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/5: 0.57
#
# Epoch 68/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/5: 0.55
#
# Epoch 69/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/5: 0.54
#
# Epoch 70/70 LR: [0.04000000000000001]
# Validation accuracy on group 5/5: 0.55
#
# Group 5 Finished!
# Best accuracy found at epoch 65: 0.57
# Target number of exemplars: 40
# Randomly extracting exemplars from class 0 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 40 exemplars.
# Testing on both open and closed world, harmonic mean acc: 0.40
#
# =============================================
#
# #################################

# %% [markdown]
# ### Store logs in more usable dtype

# %%
train_loss = [[logs[run_i]['group_train_loss'][i] for i in range(5)] for run_i in range(len(RANDOM_SEED))]
train_accuracy = [[logs[run_i]['group_train_accuracies'][i] for i in range(5)] for run_i in range(len(RANDOM_SEED))]
val_loss = [[logs[run_i]['val_losses'][i] for i in range(5)] for run_i in range(len(RANDOM_SEED))]
val_accuracy = [[logs[run_i]['val_accuracies'][i] for i in range(5)] for run_i in range(len(RANDOM_SEED))]
test_accuracy = [[logs[run_i]['test_accuracies'][i] for i in range(5)] for run_i in range(len(RANDOM_SEED))]
predictions = [logs[run_i]['predictions'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]
true_labels = [logs[run_i]['true_labels'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]

open_values = [[logs[run_i]['open_values'][i] for i in range(5)] for run_i in range(len(RANDOM_SEED))]
closed_values = [[logs[run_i]['closed_values'][i] for i in range(5)] for run_i in range(len(RANDOM_SEED))]

# %% [markdown]
# ### Save the model

# %% [markdown]
# #### Saving logs in JSON files

# %%
import json

with open('states/095_train_loss.json', 'w') as f:
  json.dump(train_loss, f)
f.close
with open('states/095_train_accuracy.json', 'w') as f:
  json.dump(train_accuracy, f)
f.close
with open('states/095_val_loss.json', 'w') as f:
  json.dump(val_loss, f)
f.close  
with open('states/095_val_accuracy.json', 'w') as f:
  json.dump(val_accuracy, f)
f.close
with open('states/095_test_accuracy.json', 'w') as f:
  json.dump(test_accuracy, f)
f.close
with open('states/095_predictions.json', 'w') as f:
  json.dump(predictions, f)
f.close
with open('states/095_true_labels.json', 'w') as f:
  json.dump(true_labels, f)
f.close
# Out:
# <function TextIOWrapper.close>

# %% [markdown]
# #### Saving best resnet on 100 classes for each seed

# %%
for i in range(len(RANDOM_SEED)):
  torch.save(best_net_tot_classes[i].state_dict(), "states/095_bestnet_seed[{}]".format(RANDOM_SEED[i]))

# %% [markdown]
# ### Print some graphs

# %%
from data.utils_plot import plot_train_val, plot_test_accuracies, plot_confusion_matrix

# %%
train_loss = np.array(train_loss)
train_accuracy = np.array(train_accuracy)
val_loss = np.array(val_loss)
val_accuracy = np.array(val_accuracy)
test_accuracy = np.array(test_accuracy)



train_loss_stats = np.array([train_loss.mean(0), train_loss.std(0)]).transpose()
train_accuracy_stats = np.array([train_accuracy.mean(0), train_accuracy.std(0)]).transpose()
val_loss_stats = np.array([val_loss.mean(0), val_loss.std(0)]).transpose()
val_accuracy_stats = np.array([val_accuracy.mean(0), val_accuracy.std(0)]).transpose()
test_accuracy_stats = np.array([test_accuracy.mean(0), test_accuracy.std(0)]).transpose()


open_values = np.array(open_values)
closed_values = np.array(closed_values)

# %%
threshold = 0.95
print(f"Threshold: {threshold}")
fig, axs = plt.subplots(1,2)
fig.set_size_inches(15, 5)



a,b,c = axs[0].hist(closed_values[0][4].cpu().numpy(), color = 'red', edgecolor = 'black', bins = [0,threshold,1])
below = c[0].get_height()
above = c[1].get_height()
print(f"closed_below:{below}, close_above:{above}")
print(f"closed world rejection rate: {below/(below+above):.2f} (should be 0)")


a,b,c = axs[1].hist(open_values[0][4].cpu().numpy(), color = 'blue', edgecolor = 'black', bins = [0,threshold,1])
below = c[0].get_height()
above = c[1].get_height()
print(f"open_below:{below}, open_above:{above}")
print(f"open world rejection rate: {below/(below+above):.2f} (should be 1)")
# Out:
# Threshold: 0.95
# closed_below:3251.0, close_above:1741.0
# closed world rejection rate: 0.65 (should be 0)
# open_below:28887.0, open_above:10793.0
# open world rejection rate: 0.73 (should be 1)

# %% [markdown]
# #### Train validation loss

# %%
def plot_losses(train_stats, val_stats, loss = bool, save_directory = None):
  train_mean = np.array(train_stats)[:, 0]
  train_std = np.array(train_stats)[:, 1]
  val_mean = np.array(val_stats)[:, 0]
  val_std = np.array(val_stats)[:, 1]
  fig, ax = plt.subplots(figsize = (10, 5), dpi = 100)
  x = np.arange(10,51,10)
  ax.errorbar(x, train_mean, train_std, label = 'Training')
  ax.errorbar(x, val_mean, val_std, label = 'Validation')
  if loss:
    ax.set_title("Training and validation loss")
    ax.set_ylabel("Loss")
  else:
    ax.set_title("Training and validation accuracy")
    ax.set_ylabel("Accuracy")
  ax.set_xlabel("Number of classes")
  plt.tight_layout()
  ax.legend()
  if save_directory != None:
    fig.savefig(save_directory)
  plt.show()

plot_losses(train_loss_stats, val_loss_stats, loss = True)

# %% [markdown]
# #### Train validation accuracy

# %%
def plot_acc(train_stats, val_stats, loss = bool, save_directory = None):
  train_mean = np.array(train_stats)[:, 0]
  train_std = np.array(train_stats)[:, 1]
  val_mean = np.array(val_stats)[:, 0]
  val_std = np.array(val_stats)[:, 1]
  fig, ax = plt.subplots(figsize = (10, 5), dpi = 100)
  x = np.arange(10, 51, 10)
  ax.errorbar(x, train_mean, train_std, label = 'Training')
  ax.errorbar(x, val_mean, val_std, label = 'Validation')
  if loss:
    ax.set_title("Training and validation loss")
    ax.set_ylabel("Loss")
  else:
    ax.set_title("Training and validation accuracy")
    ax.set_ylabel("Accuracy")
  ax.set_xlabel("Number of classes")
  plt.tight_layout()
  ax.legend()
  if save_directory != None:
    fig.savefig(save_directory)
  plt.show()

plot_acc(train_accuracy_stats, val_accuracy_stats, loss = False)

# %% [markdown]
# #### Test accuracy

# %%
def plot_test(stats, save_directory = None):
  mean = np.array(stats)[:, 0]
  std = np.array(stats)[:, 1]
  fig, ax = plt.subplots(figsize = (10, 5), dpi = 100)
  x = np.arange(10, 51, 10)
  ax.errorbar(x, mean, std)
  ax.set_title("Test accuracy")
  ax.set_xlabel("Number of classes")
  ax.set_ylabel("Accuracy")
  plt.tight_layout()
  if save_directory != None:
    fig.savefig(save_directory)
  plt.show()
  
plot_test(test_accuracy_stats)

# %% [markdown]
# #### Confusion Matrix

# %%
for run in range(len(RANDOM_SEED)):
  targets = np.array(true_labels[run])
  preds = np.array(predictions[run])

  plot_confusion_matrix(targets, preds, RANDOM_SEED[run], 't=0.95')
