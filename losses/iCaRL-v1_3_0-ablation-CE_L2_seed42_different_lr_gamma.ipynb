# %% [markdown]
# <a href="https://colab.research.google.com/github/cosminnedescu/ProjectMLDL/blob/main/losses/iCaRL-v1_3_0-ablation-CE_L2_seed42_different_lr_gamma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Avoid K80
# !nvidia-smi
# Out:
# Fri Jul  2 12:45:13 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   69C    P0    31W /  70W |   1782MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
import os
import random

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
from torch.autograd import Variable

import torchvision
from torchvision import transforms, datasets, models
from torch.utils.data import Subset, DataLoader

from PIL import Image

import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
from copy import copy
from copy import deepcopy

# %% [markdown]
# #### Cloning the Git repository

# %%
# !rm -rf ProjectMLDL
if not os.path.isdir('/content/ProjectMLDL'):
  # !git clone https://github.com/cosminnedescu/ProjectMLDL.git
  # %cd /content/ProjectMLDL
  # !rm -rf LICENSE README.md

# %%
from data.cifar100 import CIFAR100
from model.resnet32 import resnet32
import data.utils
from model.icarl_ablation import iCaRL

# %%
# True mean and std of Cifar100 dataset (src="https://gist.github.com/weiaicunzai/e623931921efefd4c331622c344d8151")
mean = [0.5071, 0.4867, 0.4408]
std = [0.2675, 0.2565, 0.2761]

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])
test_transform = transforms.Compose(
    [transforms.ToTensor(), 
     transforms.Normalize(mean, std),
     ])

# %% [markdown]
# ## Incremental Classifier and Representation Learning

# %% [markdown]
# ### Defining hyperparameters according to iCarl paper

# %%
# Settings
DEVICE = 'cuda'
NUM_CLASSES = 100         # Total number of classes
VAL_SIZE = 0.2            # Proportion of validation set with respect to training set (between 0 and 1)

# Training
BATCH_SIZE = 128          # Batch size
LR = 0.3                    # Initial learning rate
                       
MOMENTUM = 0.9            # Momentum for stochastic gradient descent (SGD)
WEIGHT_DECAY = 1e-5       # Weight decay from iCaRL

RANDOM_SEED = [42]  # Random seeds defining the runs of every method
                          # Note: this should be at least 3 to have a fair benchmark

NUM_EPOCHS = 70          # Total number of training epochs
MILESTONES = [49, 63]     # Step down policy from iCaRL (MultiStepLR)
                          # Decrease the learning rate by gamma at each milestone
GAMMA = 0.1               # Gamma factor from iCaRL (1/5)

HERDING = False           # True to perform prioritized selection, False to perform random selection
CLASSIFY = True           # True to use mean-of-exemplar classifier, False to use network's output directly for classification

# %%
def do_group_classes(run):

  train_subset = [[] for i in range(10)]
  train_dataloader = [[] for i in range(10)]
  val_dataloader = [[] for i in range(10)]
  test_dataloader = [[] for i in range(10)]

  for i in range(10):
    train_data = CIFAR100("dataset", 
                          train=True, 
                          transform=train_transform, 
                          download=(run+i==0),
                          random_state=RANDOM_SEED[run])
    test_data = CIFAR100("dataset", 
                         train=False, 
                         transform=test_transform, 
                         download=False,
                         random_state=RANDOM_SEED[run])
    
    train_data.set_index_map(train_data.splits[i])
    test_data.set_index_map([test_data.splits[j] for j in range(0, i+1)])
    
    train_indices, val_indices = train_data.train_val_split(VAL_SIZE, RANDOM_SEED[run])
    
    train_subset[i] = copy(Subset(train_data, train_indices))
    val_subset = Subset(train_data, val_indices)

    tmp_dl = DataLoader(val_subset,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    val_dataloader[i] = copy(tmp_dl)

    tmp_dl = DataLoader(test_data,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    test_dataloader[i] = copy(tmp_dl)

  return train_dataloader, val_dataloader, test_dataloader, train_subset

# %% [markdown]
# ### Going on with the model
# This is the main iCaRL step.
#
# This step is run 3 times with different `RANDOM_SEED`.
# Here the model is instantiated, trained and tested.
#
# Results and some statistics are then stored in the variable `logs`.

# %%
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
logs = [[] for i in range(len(RANDOM_SEED))]
best_net_tot_classes = [None for i in range(len(RANDOM_SEED))]

for run in range(len(RANDOM_SEED)):
  print("#################################")
  print(f"Radom seed: {RANDOM_SEED[run]}")
  print("")

  # get data_subsets separated in incremental groups of 10 classes
  train_dl, val_dl, test_dl, train_set = do_group_classes(run)

  #create the resnet
  net = resnet32()
  
  trainer = iCaRL(DEVICE,
                  net,
                  LR,
                  MOMENTUM,
                  WEIGHT_DECAY,
                  MILESTONES,
                  GAMMA,
                  train_dl,
                  val_dl,
                  test_dl,
                  BATCH_SIZE,
                  train_set,
                  train_transform,
                  test_transform, 2)

  #train and evaluate the model
  logs[run] = trainer.train_model(NUM_EPOCHS, HERDING, CLASSIFY)

  best_net_tot_classes[run] = deepcopy(trainer.best_net)

  print("#################################")
  print("")
  print("")
# Out:
# #################################
# Radom seed: 42
#
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Length of exemplars set: 0
# traing_loss = 2.91029792447244
# Epoch 1/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.18
# Best model updated
#
# traing_loss = 2.1590169629743023
# Epoch 2/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.17
#
# traing_loss = 2.1074691895515687
# Epoch 3/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.19
# Best model updated
#
# traing_loss = 2.0737565063661143
# Epoch 4/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.16
#
# traing_loss = 1.9895802967010006
# Epoch 5/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.23
# Best model updated
#
# traing_loss = 1.9471929611698273
# Epoch 6/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.25
# Best model updated
#
# traing_loss = 1.9238090053681405
# Epoch 7/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.23
#
# traing_loss = 1.87400722119116
# Epoch 8/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.26
# Best model updated
#
# traing_loss = 1.8344395699039582
# Epoch 9/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.27
# Best model updated
#
# traing_loss = 1.7670678246405818
# Epoch 10/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.28
# Best model updated
#
# traing_loss = 1.7386285758787585
# Epoch 11/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.23
#
# traing_loss = 1.7358078149057203
# Epoch 12/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.30
# Best model updated
#
# traing_loss = 1.7257087038409324
# Epoch 13/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.23
#
# traing_loss = 1.7031995519515006
# Epoch 14/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.29
#
# traing_loss = 1.6589182115370227
# Epoch 15/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.29
#
# traing_loss = 1.6373064364156416
# Epoch 16/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.37
# Best model updated
#
# traing_loss = 1.6248905658721924
# Epoch 17/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.34
#
# traing_loss = 1.5980398001209382
# Epoch 18/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.39
# Best model updated
#
# traing_loss = 1.5973142539301226
# Epoch 19/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.35
#
# traing_loss = 1.5741865711827432
# Epoch 20/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.39
# Best model updated
#
# traing_loss = 1.572063930573002
# Epoch 21/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.37
#
# traing_loss = 1.5717275604124992
# Epoch 22/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.36
#
# traing_loss = 1.5487014939708095
# Epoch 23/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.40
# Best model updated
#
# traing_loss = 1.482918212490697
# Epoch 24/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.43
# Best model updated
#
# traing_loss = 1.4713918932022587
# Epoch 25/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.35
#
# traing_loss = 1.4598880006420998
# Epoch 26/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.44
# Best model updated
#
# traing_loss = 1.449061070719073
# Epoch 27/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.41
#
# traing_loss = 1.4047678593666322
# Epoch 28/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.45
# Best model updated
#
# traing_loss = 1.3992983025889243
# Epoch 29/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.44
#
# traing_loss = 1.358917736238049
# Epoch 30/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.47
# Best model updated
#
# traing_loss = 1.3377798372699368
# Epoch 31/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.44
#
# traing_loss = 1.3141669381049372
# Epoch 32/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.50
# Best model updated
#
# traing_loss = 1.3020193461448915
# Epoch 33/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.49
#
# traing_loss = 1.2936297578196372
# Epoch 34/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.47
#
# traing_loss = 1.2853399976607291
# Epoch 35/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.48
#
# traing_loss = 1.2535939447341427
# Epoch 36/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.51
# Best model updated
#
# traing_loss = 1.2402368130222443
# Epoch 37/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.47
#
# traing_loss = 1.2079290536142164
# Epoch 38/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.49
#
# traing_loss = 1.2039238675948112
# Epoch 39/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.47
#
# traing_loss = 1.2122190979219252
# Epoch 40/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.51
# Best model updated
#
# traing_loss = 1.1648765090973145
# Epoch 41/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.52
# Best model updated
#
# traing_loss = 1.1679041750969426
# Epoch 42/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.54
# Best model updated
#
# traing_loss = 1.1486585928547768
# Epoch 43/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.52
#
# traing_loss = 1.1242891357791038
# Epoch 44/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.54
# Best model updated
#
# traing_loss = 1.0963878016318045
# Epoch 45/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.54
#
# traing_loss = 1.0636795951474098
# Epoch 46/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.52
#
# traing_loss = 1.0605130118708457
# Epoch 47/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.50
#
# traing_loss = 1.0632485958837694
# Epoch 48/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.52
#
# traing_loss = 1.055527098717228
# Epoch 49/70 LR: [0.3]
# Validation accuracy on group 1/10: 0.52
#
# traing_loss = 0.9551795644144858
# Epoch 50/70 LR: [0.03]
# Validation accuracy on group 1/10: 0.61
# Best model updated
#
# traing_loss = 0.8655808741046537
# Epoch 51/70 LR: [0.03]
# Validation accuracy on group 1/10: 0.62
# Best model updated
#
# traing_loss = 0.8539263913708348
# Epoch 52/70 LR: [0.03]
# Validation accuracy on group 1/10: 0.61
#
# traing_loss = 0.8338525487530616
# Epoch 53/70 LR: [0.03]
# Validation accuracy on group 1/10: 0.62
# Best model updated
#
# traing_loss = 0.8221394823443505
# Epoch 54/70 LR: [0.03]
# Validation accuracy on group 1/10: 0.61
#
# traing_loss = 0.8158494253312388
# Epoch 55/70 LR: [0.03]
# Validation accuracy on group 1/10: 0.61
#
# traing_loss = 0.8377049046178018
# Epoch 56/70 LR: [0.03]
# Validation accuracy on group 1/10: 0.62
# Best model updated
#
# traing_loss = 0.8106196465030793
# Epoch 57/70 LR: [0.03]
# Validation accuracy on group 1/10: 0.62
#
# traing_loss = 0.8053834611369718
# Epoch 58/70 LR: [0.03]
# Validation accuracy on group 1/10: 0.62
#
# traing_loss = 0.798691616904351
# Epoch 59/70 LR: [0.03]
# Validation accuracy on group 1/10: 0.62
#
# traing_loss = 0.7889713433481031
# Epoch 60/70 LR: [0.03]
# Validation accuracy on group 1/10: 0.63
# Best model updated
#
# traing_loss = 0.7685444604965949
# Epoch 61/70 LR: [0.03]
# Validation accuracy on group 1/10: 0.62
#
# traing_loss = 0.7726576424414112
# Epoch 62/70 LR: [0.03]
# Validation accuracy on group 1/10: 0.62
#
# traing_loss = 0.7661395534392326
# Epoch 63/70 LR: [0.03]
# Validation accuracy on group 1/10: 0.62
#
# traing_loss = 0.7472393570407745
# Epoch 64/70 LR: [0.003]
# Validation accuracy on group 1/10: 0.63
#
# traing_loss = 0.7278033033494027
# Epoch 65/70 LR: [0.003]
# Validation accuracy on group 1/10: 0.62
#
# traing_loss = 0.73301959999146
# Epoch 66/70 LR: [0.003]
# Validation accuracy on group 1/10: 0.64
# Best model updated
#
# traing_loss = 0.7265095403117519
# Epoch 67/70 LR: [0.003]
# Validation accuracy on group 1/10: 0.64
# Best model updated
#
# traing_loss = 0.7433853610869376
# Epoch 68/70 LR: [0.003]
# Validation accuracy on group 1/10: 0.63
#
# traing_loss = 0.7204568309168662
# Epoch 69/70 LR: [0.003]
# Validation accuracy on group 1/10: 0.65
# Best model updated
#
# traing_loss = 0.7228906808360931
# Epoch 70/70 LR: [0.003]
# Validation accuracy on group 1/10: 0.63
#
# Group 1 Finished!
# Best accuracy found at epoch 69: 0.65
# Target number of exemplars: 200
# Randomly extracting exemplars from class 0 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 200 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.57
#
# =============================================
#
# Length of exemplars set: 2000
# traing_loss = 2.4746705345485522
# Epoch 1/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.38
# Best model updated
#
# traing_loss = 2.0542138529860456
# Epoch 2/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.44
# Best model updated
#
# traing_loss = 1.9440629300863848
# Epoch 3/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.47
# Best model updated
#
# traing_loss = 1.8587236015693
# Epoch 4/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.53
# Best model updated
#
# traing_loss = 1.795886208181796
# Epoch 5/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.47
#
# traing_loss = 1.7846498618955198
# Epoch 6/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.54
# Best model updated
#
# traing_loss = 1.7169567787128945
# Epoch 7/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.53
#
# traing_loss = 1.6929539986278699
# Epoch 8/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.54
#
# traing_loss = 1.6873830349549004
# Epoch 9/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.50
#
# traing_loss = 1.6251302205997964
# Epoch 10/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.52
#
# traing_loss = 1.619914453962575
# Epoch 11/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.61
# Best model updated
#
# traing_loss = 1.5908011742260144
# Epoch 12/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.54
#
# traing_loss = 1.554026168325673
# Epoch 13/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.59
#
# traing_loss = 1.5338218911834385
# Epoch 14/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.60
#
# traing_loss = 1.5100973326226939
# Epoch 15/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.51
#
# traing_loss = 1.4913021455640378
# Epoch 16/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.53
#
# traing_loss = 1.4561108920885169
# Epoch 17/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.57
#
# traing_loss = 1.4506122651307478
# Epoch 18/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.57
#
# traing_loss = 1.4274661618730295
# Epoch 19/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.58
#
# traing_loss = 1.4252568431522534
# Epoch 20/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.62
# Best model updated
#
# traing_loss = 1.420767068862915
# Epoch 21/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.59
#
# traing_loss = 1.3754632317501565
# Epoch 22/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.64
# Best model updated
#
# traing_loss = 1.3458577238995095
# Epoch 23/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.63
#
# traing_loss = 1.3378067768138389
# Epoch 24/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.62
#
# traing_loss = 1.3118399277977322
# Epoch 25/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.59
#
# traing_loss = 1.287402813849242
# Epoch 26/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.63
#
# traing_loss = 1.3000664555508157
# Epoch 27/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.58
#
# traing_loss = 1.2661769856577334
# Epoch 28/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.61
#
# traing_loss = 1.2716847295346467
# Epoch 29/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.60
#
# traing_loss = 1.2350080246510713
# Epoch 30/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.57
#
# traing_loss = 1.2258032871329265
# Epoch 31/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.59
#
# traing_loss = 1.2105421864468118
# Epoch 32/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.62
#
# traing_loss = 1.2002441261125647
# Epoch 33/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.63
#
# traing_loss = 1.173844952946124
# Epoch 34/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.63
#
# traing_loss = 1.1591484533703846
# Epoch 35/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.61
#
# traing_loss = 1.1450201687605486
# Epoch 36/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.64
#
# traing_loss = 1.1615776782450469
# Epoch 37/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.63
#
# traing_loss = 1.1242593047411547
# Epoch 38/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.58
#
# traing_loss = 1.098959057227425
# Epoch 39/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.63
#
# traing_loss = 1.09701309385507
# Epoch 40/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.66
# Best model updated
#
# traing_loss = 1.0660864049973695
# Epoch 41/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.65
#
# traing_loss = 1.0501664462296858
# Epoch 42/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.62
#
# traing_loss = 1.0298163242962048
# Epoch 43/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.65
#
# traing_loss = 1.0194103665973828
# Epoch 44/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.62
#
# traing_loss = 1.0107480935428454
# Epoch 45/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.61
#
# traing_loss = 0.9922758314920508
# Epoch 46/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.61
#
# traing_loss = 1.0061427134534586
# Epoch 47/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.64
#
# traing_loss = 0.9635935814484305
# Epoch 48/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.61
#
# traing_loss = 0.9731247943380604
# Epoch 49/70 LR: [0.3]
# Validation accuracy on group 2/10: 0.63
#
# traing_loss = 0.8404871756615846
# Epoch 50/70 LR: [0.03]
# Validation accuracy on group 2/10: 0.67
# Best model updated
#
# traing_loss = 0.7641791493996329
# Epoch 51/70 LR: [0.03]
# Validation accuracy on group 2/10: 0.68
# Best model updated
#
# traing_loss = 0.7430816461210665
# Epoch 52/70 LR: [0.03]
# Validation accuracy on group 2/10: 0.68
# Best model updated
#
# traing_loss = 0.7122335550577744
# Epoch 53/70 LR: [0.03]
# Validation accuracy on group 2/10: 0.68
#
# traing_loss = 0.7125274189140486
# Epoch 54/70 LR: [0.03]
# Validation accuracy on group 2/10: 0.67
#
# traing_loss = 0.6998852620954099
# Epoch 55/70 LR: [0.03]
# Validation accuracy on group 2/10: 0.70
# Best model updated
#
# traing_loss = 0.6852107423803081
# Epoch 56/70 LR: [0.03]
# Validation accuracy on group 2/10: 0.68
#
# traing_loss = 0.6780743274999701
# Epoch 57/70 LR: [0.03]
# Validation accuracy on group 2/10: 0.67
#
# traing_loss = 0.6741734885651133
# Epoch 58/70 LR: [0.03]
# Validation accuracy on group 2/10: 0.68
#
# traing_loss = 0.6652114987373352
# Epoch 59/70 LR: [0.03]
# Validation accuracy on group 2/10: 0.69
#
# traing_loss = 0.6653080984302189
# Epoch 60/70 LR: [0.03]
# Validation accuracy on group 2/10: 0.69
#
# traing_loss = 0.6503300627936488
# Epoch 61/70 LR: [0.03]
# Validation accuracy on group 2/10: 0.67
#
# traing_loss = 0.6502872433351434
# Epoch 62/70 LR: [0.03]
# Validation accuracy on group 2/10: 0.68
#
# traing_loss = 0.6368120753246805
# Epoch 63/70 LR: [0.03]
# Validation accuracy on group 2/10: 0.69
#
# traing_loss = 0.6254364614901335
# Epoch 64/70 LR: [0.003]
# Validation accuracy on group 2/10: 0.69
#
# traing_loss = 0.6204809403937795
# Epoch 65/70 LR: [0.003]
# Validation accuracy on group 2/10: 0.67
#
# traing_loss = 0.6276658423568892
# Epoch 66/70 LR: [0.003]
# Validation accuracy on group 2/10: 0.69
#
# traing_loss = 0.6343511718770732
# Epoch 67/70 LR: [0.003]
# Validation accuracy on group 2/10: 0.68
#
# traing_loss = 0.62188537289267
# Epoch 68/70 LR: [0.003]
# Validation accuracy on group 2/10: 0.69
#
# traing_loss = 0.6265862188909365
# Epoch 69/70 LR: [0.003]
# Validation accuracy on group 2/10: 0.68
#
# traing_loss = 0.6179836366487585
# Epoch 70/70 LR: [0.003]
# Validation accuracy on group 2/10: 0.68
#
# Group 2 Finished!
# Best accuracy found at epoch 55: 0.70
# Target number of exemplars: 100
# Randomly extracting exemplars from class 0 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 100 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.61
#
# =============================================
#
# Length of exemplars set: 2000
# traing_loss = 2.5980293854423193
# Epoch 1/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.49
# Best model updated
#
# traing_loss = 2.1086832647738247
# Epoch 2/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.52
# Best model updated
#
# traing_loss = 1.9707550510116245
# Epoch 3/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.55
# Best model updated
#
# traing_loss = 1.879376971203348
# Epoch 4/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.60
# Best model updated
#
# traing_loss = 1.8002288652502971
# Epoch 5/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.58
#
# traing_loss = 1.764482855796814
# Epoch 6/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.55
#
# traing_loss = 1.71994542038959
# Epoch 7/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.61
# Best model updated
#
# traing_loss = 1.6525850010954815
# Epoch 8/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.56
#
# traing_loss = 1.6075636563093767
# Epoch 9/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.56
#
# traing_loss = 1.5643431492473767
# Epoch 10/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.61
# Best model updated
#
# traing_loss = 1.5343780310257622
# Epoch 11/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.61
# Best model updated
#
# traing_loss = 1.4942389622978542
# Epoch 12/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.60
#
# traing_loss = 1.4506810152012368
# Epoch 13/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.61
#
# traing_loss = 1.4304703085318855
# Epoch 14/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.63
# Best model updated
#
# traing_loss = 1.3841907200605974
# Epoch 15/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.62
#
# traing_loss = 1.3785429752391318
# Epoch 16/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.61
#
# traing_loss = 1.3483348229657048
# Epoch 17/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.56
#
# traing_loss = 1.3534404039382935
# Epoch 18/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.62
#
# traing_loss = 1.2956417280694712
# Epoch 19/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.63
# Best model updated
#
# traing_loss = 1.2611438295115596
# Epoch 20/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.63
#
# traing_loss = 1.2545735499133235
# Epoch 21/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.61
#
# traing_loss = 1.2677245658376943
# Epoch 22/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.65
# Best model updated
#
# traing_loss = 1.1922435747540516
# Epoch 23/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.61
#
# traing_loss = 1.1727479346420453
# Epoch 24/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.61
#
# traing_loss = 1.1302126088868016
# Epoch 25/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.62
#
# traing_loss = 1.1671713616537012
# Epoch 26/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.59
#
# traing_loss = 1.1220103826211847
# Epoch 27/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.57
#
# traing_loss = 1.097564308539681
# Epoch 28/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.62
#
# traing_loss = 1.078761486903481
# Epoch 29/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.64
#
# traing_loss = 1.0780890869057698
# Epoch 30/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.65
# Best model updated
#
# traing_loss = 1.0084302101446234
# Epoch 31/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.59
#
# traing_loss = 1.0185075207896854
# Epoch 32/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 1.0229035227195076
# Epoch 33/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.60
#
# traing_loss = 0.9884158787520035
# Epoch 34/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.59
#
# traing_loss = 0.9698547954144685
# Epoch 35/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.64
#
# traing_loss = 0.9542600382929263
# Epoch 36/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.66
# Best model updated
#
# traing_loss = 0.9501887287782587
# Epoch 37/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 0.9368663248808488
# Epoch 38/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.61
#
# traing_loss = 0.9268508851528168
# Epoch 39/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 0.9220957263656284
# Epoch 40/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.60
#
# traing_loss = 0.9077547348063925
# Epoch 41/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.62
#
# traing_loss = 0.8651822092740432
# Epoch 42/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.61
#
# traing_loss = 0.8522699073604916
# Epoch 43/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.62
#
# traing_loss = 0.8238086143265599
# Epoch 44/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.67
# Best model updated
#
# traing_loss = 0.8492753583451976
# Epoch 45/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.59
#
# traing_loss = 0.8597530968811201
# Epoch 46/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 0.8109131235143413
# Epoch 47/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.63
#
# traing_loss = 0.8166378606920657
# Epoch 48/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.62
#
# traing_loss = 0.7976887886938842
# Epoch 49/70 LR: [0.3]
# Validation accuracy on group 3/10: 0.64
#
# traing_loss = 0.6898974050646243
# Epoch 50/70 LR: [0.03]
# Validation accuracy on group 3/10: 0.69
# Best model updated
#
# traing_loss = 0.6232528207094773
# Epoch 51/70 LR: [0.03]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.5995914482552073
# Epoch 52/70 LR: [0.03]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.5890473490175994
# Epoch 53/70 LR: [0.03]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.5791891800320667
# Epoch 54/70 LR: [0.03]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.5662036551081616
# Epoch 55/70 LR: [0.03]
# Validation accuracy on group 3/10: 0.67
#
# traing_loss = 0.5548653926538385
# Epoch 56/70 LR: [0.03]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.5591272258240244
# Epoch 57/70 LR: [0.03]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.5520797864250515
# Epoch 58/70 LR: [0.03]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.5512637288674064
# Epoch 59/70 LR: [0.03]
# Validation accuracy on group 3/10: 0.67
#
# traing_loss = 0.541089988273123
# Epoch 60/70 LR: [0.03]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.5391437780597935
# Epoch 61/70 LR: [0.03]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.5281782053087068
# Epoch 62/70 LR: [0.03]
# Validation accuracy on group 3/10: 0.67
#
# traing_loss = 0.539087036381597
# Epoch 63/70 LR: [0.03]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.5275154036024342
# Epoch 64/70 LR: [0.003]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.5264625970436179
# Epoch 65/70 LR: [0.003]
# Validation accuracy on group 3/10: 0.67
#
# traing_loss = 0.5331595682579539
# Epoch 66/70 LR: [0.003]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.5247555776782657
# Epoch 67/70 LR: [0.003]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.5279266899046691
# Epoch 68/70 LR: [0.003]
# Validation accuracy on group 3/10: 0.67
#
# traing_loss = 0.5262260974749274
# Epoch 69/70 LR: [0.003]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.5224769167278124
# Epoch 70/70 LR: [0.003]
# Validation accuracy on group 3/10: 0.66
#
# Group 3 Finished!
# Best accuracy found at epoch 50: 0.69
# Target number of exemplars: 66
# Randomly extracting exemplars from class 0 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 66 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.53
#
# =============================================
#
# Length of exemplars set: 1980
# traing_loss = 2.590555939985358
# Epoch 1/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.52
# Best model updated
#
# traing_loss = 1.9149905132210774
# Epoch 2/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.58
# Best model updated
#
# traing_loss = 1.7424837169439897
# Epoch 3/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.63
# Best model updated
#
# traing_loss = 1.6113208014032114
# Epoch 4/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.61
#
# traing_loss = 1.5456478258837825
# Epoch 5/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.60
#
# traing_loss = 1.4644207228784976
# Epoch 6/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.60
#
# traing_loss = 1.4153282227723494
# Epoch 7/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.61
#
# traing_loss = 1.344192253506702
# Epoch 8/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.62
#
# traing_loss = 1.3156599739323491
# Epoch 9/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.61
#
# traing_loss = 1.255978507840115
# Epoch 10/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.64
# Best model updated
#
# traing_loss = 1.240004212959953
# Epoch 11/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.64
#
# traing_loss = 1.1561540533667025
# Epoch 12/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.65
# Best model updated
#
# traing_loss = 1.121395564597586
# Epoch 13/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.59
#
# traing_loss = 1.1086869473042695
# Epoch 14/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.58
#
# traing_loss = 1.0898391604423523
# Epoch 15/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.68
# Best model updated
#
# traing_loss = 1.0503725189229716
# Epoch 16/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.62
#
# traing_loss = 1.0374386880708777
# Epoch 17/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.64
#
# traing_loss = 1.0061435829038206
# Epoch 18/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.60
#
# traing_loss = 0.98496406233829
# Epoch 19/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.64
#
# traing_loss = 0.9758704524973164
# Epoch 20/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.59
#
# traing_loss = 0.9479645633179209
# Epoch 21/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.61
#
# traing_loss = 0.9014532345792522
# Epoch 22/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.63
#
# traing_loss = 0.9422025589839272
# Epoch 23/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.58
#
# traing_loss = 0.9243768842323966
# Epoch 24/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.67
#
# traing_loss = 0.8846252262592316
# Epoch 25/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.64
#
# traing_loss = 0.8249884040459342
# Epoch 26/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.66
#
# traing_loss = 0.8076986242895541
# Epoch 27/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.63
#
# traing_loss = 0.8118797579537267
# Epoch 28/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.63
#
# traing_loss = 0.8176740291325942
# Epoch 29/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.65
#
# traing_loss = 0.8150565365086431
# Epoch 30/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.62
#
# traing_loss = 0.8151929857938186
# Epoch 31/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.64
#
# traing_loss = 0.7630472183227539
# Epoch 32/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.65
#
# traing_loss = 0.7507434396640115
# Epoch 33/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.67
#
# traing_loss = 0.7602006184018176
# Epoch 34/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.66
#
# traing_loss = 0.730870756118194
# Epoch 35/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.69
# Best model updated
#
# traing_loss = 0.7122118706288545
# Epoch 36/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.63
#
# traing_loss = 0.7336363079755203
# Epoch 37/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.65
#
# traing_loss = 0.7155388969442119
# Epoch 38/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.66
#
# traing_loss = 0.6967583052490068
# Epoch 39/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.66
#
# traing_loss = 0.6660617356714995
# Epoch 40/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.66
#
# traing_loss = 0.6609623328499172
# Epoch 41/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.66
#
# traing_loss = 0.6545294588026793
# Epoch 42/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.69
#
# traing_loss = 0.6473990873150204
# Epoch 43/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.61
#
# traing_loss = 0.6560749871575314
# Epoch 44/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.64
#
# traing_loss = 0.6342610276263693
# Epoch 45/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.70
# Best model updated
#
# traing_loss = 0.596527354872745
# Epoch 46/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.65
#
# traing_loss = 0.611544831291489
# Epoch 47/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.64
#
# traing_loss = 0.6213730722665787
# Epoch 48/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.66
#
# traing_loss = 0.6402093230382256
# Epoch 49/70 LR: [0.3]
# Validation accuracy on group 4/10: 0.67
#
# traing_loss = 0.5386350835147111
# Epoch 50/70 LR: [0.03]
# Validation accuracy on group 4/10: 0.72
# Best model updated
#
# traing_loss = 0.48189147399819415
# Epoch 51/70 LR: [0.03]
# Validation accuracy on group 4/10: 0.71
#
# traing_loss = 0.46039318520089856
# Epoch 52/70 LR: [0.03]
# Validation accuracy on group 4/10: 0.71
#
# traing_loss = 0.45707488643086475
# Epoch 53/70 LR: [0.03]
# Validation accuracy on group 4/10: 0.71
#
# traing_loss = 0.44585148277490033
# Epoch 54/70 LR: [0.03]
# Validation accuracy on group 4/10: 0.69
#
# traing_loss = 0.4425979366768961
# Epoch 55/70 LR: [0.03]
# Validation accuracy on group 4/10: 0.70
#
# traing_loss = 0.43232970717160596
# Epoch 56/70 LR: [0.03]
# Validation accuracy on group 4/10: 0.73
# Best model updated
#
# traing_loss = 0.42650385136189667
# Epoch 57/70 LR: [0.03]
# Validation accuracy on group 4/10: 0.72
#
# traing_loss = 0.4275422284136648
# Epoch 58/70 LR: [0.03]
# Validation accuracy on group 4/10: 0.71
#
# traing_loss = 0.42159236578837683
# Epoch 59/70 LR: [0.03]
# Validation accuracy on group 4/10: 0.70
#
# traing_loss = 0.4251770215189975
# Epoch 60/70 LR: [0.03]
# Validation accuracy on group 4/10: 0.71
#
# traing_loss = 0.41979925204878266
# Epoch 61/70 LR: [0.03]
# Validation accuracy on group 4/10: 0.72
#
# traing_loss = 0.4204937627781992
# Epoch 62/70 LR: [0.03]
# Validation accuracy on group 4/10: 0.70
#
# traing_loss = 0.4155962117340254
# Epoch 63/70 LR: [0.03]
# Validation accuracy on group 4/10: 0.73
#
# traing_loss = 0.410675255500752
# Epoch 64/70 LR: [0.003]
# Validation accuracy on group 4/10: 0.72
#
# traing_loss = 0.4112541928239491
# Epoch 65/70 LR: [0.003]
# Validation accuracy on group 4/10: 0.72
#
# traing_loss = 0.40993377112823987
# Epoch 66/70 LR: [0.003]
# Validation accuracy on group 4/10: 0.71
#
# traing_loss = 0.4142186965631402
# Epoch 67/70 LR: [0.003]
# Validation accuracy on group 4/10: 0.72
#
# traing_loss = 0.4064675401086393
# Epoch 68/70 LR: [0.003]
# Validation accuracy on group 4/10: 0.71
#
# traing_loss = 0.4136754378028538
# Epoch 69/70 LR: [0.003]
# Validation accuracy on group 4/10: 0.73
# Best model updated
#
# traing_loss = 0.4140380757010501
# Epoch 70/70 LR: [0.003]
# Validation accuracy on group 4/10: 0.71
#
# Group 4 Finished!
# Best accuracy found at epoch 69: 0.73
# Target number of exemplars: 50
# Randomly extracting exemplars from class 0 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 50 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.47
#
# =============================================
#
# Length of exemplars set: 2000
# traing_loss = 2.520394180131995
# Epoch 1/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.65
# Best model updated
#
# traing_loss = 1.6991233385127524
# Epoch 2/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.71
# Best model updated
#
# traing_loss = 1.5154820680618286
# Epoch 3/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.75
# Best model updated
#
# traing_loss = 1.4214965778848399
# Epoch 4/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 1.3193812551705733
# Epoch 5/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 1.257753849029541
# Epoch 6/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 1.1906632159067236
# Epoch 7/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 1.1533521180567534
# Epoch 8/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.70
#
# traing_loss = 1.1175562739372253
# Epoch 9/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 1.0864487031231755
# Epoch 10/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.76
# Best model updated
#
# traing_loss = 1.0378059032170668
# Epoch 11/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.9972277076348014
# Epoch 12/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.77
# Best model updated
#
# traing_loss = 1.0000484857870184
# Epoch 13/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.9600509884564773
# Epoch 14/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.70
#
# traing_loss = 0.9172224985516589
# Epoch 15/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.8962929391342661
# Epoch 16/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.8761328147805255
# Epoch 17/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.8496226914550947
# Epoch 18/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.8554501455763112
# Epoch 19/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.8170656911704851
# Epoch 20/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.8057597966297813
# Epoch 21/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.7862414614014004
# Epoch 22/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.71
#
# traing_loss = 0.7513625453347745
# Epoch 23/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.71
#
# traing_loss = 0.7456872631674227
# Epoch 24/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.747974552538084
# Epoch 25/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.69
#
# traing_loss = 0.7212684297043345
# Epoch 26/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.709193422742512
# Epoch 27/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.695569783449173
# Epoch 28/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.6695142336513685
# Epoch 29/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.6474000474681025
# Epoch 30/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.68
#
# traing_loss = 0.6565224489440089
# Epoch 31/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.77
#
# traing_loss = 0.6247581204642421
# Epoch 32/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.616706146494202
# Epoch 33/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.75
#
# traing_loss = 0.6034563093081765
# Epoch 34/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.6305206094099127
# Epoch 35/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.5958778184393178
# Epoch 36/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.6035067892592886
# Epoch 37/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.563396376112233
# Epoch 38/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.5539712776308474
# Epoch 39/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.5664599421231643
# Epoch 40/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.72
#
# traing_loss = 0.5626179381557133
# Epoch 41/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.5318081119786138
# Epoch 42/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.75
#
# traing_loss = 0.5564543254997419
# Epoch 43/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.75
#
# traing_loss = 0.5706858155520066
# Epoch 44/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.5472195511278899
# Epoch 45/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.5494804155567418
# Epoch 46/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.5457204366507737
# Epoch 47/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.5254923331996669
# Epoch 48/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.5321117276730745
# Epoch 49/70 LR: [0.3]
# Validation accuracy on group 5/10: 0.74
#
# traing_loss = 0.46241215908009076
# Epoch 50/70 LR: [0.03]
# Validation accuracy on group 5/10: 0.78
# Best model updated
#
# traing_loss = 0.407938812090003
# Epoch 51/70 LR: [0.03]
# Validation accuracy on group 5/10: 0.79
# Best model updated
#
# traing_loss = 0.3957970395036366
# Epoch 52/70 LR: [0.03]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.382460887665334
# Epoch 53/70 LR: [0.03]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.38353908774645434
# Epoch 54/70 LR: [0.03]
# Validation accuracy on group 5/10: 0.77
#
# traing_loss = 0.3728629039681476
# Epoch 55/70 LR: [0.03]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.37227592649667157
# Epoch 56/70 LR: [0.03]
# Validation accuracy on group 5/10: 0.80
# Best model updated
#
# traing_loss = 0.37073537901691767
# Epoch 57/70 LR: [0.03]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.3635282542394555
# Epoch 58/70 LR: [0.03]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.36413954133572785
# Epoch 59/70 LR: [0.03]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.36125112098196277
# Epoch 60/70 LR: [0.03]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.3599999521089637
# Epoch 61/70 LR: [0.03]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.35444147755270416
# Epoch 62/70 LR: [0.03]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.35779876618281653
# Epoch 63/70 LR: [0.03]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.35331067378106323
# Epoch 64/70 LR: [0.003]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.35313208142052527
# Epoch 65/70 LR: [0.003]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.3512505979641624
# Epoch 66/70 LR: [0.003]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.34890285846979724
# Epoch 67/70 LR: [0.003]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.35076093220192456
# Epoch 68/70 LR: [0.003]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.3497169017791748
# Epoch 69/70 LR: [0.003]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.3492380808229032
# Epoch 70/70 LR: [0.003]
# Validation accuracy on group 5/10: 0.80
#
# Group 5 Finished!
# Best accuracy found at epoch 56: 0.80
# Target number of exemplars: 40
# Randomly extracting exemplars from class 0 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 40 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.41
#
# =============================================
#
# Length of exemplars set: 2000
# traing_loss = 2.597179221070331
# Epoch 1/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.61
# Best model updated
#
# traing_loss = 1.6254010070925173
# Epoch 2/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.69
# Best model updated
#
# traing_loss = 1.4426767074543496
# Epoch 3/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.65
#
# traing_loss = 1.3294981873553733
# Epoch 4/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.72
# Best model updated
#
# traing_loss = 1.2612635596938755
# Epoch 5/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.73
# Best model updated
#
# traing_loss = 1.1923200760198676
# Epoch 6/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.72
#
# traing_loss = 1.1413402013156726
# Epoch 7/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.72
#
# traing_loss = 1.0870532419370569
# Epoch 8/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.69
#
# traing_loss = 1.0243287138316943
# Epoch 9/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.71
#
# traing_loss = 1.0228751120360002
# Epoch 10/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.71
#
# traing_loss = 0.9746295161869215
# Epoch 11/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.74
# Best model updated
#
# traing_loss = 0.94773603003958
# Epoch 12/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.68
#
# traing_loss = 0.9305079410905424
# Epoch 13/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.70
#
# traing_loss = 0.9026828563731649
# Epoch 14/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.71
#
# traing_loss = 0.8865015675192294
# Epoch 15/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.73
#
# traing_loss = 0.8476779422034388
# Epoch 16/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.74
# Best model updated
#
# traing_loss = 0.8174573882766392
# Epoch 17/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.70
#
# traing_loss = 0.7995042464007502
# Epoch 18/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.68
#
# traing_loss = 0.7741251782230709
# Epoch 19/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.73
#
# traing_loss = 0.7556463985339456
# Epoch 20/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.70
#
# traing_loss = 0.7742179347121197
# Epoch 21/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.7188683489094609
# Epoch 22/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.75
# Best model updated
#
# traing_loss = 0.7109069370705149
# Epoch 23/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.69
#
# traing_loss = 0.6930109366126682
# Epoch 24/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.71
#
# traing_loss = 0.6918095350265503
# Epoch 25/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.7102286271426989
# Epoch 26/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.72
#
# traing_loss = 0.6834192068680472
# Epoch 27/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.72
#
# traing_loss = 0.6055680170007374
# Epoch 28/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.72
#
# traing_loss = 0.6429091044094252
# Epoch 29/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.69
#
# traing_loss = 0.6250794555829919
# Epoch 30/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.6224390929159911
# Epoch 31/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.72
#
# traing_loss = 0.6347292694060699
# Epoch 32/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.70
#
# traing_loss = 0.597771295386812
# Epoch 33/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.70
#
# traing_loss = 0.6054249652053999
# Epoch 34/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.71
#
# traing_loss = 0.5711405426263809
# Epoch 35/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.72
#
# traing_loss = 0.5805929432744565
# Epoch 36/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.5783834101065345
# Epoch 37/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.5741460349248804
# Epoch 38/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.71
#
# traing_loss = 0.5905692331168962
# Epoch 39/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.69
#
# traing_loss = 0.5391615428354429
# Epoch 40/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.75
# Best model updated
#
# traing_loss = 0.5384321860645128
# Epoch 41/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.69
#
# traing_loss = 0.5445250292187152
# Epoch 42/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.5424191323311432
# Epoch 43/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.70
#
# traing_loss = 0.5315296118674071
# Epoch 44/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.71
#
# traing_loss = 0.508561565824177
# Epoch 45/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.71
#
# traing_loss = 0.49439413456813147
# Epoch 46/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.72
#
# traing_loss = 0.5203173892653506
# Epoch 47/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.71
#
# traing_loss = 0.5096099927373554
# Epoch 48/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.76
# Best model updated
#
# traing_loss = 0.49292913856713666
# Epoch 49/70 LR: [0.3]
# Validation accuracy on group 6/10: 0.74
#
# traing_loss = 0.4344029750512994
# Epoch 50/70 LR: [0.03]
# Validation accuracy on group 6/10: 0.78
# Best model updated
#
# traing_loss = 0.38799330721730774
# Epoch 51/70 LR: [0.03]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.3759174544526183
# Epoch 52/70 LR: [0.03]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.3598041787095692
# Epoch 53/70 LR: [0.03]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.3624106509530026
# Epoch 54/70 LR: [0.03]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.35253369030745135
# Epoch 55/70 LR: [0.03]
# Validation accuracy on group 6/10: 0.79
# Best model updated
#
# traing_loss = 0.3508354146843371
# Epoch 56/70 LR: [0.03]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.34757406620875647
# Epoch 57/70 LR: [0.03]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.3475077307742575
# Epoch 58/70 LR: [0.03]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.3456729715285094
# Epoch 59/70 LR: [0.03]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.3357650054537732
# Epoch 60/70 LR: [0.03]
# Validation accuracy on group 6/10: 0.79
# Best model updated
#
# traing_loss = 0.3379849454630976
# Epoch 61/70 LR: [0.03]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.33478967456713965
# Epoch 62/70 LR: [0.03]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.3370201561761939
# Epoch 63/70 LR: [0.03]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.33634375035762787
# Epoch 64/70 LR: [0.003]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.3317989719950635
# Epoch 65/70 LR: [0.003]
# Validation accuracy on group 6/10: 0.79
#
# traing_loss = 0.33323874583710794
# Epoch 66/70 LR: [0.003]
# Validation accuracy on group 6/10: 0.79
#
# traing_loss = 0.3358631947118303
# Epoch 67/70 LR: [0.003]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.33265705147515173
# ...
# Best model updated
#
# traing_loss = 1.2579850191655366
# Epoch 3/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.80
# Best model updated
#
# traing_loss = 1.157785459705021
# Epoch 4/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 1.1030019094114718
# Epoch 5/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.79
#
# traing_loss = 1.050889481668887
# Epoch 6/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.994474637767543
# Epoch 7/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.9347334607787754
# Epoch 8/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.9137945706429689
# Epoch 9/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.79
#
# traing_loss = 0.900570352440295
# Epoch 10/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.79
#
# traing_loss = 0.8590760386508444
# Epoch 11/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.8720650232356527
# Epoch 12/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.8418361233628314
# Epoch 13/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.8235673632310785
# Epoch 14/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.80
#
# traing_loss = 0.7953381784584211
# Epoch 15/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.81
# Best model updated
#
# traing_loss = 0.7753900535728621
# Epoch 16/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.7643576419871786
# Epoch 17/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.80
#
# traing_loss = 0.72062839243723
# Epoch 18/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.79
#
# traing_loss = 0.7323197100473486
# Epoch 19/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.7381632911122363
# Epoch 20/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.7255471763403519
# Epoch 21/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.6924194421457208
# Epoch 22/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.80
#
# traing_loss = 0.6708172171012216
# Epoch 23/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.6838837602864141
# Epoch 24/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.79
#
# traing_loss = 0.6797552024540694
# Epoch 25/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.720297669586928
# Epoch 26/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.7018750245156495
# Epoch 27/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.6474281938179679
# Epoch 28/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.80
#
# traing_loss = 0.616276349062505
# Epoch 29/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.6306342981431795
# Epoch 30/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.79
#
# traing_loss = 0.6051024703875832
# Epoch 31/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.80
#
# traing_loss = 0.6041349950044052
# Epoch 32/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.5905742036259692
# Epoch 33/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.80
#
# traing_loss = 0.5841483583916789
# Epoch 34/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.81
# Best model updated
#
# traing_loss = 0.5782327658456304
# Epoch 35/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.5735588851182357
# Epoch 36/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.81
# Best model updated
#
# traing_loss = 0.5963564048642698
# Epoch 37/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.6018165077852167
# Epoch 38/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.5995346884364667
# Epoch 39/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.5825127745452134
# Epoch 40/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.596794412187908
# Epoch 41/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.80
#
# traing_loss = 0.5634903888339582
# Epoch 42/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.5623513946066732
# Epoch 43/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.5827036830394164
# Epoch 44/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.5670559788527696
# Epoch 45/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.81
#
# traing_loss = 0.5294192375048347
# Epoch 46/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.80
#
# traing_loss = 0.5461862365836683
# Epoch 47/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.79
#
# traing_loss = 0.5400889302077501
# Epoch 48/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.79
#
# traing_loss = 0.539085869555888
# Epoch 49/70 LR: [0.3]
# Validation accuracy on group 9/10: 0.79
#
# traing_loss = 0.4968518867440846
# Epoch 50/70 LR: [0.03]
# Validation accuracy on group 9/10: 0.82
# Best model updated
#
# traing_loss = 0.4494280912305998
# Epoch 51/70 LR: [0.03]
# Validation accuracy on group 9/10: 0.83
# Best model updated
#
# traing_loss = 0.44217436209968897
# Epoch 52/70 LR: [0.03]
# Validation accuracy on group 9/10: 0.83
# Best model updated
#
# traing_loss = 0.4338969147723654
# Epoch 53/70 LR: [0.03]
# Validation accuracy on group 9/10: 0.83
# Best model updated
#
# traing_loss = 0.4287214505931605
# Epoch 54/70 LR: [0.03]
# Validation accuracy on group 9/10: 0.83
#
# traing_loss = 0.42571003605490143
# Epoch 55/70 LR: [0.03]
# Validation accuracy on group 9/10: 0.83
#
# traing_loss = 0.4196503855611967
# Epoch 56/70 LR: [0.03]
# Validation accuracy on group 9/10: 0.84
# Best model updated
#
# traing_loss = 0.41478055909923883
# Epoch 57/70 LR: [0.03]
# Validation accuracy on group 9/10: 0.81
#
# traing_loss = 0.4154911831669185
# Epoch 58/70 LR: [0.03]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.41265040247336676
# Epoch 59/70 LR: [0.03]
# Validation accuracy on group 9/10: 0.84
#
# traing_loss = 0.41185773196427716
# Epoch 60/70 LR: [0.03]
# Validation accuracy on group 9/10: 0.83
#
# traing_loss = 0.40532304281773773
# Epoch 61/70 LR: [0.03]
# Validation accuracy on group 9/10: 0.84
#
# traing_loss = 0.40992037433645
# Epoch 62/70 LR: [0.03]
# Validation accuracy on group 9/10: 0.83
#
# traing_loss = 0.40315893098064093
# Epoch 63/70 LR: [0.03]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.405239251644715
# Epoch 64/70 LR: [0.003]
# Validation accuracy on group 9/10: 0.84
#
# traing_loss = 0.3978757521380549
# Epoch 65/70 LR: [0.003]
# Validation accuracy on group 9/10: 0.83
#
# traing_loss = 0.40453741343125055
# Epoch 66/70 LR: [0.003]
# Validation accuracy on group 9/10: 0.83
#
# traing_loss = 0.4021388862444007
# Epoch 67/70 LR: [0.003]
# Validation accuracy on group 9/10: 0.82
#
# traing_loss = 0.4034332160068595
# Epoch 68/70 LR: [0.003]
# Validation accuracy on group 9/10: 0.83
#
# traing_loss = 0.4062070185723512
# Epoch 69/70 LR: [0.003]
# Validation accuracy on group 9/10: 0.84
#
# traing_loss = 0.398126315811406
# Epoch 70/70 LR: [0.003]
# Validation accuracy on group 9/10: 0.83
#
# Group 9 Finished!
# Best accuracy found at epoch 56: 0.84
# Target number of exemplars: 22
# Randomly extracting exemplars from class 0 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 22 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.32
#
# =============================================
#
# Length of exemplars set: 1980
# traing_loss = 2.6034359076748723
# Epoch 1/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.70
# Best model updated
#
# traing_loss = 1.4020158207934836
# Epoch 2/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.75
# Best model updated
#
# traing_loss = 1.2171034372371177
# Epoch 3/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 1.1273389730764471
# Epoch 4/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.77
# Best model updated
#
# traing_loss = 1.0322221336157427
# Epoch 5/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.9760457147722659
# Epoch 6/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.79
# Best model updated
#
# traing_loss = 0.9619761523993119
# Epoch 7/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.9225013696629069
# Epoch 8/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.8979202470053798
# Epoch 9/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.8770037423009458
# Epoch 10/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.844167084797569
# Epoch 11/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.8170998537022135
# Epoch 12/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.7837454650713049
# Epoch 13/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.7723512286725251
# Epoch 14/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.7564939286397852
# Epoch 15/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.7448977154234181
# Epoch 16/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.7290255621723507
# Epoch 17/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.7313079872856969
# Epoch 18/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.7491873321325883
# Epoch 19/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.714925616979599
# Epoch 20/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.708875192248303
# Epoch 21/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.7178025660307511
# Epoch 22/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.692110714705094
# Epoch 23/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.6841277441252833
# Epoch 24/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.6303377851195957
# Epoch 25/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.80
# Best model updated
#
# traing_loss = 0.6329275583443434
# Epoch 26/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.73
#
# traing_loss = 0.6550257296665855
# Epoch 27/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.6453795899515566
# Epoch 28/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.6795937380065089
# Epoch 29/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.6609673564848693
# Epoch 30/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.6372696718443995
# Epoch 31/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.6316749246224113
# Epoch 32/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.6368648798569388
# Epoch 33/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.5921250348505767
# Epoch 34/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.5942456877749899
# Epoch 35/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.5888980076364849
# Epoch 36/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.5782428409742273
# Epoch 37/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.5909720795310062
# Epoch 38/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.5784530853447707
# Epoch 39/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.81
# Best model updated
#
# traing_loss = 0.5762835080208986
# Epoch 40/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.5691720564728198
# Epoch 41/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.5540510668702747
# Epoch 42/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.5652659062458121
# Epoch 43/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.5412884911765223
# Epoch 44/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.5462739610153696
# Epoch 45/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.5565103648797326
# Epoch 46/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.5657337891018909
# Epoch 47/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.5436366193968317
# Epoch 48/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.551388139957967
# Epoch 49/70 LR: [0.3]
# Validation accuracy on group 10/10: 0.81
# Best model updated
#
# traing_loss = 0.5076784089855526
# Epoch 50/70 LR: [0.03]
# Validation accuracy on group 10/10: 0.82
# Best model updated
#
# traing_loss = 0.46324749614881433
# Epoch 51/70 LR: [0.03]
# Validation accuracy on group 10/10: 0.82
# Best model updated
#
# traing_loss = 0.45393842005211377
# Epoch 52/70 LR: [0.03]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.4421795457601547
# Epoch 53/70 LR: [0.03]
# Validation accuracy on group 10/10: 0.81
#
# traing_loss = 0.4406247650799544
# Epoch 54/70 LR: [0.03]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.43332461559254193
# Epoch 55/70 LR: [0.03]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.43049675679725147
# Epoch 56/70 LR: [0.03]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.4288830232361089
# Epoch 57/70 LR: [0.03]
# Validation accuracy on group 10/10: 0.83
# Best model updated
#
# traing_loss = 0.42049961116002954
# Epoch 58/70 LR: [0.03]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.42136492936507514
# Epoch 59/70 LR: [0.03]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.4187656997338585
# Epoch 60/70 LR: [0.03]
# Validation accuracy on group 10/10: 0.83
#
# traing_loss = 0.41915727503921674
# Epoch 61/70 LR: [0.03]
# Validation accuracy on group 10/10: 0.83
# Best model updated
#
# traing_loss = 0.41790140452592267
# Epoch 62/70 LR: [0.03]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.4150738359793373
# Epoch 63/70 LR: [0.03]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.41246891540029773
# Epoch 64/70 LR: [0.003]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.4114735716063043
# Epoch 65/70 LR: [0.003]
# Validation accuracy on group 10/10: 0.83
#
# traing_loss = 0.4127006550198016
# Epoch 66/70 LR: [0.003]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.41560983398686285
# Epoch 67/70 LR: [0.003]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.41204806838346564
# Epoch 68/70 LR: [0.003]
# Validation accuracy on group 10/10: 0.83
#
# traing_loss = 0.40993110576401587
# Epoch 69/70 LR: [0.003]
# Validation accuracy on group 10/10: 0.82
#
# traing_loss = 0.41362776186155237
# Epoch 70/70 LR: [0.003]
# Validation accuracy on group 10/10: 0.83
#
# Group 10 Finished!
# Best accuracy found at epoch 61: 0.83
# Target number of exemplars: 20
# Randomly extracting exemplars from class 0 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 20 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.30
#
# =============================================
#
# #################################

# %% [markdown]
# ### Store logs in more usable dtype

# %%
train_loss = [[logs[run_i]['group_train_loss'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
train_accuracy = [[logs[run_i]['group_train_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
val_loss = [[logs[run_i]['val_losses'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
val_accuracy = [[logs[run_i]['val_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
test_accuracy = [[logs[run_i]['test_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
predictions = [logs[run_i]['predictions'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]
true_labels = [logs[run_i]['true_labels'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]

# %% [markdown]
# ### Save the model

# %% [markdown]
# #### Saving logs in JSON files

# %%
import json

with open('states/iCaRL_ablationCE+L2_train_loss_seed42_different_lr_gamma.json', 'w') as f:
  json.dump(train_loss, f)
f.close
with open('states/iCaRL_ablationCE+L2_train_accuracy_seed42_different_lr_gamma.json', 'w') as f:
  json.dump(train_accuracy, f)
f.close
with open('states/iCaRL_ablationCE+L2_val_loss_seed42_different_lr_gamma.json', 'w') as f:
  json.dump(val_loss, f)
f.close  
with open('states/iCaRL_ablationCE+L2_val_accuracy_seed42_different_lr_gamma.json', 'w') as f:
  json.dump(val_accuracy, f)
f.close
with open('states/iCaRL_ablationCE+L2_test_accuracy_seed42_different_lr_gamma.json', 'w') as f:
  json.dump(test_accuracy, f)
f.close
with open('states/iCaRL_ablationCE+L2_predictions_seed42_different_lr_gamma.json', 'w') as f:
  json.dump(predictions, f)
f.close
with open('states/iCaRL_ablationCE+L2_true_labels_seed42_different_lr_gamma.json', 'w') as f:
  json.dump(true_labels, f)
f.close
# Out:
# <function TextIOWrapper.close>

# %% [markdown]
# #### Saving best resnet on 100 classes for each seed

# %%
for i in range(len(RANDOM_SEED)):
  torch.save(best_net_tot_classes[i].state_dict(), "states/iCaRL_ablationCE+L2_different_lr_gamma_bestnet_seed[{}]".format(RANDOM_SEED[i]))

# %%
from google.colab import files
files.download('states/iCaRL_ablationCE+L2_train_loss_seed42_different_lr_gamma.json')
files.download('states/iCaRL_ablationCE+L2_train_accuracy_seed42_different_lr_gamma.json')
files.download('states/iCaRL_ablationCE+L2_val_loss_seed42_different_lr_gamma.json')
files.download('states/iCaRL_ablationCE+L2_val_accuracy_seed42_different_lr_gamma.json')
files.download('states/iCaRL_ablationCE+L2_test_accuracy_seed42_different_lr_gamma.json')
files.download('states/iCaRL_ablationCE+L2_predictions_seed42_different_lr_gamma.json')
files.download('states/iCaRL_ablationCE+L2_true_labels_seed42_different_lr_gamma.json')
for i in range(len(RANDOM_SEED)):
  files.download('states/iCaRL_ablationCE+L2_different_lr_gamma_bestnet_seed[{}]'.format(RANDOM_SEED[i]))

# %% [markdown]
# ### Print some graphs

# %%
from data.utils_plot import plot_train_val, plot_test_accuracies, plot_confusion_matrix

# %%
train_loss = np.array(train_loss)
train_accuracy = np.array(train_accuracy)
val_loss = np.array(val_loss)
val_accuracy = np.array(val_accuracy)
test_accuracy = np.array(test_accuracy)

train_loss_stats = np.array([train_loss.mean(0), train_loss.std(0)]).transpose()
train_accuracy_stats = np.array([train_accuracy.mean(0), train_accuracy.std(0)]).transpose()
val_loss_stats = np.array([val_loss.mean(0), val_loss.std(0)]).transpose()
val_accuracy_stats = np.array([val_accuracy.mean(0), val_accuracy.std(0)]).transpose()
test_accuracy_stats = np.array([test_accuracy.mean(0), test_accuracy.std(0)]).transpose()

# %% [markdown]
# #### Train validation loss

# %%
plot_train_val(train_loss_stats, val_loss_stats, loss = True)

# %% [markdown]
# #### Train validation accuracy

# %%
plot_train_val(train_accuracy_stats, val_accuracy_stats, loss = False)

# %% [markdown]
# #### Test accuracy

# %%
plot_test_accuracies(test_accuracy_stats)

# %% [markdown]
# #### Confusion Matrix

# %%
for run in range(len(RANDOM_SEED)):
  targets = np.array(true_labels[run])
  preds = np.array(predictions[run])

  plot_confusion_matrix(targets, preds, RANDOM_SEED[run], 'iCaRL')
