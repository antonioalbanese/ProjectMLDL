# %% [markdown]
# <a href="https://colab.research.google.com/github/cosminnedescu/ProjectMLDL/blob/main/baselines/iCaRL-v1_3_0-ablation-CE_L2_seed10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Avoid K80
# !nvidia-smi
# Out:
# Thu Jul  1 13:51:10 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import random

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
from torch.autograd import Variable

import torchvision
from torchvision import transforms, datasets, models
from torch.utils.data import Subset, DataLoader

from PIL import Image

import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
from copy import copy
from copy import deepcopy

# %% [markdown]
# #### Cloning the Git repository

# %%
# !rm -rf ProjectMLDL
if not os.path.isdir('/content/ProjectMLDL'):
  # !git clone https://github.com/cosminnedescu/ProjectMLDL.git
  # %cd /content/ProjectMLDL
  # !rm -rf LICENSE README.md
# Out:
# Cloning into 'ProjectMLDL'...
# remote: Enumerating objects: 1507, done.
# remote: Counting objects: 100% (414/414), done.
# remote: Compressing objects: 100% (337/337), done.
# remote: Total 1507 (delta 255), reused 73 (delta 73), pack-reused 1093
# Receiving objects: 100% (1507/1507), 61.41 MiB | 22.37 MiB/s, done.
# Resolving deltas: 100% (780/780), done.
# /content/ProjectMLDL

# %%
from data.cifar100 import CIFAR100
from model.resnet32 import resnet32
import data.utils
from model.icarl_ablation import iCaRL

# %%
# True mean and std of Cifar100 dataset (src="https://gist.github.com/weiaicunzai/e623931921efefd4c331622c344d8151")
mean = [0.5071, 0.4867, 0.4408]
std = [0.2675, 0.2565, 0.2761]

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])
test_transform = transforms.Compose(
    [transforms.ToTensor(), 
     transforms.Normalize(mean, std),
     ])

# %% [markdown]
# ## Incremental Classifier and Representation Learning

# %% [markdown]
# ### Defining hyperparameters according to iCarl paper

# %%
# Settings
DEVICE = 'cuda'
NUM_CLASSES = 100         # Total number of classes
VAL_SIZE = 0.2            # Proportion of validation set with respect to training set (between 0 and 1)

# Training
BATCH_SIZE = 128          # Batch size
LR = 0.1                    # Initial learning rate
                       
MOMENTUM = 0.9            # Momentum for stochastic gradient descent (SGD)
WEIGHT_DECAY = 1e-5       # Weight decay from iCaRL

RANDOM_SEED = [10]  # Random seeds defining the runs of every method
                          # Note: this should be at least 3 to have a fair benchmark

NUM_EPOCHS = 70          # Total number of training epochs
MILESTONES = [49, 63]     # Step down policy from iCaRL (MultiStepLR)
                          # Decrease the learning rate by gamma at each milestone
GAMMA = 1 #0.2               # Gamma factor from iCaRL (1/5)

HERDING = False           # True to perform prioritized selection, False to perform random selection
CLASSIFY = True           # True to use mean-of-exemplar classifier, False to use network's output directly for classification

# %%
def do_group_classes(run):

  train_subset = [[] for i in range(10)]
  train_dataloader = [[] for i in range(10)]
  val_dataloader = [[] for i in range(10)]
  test_dataloader = [[] for i in range(10)]

  for i in range(10):
    train_data = CIFAR100("dataset", 
                          train=True, 
                          transform=train_transform, 
                          download=(run+i==0),
                          random_state=RANDOM_SEED[run])
    test_data = CIFAR100("dataset", 
                         train=False, 
                         transform=test_transform, 
                         download=False,
                         random_state=RANDOM_SEED[run])
    
    train_data.set_index_map(train_data.splits[i])
    test_data.set_index_map([test_data.splits[j] for j in range(0, i+1)])
    
    train_indices, val_indices = train_data.train_val_split(VAL_SIZE, RANDOM_SEED[run])
    
    train_subset[i] = copy(Subset(train_data, train_indices))
    val_subset = Subset(train_data, val_indices)

    tmp_dl = DataLoader(val_subset,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    val_dataloader[i] = copy(tmp_dl)

    tmp_dl = DataLoader(test_data,
                       batch_size=BATCH_SIZE,
                       shuffle=True, 
                       num_workers=4,
                       drop_last=True)
    test_dataloader[i] = copy(tmp_dl)

  return train_dataloader, val_dataloader, test_dataloader, train_subset

# %% [markdown]
# ### Going on with the model
# This is the main iCaRL step.
#
# This step is run 3 times with different `RANDOM_SEED`.
# Here the model is instantiated, trained and tested.
#
# Results and some statistics are then stored in the variable `logs`.

# %%
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
logs = [[] for i in range(len(RANDOM_SEED))]
best_net_tot_classes = [None for i in range(len(RANDOM_SEED))]

for run in range(len(RANDOM_SEED)):
  print("#################################")
  print(f"Radom seed: {RANDOM_SEED[run]}")
  print("")

  # get data_subsets separated in incremental groups of 10 classes
  train_dl, val_dl, test_dl, train_set = do_group_classes(run)

  #create the resnet
  net = resnet32()
  
  trainer = iCaRL(DEVICE,
                  net,
                  LR,
                  MOMENTUM,
                  WEIGHT_DECAY,
                  MILESTONES,
                  GAMMA,
                  train_dl,
                  val_dl,
                  test_dl,
                  BATCH_SIZE,
                  train_set,
                  train_transform,
                  test_transform, 2)

  #train and evaluate the model
  logs[run] = trainer.train_model(NUM_EPOCHS, HERDING, CLASSIFY)

  best_net_tot_classes[run] = deepcopy(trainer.best_net)

  print("#################################")
  print("")
  print("")
# Out:
# #################################
# Radom seed: 10
#
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to dataset/cifar-100-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=169001437.0), HTML(value='')))
# Extracting dataset/cifar-100-python.tar.gz to dataset
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Length of exemplars set: 0
# traing_loss = 2.202566466023845
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.23
# Best model updated
#
# traing_loss = 1.9037814409502092
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.33
# Best model updated
#
# traing_loss = 1.7641303577730734
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.33
#
# traing_loss = 1.6575131224047752
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.43
# Best model updated
#
# traing_loss = 1.5893846442622523
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.42
#
# traing_loss = 1.5095108286026986
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.44
# Best model updated
#
# traing_loss = 1.4508724904829455
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.38
#
# traing_loss = 1.3671518410405805
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.52
# Best model updated
#
# traing_loss = 1.274762257452934
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.45
#
# traing_loss = 1.263564440511888
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.50
#
# traing_loss = 1.2006312012672424
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.51
#
# traing_loss = 1.1478703214276222
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.57
# Best model updated
#
# traing_loss = 1.068169689947559
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.51
#
# traing_loss = 1.054869488362343
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.59
# Best model updated
#
# traing_loss = 1.0452419750152095
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.57
#
# traing_loss = 0.9805553517033977
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.58
#
# traing_loss = 0.9540447285098415
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.62
# Best model updated
#
# traing_loss = 0.8796836041635082
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.45
#
# traing_loss = 0.8597840051497182
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.61
#
# traing_loss = 0.8526404846099115
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.58
#
# traing_loss = 0.8429155080549179
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.62
#
# traing_loss = 0.8075784290990522
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.55
#
# traing_loss = 0.7455089649846477
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.65
# Best model updated
#
# traing_loss = 0.7068974856407412
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.65
#
# traing_loss = 0.7465174198150635
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.68
# Best model updated
#
# traing_loss = 0.6632295827711782
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.63
#
# traing_loss = 0.6237114292960013
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.62
#
# traing_loss = 0.6103034327107091
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.66
#
# traing_loss = 0.5725307897213967
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.67
#
# traing_loss = 0.5740003230110291
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.68
# Best model updated
#
# traing_loss = 0.5262241180865995
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.69
# Best model updated
#
# traing_loss = 0.5288753201884608
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.64
#
# traing_loss = 0.5200692905533698
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.68
#
# traing_loss = 0.46959908066257355
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.62
#
# traing_loss = 0.4665819646850709
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.71
# Best model updated
#
# traing_loss = 0.4415785833712547
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.67
#
# traing_loss = 0.41823507701196977
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.65
#
# traing_loss = 0.42327010919970853
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.69
#
# traing_loss = 0.4330976605415344
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.69
#
# traing_loss = 0.41346489614056003
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.69
#
# traing_loss = 0.3940431273752643
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.65
#
# traing_loss = 0.3539627843326138
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.68
#
# traing_loss = 0.350915749226847
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.72
# Best model updated
#
# traing_loss = 0.36413997892410527
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.65
#
# traing_loss = 0.35428296269909026
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.71
#
# traing_loss = 0.2958458681260386
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.73
# Best model updated
#
# traing_loss = 0.30175231541356734
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.71
#
# traing_loss = 0.28923294476924405
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.71
#
# traing_loss = 0.2668912062241185
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.73
#
# traing_loss = 0.2788495498318826
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.68
#
# traing_loss = 0.26781454345872324
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.68
#
# traing_loss = 0.2318153102551737
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.74
# Best model updated
#
# traing_loss = 0.21834445961060062
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.71
#
# traing_loss = 0.22379789044780116
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.74
# Best model updated
#
# traing_loss = 0.22023340915479966
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.69
#
# traing_loss = 0.21624861176936858
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.69
#
# traing_loss = 0.22508224123908627
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.74
# Best model updated
#
# traing_loss = 0.19852441525267017
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.72
#
# traing_loss = 0.18142603530037787
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.67
#
# traing_loss = 0.18666503914902288
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.74
#
# traing_loss = 0.18200435561518516
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.71
#
# traing_loss = 0.17489332176985278
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.73
#
# traing_loss = 0.18310435596973665
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.71
#
# traing_loss = 0.19154782449045488
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.69
#
# traing_loss = 0.17691458473282476
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.73
#
# traing_loss = 0.15181571052920434
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.73
#
# traing_loss = 0.13669406923074875
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.74
#
# traing_loss = 0.1405641734600067
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.72
#
# traing_loss = 0.15515359016435762
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.72
#
# traing_loss = 0.1605751502417749
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 1/10: 0.75
# Best model updated
#
# Group 1 Finished!
# Best accuracy found at epoch 70: 0.75
# Target number of exemplars: 200
# Randomly extracting exemplars from class 0 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 200 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.76
#
# =============================================
#
# Length of exemplars set: 2000
# traing_loss = 2.1802785914877187
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.59
# Best model updated
#
# traing_loss = 1.5317961236704951
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.67
# Best model updated
#
# traing_loss = 1.343520234460416
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.68
# Best model updated
#
# traing_loss = 1.2430993525878242
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.72
# Best model updated
#
# traing_loss = 1.1318103010239808
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.70
#
# traing_loss = 1.0708738941213358
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.72
# Best model updated
#
# traing_loss = 1.039900287337925
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.72
# Best model updated
#
# traing_loss = 0.9735163826009502
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.70
#
# traing_loss = 0.9544102938278861
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.76
# Best model updated
#
# traing_loss = 0.9156454659026602
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.75
#
# traing_loss = 0.8826488321242125
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.75
#
# traing_loss = 0.8435562551021576
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.76
#
# traing_loss = 0.8339493792989979
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.75
#
# traing_loss = 0.8217141887416011
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.73
#
# traing_loss = 0.7963658623073412
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.75
#
# traing_loss = 0.7784853914509648
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.79
# Best model updated
#
# traing_loss = 0.7374230662117833
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.76
#
# traing_loss = 0.7551693514637325
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.80
# Best model updated
#
# traing_loss = 0.7193927324336508
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.6926532180412955
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.690751982771832
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.79
#
# traing_loss = 0.6686176268950753
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.79
#
# traing_loss = 0.693739009940106
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.80
#
# traing_loss = 0.6430235673551974
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.76
#
# traing_loss = 0.6507759340431379
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.76
#
# traing_loss = 0.648640311282614
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.72
#
# traing_loss = 0.6307238476431888
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.74
#
# traing_loss = 0.5988879223232684
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.79
#
# traing_loss = 0.6019982462343962
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.77
#
# traing_loss = 0.595332709343537
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.5880040098791537
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.75
#
# traing_loss = 0.5676426544137623
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.5592313227446183
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.79
#
# traing_loss = 0.5536087336747543
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.79
#
# traing_loss = 0.5267509053582731
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.80
# Best model updated
#
# traing_loss = 0.5698729364768319
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.5343008844748788
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.76
#
# traing_loss = 0.5318114530781041
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.80
# Best model updated
#
# traing_loss = 0.5596738133741461
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.5457894808572271
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.79
#
# traing_loss = 0.520213488003482
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.80
#
# traing_loss = 0.5103244470513385
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.5110682760891707
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.77
#
# traing_loss = 0.5062037524969681
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.79
#
# traing_loss = 0.5071371800225714
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.80
#
# traing_loss = 0.4924457021381544
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.4818593594043151
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.79
#
# traing_loss = 0.5029824291882308
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.75
#
# traing_loss = 0.4944795901360719
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.4846144201962844
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.83
# Best model updated
#
# traing_loss = 0.48238005262354144
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.4700472102217052
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.75
#
# traing_loss = 0.46395102791164233
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.81
#
# traing_loss = 0.45883385837078094
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.80
#
# traing_loss = 0.4704772033121275
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.83
# Best model updated
#
# traing_loss = 0.4795023507398108
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.79
#
# traing_loss = 0.472968230428903
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.82
#
# traing_loss = 0.4547345411518346
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.4442563031030738
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.82
#
# traing_loss = 0.4429970578007076
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.80
#
# traing_loss = 0.4430220081754353
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.84
# Best model updated
#
# traing_loss = 0.4416534142649692
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.80
#
# traing_loss = 0.4299832874018213
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.81
#
# traing_loss = 0.4244579297045003
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.82
#
# traing_loss = 0.43064946648867236
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.82
#
# traing_loss = 0.43319138625393744
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.82
#
# traing_loss = 0.42945667259071185
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.79
#
# traing_loss = 0.4404782432576884
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.4419197420711103
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.78
#
# traing_loss = 0.4366436684909074
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 2/10: 0.81
#
# Group 2 Finished!
# Best accuracy found at epoch 61: 0.84
# Target number of exemplars: 100
# Randomly extracting exemplars from class 0 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 100 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.75
#
# =============================================
#
# Length of exemplars set: 2000
# traing_loss = 2.2826387078865715
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.63
# Best model updated
#
# traing_loss = 1.5936378655226335
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
# Best model updated
#
# traing_loss = 1.4392742462780164
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.70
# Best model updated
#
# traing_loss = 1.3251602623773657
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 1.2356248860773833
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.65
#
# traing_loss = 1.1732095350389895
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.70
#
# traing_loss = 1.1347614060277524
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.74
# Best model updated
#
# traing_loss = 1.096452693576398
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 1.0249755849008975
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.72
#
# traing_loss = 0.9904823186604873
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.72
#
# traing_loss = 0.9945933430091195
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.71
#
# traing_loss = 0.9394115520560223
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.71
#
# traing_loss = 0.9077521186807881
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.71
#
# traing_loss = 0.8922621296799701
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.70
#
# traing_loss = 0.9086339719917463
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.8735774859138157
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.848777992569882
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.70
#
# traing_loss = 0.8091552166835122
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.74
# Best model updated
#
# traing_loss = 0.8109202073967975
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.71
#
# traing_loss = 0.7710700890292292
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.72
#
# traing_loss = 0.770106412794279
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.70
#
# traing_loss = 0.7558720681978308
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.73
#
# traing_loss = 0.6995780662350033
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.73
#
# traing_loss = 0.7589289766290913
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.71
#
# traing_loss = 0.7126286768394968
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.73
#
# traing_loss = 0.686611251986545
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.64
#
# traing_loss = 0.700136097876922
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.70
#
# traing_loss = 0.6563367791797804
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.6792347988356715
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.72
#
# traing_loss = 0.6623085685398268
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.6263331615406534
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.72
#
# traing_loss = 0.6079421004523402
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.70
#
# traing_loss = 0.6008973912052487
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.73
#
# traing_loss = 0.6042338668004327
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.74
#
# traing_loss = 0.6023430053306662
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.5965852763341821
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.72
#
# traing_loss = 0.5741275341614432
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.73
#
# traing_loss = 0.5635647663603658
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.71
#
# traing_loss = 0.57030790331571
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.70
#
# traing_loss = 0.584364766659944
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.71
#
# traing_loss = 0.6268295269945393
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.71
#
# traing_loss = 0.5331721357677294
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.72
#
# traing_loss = 0.5253360219623732
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.74
#
# traing_loss = 0.5604599681885346
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.72
#
# traing_loss = 0.5669304598932681
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.69
#
# traing_loss = 0.557828588978104
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.72
#
# traing_loss = 0.5383922982475032
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.74
#
# traing_loss = 0.5167372207278791
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.72
#
# traing_loss = 0.4996162283679713
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.73
#
# traing_loss = 0.5252171301323435
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.71
#
# traing_loss = 0.5083354497733323
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.75
# Best model updated
#
# traing_loss = 0.4984092511560606
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.73
#
# traing_loss = 0.49474417839361273
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.74
#
# traing_loss = 0.4829209369161855
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.74
#
# traing_loss = 0.4728558517020682
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.72
#
# traing_loss = 0.4894350793050683
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.70
#
# traing_loss = 0.472332951815232
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.68
#
# traing_loss = 0.4948216417561407
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.73
#
# traing_loss = 0.4626238942146301
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.76
# Best model updated
#
# traing_loss = 0.4545224211786104
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.72
#
# traing_loss = 0.48106704781884735
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.71
#
# traing_loss = 0.4996666914742926
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.74
#
# traing_loss = 0.4803793877363205
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.73
#
# traing_loss = 0.47013510439706885
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.76
# Best model updated
#
# traing_loss = 0.4890446682339129
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.74
#
# traing_loss = 0.45455832131530927
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.74
#
# traing_loss = 0.47892849147319794
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.66
#
# traing_loss = 0.4728275265382684
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.71
#
# traing_loss = 0.43883462379808014
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.75
#
# traing_loss = 0.416292711444523
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 3/10: 0.75
#
# Group 3 Finished!
# Best accuracy found at epoch 64: 0.76
# Target number of exemplars: 66
# Randomly extracting exemplars from class 0 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 66 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.62
#
# =============================================
#
# Length of exemplars set: 1980
# traing_loss = 2.3743274937505308
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.66
# Best model updated
#
# traing_loss = 1.5316436420316282
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.67
# Best model updated
#
# traing_loss = 1.368056727492291
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.69
# Best model updated
#
# traing_loss = 1.2458529329818229
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.70
# Best model updated
#
# traing_loss = 1.1680992582569951
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.73
# Best model updated
#
# traing_loss = 1.0754892217076344
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.71
#
# traing_loss = 1.0531819281370745
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.69
#
# traing_loss = 0.9938650714314502
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.72
#
# traing_loss = 0.9261232303536456
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.73
#
# traing_loss = 0.9162184803382211
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
# Best model updated
#
# traing_loss = 0.8768680976784747
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.75
# Best model updated
#
# traing_loss = 0.8425918921180393
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
# Best model updated
#
# traing_loss = 0.8232735900775247
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
#
# traing_loss = 0.7865440780701844
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.73
#
# traing_loss = 0.8019445590350939
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.72
#
# traing_loss = 0.752646355525307
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.72
#
# traing_loss = 0.7509393601313882
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
#
# traing_loss = 0.7348671918329985
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.73
#
# traing_loss = 0.7183394159959711
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.75
#
# traing_loss = 0.6842981421429178
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
# Best model updated
#
# traing_loss = 0.6694988530615101
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.78
# Best model updated
#
# traing_loss = 0.6461661088725795
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
#
# traing_loss = 0.6548108834287395
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
#
# traing_loss = 0.6445276218911876
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.75
#
# traing_loss = 0.6377440639164137
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.72
#
# traing_loss = 0.6318380515212598
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
#
# traing_loss = 0.6079326913408611
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.77
#
# traing_loss = 0.6044969759557558
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
#
# traing_loss = 0.5755385613959768
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.73
#
# traing_loss = 0.5611142567966295
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
#
# traing_loss = 0.5484025024849436
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.78
# Best model updated
#
# traing_loss = 0.5707574104485305
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
#
# traing_loss = 0.5327030420303345
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.75
#
# traing_loss = 0.5526336327843044
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
#
# traing_loss = 0.5245699396599894
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
#
# traing_loss = 0.5411160134750864
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.75
#
# traing_loss = 0.528977038419765
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.75
#
# traing_loss = 0.5212322181981542
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.77
#
# traing_loss = 0.5195916314487872
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
#
# traing_loss = 0.5488129873638568
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.70
#
# traing_loss = 0.5346217926429666
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.77
#
# traing_loss = 0.49610453325769177
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
#
# traing_loss = 0.5002616443063902
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.75
#
# traing_loss = 0.4836361233306968
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
#
# traing_loss = 0.4815585056076879
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.75
#
# traing_loss = 0.47913951783076575
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
#
# traing_loss = 0.4680414672779
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.77
#
# traing_loss = 0.4763382569603298
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
#
# traing_loss = 0.4647994786500931
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
#
# traing_loss = 0.4509287295134171
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
#
# traing_loss = 0.44646669729896216
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.78
#
# traing_loss = 0.4437376636525859
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.77
#
# traing_loss = 0.4387025781299757
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.75
#
# traing_loss = 0.43973883662534796
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.79
# Best model updated
#
# traing_loss = 0.4512271012948907
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
#
# traing_loss = 0.4450278016536132
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
#
# traing_loss = 0.4401151311138402
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.78
#
# traing_loss = 0.43392248257346777
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
#
# traing_loss = 0.4433000016471614
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.74
#
# traing_loss = 0.43218831847543304
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.75
#
# traing_loss = 0.433147062426028
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.78
#
# traing_loss = 0.43048767421556555
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.75
#
# traing_loss = 0.408547751929449
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.78
#
# traing_loss = 0.4265807271003723
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
#
# traing_loss = 0.440295301053835
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.77
#
# traing_loss = 0.41810304120830866
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.79
#
# traing_loss = 0.4231645562078642
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.76
#
# traing_loss = 0.41486670335997705
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.78
#
# traing_loss = 0.403805281157079
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.78
#
# traing_loss = 0.3876503200634666
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 4/10: 0.77
#
# Group 4 Finished!
# Best accuracy found at epoch 54: 0.79
# Target number of exemplars: 50
# Randomly extracting exemplars from class 0 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 50 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 50 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.56
#
# =============================================
#
# Length of exemplars set: 2000
# traing_loss = 2.3905026731283767
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.77
# Best model updated
#
# traing_loss = 1.388413817986198
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
# Best model updated
#
# traing_loss = 1.216342101926389
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 1.1105678871921871
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
# Best model updated
#
# traing_loss = 1.0124563756196394
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.9576315737288931
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.82
# Best model updated
#
# traing_loss = 0.9150312361509904
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.75
#
# traing_loss = 0.8980356713999873
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.8552004643108534
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.8054201097592063
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.7935090790624204
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.7524556064087412
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.73
#
# traing_loss = 0.7280854997427567
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.7071816804616348
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.6910925961059072
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.6907856542131176
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.6671373410069424
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.6400676900925844
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.81
#
# traing_loss = 0.6445065037063931
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.6657197864159293
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.6153514942397242
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.77
#
# traing_loss = 0.6054492916749872
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.5852147489786148
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.5931093459543975
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.5816340278024259
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.5671735334655513
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.83
# Best model updated
#
# traing_loss = 0.531480663496515
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.81
#
# traing_loss = 0.5246584344169368
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.52200420719126
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.81
#
# traing_loss = 0.5237284762703854
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.77
#
# traing_loss = 0.5109623145797978
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.78
#
# traing_loss = 0.5101730434790902
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.77
#
# traing_loss = 0.5252313879520997
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.81
#
# traing_loss = 0.5043486317862635
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.82
#
# traing_loss = 0.5038535892963409
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.82
#
# traing_loss = 0.4840495404989823
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.82
#
# traing_loss = 0.47302950011647266
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.83
#
# traing_loss = 0.46365190070608386
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.4590060399926227
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.48803199179794476
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.468009937716567
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.81
#
# traing_loss = 0.4548833771892216
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.83
# Best model updated
#
# traing_loss = 0.46396492227264075
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.82
#
# traing_loss = 0.4707749596108561
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.4669921637877174
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.4593639198852622
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.82
#
# traing_loss = 0.46737581815408624
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.4432657497084659
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.45531007388363715
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.76
#
# traing_loss = 0.4634071964284648
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.42309635100157367
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.423564780017604
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.41296261354633
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.81
#
# traing_loss = 0.4114346465338831
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.83
#
# traing_loss = 0.4175169578065043
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.82
#
# traing_loss = 0.39487525626369147
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.83
# Best model updated
#
# traing_loss = 0.3954132873079051
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.3953910942958749
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.3834496911453164
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.82
#
# traing_loss = 0.37944650455661444
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.82
#
# traing_loss = 0.3805165932230327
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.81
#
# traing_loss = 0.40868276552013727
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.81
#
# traing_loss = 0.44702136322208075
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.4403770760349605
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.79
#
# traing_loss = 0.42627401390801306
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.83
#
# traing_loss = 0.4183732828368311
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.81
#
# traing_loss = 0.4208588075378667
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.80
#
# traing_loss = 0.40183986593847687
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.84
# Best model updated
#
# traing_loss = 0.3917826193830241
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.84
# Best model updated
#
# traing_loss = 0.3791415594194246
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 5/10: 0.82
#
# Group 5 Finished!
# Best accuracy found at epoch 69: 0.84
# Target number of exemplars: 40
# Randomly extracting exemplars from class 0 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 40 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 40 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.49
#
# =============================================
#
# Length of exemplars set: 2000
# traing_loss = 2.4953396035277327
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.68
# Best model updated
#
# traing_loss = 1.3733093116594397
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.75
# Best model updated
#
# traing_loss = 1.1555660976016002
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
# Best model updated
#
# traing_loss = 1.073132802610812
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.9904131682022758
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.79
# Best model updated
#
# traing_loss = 0.9241889261681101
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.899429677621178
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.8634385946004287
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.79
# Best model updated
#
# traing_loss = 0.8152738135793934
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.80
# Best model updated
#
# traing_loss = 0.7877641099950542
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.83
# Best model updated
#
# traing_loss = 0.7620078234568887
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.76
#
# traing_loss = 0.7624587002007858
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.6941431696000306
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.80
#
# traing_loss = 0.6840911028177842
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.81
#
# traing_loss = 0.6955550559189009
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.80
#
# traing_loss = 0.6585064906141033
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.80
#
# traing_loss = 0.6331162737763446
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.83
#
# traing_loss = 0.6295235312503317
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.6238904342703198
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.78
#
# traing_loss = 0.6052127059387125
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.81
#
# traing_loss = 0.5826568655345751
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.81
#
# traing_loss = 0.5945707430010256
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.79
#
# traing_loss = 0.5996265398419421
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.83
#
# traing_loss = 0.5604753351729849
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.81
#
# traing_loss = 0.5378477074529814
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.81
#
# traing_loss = 0.5419617560894593
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.79
#
# traing_loss = 0.529824563342592
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.81
#
# traing_loss = 0.5333374939534975
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.83
#
# traing_loss = 0.5406485329503599
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.81
#
# traing_loss = 0.5007658134336057
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.84
# Best model updated
#
# traing_loss = 0.47032459663308185
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.82
#
# traing_loss = 0.4675665057223776
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.83
#
# traing_loss = 0.48162296673525934
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.80
#
# traing_loss = 0.5033363330623378
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.81
#
# traing_loss = 0.4854111943555915
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.81
#
# traing_loss = 0.4697345909865006
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.79
#
# traing_loss = 0.46036106736763666
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.81
#
# traing_loss = 0.4592661248601001
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.79
#
# traing_loss = 0.47226086453251215
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.77
#
# traing_loss = 0.45452505609263544
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.82
#
# traing_loss = 0.44276750865189923
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.82
#
# traing_loss = 0.4336426556110382
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.81
#
# traing_loss = 0.41634776151698566
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.81
#
# traing_loss = 0.42586746487928473
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.81
#
# traing_loss = 0.41323055715664575
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.83
#
# traing_loss = 0.4166457782620969
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.81
#
# traing_loss = 0.3914953159249347
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.83
#
# traing_loss = 0.39045183749302576
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.81
#
# traing_loss = 0.4102705166391704
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.81
#
# traing_loss = 0.40558785847995593
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.82
#
# traing_loss = 0.39594361250815185
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.82
#
# traing_loss = 0.3915220285239427
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.81
#
# traing_loss = 0.42673885303994885
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.79
#
# traing_loss = 0.41987575396247534
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.82
#
# traing_loss = 0.41314573197261145
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.82
#
# traing_loss = 0.4026979227428851
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.83
#
# traing_loss = 0.3914152740136437
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.82
#
# traing_loss = 0.38641496715338336
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.82
#
# traing_loss = 0.3937242134757664
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.84
# Best model updated
#
# traing_loss = 0.40951042071632715
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.83
#
# traing_loss = 0.4001403101112532
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.83
#
# traing_loss = 0.3934380185344945
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.84
#
# traing_loss = 0.37577685260254406
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.84
#
# traing_loss = 0.3767612731975058
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.81
#
# traing_loss = 0.37282500772372534
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.85
# Best model updated
#
# traing_loss = 0.3573166222675987
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.84
#
# traing_loss = 0.3406855943410293
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.82
#
# traing_loss = 0.3415273447399554
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.82
#
# traing_loss = 0.33977441230545874
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 6/10: 0.84
#
# traing_loss = 0.35418143544508063
# Epoch 70/70 LR: [0.1]
# ...
# Best model updated
#
# traing_loss = 1.277925071508988
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
# Best model updated
#
# traing_loss = 1.1928553762643233
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 1.0736119773076929
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
# Best model updated
#
# traing_loss = 1.0603408126727394
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.72
#
# traing_loss = 0.9877204687699027
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.9308171790579091
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.8691739038280819
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.8484904986360798
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.8478257267371468
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
# Best model updated
#
# traing_loss = 0.8148513475190038
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.7910915522471719
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.7539330358090608
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.7572247658086859
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.72
#
# traing_loss = 0.7497448584307795
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
# Best model updated
#
# traing_loss = 0.7146768168262814
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.7175452968348628
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.6856041485848634
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.6794329713220182
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.72
#
# traing_loss = 0.6585014799366826
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
# Best model updated
#
# traing_loss = 0.6551689363044241
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.72
#
# traing_loss = 0.6534276151138804
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
# Best model updated
#
# traing_loss = 0.6182789744242377
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.6310508406680563
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.6456778483546298
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.6337873158247574
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.6014138460159302
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.6021176382251407
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.575881676181503
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.6207670906315679
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.5762147890484851
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.5894326548213544
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.5443622567083525
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.5378338079089704
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.72
#
# traing_loss = 0.5292880321326463
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.5136408922464951
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.5279123381428097
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.4946154349524042
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.5208160248787507
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.5123453690953876
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.5116212536459384
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.5398690590391988
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.501060787750327
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.4997725953226504
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.49661567159320996
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.4902179221744123
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.4741938658382582
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.4573327471380648
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.4666871707076612
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.79
# Best model updated
#
# traing_loss = 0.46768710989019147
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.79
# Best model updated
#
# traing_loss = 0.4542589667050735
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.4645108075245567
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.75
#
# traing_loss = 0.4731033424968305
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.4723483848830928
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.80
# Best model updated
#
# traing_loss = 0.4551958156668622
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.4753196051587229
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.73
#
# traing_loss = 0.49865873611491657
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.4904599261024724
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.473427410358968
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.45520608191904816
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.4494781377522842
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.4414962167325227
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.74
#
# traing_loss = 0.456457261805949
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.76
#
# traing_loss = 0.4159004053343897
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.80
#
# traing_loss = 0.4172758745110553
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.80
#
# traing_loss = 0.40651495430780493
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.79
#
# traing_loss = 0.4205090908900551
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# traing_loss = 0.41316658971102344
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.78
#
# traing_loss = 0.42076842551646026
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 9/10: 0.77
#
# Group 9 Finished!
# Best accuracy found at epoch 55: 0.80
# Target number of exemplars: 22
# Randomly extracting exemplars from class 0 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 22 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 22 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.34
#
# =============================================
#
# Length of exemplars set: 1980
# traing_loss = 2.7578277950701504
# Epoch 1/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.67
# Best model updated
#
# traing_loss = 1.490280832933343
# Epoch 2/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.67
# Best model updated
#
# traing_loss = 1.2555082906847415
# Epoch 3/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.72
# Best model updated
#
# traing_loss = 1.1189520462699558
# Epoch 4/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.71
#
# traing_loss = 1.0550963321457738
# Epoch 5/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.71
#
# traing_loss = 0.9995993246202883
# Epoch 6/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
# Best model updated
#
# traing_loss = 0.9667443801527438
# Epoch 7/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.72
#
# traing_loss = 0.9066992052223372
# Epoch 8/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.8748847129552261
# Epoch 9/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.74
#
# traing_loss = 0.8397840144841567
# Epoch 10/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
# Best model updated
#
# traing_loss = 0.7987877078678297
# Epoch 11/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.74
#
# traing_loss = 0.7908483938030575
# Epoch 12/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
# Best model updated
#
# traing_loss = 0.7642099390859189
# Epoch 13/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.7341788553673289
# Epoch 14/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.7173254256663115
# Epoch 15/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
# Best model updated
#
# traing_loss = 0.7170855662097102
# Epoch 16/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.74
#
# traing_loss = 0.7221438716287198
# Epoch 17/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.74
#
# traing_loss = 0.6778731955134351
# Epoch 18/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.6694428791170535
# Epoch 19/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.6561506798733836
# Epoch 20/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.6484491993551669
# Epoch 21/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.74
#
# traing_loss = 0.6477975314078124
# Epoch 22/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.6485155121139858
# Epoch 23/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.6402010723300602
# Epoch 24/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
# Best model updated
#
# traing_loss = 0.6425326019525528
# Epoch 25/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.6342859235794648
# Epoch 26/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.6072503133960392
# Epoch 27/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
# Best model updated
#
# traing_loss = 0.5700514711763548
# Epoch 28/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.5706499594709148
# Epoch 29/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.5592656802871953
# Epoch 30/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
# Best model updated
#
# traing_loss = 0.5756780362647512
# Epoch 31/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.560086142109788
# Epoch 32/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.5514050611983174
# Epoch 33/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.5556864155375439
# Epoch 34/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.5419394911631293
# Epoch 35/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.5490947974764783
# Epoch 36/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.5361856701581375
# Epoch 37/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.5156929318023764
# Epoch 38/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
# Best model updated
#
# traing_loss = 0.5075851108716882
# Epoch 39/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
# Best model updated
#
# traing_loss = 0.49195988865002344
# Epoch 40/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.5080715495607128
# Epoch 41/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.5095261717620103
# Epoch 42/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.4970749707325645
# Epoch 43/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.4700221373983052
# Epoch 44/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.4795758542807206
# Epoch 45/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.478078196230142
# Epoch 46/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.49268843298373016
# Epoch 47/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.48896581388038135
# Epoch 48/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.4741858768722285
# Epoch 49/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.46070695700852765
# Epoch 50/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.4817843301140744
# Epoch 51/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.4549493323201719
# Epoch 52/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.4548625900693562
# Epoch 53/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.4300188545299613
# Epoch 54/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.42708212849886523
# Epoch 55/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.4243674472622249
# Epoch 56/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.4384617021550303
# Epoch 57/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.43500857508700824
# Epoch 58/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.4312856067781863
# Epoch 59/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.42919621908146405
# Epoch 60/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.79
#
# traing_loss = 0.4162044298389684
# Epoch 61/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.4095075370176979
# Epoch 62/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.41287362705106323
# Epoch 63/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.39749123674371967
# Epoch 64/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.81
# Best model updated
#
# traing_loss = 0.4077855659567792
# Epoch 65/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.80
#
# traing_loss = 0.41196258042169653
# Epoch 66/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# traing_loss = 0.43961382948833966
# Epoch 67/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.77
#
# traing_loss = 0.452925192921058
# Epoch 68/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.75
#
# traing_loss = 0.43702364227046137
# Epoch 69/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.76
#
# traing_loss = 0.4201385430667711
# Epoch 70/70 LR: [0.1]
# Validation accuracy on group 10/10: 0.78
#
# Group 10 Finished!
# Best accuracy found at epoch 64: 0.81
# Target number of exemplars: 20
# Randomly extracting exemplars from class 0 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 20 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 20 exemplars.
# Computing mean of exemplars... done
# Testing classes seen so far, accuracy: 0.33
#
# =============================================
#
# #################################

# %% [markdown]
# ### Store logs in more usable dtype

# %%
train_loss = [[logs[run_i]['group_train_loss'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
train_accuracy = [[logs[run_i]['group_train_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
val_loss = [[logs[run_i]['val_losses'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
val_accuracy = [[logs[run_i]['val_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
test_accuracy = [[logs[run_i]['test_accuracies'][i] for i in range(10)] for run_i in range(len(RANDOM_SEED))]
predictions = [logs[run_i]['predictions'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]
true_labels = [logs[run_i]['true_labels'].cpu().data.numpy().tolist() for run_i in range(len(RANDOM_SEED))]

# %% [markdown]
# ### Save the model

# %% [markdown]
# #### Saving logs in JSON files

# %%
import json

with open('states/iCaRL_ablationCE+L2_train_loss_seed10.json', 'w') as f:
  json.dump(train_loss, f)
f.close
with open('states/iCaRL_ablationCE+L2_train_accuracy_seed10.json', 'w') as f:
  json.dump(train_accuracy, f)
f.close
with open('states/iCaRL_ablationCE+L2_val_loss_seed10.json', 'w') as f:
  json.dump(val_loss, f)
f.close  
with open('states/iCaRL_ablationCE+L2_val_accuracy_seed10.json', 'w') as f:
  json.dump(val_accuracy, f)
f.close
with open('states/iCaRL_ablationCE+L2_test_accuracy_seed10.json', 'w') as f:
  json.dump(test_accuracy, f)
f.close
with open('states/iCaRL_ablationCE+L2_predictions_seed10.json', 'w') as f:
  json.dump(predictions, f)
f.close
with open('states/iCaRL_ablationCE+L2_true_labels_seed10.json', 'w') as f:
  json.dump(true_labels, f)
f.close
# Out:
# <function TextIOWrapper.close>

# %% [markdown]
# #### Saving best resnet on 100 classes for each seed

# %%
for i in range(len(RANDOM_SEED)):
  torch.save(best_net_tot_classes[i].state_dict(), "states/iCaRL_ablationCE+L2_bestnet_seed[{}]".format(RANDOM_SEED[i]))

# %%
from google.colab import files
files.download('states/iCaRL_ablationCE+L2_train_loss_seed10.json')
files.download('states/iCaRL_ablationCE+L2_train_accuracy_seed10.json')
files.download('states/iCaRL_ablationCE+L2_val_loss_seed10.json')
files.download('states/iCaRL_ablationCE+L2_val_accuracy_seed10.json')
files.download('states/iCaRL_ablationCE+L2_test_accuracy_seed10.json')
files.download('states/iCaRL_ablationCE+L2_predictions_seed10.json')
files.download('states/iCaRL_ablationCE+L2_true_labels_seed10.json')
for i in range(len(RANDOM_SEED)):
  files.download('states/iCaRL_ablationCE+L2_bestnet_seed[{}]'.format(RANDOM_SEED[i]))

# %% [markdown]
# ### Print some graphs

# %%
from data.utils_plot import plot_train_val, plot_test_accuracies, plot_confusion_matrix

# %%
train_loss = np.array(train_loss)
train_accuracy = np.array(train_accuracy)
val_loss = np.array(val_loss)
val_accuracy = np.array(val_accuracy)
test_accuracy = np.array(test_accuracy)

train_loss_stats = np.array([train_loss.mean(0), train_loss.std(0)]).transpose()
train_accuracy_stats = np.array([train_accuracy.mean(0), train_accuracy.std(0)]).transpose()
val_loss_stats = np.array([val_loss.mean(0), val_loss.std(0)]).transpose()
val_accuracy_stats = np.array([val_accuracy.mean(0), val_accuracy.std(0)]).transpose()
test_accuracy_stats = np.array([test_accuracy.mean(0), test_accuracy.std(0)]).transpose()

# %% [markdown]
# #### Train validation loss

# %%
plot_train_val(train_loss_stats, val_loss_stats, loss = True)

# %% [markdown]
# #### Train validation accuracy

# %%
plot_train_val(train_accuracy_stats, val_accuracy_stats, loss = False)

# %% [markdown]
# #### Test accuracy

# %%
plot_test_accuracies(test_accuracy_stats)

# %% [markdown]
# #### Confusion Matrix

# %%
for run in range(len(RANDOM_SEED)):
  targets = np.array(true_labels[run])
  preds = np.array(predictions[run])

  plot_confusion_matrix(targets, preds, RANDOM_SEED[run], 'iCaRL')
